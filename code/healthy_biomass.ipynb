# %%
import matplotlib.pyplot as plt
import cobra
from cobra.io import validate_sbml_model
import importlib
import utils.Model_correction as mc
import utils.model_maj as mj
import utils.viz_utils as vu
#import cplex
import plotly.express as px
from cobra.core.model import Model
# Out:
# pyparsing import
#
# INFO: No xlwt module available, Excel spreadsheet creation disabled
# CBGLPK based on swiglpk: not all methods implimented yet! 5.0
#
# *****
# Using CPLEX
# *****
#
# doFBAMinSum not available with GLPK
#
# INFO: No xlrd module available, Excel spreadsheet reading disabled
#
#
# ***********************************************************************
# * Welcome to CBMPy (0.8.4) - PySCeS Constraint Based Modelling        *
# *                http://cbmpy.sourceforge.net                         *
# * Copyright(C) Brett G. Olivier 2014 - 2020                           *
# * Systems Biology Lab, Vrije Universiteit Amsterdam                   *
# * Amsterdam, The Netherlands                                          *
# * CBMPy is developed as part of the BeBasic MetaToolKit Project       *
# * Distributed under the GNU GPL v 3.0 licence, see                    *
# * LICENCE (supplied with this release) for details                    *
# ***********************************************************************

# %%
HepG2, errors = validate_sbml_model("../models_storage/HepG2_medium.xml")

# %%
healthy, errors = validate_sbml_model("../models_storage/iHep_updated_v011.xml")

# %% [markdown]
# ### Original biomass reaction :

# %%
print("REACTANTS: \n")
for metabolite_r in HepG2.reactions.get_by_id("biomass_components").reactants:
    print(f"ID : {metabolite_r.id} -- NAME : {metabolite_r.name}")

print("PRODUCTS: \n")
for metabolite_p in HepG2.reactions.get_by_id("biomass_components").products:
    print(f"ID : {metabolite_p.id} -- NAME : {metabolite_p.name}")
# Out:
# REACTANTS:
#
# ID : m01307c -- NAME : alanine
# ID : m01365c -- NAME : arginine
# ID : m01369c -- NAME : asparagine
# ID : m01370c -- NAME : aspartate
# ID : m01450c -- NAME : cholesterol
# ID : m01451r -- NAME : cholesterol-ester pool
# ID : m01589c -- NAME : CL pool
# ID : m01628c -- NAME : cysteine
# ID : m01721n -- NAME : DNA
# ID : m01722n -- NAME : DNA-5-methylcytosine
# ID : m01974c -- NAME : glutamate
# ID : m01975c -- NAME : glutamine
# ID : m01986c -- NAME : glycine
# ID : m02125c -- NAME : histidine
# ID : m02184c -- NAME : isoleucine
# ID : m02360c -- NAME : leucine
# ID : m02392c -- NAME : lipid droplet
# ID : m02426c -- NAME : lysine
# ID : m02471c -- NAME : methionine
# ID : m02724c -- NAME : phenylalanine
# ID : m02733c -- NAME : phosphatidate-LD-TAG pool
# ID : m02750c -- NAME : PI pool
# ID : m02770c -- NAME : proline
# ID : m02847c -- NAME : RNA
# ID : m02896c -- NAME : serine
# ID : m02908c -- NAME : SM pool
# ID : m02993c -- NAME : threonine
# ID : m03089c -- NAME : tryptophan
# ID : m03101c -- NAME : tyrosine
# ID : m03135c -- NAME : valine
# ID : m03161c -- NAME : glycogen
# PRODUCTS:
#
# ID : temp001x -- NAME : biomass
# ID : m02039x -- NAME : H+
# ID : m01285c -- NAME : ADP

# %% [markdown]
# ### Adding NTPs to the biomass reaction reactants :

# %%
for metabolite in healthy.metabolites:
    id = metabolite.id
    if "TP" in metabolite.name:
        print(metabolite.id, metabolite.name)
# Out:
# m00111c (6Z,9Z,12Z,15Z,18Z)-TPA
# m00111l (6Z,9Z,12Z,15Z,18Z)-TPA
# m00111r (6Z,9Z,12Z,15Z,18Z)-TPA
# m00111s (6Z,9Z,12Z,15Z,18Z)-TPA
# m00135c (9Z,12Z,15Z,18Z,21Z)-TPA
# m00135l (9Z,12Z,15Z,18Z,21Z)-TPA
# m00135r (9Z,12Z,15Z,18Z,21Z)-TPA
# m00135s (9Z,12Z,15Z,18Z,21Z)-TPA
# m01371c ATP
# m01371g ATP
# m01371l ATP
# m01371m ATP
# m01371n ATP
# m01371p ATP
# m01371r ATP
# m01371s ATP
# m01623c CTP
# m01623m CTP
# m01623n CTP
# m01623s CTP
# m01642c dATP
# m01642m dATP
# m01642n dATP
# m01645c dCTP
# m01645m dCTP
# m01645n dCTP
# m01688c dGTP
# m01688m dGTP
# m01688n dGTP
# m01714c dITP
# m01714m dITP
# m01714n dITP
# m01714s dITP
# m01753c dTTP
# m01753m dTTP
# m01753n dTTP
# m01756c dUTP
# m01756m dUTP
# m01756n dUTP
# m02034c GTP
# m02034m GTP
# m02034n GTP
# m02034s GTP
# m02193c ITP
# m02193m ITP
# m02193n ITP
# m02193s ITP
# m03130c UTP
# m03130m UTP
# m03130n UTP
# m03130s UTP
# m03154c XTP
# m03154s XTP
# m02193x ITP
# m01714x dITP
# m02034x GTP
# m03130x UTP
# m03154x XTP

# %%
healthy.reactions.get_by_id("biomass_components").add_metabolites({healthy.metabolites.get_by_id("m01371c") : -1.0, healthy.metabolites.get_by_id("m01623c") : -1.0, healthy.metabolites.get_by_id("m02034c") : -1.0, healthy.metabolites.get_by_id("m03130c") : -1.0})
# Out:
# 1.0 alanine + 1.0 arginine + 1.0 asparagine + 1.0 aspartate + 1.0 cholesterol + 1.0 cholesterol-ester pool + 1.0 CL pool + 1.0 cysteine + 1.0 DNA_C10H17O8PR2(C5H8O5PR)n + 1.0 DNA-5-methylcytosine_C10H16N3O7P(C5H8O5PR)n(C5H8O5PR)n + 1.0 glutamate + 1.0 glutamine + 1.0 glycine + 1.0 histidine + 1.0 isoleucine + 1.0 leucine + 1.0 lipid droplet_ + 1.0 lysine + 1.0 methionine + 1.0 phenylalanine + 1.0 phosphatidate-LD-TAG pool + 1.0 PI pool + 1.0 proline + 1.0 RNA_C10H18O13P2R2(C5H8O6PR)n + 1.0 serine + 1.0 SM pool + 1.0 threonine + 1.0 tryptophan + 1.0 tyrosine + 1.0 valine + 1.0 glycogen + 1.0 ATP + 1.0 CTP + 1.0 GTP + 1.0 UTP <=> 1.0 biomass + 1.0 H+ + 1.0 ADP
#
# 1.0 m01307c + 1.0 m01365c + 1.0 m01369c + 1.0 m01370c + 1.0 m01450c + 1.0 m01451r + 1.0 m01589c + 1.0 m01628c + 1.0 m01721n + 1.0 m01722n + 1.0 m01974c + 1.0 m01975c + 1.0 m01986c + 1.0 m02125c + 1.0 m02184c + 1.0 m02360c + 1.0 m02392c + 1.0 m02426c + 1.0 m02471c + 1.0 m02724c + 1.0 m02733c + 1.0 m02750c + 1.0 m02770c + 1.0 m02847c + 1.0 m02896c + 1.0 m02908c + 1.0 m02993c + 1.0 m03089c + 1.0 m03101c + 1.0 m03135c + 1.0 m03161c + 1.0 m01371c + 1.0 m01623c + 1.0 m02034c + 1.0 m03130c <=> 1.0 temp001x + 1.0 m02039x + 1.0 m01285c

# %%
print("REACTANTS: \n")
for metabolite_r in healthy.reactions.get_by_id("biomass_components").reactants:
    print(f"ID : {metabolite_r.id} -- NAME : {metabolite_r.name}")

print("PRODUCTS: \n")
for metabolite_p in healthy.reactions.get_by_id("biomass_components").products:
    print(f"ID : {metabolite_p.id} -- NAME : {metabolite_p.name}")
# Out:
# REACTANTS:
#
# ID : m01307c -- NAME : alanine
# ID : m01365c -- NAME : arginine
# ID : m01369c -- NAME : asparagine
# ID : m01370c -- NAME : aspartate
# ID : m01450c -- NAME : cholesterol
# ID : m01451r -- NAME : cholesterol-ester pool
# ID : m01589c -- NAME : CL pool
# ID : m01628c -- NAME : cysteine
# ID : m01721n -- NAME : DNA_C10H17O8PR2(C5H8O5PR)n
# ID : m01722n -- NAME : DNA-5-methylcytosine_C10H16N3O7P(C5H8O5PR)n(C5H8O5PR)n
# ID : m01974c -- NAME : glutamate
# ID : m01975c -- NAME : glutamine
# ID : m01986c -- NAME : glycine
# ID : m02125c -- NAME : histidine
# ID : m02184c -- NAME : isoleucine
# ID : m02360c -- NAME : leucine
# ID : m02392c -- NAME : lipid droplet_
# ID : m02426c -- NAME : lysine
# ID : m02471c -- NAME : methionine
# ID : m02724c -- NAME : phenylalanine
# ID : m02733c -- NAME : phosphatidate-LD-TAG pool
# ID : m02750c -- NAME : PI pool
# ID : m02770c -- NAME : proline
# ID : m02847c -- NAME : RNA_C10H18O13P2R2(C5H8O6PR)n
# ID : m02896c -- NAME : serine
# ID : m02908c -- NAME : SM pool
# ID : m02993c -- NAME : threonine
# ID : m03089c -- NAME : tryptophan
# ID : m03101c -- NAME : tyrosine
# ID : m03135c -- NAME : valine
# ID : m03161c -- NAME : glycogen
# ID : m01371c -- NAME : ATP
# ID : m01623c -- NAME : CTP
# ID : m02034c -- NAME : GTP
# ID : m03130c -- NAME : UTP
# PRODUCTS:
#
# ID : temp001x -- NAME : biomass
# ID : m02039x -- NAME : H+
# ID : m01285c -- NAME : ADP

# %%
healthy.objective = "biomass_components"
healthy.optimize()
vu.print_exchanges(healthy, "all")
# Out:
# ##########
# INTAKES :
#
# EX_m03146x : 0           ub : 1000.0	---		metabolites : 	 id : m03146x --- metabolite name : VLDL remnant_ ; id : m03146x
# EX_m00549x : 0           ub : 1000.0	---		metabolites : 	 id : m00549x --- metabolite name : 1-organyl-2-lyso-sn-glycero-3-phosphocholine ; id : m00549x
# EX_m02389x : 3           ub : 1000.0	---		metabolites : 	 id : m02389x --- metabolite name : linolenate ; id : m02389x
# EX_m02360x : 15          ub : 1000.0	---		metabolites : 	 id : m02360x --- metabolite name : leucine ; id : m02360x
# EX_m01745x : 28          ub : 1000.0	---		metabolites : 	 id : m01745x --- metabolite name : D-tagatose ; id : m01745x
# EX_m01253x : 46          ub : 1000.0	---		metabolites : 	 id : m01253x --- metabolite name : acetoacetate ; id : m01253x
# EX_m01668x : 62          ub : 1000.0	---		metabolites : 	 id : m01668x --- metabolite name : deoxycytidine ; id : m01668x
# EX_m02819x : 63          ub : 1000.0	---		metabolites : 	 id : m02819x --- metabolite name : pyruvate ; id : m02819x
# EX_m02896x : 74          ub : 1000.0	---		metabolites : 	 id : m02896x --- metabolite name : serine ; id : m02896x
# EX_m03135x : 86          ub : 1000.0	---		metabolites : 	 id : m03135x --- metabolite name : valine ; id : m03135x
# EX_m02930x : 89          ub : 1000.0	---		metabolites : 	 id : m02930x --- metabolite name : sphingosine-1-phosphate ; id : m02930x
# EX_m02552x : 90          ub : 1000.0	---		metabolites : 	 id : m02552x --- metabolite name : NAD+ ; id : m02552x
# EX_m01365x : 91          ub : 1000.0	---		metabolites : 	 id : m01365x --- metabolite name : arginine ; id : m01365x
# EX_m02993x : 92          ub : 1000.0	---		metabolites : 	 id : m02993x --- metabolite name : threonine ; id : m02993x
# EX_m02184x : 107         ub : 1000.0	---		metabolites : 	 id : m02184x --- metabolite name : isoleucine ; id : m02184x
# EX_m02996x : 111         ub : 1000.0	---		metabolites : 	 id : m02996x --- metabolite name : thymidine ; id : m02996x
# EX_m01369x : 115         ub : 1000.0	---		metabolites : 	 id : m01369x --- metabolite name : asparagine ; id : m01369x
# EX_m01451x : 129         ub : 1000.0	---		metabolites : 	 id : m01451x --- metabolite name : cholesterol-ester pool ; id : m01451x
# EX_m02471x : 136         ub : 1000.0	---		metabolites : 	 id : m02471x --- metabolite name : methionine ; id : m02471x
# EX_m02125x : 137         ub : 1000.0	---		metabolites : 	 id : m02125x --- metabolite name : histidine ; id : m02125x
# EX_m03089x : 143         ub : 1000.0	---		metabolites : 	 id : m03089x --- metabolite name : tryptophan ; id : m03089x
# EX_m02171x : 159         ub : 1000.0	---		metabolites : 	 id : m02171x --- metabolite name : inositol ; id : m02171x
# EX_m02583x : 159         ub : 1000.0	---		metabolites : 	 id : m02583x --- metabolite name : nicotinamide ; id : m02583x
# EX_m03161x : 159         ub : 1000.0	---		metabolites : 	 id : m03161x --- metabolite name : glycogen ; id : m03161x
# EX_m02366x : 174         ub : 1000.0	---		metabolites : 	 id : m02366x --- metabolite name : leukotriene C4 ; id : m02366x
# EX_m01630x : 209         ub : 1000.0	---		metabolites : 	 id : m01630x --- metabolite name : cytidine ; id : m01630x
# EX_m02724x : 243         ub : 1000.0	---		metabolites : 	 id : m02724x --- metabolite name : phenylalanine ; id : m02724x
# EX_m02037x : 277         ub : 1000.0	---		metabolites : 	 id : m02037x --- metabolite name : guanine ; id : m02037x
# EX_m01288x : 311         ub : 1000.0	---		metabolites : 	 id : m01288x --- metabolite name : ADP-ribose ; id : m01288x
# EX_m00577x : 329         ub : 1000.0	---		metabolites : 	 id : m00577x --- metabolite name : 2,6-dimethylheptanoyl-carnitine ; id : m00577x
# EX_m03130x : 468         ub : 1000.0	---		metabolites : 	 id : m03130x --- metabolite name : UTP ; id : m03130x
# EX_m01368x : 470         ub : 1000.0	---		metabolites : 	 id : m01368x --- metabolite name : ascorbate ; id : m01368x
# EX_m02560x : 504         ub : 1000.0	---		metabolites : 	 id : m02560x --- metabolite name : NEFA blood pool in ; id : m02560x
# EX_m02630x : 561         ub : 1000.0	---		metabolites : 	 id : m02630x --- metabolite name : O2 ; id : m02630x
# EX_m01260x : 620         ub : 1000.0	---		metabolites : 	 id : m01260x --- metabolite name : acetylcholine ; id : m01260x
# EX_m01666x : 723         ub : 1000.0	---		metabolites : 	 id : m01666x --- metabolite name : deoxyadenosine ; id : m01666x
# EX_m02426x : 805         ub : 1000.0	---		metabolites : 	 id : m02426x --- metabolite name : lysine ; id : m02426x
# EX_m03123x : 982         ub : 1000.0	---		metabolites : 	 id : m03123x --- metabolite name : uridine ; id : m03123x
# EX_m01975x : 1000        ub : 1000.0	---		metabolites : 	 id : m01975x --- metabolite name : glutamine ; id : m01975x
# EX_m01628x : 1000        ub : 1000.0	---		metabolites : 	 id : m01628x --- metabolite name : cysteine ; id : m01628x
# EX_m02040x : 1000        ub : 1000.0	---		metabolites : 	 id : m02040x --- metabolite name : H2O ; id : m02040x
# EX_m02949x : 1000        ub : 1000.0	---		metabolites : 	 id : m02949x --- metabolite name : sulfite ; id : m02949x
# EX_m02370x : 1000        ub : 1000.0	---		metabolites : 	 id : m02370x --- metabolite name : leukotriene F4 ; id : m02370x
# EX_m01069x : 1000        ub : 1000.0	---		metabolites : 	 id : m01069x --- metabolite name : 5-alpha-dihydrotestosterone ; id : m01069x
# EX_m01344x : 1000        ub : 1000.0	---		metabolites : 	 id : m01344x --- metabolite name : antipyrine ; id : m01344x
# EX_m01615x : 1000        ub : 1000.0	---		metabolites : 	 id : m01615x --- metabolite name : cortisol ; id : m01615x
# EX_m02041x : 1000        ub : 1000.0	---		metabolites : 	 id : m02041x --- metabolite name : H2O2 ; id : m02041x
# EX_m02631x : 1000        ub : 1000.0	---		metabolites : 	 id : m02631x --- metabolite name : O2- ; id : m02631x
# EX_m02147x : 1000        ub : 1000.0	---		metabolites : 	 id : m02147x --- metabolite name : hydroxide ; id : m02147x
#
# ##########
# SECRETIONS :
#
# EX_temp001x : 159        ub : 1000.0	---		metabolites : 	 id : temp001x --- metabolite name : biomass ; id : temp001x
# EX_m02842x : 0           ub : 1000.0	---		metabolites : 	 id : m02842x --- metabolite name : riboflavin ; id : m02842x
# EX_m01982x : 0           ub : 1000.0	---		metabolites : 	 id : m01982x --- metabolite name : glycerate ; id : m01982x
# EX_m02931x : -1          ub : 1000.0	---		metabolites : 	 id : m02931x --- metabolite name : sphingosylphosphorylcholine ; id : m02931x
# EX_m00325x : -2          ub : 1000.0	---		metabolites : 	 id : m00325x --- metabolite name : 12-hydroxydodecanoic acid ; id : m00325x
# EX_m00371x : -4          ub : 1000.0	---		metabolites : 	 id : m00371x --- metabolite name : 14-hydroxytetradecanoic acid ; id : m00371x
# EX_m01797x : -93         ub : 1000.0	---		metabolites : 	 id : m01797x --- metabolite name : ethanolamine ; id : m01797x
# EX_m01986x : -113        ub : 1000.0	---		metabolites : 	 id : m01986x --- metabolite name : glycine ; id : m01986x
# EX_m01983x : -124        ub : 1000.0	---		metabolites : 	 id : m01983x --- metabolite name : glycerol ; id : m01983x
# EX_m02182x : -132        ub : 1000.0	---		metabolites : 	 id : m02182x --- metabolite name : isocaproic-aldehyde ; id : m02182x
# EX_m02769x : -132        ub : 1000.0	---		metabolites : 	 id : m02769x --- metabolite name : progesterone ; id : m02769x
# EX_m00157x : -136        ub : 1000.0	---		metabolites : 	 id : m00157x --- metabolite name : (R)-3-hydroxybutanoate ; id : m00157x
# EX_m02039x : -159        ub : 1000.0	---		metabolites : 	 id : m02039x --- metabolite name : H+ ; id : m02039x
# EX_m02418x : -174        ub : 1000.0	---		metabolites : 	 id : m02418x --- metabolite name : LTD4 ; id : m02418x
# EX_m00536x : -249        ub : 1000.0	---		metabolites : 	 id : m00536x --- metabolite name : 1-methylnicotinamide ; id : m00536x
# EX_m02997x : -277        ub : 1000.0	---		metabolites : 	 id : m02997x --- metabolite name : thymine ; id : m02997x
# EX_m00665x : -298        ub : 1000.0	---		metabolites : 	 id : m00665x --- metabolite name : 2-methylcitrate ; id : m00665x
# EX_m02348x : -329        ub : 1000.0	---		metabolites : 	 id : m02348x --- metabolite name : L-carnitine ; id : m02348x
# EX_m02470x : -329        ub : 1000.0	---		metabolites : 	 id : m02470x --- metabolite name : methanol ; id : m02470x
# EX_m00816x : -424        ub : 1000.0	---		metabolites : 	 id : m00816x --- metabolite name : 3-mercaptolactate-cysteine-disulfide ; id : m00816x
# EX_m01655x : -470        ub : 1000.0	---		metabolites : 	 id : m01655x --- metabolite name : dehydroascorbic acid ; id : m01655x
# EX_m00204x : -724        ub : 1000.0	---		metabolites : 	 id : m00204x --- metabolite name : [protein]-L-lysine ; id : m00204x
# EX_m02770x : -881        ub : 1000.0	---		metabolites : 	 id : m02770x --- metabolite name : proline ; id : m02770x
# EX_m01370x : -1000       ub : 1000.0	---		metabolites : 	 id : m01370x --- metabolite name : aspartate ; id : m01370x
# EX_m02578x : -1000       ub : 1000.0	---		metabolites : 	 id : m02578x --- metabolite name : NH3 ; id : m02578x
# EX_m02046x : -1000       ub : 1000.0	---		metabolites : 	 id : m02046x --- metabolite name : HCO3- ; id : m02046x
# EX_m01513x : -1000       ub : 1000.0	---		metabolites : 	 id : m01513x --- metabolite name : choline ; id : m01513x
# EX_m01252x : -1000       ub : 1000.0	---		metabolites : 	 id : m01252x --- metabolite name : acetate ; id : m01252x
# EX_m02403x : -1000       ub : 1000.0	---		metabolites : 	 id : m02403x --- metabolite name : L-lactate ; id : m02403x
# EX_m01071x : -1000       ub : 1000.0	---		metabolites : 	 id : m01071x --- metabolite name : 5alpha-dihydrotestosterone-sulfate ; id : m01071x
# EX_m01249x : -1000       ub : 1000.0	---		metabolites : 	 id : m01249x --- metabolite name : acetaldehyde ; id : m01249x
# EX_m01279x : -1000       ub : 1000.0	---		metabolites : 	 id : m01279x --- metabolite name : adenine ; id : m01279x
# EX_m01614x : -1000       ub : 1000.0	---		metabolites : 	 id : m01614x --- metabolite name : corticosterone ; id : m01614x
# EX_m01768x : -1000       ub : 1000.0	---		metabolites : 	 id : m01768x --- metabolite name : edaravone ; id : m01768x
# EX_m02369x : -1000       ub : 1000.0	---		metabolites : 	 id : m02369x --- metabolite name : leukotriene E4 ; id : m02369x
# EX_m02841x : -1000       ub : 1000.0	---		metabolites : 	 id : m02841x --- metabolite name : ribitol ; id : m02841x
# EX_m03118x : -1000       ub : 1000.0	---		metabolites : 	 id : m03118x --- metabolite name : uracil ; id : m03118x

# %% [markdown]
# With glycogen in the reactants part of the biomass reaction, how does the model handle that ?

# %%
vu.run_parcours("EX_m03161x", healthy)
# Out:
# [EX_m03161x] : Getting all related reactions and fluxes...
# --> 1.0 glycogen
#
# --> 1.0 m03161x
# FLUX : 159.22487444355636 --- ID : EX_m03161x --- COMPARTMENT : {'C_x'}
#
# SUBSYSTEM :  --- GENE NAME : EX_m03161x
#
# ---
#
#
# 1.0 glycogen --> 1.0 glycogen
#
# 1.0 m03161x --> 1.0 m03161s
# FLUX : 159.22487444355636 --- ID : HMR_9729 --- COMPARTMENT : {'C_s', 'C_x'}
#
# SUBSYSTEM : Exchange reactions --- GENE NAME :
#
# ---
#
#
# 1.0 glycogen <-- 1.0 glycogen
#
# 1.0 m03161c <-- 1.0 m03161s
# FLUX : -159.22487444355636 --- ID : HMR_9728 --- COMPARTMENT : {'C_s', 'C_c'}
#
# SUBSYSTEM : Transport, extracellular --- GENE NAME :
#
# ---
#
#
# 1.0 alanine + 1.0 arginine + 1.0 asparagine + 1.0 aspartate + 1.0 cholesterol + 1.0 cholesterol-ester pool + 1.0 CL pool + 1.0 cysteine + 1.0 DNA_C10H17O8PR2(C5H8O5PR)n + 1.0 DNA-5-methylcytosine_C10H16N3O7P(C5H8O5PR)n(C5H8O5PR)n + 1.0 glutamate + 1.0 glutamine + 1.0 glycine + 1.0 histidine + 1.0 isoleucine + 1.0 leucine + 1.0 lipid droplet_ + 1.0 lysine + 1.0 methionine + 1.0 phenylalanine + 1.0 phosphatidate-LD-TAG pool + 1.0 PI pool + 1.0 proline + 1.0 RNA_C10H18O13P2R2(C5H8O6PR)n + 1.0 serine + 1.0 SM pool + 1.0 threonine + 1.0 tryptophan + 1.0 tyrosine + 1.0 valine + 1.0 glycogen + 1.0 ATP + 1.0 CTP + 1.0 GTP + 1.0 UTP --> 1.0 biomass + 1.0 H+ + 1.0 ADP
#
# 1.0 m01307c + 1.0 m01365c + 1.0 m01369c + 1.0 m01370c + 1.0 m01450c + 1.0 m01451r + 1.0 m01589c + 1.0 m01628c + 1.0 m01721n + 1.0 m01722n + 1.0 m01974c + 1.0 m01975c + 1.0 m01986c + 1.0 m02125c + 1.0 m02184c + 1.0 m02360c + 1.0 m02392c + 1.0 m02426c + 1.0 m02471c + 1.0 m02724c + 1.0 m02733c + 1.0 m02750c + 1.0 m02770c + 1.0 m02847c + 1.0 m02896c + 1.0 m02908c + 1.0 m02993c + 1.0 m03089c + 1.0 m03101c + 1.0 m03135c + 1.0 m03161c + 1.0 m01371c + 1.0 m01623c + 1.0 m02034c + 1.0 m03130c --> 1.0 temp001x + 1.0 m02039x + 1.0 m01285c
# FLUX : 159.22487444355636 --- ID : biomass_components --- COMPARTMENT : {'C_x', 'C_c', 'C_r', 'C_n'}
#
# SUBSYSTEM :  --- GENE NAME : Null
#
# ---
#
#
# 1.0 alanine <-- 1.0 alanine
#
# 1.0 m01307c <-- 1.0 m01307p
# FLUX : -0.25475979910969215 --- ID : HMR_4790 --- COMPARTMENT : {'C_p', 'C_c'}
#
# SUBSYSTEM : Transport, peroxisomal --- GENE NAME :
#
# ---
#
#
# 1.0 pyruvate + 1.0 serine --> 1.0 alanine + 1.0 hydroxypyruvate
#
# 1.0 m02819p + 1.0 m02896p --> 1.0 m01307p + 1.0 m02154p
# FLUX : 0.25475979910969215 --- ID : HMR_4467 --- COMPARTMENT : {'C_p'}
#
# SUBSYSTEM : Glycine, serine and threonine metabolism --- GENE NAME : AGXT
#
# ---
#
#
# 1.0 H+ + 1.0 NADH + 1.0 pyruvate --> 1.0 L-lactate + 1.0 NAD+
#
# 1.0 m02039p + 1.0 m02553p + 1.0 m02819p --> 1.0 m02403p + 1.0 m02552p
# FLUX : 108.4943553903897 --- ID : HMR_4281 --- COMPARTMENT : {'C_p'}
#
# SUBSYSTEM : Glycolysis / Gluconeogenesis --- GENE NAME : LDHB/LDHAL6A/LDHC/UEVLD/LDHAL6B
#
# ---
#
#
# 1.0 H+ + 1.0 L-lactate <-- 1.0 H+ + 1.0 L-lactate
#
# 1.0 m02039c + 1.0 m02403c <-- 1.0 m02039p + 1.0 m02403p
# FLUX : -108.4943553903897 --- ID : HMR_3007 --- COMPARTMENT : {'C_p', 'C_c'}
#
# SUBSYSTEM : Transport, peroxisomal --- GENE NAME : SLC16A1
#
# ---
#
#
# 1.0 2-hydroxybutyrate + 1.0 L-lactate <-- 1.0 2-hydroxybutyrate + 1.0 L-lactate
#
# 1.0 m00648c + 1.0 m02403s <-- 1.0 m00648s + 1.0 m02403c
# FLUX : -1000.0 --- ID : HMR_6011 --- COMPARTMENT : {'C_s', 'C_c'}
#
# SUBSYSTEM : Transport, extracellular --- GENE NAME : SLC16A4/SLC16A6/SLC16A1/SLC16A8/SLC16A3/SLC16A5/SLC16A7
#
# ---
#
#
# 1.0 2-hydroxybutyrate + 1.0 propanoate --> 1.0 2-hydroxybutyrate + 1.0 propanoate
#
# 1.0 m00648c + 1.0 m02772s --> 1.0 m00648s + 1.0 m02772c
# FLUX : 1000.0 --- ID : HMR_6010 --- COMPARTMENT : {'C_s', 'C_c'}
#
# SUBSYSTEM : Transport, extracellular --- GENE NAME : SLC16A4/SLC16A6/SLC16A1/SLC16A8/SLC16A3/SLC16A5/SLC16A7
#
# ---
#
#
# 1.0 acetoacetate + 1.0 propanoate <-- 1.0 acetoacetate + 1.0 propanoate
#
# 1.0 m01253c + 1.0 m02772s <-- 1.0 m01253s + 1.0 m02772c
# FLUX : -1000.0 --- ID : HMR_6003 --- COMPARTMENT : {'C_s', 'C_c'}
#
# SUBSYSTEM : Transport, extracellular --- GENE NAME : SLC16A4/SLC16A6/SLC16A1/SLC16A8/SLC16A3/SLC16A5/SLC16A7
#
# ---
#
#
# 1.0 acetoacetate + 1.0 retinoate --> 1.0 acetoacetate + 1.0 retinoate
#
# 1.0 m01253c + 1.0 m02833s --> 1.0 m01253s + 1.0 m02833c
# FLUX : 1000.0 --- ID : HMR_6005 --- COMPARTMENT : {'C_s', 'C_c'}
#
# SUBSYSTEM : Transport, extracellular --- GENE NAME : SLC16A4/SLC16A6/SLC16A1/SLC16A8/SLC16A3/SLC16A5/SLC16A7
#
# ---
#
#
# 1.0 retinoate --> 1.0 retinoate
#
# 1.0 m02833c --> 1.0 m02833s
# FLUX : 1000.0 --- ID : HMR_8721 --- COMPARTMENT : {'C_s', 'C_c'}
#
# SUBSYSTEM : Transport, extracellular --- GENE NAME :
#
# ---
#
#
# 1.0 H+ + 1.0 NADPH + 1.0 retinoate <-- 1.0 H2O + 1.0 NADP+ + 1.0 retinal
#
# 1.0 m02039c + 1.0 m02555c + 1.0 m02833c <-- 1.0 m02040c + 1.0 m02554c + 1.0 m02832c
# FLUX : -543.428334010469 --- ID : HMR_8698 --- COMPARTMENT : {'C_c'}
#
# SUBSYSTEM : Retinol metabolism --- GENE NAME :
#
# ---
#
#
# 1.0 13-cis-retinal --> 1.0 retinal
#
# 1.0 m00349c --> 1.0 m02832c
# FLUX : 543.428334010469 --- ID : HMR_6672 --- COMPARTMENT : {'C_c'}
#
# SUBSYSTEM : Retinol metabolism --- GENE NAME :
#
# ---
#
#
# 1.0 13-cis-retinal + 1.0 H2O + 1.0 NAD+ <-- 1.0 13-cis-retinoate + 1.0 H+ + 1.0 NADH
#
# 1.0 m00349c + 1.0 m02040c + 1.0 m02552c <-- 1.0 m00350c + 1.0 m02039c + 1.0 m02553c
# FLUX : -543.428334010469 --- ID : HMR_6675 --- COMPARTMENT : {'C_c'}
#
# SUBSYSTEM : Retinol metabolism --- GENE NAME : ALDH1A2/ALDH1A1
#
# ---
#
#
# 1.0 13-cis-retinoate <-- 1.0 retinoate
#
# 1.0 m00350c <-- 1.0 m02833c
# FLUX : -543.428334010469 --- ID : HMR_6661 --- COMPARTMENT : {'C_c'}
#
# SUBSYSTEM : Retinol metabolism --- GENE NAME :
#
# ---
#
#
# 1.0 acetoacetate + 1.0 AKG --> 1.0 acetoacetate + 1.0 AKG
#
# 1.0 m01253s + 1.0 m01306c --> 1.0 m01253c + 1.0 m01306s
# FLUX : 45.688013764355816 --- ID : HMR_6025 --- COMPARTMENT : {'C_s', 'C_c'}
#
# SUBSYSTEM : Transport, extracellular --- GENE NAME : SLC16A4/SLC16A6/SLC16A1/SLC16A8/SLC16A3/SLC16A5/SLC16A7
#
# ---
#
#
# 1.0 AKG + 1.0 alanine <-- 1.0 glutamate + 1.0 pyruvate
#
# 1.0 m01306c + 1.0 m01307c <-- 1.0 m01974c + 1.0 m02819c
# FLUX : -1000.0 --- ID : HMR_3899 --- COMPARTMENT : {'C_c'}
#
# SUBSYSTEM : Alanine, aspartate and glutamate metabolism --- GENE NAME : GPT
#
# ---
#
#
# 1.0 glutamate --> 1.0 glutamate
#
# 1.0 m01974l --> 1.0 m01974c
# FLUX : 101.42821314714749 --- ID : HMR_5067 --- COMPARTMENT : {'C_l', 'C_c'}
#
# SUBSYSTEM : Transport, lysosomal --- GENE NAME : SLC36A1
#
# ---
#
#
# 1.0 apoE_ + 158.0 ATP + 158.0 H2O --> 158.0 ADP + 39.0 alanine + 34.0 arginine + 1.0 asparagine + 11.0 aspartate + 2.0 cysteine + 40.0 glutamate + 32.0 glutamine + 18.0 glycine + 2.0 histidine + 2.0 isoleucine + 41.0 leucine + 13.0 lysine + 8.0 methionine + 4.0 phenylalanine + 158.0 Pi + 8.0 proline + 14.0 serine + 12.0 threonine + 8.0 tryptophan + 4.0 tyrosine + 24.0 valine
#
# 1.0 m01359l + 158.0 m01371l + 158.0 m02040l --> 158.0 m01285l + 39.0 m01307l + 34.0 m01365l + 1.0 m01369l + 11.0 m01370l + 2.0 m01628l + 40.0 m01974l + 32.0 m01975l + 18.0 m01986l + 2.0 m02125l + 2.0 m02184l + 41.0 m02360l + 13.0 m02426l + 8.0 m02471l + 4.0 m02724l + 158.0 m02751l + 8.0 m02770l + 14.0 m02896l + 12.0 m02993l + 8.0 m03089l + 4.0 m03101l + 24.0 m03135l
# FLUX : 1.2283693633737585 --- ID : HMR_5282 --- COMPARTMENT : {'C_l'}
#
# SUBSYSTEM : Protein degradation --- GENE NAME : CTSK/CTSW/TPP1/CTSE/CTSH/CTSA/CTSF/CTSZ/CTSD/CTSO/CTSC/CTSV/CTSL/CTSB
#
# ---
#
#
# 1.0 VLDL remnant_ --> 165.0 2-lysolecithin pool + 1.0 apoB100_ + 7.0 apoE_ + 500.0 cholesterol + 1645.0 cholesterol-ester pool + 2165.0 PC-LD pool + 185.0 PE-LD pool + 1.0 PI pool + 755.0 SM pool
#
# 1.0 m03146l --> 165.0 m00656l + 1.0 m01351l + 7.0 m01359l + 500.0 m01450l + 1645.0 m01451l + 2165.0 m02684l + 185.0 m02685l + 1.0 m02750l + 755.0 m02908l
# FLUX : 0.17548133762482263 --- ID : HMR_5243 --- COMPARTMENT : {'C_l'}
#
# SUBSYSTEM : Pool reactions --- GENE NAME :
#
# ---
#
#
# 1.0 VLDL remnant_ --> 1.0 VLDL remnant_
#
# 1.0 m03146s --> 1.0 m03146l
# FLUX : 0.17548133762482263 --- ID : HMR_5241 --- COMPARTMENT : {'C_s', 'C_l'}
#
# SUBSYSTEM : Transport, extracellular --- GENE NAME : LDLR
#
# ---
#
#
# 1.0 VLDL remnant_ --> 1.0 VLDL remnant_
#
# 1.0 m03146x --> 1.0 m03146s
# FLUX : 0.17548133762482263 --- ID : HMR_9029 --- COMPARTMENT : {'C_s', 'C_x'}
#
# SUBSYSTEM : Exchange reactions --- GENE NAME :
#
# ---
#
#
# --> 1.0 VLDL remnant_
#
# --> 1.0 m03146x
# FLUX : 0.17548133762482263 --- ID : EX_m03146x --- COMPARTMENT : {'C_x'}
#
# SUBSYSTEM :  --- GENE NAME : EX_m03146x
#
# ---
#
#
# 1.0 2-lysolecithin pool --> 1.0 2-lysolecithin pool
#
# 1.0 m00656l --> 1.0 m00656r
# FLUX : 28.954420708095732 --- ID : HMR_5255 --- COMPARTMENT : {'C_l', 'C_r'}
#
# SUBSYSTEM : Transport, lysosome to ER --- GENE NAME :
#
# ---
#
#
# 1.0 2-lysolecithin pool <-- 1.0 2-lysolecithin pool
#
# 1.0 m00656c <-- 1.0 m00656r
# FLUX : -28.95442070809832 --- ID : HMR_0462 --- COMPARTMENT : {'C_c', 'C_r'}
#
# SUBSYSTEM : Transport, endoplasmic reticular --- GENE NAME :
#
# ---
#
#
# 0.19 1,2-diacylglycerol-LD-TAG pool + 0.0014 1-acyl-PE pool + 0.0024 1-radyl-2-acyl-sn-glycero-3-phosphocholine + 0.0006 2-lysolecithin pool + 0.005 cholesterol + 0.34 cholesterol-ester pool + 0.005 fatty acid-LD-TG1 pool + 0.0008 O-1-alk-1-enyl-2-acyl-sn-glycero-3-phosphoethanolamine + 0.0092 PC-LD pool + 0.0034 PE-LD pool + 0.0016 PI pool + 0.0002 PS-LD pool + 0.0004 SM pool + 0.44 TAG-LD pool --> 1.0 lipid droplet_
#
# 0.19 m00240c + 0.0014 m00511c + 0.0024 m00560c + 0.0006 m00656c + 0.005 m01450c + 0.34 m01451c + 0.005 m01813c + 0.0008 m02629c + 0.0092 m02684c + 0.0034 m02685c + 0.0016 m02750c + 0.0002 m02808c + 0.0004 m02908c + 0.44 m02958c --> 1.0 m02392c
# FLUX : 159.22487444355636 --- ID : HMR_0031 --- COMPARTMENT : {'C_c'}
#
# SUBSYSTEM : Pool reactions --- GENE NAME : FITM1/PLIN4/PLIN3
#
# ---
#
#
# 1.0 1,2-diacylglycerol-LD-TAG pool + 1.0 ATP --> 1.0 ADP + 1.0 phosphatidate-LD-TAG pool
#
# 1.0 m00240c + 1.0 m01371c --> 1.0 m01285c + 1.0 m02733c
# FLUX : 159.22487444355636 --- ID : HMR_0604 --- COMPARTMENT : {'C_c'}
#
# SUBSYSTEM : Acylglycerides metabolism --- GENE NAME : Null/DGKD/DGKA/DGKB/DGKH/DGKZ/DGKQ/DGKI/DGKE/DGKG
#
# ---
#
#
# 1.0 1,2-diacylglycerol-LD-TAG pool + 1.0 H2O --> 1.0 1-acylglycerol-LD-TG1 pool + 1.0 fatty acid-LD-TG2 pool
#
# 1.0 m00240c + 1.0 m02040c --> 1.0 m00509c + 1.0 m01814c
# FLUX : 0.1273798995548451 --- ID : HMR_0667 --- COMPARTMENT : {'C_c'}
#
# SUBSYSTEM : Acylglycerides metabolism --- GENE NAME : CEL/PNLIPRP1/LIPF/LIPE/PNLIPRP3/PNPLA4/PNPLA3/AADAC/LIPG/LIPC/PNLIPRP2/PNLIP
#
# ---
#
#
# 1.0 1-acylglycerol-LD-TG1 pool + 1.0 ATP --> 1.0 1-acylglycerol-3P-LD-TG1 pool + 1.0 ADP
#
# 1.0 m00509c + 1.0 m01371c --> 1.0 m00490c + 1.0 m01285c
# FLUX : 0.1273798995548451 --- ID : HMR_0673 --- COMPARTMENT : {'C_c'}
#
# SUBSYSTEM : Glycerolipid metabolism --- GENE NAME : AGK
#
# ---
#
#
# 1.0 1-acylglycerol-3P-LD-TG1 pool + 1.0 NADP+ --> 1.0 acylglycerone-phosphate + 1.0 H+ + 1.0 NADPH
#
# 1.0 m00490c + 1.0 m02554c --> 1.0 m01278c + 1.0 m02039c + 1.0 m02555c
# FLUX : 0.1273798995548451 --- ID : HMR_7591 --- COMPARTMENT : {'C_c'}
#
# SUBSYSTEM : Glycerophospholipid metabolism --- GENE NAME : AKR1A1
#
# ---
#
#
# 1.0 acylglycerone-phosphate --> 1.0 acylglycerone-phosphate
#
# 1.0 m01278c --> 1.0 m01278p
# FLUX : 0.1273798995548451 --- ID : HMR_7590 --- COMPARTMENT : {'C_p', 'C_c'}
#
# SUBSYSTEM : Transport, peroxisomal --- GENE NAME :
#
# ---
#
#
# 1.0 acylglycerone-phosphate + 1.0 hexadecanol --> 1.0 alkyl-glycerone-3-phosphate + 1.0 palmitate
#
# 1.0 m01278p + 1.0 m02114p --> 1.0 m01311p + 1.0 m02674p
# FLUX : 0.1273798995548451 --- ID : HMR_7594 --- COMPARTMENT : {'C_p'}
#
# SUBSYSTEM : Glycerophospholipid metabolism --- GENE NAME : AGPS
#
# ---
#
#
# 2.0 H+ + 2.0 NADPH + 1.0 palmitoyl-CoA --> 1.0 CoA + 1.0 hexadecanol + 2.0 NADP+
#
# 2.0 m02039p + 2.0 m02555p + 1.0 m02678p --> 1.0 m01597p + 1.0 m02114p + 2.0 m02554p
# FLUX : 0.1273798995548451 --- ID : HMR_0703 --- COMPARTMENT : {'C_p'}
#
# SUBSYSTEM : Ether lipid metabolism --- GENE NAME : FAR1/FAR2
#
# ---
#
#
# 1.0 3-oxooctadecanoyl-CoA + 1.0 CoA --> 1.0 acetyl-CoA + 1.0 palmitoyl-CoA
#
# 1.0 m00890p + 1.0 m01597p --> 1.0 m01261p + 1.0 m02678p
# FLUX : 0.6138072116416102 --- ID : HMR_3077 --- COMPARTMENT : {'C_p'}
#
# SUBSYSTEM : Beta oxidation of even-chain fatty acids (peroxisomal) --- GENE NAME : ACAA1/MYO5B
#
# ---
#
#
# 1.0 3-hydroxyoctadecanoyl-CoA + 1.0 NAD+ --> 1.0 3-oxooctadecanoyl-CoA + 1.0 H+ + 1.0 NADH
#
# 1.0 m00793p + 1.0 m02552p --> 1.0 m00890p + 1.0 m02039p + 1.0 m02553p
# FLUX : 0.6138072116416102 --- ID : HMR_3076 --- COMPARTMENT : {'C_p'}
#
# SUBSYSTEM : Beta oxidation of even-chain fatty acids (peroxisomal) --- GENE NAME : EHHADH/HSD17B4
#
# ---
#
#
# 1.0 (2E)-octadecenoyl-CoA + 1.0 H2O --> 1.0 3-hydroxyoctadecanoyl-CoA
#
# 1.0 m00057p + 1.0 m02040p --> 1.0 m00793p
# FLUX : 0.6138072116416102 --- ID : HMR_3075 --- COMPARTMENT : {'C_p'}
#
# SUBSYSTEM : Beta oxidation of even-chain fatty acids (peroxisomal) --- GENE NAME : EHHADH
#
# ---
#
#
# 1.0 O2 + 1.0 stearoyl-CoA --> 1.0 (2E)-octadecenoyl-CoA + 1.0 H2O2
#
# 1.0 m02630p + 1.0 m02941p --> 1.0 m00057p + 1.0 m02041p
# FLUX : 0.6138072116416102 --- ID : HMR_3074 --- COMPARTMENT : {'C_p'}
#
# SUBSYSTEM : Beta oxidation of even-chain fatty acids (peroxisomal) --- GENE NAME : ACOX1/ACOX3
#
# ---
#
#
# 1.0 3-oxoeicosanoyl-CoA + 1.0 CoA --> 1.0 acetyl-CoA + 1.0 stearoyl-CoA
#
# 1.0 m00872p + 1.0 m01597p --> 1.0 m01261p + 1.0 m02941p
# FLUX : 0.6138072116416102 --- ID : HMR_3073 --- COMPARTMENT : {'C_p'}
#
# SUBSYSTEM : Beta oxidation of even-chain fatty acids (peroxisomal) --- GENE NAME : ACAA1/MYO5B
#
# ---
#
#
# 1.0 3-hydroxyeicosanoyl-CoA + 1.0 NAD+ --> 1.0 3-oxoeicosanoyl-CoA + 1.0 H+ + 1.0 NADH
#
# 1.0 m00777p + 1.0 m02552p --> 1.0 m00872p + 1.0 m02039p + 1.0 m02553p
# FLUX : 0.6138072116416102 --- ID : HMR_3072 --- COMPARTMENT : {'C_p'}
#
# SUBSYSTEM : Beta oxidation of even-chain fatty acids (peroxisomal) --- GENE NAME : EHHADH/HSD17B4
#
# ---
#
#
# 1.0 (2E)-eicosenoyl-CoA + 1.0 H2O --> 1.0 3-hydroxyeicosanoyl-CoA
#
# 1.0 m00043p + 1.0 m02040p --> 1.0 m00777p
# FLUX : 0.6138072116416102 --- ID : HMR_3071 --- COMPARTMENT : {'C_p'}
#
# SUBSYSTEM : Beta oxidation of even-chain fatty acids (peroxisomal) --- GENE NAME : EHHADH
#
# ---
#
#
# 1.0 eicosanoyl-CoA + 1.0 O2 --> 1.0 (2E)-eicosenoyl-CoA + 1.0 H2O2
#
# 1.0 m01773p + 1.0 m02630p --> 1.0 m00043p + 1.0 m02041p
# FLUX : 0.6138072116416102 --- ID : HMR_3070 --- COMPARTMENT : {'C_p'}
#
# SUBSYSTEM : Beta oxidation of even-chain fatty acids (peroxisomal) --- GENE NAME : ACOX1/ACOX3
#
# ---
#
#
# 1.0 3-oxodocosanoyl-CoA + 1.0 CoA --> 1.0 acetyl-CoA + 1.0 eicosanoyl-CoA
#
# 1.0 m00866p + 1.0 m01597p --> 1.0 m01261p + 1.0 m01773p
# FLUX : 0.6138072116416102 --- ID : HMR_3069 --- COMPARTMENT : {'C_p'}
#
# SUBSYSTEM : Beta oxidation of even-chain fatty acids (peroxisomal) --- GENE NAME : ACAA1/MYO5B
#
# ---
#
#
# 1.0 3-hydroxydocosanoyl-CoA + 1.0 NAD+ --> 1.0 3-oxodocosanoyl-CoA + 1.0 H+ + 1.0 NADH
#
# 1.0 m00776p + 1.0 m02552p --> 1.0 m00866p + 1.0 m02039p + 1.0 m02553p
# FLUX : 0.6138072116416102 --- ID : HMR_3068 --- COMPARTMENT : {'C_p'}
#
# SUBSYSTEM : Beta oxidation of even-chain fatty acids (peroxisomal) --- GENE NAME : EHHADH/HSD17B4
#
# ---
#
#
# 1.0 (2E)-docosenoyl-CoA + 1.0 H2O --> 1.0 3-hydroxydocosanoyl-CoA
#
# 1.0 m00040p + 1.0 m02040p --> 1.0 m00776p
# FLUX : 0.6138072116416102 --- ID : HMR_3067 --- COMPARTMENT : {'C_p'}
#
# SUBSYSTEM : Beta oxidation of even-chain fatty acids (peroxisomal) --- GENE NAME : EHHADH
#
# ---
#
#
# 1.0 docosanoyl-CoA + 1.0 O2 --> 1.0 (2E)-docosenoyl-CoA + 1.0 H2O2
#
# 1.0 m01725p + 1.0 m02630p --> 1.0 m00040p + 1.0 m02041p
# FLUX : 0.6138072116416102 --- ID : HMR_3066 --- COMPARTMENT : {'C_p'}
#
# SUBSYSTEM : Beta oxidation of even-chain fatty acids (peroxisomal) --- GENE NAME : ACOX1/ACOX3
#
# ---
#
#
# 1.0 3-oxotetracosanoyl-CoA + 1.0 CoA --> 1.0 acetyl-CoA + 1.0 docosanoyl-CoA
#
# 1.0 m00904p + 1.0 m01597p --> 1.0 m01261p + 1.0 m01725p
# FLUX : 0.6138072116416102 --- ID : HMR_3065 --- COMPARTMENT : {'C_p'}
#
# SUBSYSTEM : Beta oxidation of even-chain fatty acids (peroxisomal) --- GENE NAME : ACAA1/MYO5B
#
# ---
#
#
# 1.0 3-hydroxytetracosanoyl-CoA + 1.0 NAD+ --> 1.0 3-oxotetracosanoyl-CoA + 1.0 H+ + 1.0 NADH
#
# 1.0 m00800p + 1.0 m02552p --> 1.0 m00904p + 1.0 m02039p + 1.0 m02553p
# FLUX : 0.6138072116416102 --- ID : HMR_3064 --- COMPARTMENT : {'C_p'}
#
# SUBSYSTEM : Beta oxidation of even-chain fatty acids (peroxisomal) --- GENE NAME : EHHADH/HSD17B4
#
# ---
#
#
# 1.0 (2E)-tetracosenoyl-CoA + 1.0 H2O --> 1.0 3-hydroxytetracosanoyl-CoA
#
# 1.0 m00064p + 1.0 m02040p --> 1.0 m00800p
# FLUX : 0.6138072116416102 --- ID : HMR_3063 --- COMPARTMENT : {'C_p'}
#
# SUBSYSTEM : Beta oxidation of even-chain fatty acids (peroxisomal) --- GENE NAME : EHHADH
#
# ---
#
#
# 1.0 O2 + 1.0 tetracosanoyl-CoA --> 1.0 (2E)-tetracosenoyl-CoA + 1.0 H2O2
#
# 1.0 m02630p + 1.0 m02971p --> 1.0 m00064p + 1.0 m02041p
# FLUX : 0.6138072116416102 --- ID : HMR_3062 --- COMPARTMENT : {'C_p'}
#
# SUBSYSTEM : Beta oxidation of even-chain fatty acids (peroxisomal) --- GENE NAME : ACOX1/ACOX3
#
# ---
#
#
# 1.0 tetracosanoyl-CoA --> 1.0 tetracosanoyl-CoA
#
# 1.0 m02971c --> 1.0 m02971p
# FLUX : 0.4832811065741541 --- ID : HMR_3019 --- COMPARTMENT : {'C_p', 'C_c'}
#
# SUBSYSTEM : Transport, peroxisomal --- GENE NAME : ABCD1
#
# ---
#
#
 0.0001 10,13,16-docosatrienoyl-CoA + 0.0001 12,15,18,21-tetracosatetraenoyl-CoA + 0.0001 13,16,19-docosatrienoyl-CoA + 0.0001 5-tetradecenoyl-CoA + 0.014 7-hexadecenoyl-CoA + 0.0001 9-eicosenoyl-CoA + 0.0001 9-heptadecenoyl-CoA + 0.0264 arachidonyl-CoA + 0.0194 cis-vaccenoyl-CoA + 0.0141 dihomo-gamma-linolenoyl-CoA + 0.0001 docosanoyl-CoA + 0.0001 eicosanoyl-CoA + 0.0081 gamma-linolenoyl-CoA + 0.0001 heneicosanoyl-CoA + 0.0001 heptadecanoyl-CoA + 0.0001 hexacosanoyl-CoA + 0.0001 hexacosenoyl-CoA + 0.0001 lauroyl-CoA + 0.0023 linolenoyl-CoA + 0.278 linoleoyl-CoA + 0.003 myristoyl-CoA + 0.0001 nonadecanoyl-CoA + 0.4519 oleoyl-CoA + 0.0001 palmitoleoyl-CoA + 0.0849 palmitoyl-CoA + 0.0001 pentadecanoyl-CoA + 0.0584 stearoyl-CoA + 0.0001 tetracosanoyl-CoA + 0.0001 tricosanoyl-CoA + 0.0001 tridecanoyl-CoA --> 1.0 acyl-CoA-LD-TG3 pool
#
# 0.0001 m00004c + 0.0001 m00006c + 0.0001 m00007c + 0.0001 m00009c + 0.0001 m00012c + 0.0001 m00016c + 0.0001 m00018c + 0.0001 m00020c + 0.0001 m00023c + 0.0001 m00025c + 0.0011 m00093c + 0.0221 m00095c + 0.0001 m00101c + 0.0035 m00103c + 0.0001 m00106c + 0.0026 m00108c + 0.0001 m00110c + 0.0001 m00113c + 0.0001 m00116c + 0.0001 m00118c + 0.0022 m00119c + 0.0038 m00121c + 0.0001 m00123c + 0.0001 m00125c + 0.0001 m00127c + 0.0001 m00129c + 0.0001 m00131c + 0.0001 m00134c + 0.0001 m00262c + 0.0001 m00264c + 0.0001 m00317c + 0.0001 m00343c + 0.0001 m01141c + 0.014 m01191c + 0.0001 m01236c + 0.0001 m01237c + 0.0264 m01364c + 0.0194 m01586c + 0.0141 m01697c + 0.0001 m01725c + 0.0001 m01773c + 0.0081 m01934c + 0.0001 m02052c + 0.0001 m02101c + 0.0001 m02110c + 0.0001 m02112c + 0.0001 m02345c + 0.0023 m02390c + 0.278 m02391c + 0.003 m02495c + 0.0001 m02612c + 0.4519 m02647c + 0.0001 m02677c + 0.0849 m02678c + 0.0001 m02689c + 0.0584 m02941c + 0.0001 m02971c + 0.0001 m03047c + 0.0001 m03050c --> 1.0 m01277c
# FLUX : 70.05894475516479 --- ID : HMR_0547 --- COMPARTMENT : {'C_c'}
#
# SUBSYSTEM : Pool reactions --- GENE NAME :
#
# ---
#
#
# 1.0 (11Z)-docosenoyl-CoA + 1.0 AMP + 1.0 PPi <-- 1.0 ATP + 1.0 cis-cetoleic acid + 1.0 CoA
#
# 1.0 m00006c + 1.0 m01334c + 1.0 m02759c <-- 1.0 m01371c + 1.0 m01582c + 1.0 m01597c
# FLUX : -0.15899002962004688 --- ID : HMR_0323 --- COMPARTMENT : {'C_c'}
#
# SUBSYSTEM :
# 1.0 m01811c --> 0.0005 m00003c + 0.0005 m00008c + 0.0005 m00010c + 0.0005 m00017c + 0.0005 m00019c + 0.0005 m00021c + 0.0055 m00094c + 0.0005 m00104c + 0.0005 m00111c + 0.0005 m00114c + 0.0005 m00115c + 0.0005 m00117c + 0.0005 m00128c + 0.0005 m00132c + 0.0005 m00135c + 0.0005 m00260c + 0.0005 m00265c + 0.0005 m00315c + 0.0005 m00341c + 0.0005 m01197c + 0.0005 m01207c + 0.0005 m01235c + 0.0005 m01238c + 0.0043 m01291c + 0.2005 m01362c + 0.0005 m01373c + 0.0005 m01432c + 0.0005 m01582c + 0.0005 m01583c + 0.0005 m01584c + 0.0131 m01585c + 0.0931 m01689c + 0.0089 m01696c + 0.0329 m01741c + 0.0005 m01771c + 0.0005 m01778c + 0.0286 m01784c + 0.0011 m01932c + 0.0005 m02053c + 0.0005 m02344c + 0.0005 m02385c + 0.0177 m02387c + 0.0035 m02389c + 0.0005 m02456c + 0.0005 m02457c + 0.0055 m02494c + 0.0005 m02564c + 0.0005 m02613c + 0.0323 m02646c + 0.0174 m02648c + 0.0337 m02674c + 0.0058 m02675c + 0.0005 m02690c + 0.0005 m02745c + 0.4731 m02938c + 0.0025 m02939c + 0.0005 m03045c + 0.0005 m03051c + 0.0005 m03153c
# FLUX : 192.63953529575244 --- ID : HMR_0690 --- COMPARTMENT : {'C_c'}
#
# SUBSYSTEM : Pool reactions --- GENE NAME :
#
# ---
#
#
# 1.0 1-acylglycerol-LD-PS pool + 1.0 H2O --> 1.0 fatty acid-LD-PS pool + 1.0 glycerol
#
# 1.0 m00507c + 1.0 m02040c --> 1.0 m01811c + 1.0 m01983c
# FLUX : 96.31976764787622 --- ID : HMR_0682 --- COMPARTMENT : {'C_c'}
#
# SUBSYSTEM : Acylglycerides metabolism --- GENE NAME : MGLL/ABHD6
#
# ---
#
#
# 1.0 1,2-diacylglycerol-LD-PS pool + 1.0 H2O --> 1.0 1-acylglycerol-LD-PS pool + 1.0 fatty acid-LD-PS pool
#
# 1.0 m00238c + 1.0 m02040c --> 1.0 m00507c + 1.0 m01811c
# FLUX : 96.31976764787622 --- ID : HMR_0671 --- COMPARTMENT : {'C_c'}
#
# SUBSYSTEM : Acylglycerides metabolism --- GENE NAME : CEL/PNLIPRP1/LIPF/LIPE/PNLIPRP3/PNPLA4/PNPLA3/AADAC/LIPG/LIPC/PNLIPRP2/PNLIP
#
# ---
#
#
# 1.0 H2O + 1.0 phosphatidate-LD-PS pool --> 1.0 1,2-diacylglycerol-LD-PS pool + 1.0 Pi
#
# 1.0 m02040c + 1.0 m02731c --> 1.0 m00238c + 1.0 m02751c
# FLUX : 96.31976764787622 --- ID : HMR_0599 --- COMPARTMENT : {'C_c'}
#
# SUBSYSTEM : Glycerophospholipid metabolism --- GENE NAME : PLPP5/LPIN1/PLPPR4/PLPP3/PLPP4/LPIN2/PLPPR2/PLPP1/PLPP2
#
# ---
#
#
# 1.0 H2O + 1.0 PS-LD pool --> 1.0 phosphatidate-LD-PS pool + 1.0 serine
#
# 1.0 m02040c + 1.0 m02808c --> 1.0 m02731c + 1.0 m02896c
# FLUX : 96.31976764787622 --- ID : HMR_0660 --- COMPARTMENT : {'C_c'}
#
# SUBSYSTEM : Glycerophospholipid metabolism --- GENE NAME : PLD1/PLD3/PLD2
#
# ---
#
#
# 1.0 PC-LD pool + 1.0 serine --> 1.0 choline + 1.0 PS-LD pool
#
# 1.0 m02684c + 1.0 m02896c --> 1.0 m01513c + 1.0 m02808c
# FLUX : 64.6518445594943 --- ID : HMR_0623 --- COMPARTMENT : {'C_c'}
#
# SUBSYSTEM : Glycerophospholipid metabolism --- GENE NAME : PTDSS1
#
# ---
#
#
# 1.0 cholesterol + 1.0 PC-LD pool --> 1.0 2-lysolecithin pool + 1.0 cholesterol-ester pool
#
# 1.0 m01450c + 1.0 m02684c --> 1.0 m00656c + 1.0 m01451c
# FLUX : 54.13645731080916 --- ID : HMR_0634 --- COMPARTMENT : {'C_c'}
#
# SUBSYSTEM : Glycerophospholipid metabolism --- GENE NAME : LCAT
#
# ---
#
#
# 1.0 cholesterol <-- 1.0 cholesterol
#
# 1.0 m01450c <-- 1.0 m01450m
# FLUX : -214.15745612658327 --- ID : HMR_1915 --- COMPARTMENT : {'C_c', 'C_m'}
#
# SUBSYSTEM : Transport, mitochondrial --- GENE NAME :
#
# ---
#
#
# 1.0 cholesterol + 1.0 H+ + 1.0 NADPH + 2.0 O2 --> 2.0 H2O + 1.0 isocaproic-aldehyde + 1.0 NADP+ + 1.0 pregnenolone
#
# 1.0 m01450m + 1.0 m02039m + 1.0 m02555m + 2.0 m02630m --> 2.0 m02040m + 1.0 m02182m + 1.0 m02554m + 1.0 m02763m
# FLUX : 132.18440355353056 --- ID : HMR_7935 --- COMPARTMENT : {'C_m'}
#
# SUBSYSTEM : Steroid metabolism --- GENE NAME : CYP11A1
#
# ---
#
#
# 1.0 isocaproic-aldehyde --> 1.0 isocaproic-aldehyde
#
# 1.0 m02182m --> 1.0 m02182c
# FLUX : 132.18440355353056 --- ID : HMR_1930 --- COMPARTMENT : {'C_c', 'C_m'}
#
# SUBSYSTEM : Transport, mitochondrial --- GENE NAME :
#
# ---
#
#
# 1.0 isocaproic-aldehyde --> 1.0 isocaproic-aldehyde
#
# 1.0 m02182c --> 1.0 m02182s
# FLUX : 132.18440355353056 --- ID : HMR_8100 --- COMPARTMENT : {'C_s', 'C_c'}
#
# SUBSYSTEM : Transport, extracellular --- GENE NAME :
#
# ---
#
#
# 1.0 isocaproic-aldehyde <-- 1.0 isocaproic-aldehyde
#
# 1.0 m02182x <-- 1.0 m02182s
# FLUX : -132.18440355353056 --- ID : HMR_9225 --- COMPARTMENT : {'C_s', 'C_x'}
#
# SUBSYSTEM : Exchange reactions --- GENE NAME :
#
# ---
#
#
# <-- 1.0 isocaproic-aldehyde
#
# <-- 1.0 m02182x
# FLUX : -132.18440355353056 --- ID : EX_m02182x --- COMPARTMENT : {'C_x'}
#
# SUBSYSTEM :  --- GENE NAME : EX_m02182x
#
# ---
#
#
# 1.0 pregnenolone <-- 1.0 pregnenolone
#
# 1.0 m02763c <-- 1.0 m02763m
# FLUX : -132.18440355353056 --- ID : HMR_1936 --- COMPARTMENT : {'C_c', 'C_m'}
#
# SUBSYSTEM : Transport, mitochondrial --- GENE NAME :
#
# ---
#
#
# 1.0 NAD+ + 1.0 pregnenolone --> 1.0 H+ + 1.0 NADH + 1.0 pregn-5-ene-3,20-dione
#
# 1.0 m02552c + 1.0 m02763c --> 1.0 m02039c + 1.0 m02553c + 1.0 m02760c
# FLUX : 132.18440355353056 --- ID : HMR_1979 --- COMPARTMENT : {'C_c'}
#
# SUBSYSTEM : Glucocorticoid biosynthesis --- GENE NAME : HSD3B1/HSD3B2
#
# ---
#
#
# 1.0 pregn-5-ene-3,20-dione --> 1.0 progesterone
#
# 1.0 m02760c --> 1.0 m02769c
# FLUX : 132.18440355353056 --- ID : HMR_1980 --- COMPARTMENT : {'C_c'}
#
# SUBSYSTEM : Glucocorticoid biosynthesis --- GENE NAME : HSD3B1/HSD3B2
#
# ---
#
#
# 1.0 progesterone --> 1.0 progesterone
#
# 1.0 m02769c --> 1.0 m02769s
# FLUX : 132.18440355353056 --- ID : HMR_8931 --- COMPARTMENT : {'C_s', 'C_c'}
#
# SUBSYSTEM : Transport, extracellular --- GENE NAME :
#
# ---
#
#
# 1.0 progesterone <-- 1.0 progesterone
#
# 1.0 m02769x <-- 1.0 m02769s
# FLUX : -132.18440355353056 --- ID : HMR_9393 --- COMPARTMENT : {'C_s', 'C_x'}
#
# SUBSYSTEM : Exchange reactions --- GENE NAME :
#
# ---
#
#
# <-- 1.0 progesterone
#
# <-- 1.0 m02769x
# FLUX : -132.18440355353056 --- ID : EX_m02769x --- COMPARTMENT : {'C_x'}
#
# SUBSYSTEM :  --- GENE NAME : EX_m02769x
#
# ---
#
#
# 1.0 cholesterol --> 1.0 cholesterol
#
# 1.0 m01450l --> 1.0 m01450m
# FLUX : 346.3418596801138 --- ID : HMR_5046 --- COMPARTMENT : {'C_l', 'C_m'}
#
# SUBSYSTEM : Transport, mitochondrial --- GENE NAME : STARD3
#
# ---
#
#
# 1.0 cholesterol-ester-11-eico + 1.0 H2O --> 1.0 cholesterol + 1.0 cis-gondoic acid
#
# 1.0 m01458l + 1.0 m02040l --> 1.0 m01450l + 1.0 m01584l
# FLUX : 0.025860119086769943 --- ID : HMR_3561 --- COMPARTMENT : {'C_l'}
#
# SUBSYSTEM : Formation and hydrolysis of cholesterol esters --- GENE NAME : CEL/LIPA
#
# ---
#
#
# 1.0 cholesterol-ester pool --> 0.0001 cholesterol-ester-10,13,16,19-docosa + 0.0001 cholesterol-ester-10,13,16-docosa + 0.0001 cholesterol-ester-10-hepta + 0.0001 cholesterol-ester-11,14,17-eico + 0.0001 cholesterol-ester-11,14-eicosa + 0.0001 cholesterol-ester-11-docose + 0.0001 cholesterol-ester-11-eico + 0.0001 cholesterol-ester-12,15,18,21-tetracosa + 0.0001 cholesterol-ester-13,16,19-doco + 0.0001 cholesterol-ester-13,16-docosa + 0.0001 cholesterol-ester-13-docose + 0.0001 cholesterol-ester-13-eicose + 0.0001 cholesterol-ester-13-octade + 0.0001 cholesterol-ester-15-tetra + 0.0041 cholesterol-ester-4,7,10,13,16,19-doco + 0.0001 cholesterol-ester-4,7,10,13,16-docosa + 0.0071 cholesterol-ester-5,8,11,14,17-eico + 0.0001 cholesterol-ester-5,8,11-eico + 0.0001 cholesterol-ester-5-tetra + 0.0001 cholesterol-ester-6,9,12,15,18,21-tetra + 0.0001 cholesterol-ester-6,9,12,15,18-tetraco + 0.0001 cholesterol-ester-6,9,12,15-octa + 0.0001 cholesterol-ester-6,9-octa + 0.0001 cholesterol-ester-7,10,13,16,19-docosa + 0.0001 cholesterol-ester-7,10,13,16-docosa + 0.0406 cholesterol-ester-7-hexa + 0.0001 cholesterol-ester-7-octade + 0.0001 cholesterol-ester-7-tetrade + 0.0001 cholesterol-ester-8,11,14,17-eico + 0.0001 cholesterol-ester-8,11-eico + 0.0001 cholesterol-ester-9,12,15,18,21-tetra + 0.0001 cholesterol-ester-9,12,15,18-tetraco + 0.0001 cholesterol-ester-9-eicose + 0.0001 cholesterol-ester-9-heptade + 0.0001 cholesterol-ester-9-octa + 0.0001 cholesterol-ester-9-tetrade + 0.0518 cholesterol-ester-arach + 0.0001 cholesterol-ester-cis-vac + 0.005 cholesterol-ester-dihomo-gamma + 0.0001 cholesterol-ester-docosa + 0.0001 cholesterol-ester-eico + 0.0001 cholesterol-ester-gamma-lin + 0.0001 cholesterol-ester-heneico + 0.0001 cholesterol-ester-hepta + 0.0001 cholesterol-ester-hexacosa + 0.0001 cholesterol-ester-hexecose + 0.0001 cholesterol-ester-laur + 0.5254 cholesterol-ester-lin + 0.0061 cholesterol-ester-linolen + 0.0081 cholesterol-ester-myrist + 0.0001 cholesterol-ester-nanode + 0.1958 cholesterol-ester-ol + 0.138 cholesterol-ester-palm + 0.0001 cholesterol-ester-palmn + 0.0001 cholesterol-ester-penta + 0.0132 cholesterol-ester-stea + 0.0001 cholesterol-ester-tetraco + 0.0001 cholesterol-ester-trico + 0.0001 cholesterol-ester-tridec
#
# 1.0 m01451l --> 0.0001 m01452l + 0.0001 m01453l + 0.0001 m01454l + 0.0001 m01455l + 0.0001 m01456l + 0.0001 m01457l + 0.0001 m01458l + 0.0001 m01459l + 0.0001 m01460l + 0.0001 m01461l + 0.0001 m01462l + 0.0001 m01463l + 0.0001 m01464l + 0.0001 m01465l + 0.0041 m01466l + 0.0001 m01467l + 0.0071 m01468l + 0.0001 m01469l + 0.0001 m01470l + 0.0001 m01471l + 0.0001 m01472l + 0.0001 m01473l + 0.0001 m01474l + 0.0001 m01475l + 0.0001 m01476l + 0.0406 m01477l + 0.0001 m01478l + 0.0001 m01479l + 0.0001 m01480l + 0.0001 m01481l + 0.0001 m01482l + 0.0001 m01483l + 0.0001 m01484l + 0.0001 m01485l + 0.0001 m01486l + 0.0001 m01487l + 0.0518 m01488l + 0.0001 m01489l + 0.005 m01490l + 0.0001 m01491l + 0.0001 m01492l + 0.0001 m01493l + 0.0001 m01494l + 0.0001 m01495l + 0.0001 m01496l + 0.0001 m01497l + 0.0001 m01498l + 0.5254 m01499l + 0.0061 m01500l + 0.0081 m01501l + 0.0001 m01502l + 0.1958 m01503l + 0.138 m01504l + 0.0001 m01505l + 0.0001 m01506l + 0.0132 m01507l + 0.0001 m01508l + 0.0001 m01509l + 0.0001 m01510l
# FLUX : 258.6011908676994 --- ID : HMR_3537 --- COMPARTMENT : {'C_l'}
#
# SUBSYSTEM : Formation and hydrolysis of cholesterol esters --- GENE NAME :
#
# ---
#
#
# 1.0 cholesterol-ester pool --> 1.0 cholesterol-ester pool
#
# 1.0 m01451l --> 1.0 m01451r
# FLUX : 159.22487444355636 --- ID : HMR_3597 --- COMPARTMENT : {'C_l', 'C_r'}
#
# SUBSYSTEM : Transport, lysosome to ER --- GENE NAME :
#
# ---
#
#
# 1.0 cholesterol-ester pool --> 1.0 cholesterol-ester pool
#
# 1.0 m01451x --> 1.0 m01451l
# FLUX : 129.15926491842254 --- ID : HMR_9736 --- COMPARTMENT : {'C_x', 'C_l'}
#
# SUBSYSTEM : Exchange reactions --- GENE NAME : Fake cholesterol Uptake
#
# ---
#
#
# --> 1.0 cholesterol-ester pool
#
# --> 1.0 m01451x
# FLUX : 129.15926491842254 --- ID : EX_m01451x --- COMPARTMENT : {'C_x'}
#
# SUBSYSTEM :  --- GENE NAME : EX_m01451x
#
# ---
#
#
# 1.0 cholesterol-ester-10,13,16,19-docosa + 1.0 H2O --> 1.0 10,13,16,19-docosatetraenoic acid + 1.0 cholesterol
#
# 1.0 m01452l + 1.0 m02040l --> 1.0 m00260l + 1.0 m01450l
# FLUX : 0.025860119086769943 --- ID : HMR_3584 --- COMPARTMENT : {'C_l'}
#
# SUBSYSTEM : Formation and hydrolysis of cholesterol esters --- GENE NAME : CEL/LIPA
#
# ---
#
#
# 1.0 10,13,16,19-docosatetraenoic acid --> 1.0 10,13,16,19-docosatetraenoic acid
#
# 1.0 m00260l --> 1.0 m00260c
# FLUX : 0.025860119086769943 --- ID : HMR_9753 --- COMPARTMENT : {'C_l', 'C_c'}
#
# SUBSYSTEM : Transport, lysosome to cytosol --- GENE NAME :
#
# ---
#
#
# 1.0 10,13,16,19-docosatetraenoic acid --> 1.0 10,13,16,19-docosatetraenoic acid
#
# 1.0 m00260s --> 1.0 m00260c
# FLUX : 0.050393571643813986 --- ID : HMR_0388 --- COMPARTMENT : {'C_s', 'C_c'}
#
# SUBSYSTEM : Transport, extracellular --- GENE NAME : FABP5/SLC27A1/FABP1/FABP12/SLC27A3/SLC27A4/FABP4/SLC27A6
#
# ---
#
#
# 1.0 NEFA blood pool in --> 0.0048 (10Z)-heptadecenoic acid + 0.0016 (11Z,14Z)-eicosadienoic acid + 0.0016 (11Z,14Z,17Z)-eicosatrienoic acid + 0.0001 (13Z)-eicosenoic acid + 0.0001 (13Z)-octadecenoic acid + 0.0001 (13Z,16Z)-docosadienoic acid + 0.0001 (4Z,7Z,10Z,13Z,16Z)-DPA + 0.0001 (6Z,9Z)-octadecadienoic acid + 0.0001 (6Z,9Z,12Z,15Z,18Z)-TPA + 0.0001 (6Z,9Z,12Z,15Z,18Z,21Z)-THA + 0.0001 (7Z)-octadecenoic acid + 0.0001 (7Z)-tetradecenoic acid + 0.0001 (9E)-tetradecenoic acid + 0.0001 (9Z,12Z,15Z,18Z)-TTA + 0.0001 (9Z,12Z,15Z,18Z,21Z)-TPA + 0.0001 10,13,16,19-docosatetraenoic acid + 0.0001 10,13,16-docosatriynoic acid + 0.0001 12,15,18,21-tetracosatetraenoic acid + 0.0001 13,16,19-docosatrienoic acid + 0.0001 7-palmitoleic acid + 0.0001 8,11-eicosadienoic acid + 0.0001 9-eicosenoic acid + 0.0001 9-heptadecylenic acid + 0.0017 adrenic acid + 0.0137 arachidonate + 0.0007 behenic acid + 0.0005 cerotic acid + 0.0001 cis-cetoleic acid + 0.0002 cis-erucic acid + 0.0001 cis-gondoic acid + 0.0001 cis-vaccenic acid + 0.0046 DHA + 0.0025 dihomo-gamma-linolenate + 0.0019 DPA + 0.0011 eicosanoate + 0.0001 elaidate + 0.002 EPA + 0.0048 gamma-linolenate + 0.0001 henicosanoic acid + 0.0034 lauric acid + 0.0012 lignocerate + 0.071 linoleate + 0.0005 linolenate + 0.0056 margaric acid + 0.0005 mead acid + 0.0283 myristic acid + 0.0003 nervonic acid + 0.0001 nonadecylic acid + 0.3746 oleate + 0.0001 omega-3-arachidonic acid + 0.2949 palmitate + 0.0686 palmitolate + 0.003 pentadecylic acid + 0.0001 physeteric acid + 0.1031 stearate + 0.0001 stearidonic acid + 0.0002 tricosanoic acid + 0.0001 tridecylic acid + 0.0001 ximenic acid
#
# 1.0 m02560s --> 0.0048 m00003s + 0.0016 m00008s + 0.0016 m00010s + 0.0001 m00017s + 0.0001 m00019s + 0.0001 m00021s + 0.0001 m00094s + 0.0001 m00104s + 0.0001 m00111s + 0.0001 m00114s + 0.0001 m00115s + 0.0001 m00117s + 0.0001 m00128s + 0.0001 m00132s + 0.0001 m00135s + 0.0001 m00260s + 0.0001 m00265s + 0.0001 m00315s + 0.0001 m00341s + 0.0001 m01197s + 0.0001 m01207s + 0.0001 m01235s + 0.0001 m01238s + 0.0017 m01291s + 0.0137 m01362s + 0.0007 m01373s + 0.0005 m01432s + 0.0001 m01582s + 0.0002 m01583s + 0.0001 m01584s + 0.0001 m01585s + 0.0046 m01689s + 0.0025 m01696s + 0.0019 m01741s + 0.0011 m01771s + 0.0001 m01778s + 0.002 m01784s + 0.0048 m01932s + 0.0001 m02053s + 0.0034 m02344s + 0.0012 m02385s + 0.071 m02387s + 0.0005 m02389s + 0.0056 m02456s + 0.0005 m02457s + 0.0283 m02494s + 0.0003 m02564s + 0.0001 m02613s + 0.3746 m02646s + 0.0001 m02648s + 0.2949 m02674s + 0.0686 m02675s + 0.003 m02690s + 0.0001 m02745s + 0.1031 m02938s + 0.0001 m02939s + 0.0002 m03045s + 0.0001 m03051s + 0.0001 m03153s
# FLUX : 503.9357164381398 --- ID : HMR_0015 --- COMPARTMENT : {'C_s'}
#
# SUBSYSTEM : Transport, extracellular --- GENE NAME :
#
# ---
#
#
# 1.0 NEFA blood pool in --> 1.0 NEFA blood pool in
#
# 1.0 m02560x --> 1.0 m02560s
# FLUX : 503.9357164381398 --- ID : HMR_9033 --- COMPARTMENT : {'C_s', 'C_x'}
#
# SUBSYSTEM : Exchange reactions --- GENE NAME :
#
# ---
#
#
# --> 1.0 NEFA blood pool in
#
# --> 1.0 m02560x
# FLUX : 503.9357164381398 --- ID : EX_m02560x --- COMPARTMENT : {'C_x'}
#
# SUBSYSTEM :  --- GENE NAME : EX_m02560x
#
# ---
#
#
# 1.0 (10Z)-heptadecenoic acid --> 1.0 (10Z)-heptadecenoic acid
#
# 1.0 m00003s --> 1.0 m00003c
# FLUX : 2.418891438903071 --- ID : HMR_0240 --- COMPARTMENT : {'C_s', 'C_c'}
#
# SUBSYSTEM : Transport, extracellular --- GENE NAME : FABP5/SLC27A1/FABP1/FABP12/SLC27A3/SLC27A4/FABP4/SLC27A6
#
# ---
#
#
# 1.0 (10Z)-heptadecenoic acid + 1.0 ATP + 1.0 CoA --> 1.0 (10Z)-heptadecenoyl-CoA + 1.0 AMP + 1.0 PPi
#
# 1.0 m00003c + 1.0 m01371c + 1.0 m01597c --> 1.0 m00004c + 1.0 m01334c + 1.0 m02759c
# FLUX : 2.527487896879304 --- ID : HMR_0241 --- COMPARTMENT : {'C_c'}
#
# SUBSYSTEM :
0.0285 m01585c + 0.0459 m01689c + 0.0411 m01696c + 0.0067 m01741c + 0.0005 m01771c + 0.0005 m01778c + 0.0221 m01784c + 0.0011 m01932c + 0.0005 m02053c + 0.0005 m02344c + 0.0005 m02385c + 0.1312 m02387c + 0.0166 m02389c + 0.0005 m02456c + 0.0005 m02457c + 0.0319 m02494c + 0.0005 m02564c + 0.0005 m02613c + 0.0619 m02646c + 0.0163 m02648c + 0.1243 m02674c + 0.0327 m02675c + 0.0005 m02690c + 0.0005 m02745c + 0.1983 m02938c + 0.0025 m02939c + 0.0005 m03045c + 0.0005 m03051c + 0.0005 m03153c
# FLUX : 0.22291482422097889 --- ID : HMR_0689 --- COMPARTMENT : {'C_c'}
#
# SUBSYSTEM : Pool reactions --- GENE NAME :
#
# ---
#
#
# 1.0 H2O + 1.0 PE-LD pool --> 1.0 1-acyl-PE pool + 1.0 fatty acid-LD-PE pool
#
# 1.0 m02040c + 1.0 m02685c --> 1.0 m00511c + 1.0 m01809c
# FLUX : 0.22291482422097889 --- ID : HMR_0643 --- COMPARTMENT : {'C_c'}
#
# SUBSYSTEM : Glycerophospholipid metabolism --- GENE NAME : PLA2G2A/PLB1/JMJD7-PLA2G4B/PLAAT3/PLA2G10/PLA2G4E/PLA2G4C/PLA2G2E/PLA2G2D/PLA2G5/PLA2G4D/PLA2G3/PLA2G4F/PLA2G4A/PLA2G1B/PLA2G12A/PLA2G6/PLA2G2F
#
# ---
#
#
# 1.0 PE-LD pool <-- 1.0 PE-LD pool
#
# 1.0 m02685c <-- 1.0 m02685r
# FLUX : -32.46404746059971 --- ID : HMR_0464 --- COMPARTMENT : {'C_c', 'C_r'}
#
# SUBSYSTEM : Transport, endoplasmic reticular --- GENE NAME :
#
# ---
#
#
# 1.0 PE-LD pool --> 1.0 PE-LD pool
#
# 1.0 m02685l --> 1.0 m02685r
# FLUX : 32.464047460592184 --- ID : HMR_5252 --- COMPARTMENT : {'C_l', 'C_r'}
#
# SUBSYSTEM : Transport, lysosome to ER --- GENE NAME :
#
# ---
#
#
# 1.0 PE-LD pool + 1.0 serine --> 1.0 ethanolamine + 1.0 PS-LD pool
#
# 1.0 m02685c + 1.0 m02896c --> 1.0 m01797c + 1.0 m02808c
# FLUX : 31.69976806327064 --- ID : HMR_0622 --- COMPARTMENT : {'C_c'}
#
# SUBSYSTEM : Glycerophospholipid metabolism --- GENE NAME : PTDSS2
#
# ---
#
#
# 1.0 serine --> 1.0 serine
#
# 1.0 m02896s --> 1.0 m02896c
# FLUX : 73.52562378139167 --- ID : HMR_5079 --- COMPARTMENT : {'C_s', 'C_c'}
#
# SUBSYSTEM : Transport, extracellular --- GENE NAME : SLC7A1/SLC7A5/SLC7A8/SLC43A1/SLC7A2/SLC36A1/SLC43A2/SLC3A2/SLC7A7/SLC7A10/SLC7A3
#
# ---
#
#
# 1.0 serine --> 1.0 serine
#
# 1.0 m02896x --> 1.0 m02896s
# FLUX : 73.52562378139167 --- ID : HMR_9069 --- COMPARTMENT : {'C_s', 'C_x'}
#
# SUBSYSTEM : Exchange reactions --- GENE NAME :
#
# ---
#
#
# --> 1.0 serine
#
# --> 1.0 m02896x
# FLUX : 73.52562378139167 --- ID : EX_m02896x --- COMPARTMENT : {'C_x'}
#
# SUBSYSTEM :  --- GENE NAME : EX_m02896x
#
# ---
#
#
# 1.0 serine --> 1.0 serine
#
# 1.0 m02896c --> 1.0 m02896p
# FLUX : 0.25475979910969215 --- ID : HMR_4468 --- COMPARTMENT : {'C_p', 'C_c'}
#
# SUBSYSTEM : Transport, peroxisomal --- GENE NAME :
#
# ---
#
#
# 1.0 serine --> 1.0 serine
#
# 1.0 m02896l --> 1.0 m02896c
# FLUX : 85.98585543616309 --- ID : HMR_5060 --- COMPARTMENT : {'C_l', 'C_c'}
#
# SUBSYSTEM : Transport, lysosomal --- GENE NAME : SLC36A1
#
# ---
#
#
# 1.0 apoB100_ + 2280.0 ATP + 2280.0 H2O --> 2280.0 ADP + 275.0 alanine + 150.0 arginine + 247.0 asparagine + 233.0 aspartate + 25.0 cysteine + 298.0 glutamate + 230.0 glutamine + 207.0 glycine + 115.0 histidine + 285.0 isoleucine + 533.0 leucine + 357.0 lysine + 79.0 methionine + 224.0 phenylalanine + 2280.0 Pi + 171.0 proline + 392.0 serine + 300.0 threonine + 37.0 tryptophan + 151.0 tyrosine + 252.0 valine
#
# 1.0 m01351l + 2280.0 m01371l + 2280.0 m02040l --> 2280.0 m01285l + 275.0 m01307l + 150.0 m01365l + 247.0 m01369l + 233.0 m01370l + 25.0 m01628l + 298.0 m01974l + 230.0 m01975l + 207.0 m01986l + 115.0 m02125l + 285.0 m02184l + 533.0 m02360l + 357.0 m02426l + 79.0 m02471l + 224.0 m02724l + 2280.0 m02751l + 171.0 m02770l + 392.0 m02896l + 300.0 m02993l + 37.0 m03089l + 151.0 m03101l + 252.0 m03135l
# FLUX : 0.17548133762482263 --- ID : HMR_5265 --- COMPARTMENT : {'C_l'}
#
# SUBSYSTEM : Protein degradation --- GENE NAME : CTSK/CTSW/TPP1/CTSE/CTSH/CTSA/CTSF/CTSZ/CTSD/CTSO/CTSC/CTSV/CTSL/CTSB
#
# ---
#
#
# 1.0 alanine --> 1.0 alanine
#
# 1.0 m01307l --> 1.0 m01307c
# FLUX : 96.1637730184028 --- ID : HMR_5064 --- COMPARTMENT : {'C_l', 'C_c'}
#
# SUBSYSTEM : Transport, lysosomal --- GENE NAME : SLC36A1
#
# ---
#
#
# 1.0 arginine --> 1.0 arginine
#
# 1.0 m01365l --> 1.0 m01365c
# FLUX : 68.08675899843118 --- ID : HMR_5048 --- COMPARTMENT : {'C_l', 'C_c'}
#
# SUBSYSTEM : Transport, lysosomal --- GENE NAME : SLC36A1
#
# ---
#
#
# 1.0 arginine + 1.0 glycine --> 1.0 arginine + 1.0 glycine
#
# 1.0 m01365s + 1.0 m01986c --> 1.0 m01365c + 1.0 m01986s
# FLUX : 518.3409197344257 --- ID : HMR_5923 --- COMPARTMENT : {'C_s', 'C_c'}
#
# SUBSYSTEM : Transport, extracellular --- GENE NAME : SLC7A6/SLC7A9/SLC3A1
#
# ---
#
#
# 1.0 arginine --> 1.0 arginine
#
# 1.0 m01365x --> 1.0 m01365s
# FLUX : 91.1381154451152 --- ID : HMR_9066 --- COMPARTMENT : {'C_s', 'C_x'}
#
# SUBSYSTEM : Exchange reactions --- GENE NAME :
#
# ---
#
#
# --> 1.0 arginine
#
# --> 1.0 m01365x
# FLUX : 91.1381154451152 --- ID : EX_m01365x --- COMPARTMENT : {'C_x'}
#
# SUBSYSTEM :  --- GENE NAME : EX_m01365x
#
# ---
#
#
# 1.0 arginine + 1.0 Na+ + 1.0 threonine --> 1.0 arginine + 1.0 Na+ + 1.0 threonine
#
# 1.0 m01365c + 1.0 m02519s + 1.0 m02993s --> 1.0 m01365s + 1.0 m02519c + 1.0 m02993c
# FLUX : 427.2028042893105 --- ID : HMR_5893 --- COMPARTMENT : {'C_s', 'C_c'}
#
# SUBSYSTEM : Transport, extracellular --- GENE NAME : SLC7A6
#
# ---
#
#
# 1.0 leucine + 1.0 threonine <-- 1.0 leucine + 1.0 threonine
#
# 1.0 m02360c + 1.0 m02993s <-- 1.0 m02360s + 1.0 m02993c
# FLUX : -335.36276349368603 --- ID : HMR_5560 --- COMPARTMENT : {'C_s', 'C_c'}
#
# SUBSYSTEM : Transport, extracellular --- GENE NAME : SLC7A5
#
# ---
#
#
# 1.0 leucine --> 1.0 leucine
#
# 1.0 m02360l --> 1.0 m02360c
# FLUX : 143.89469685235457 --- ID : HMR_5055 --- COMPARTMENT : {'C_l', 'C_c'}
#
# SUBSYSTEM : Transport, lysosomal --- GENE NAME : SLC36A1
#
# ---
#
#
# 1.0 leucine --> 1.0 leucine
#
# 1.0 m02360c --> 1.0 m02360s
# ...
#  'HMR_0372': 0.050393571643813986,
#  'HMR_0528': 0.07965207645252059,
#  'HMR_0369': 0.15899002962004688,
#  'HMR_0368': 0.050393571643813986,
#  'HMR_9752': 0.025860119086769943,
#  'HMR_3579': 0.025860119086769943,
#  'HMR_2493': 3.129098310197225,
#  'HMR_2491': 3.129098310197225,
#  'HMR_2489': 3.129098310197225,
#  'HMR_2486': 3.129098310197225,
#  'HMR_0525': 0.685007857491677,
#  'HMR_2720': -9.075351558597989,
#  'HMR_2865': -9.075351558597989,
#  'HMR_2866': 9.075351558597989,
#  'HMR_2984': -9.075351558597989,
#  'HMR_2949': -61.02398450137267,
#  'HMR_2803': -61.02398450137267,
#  'HMR_2801': 61.02398450137267,
#  'HMR_2626': 61.02398450137267,
#  'HMR_0217': -199.14095257125368,
#  'HMR_0216': 148.61064277760744,
#  'HMR_9788': 35.686964339742524,
#  'HMR_3545': 35.686964339742524,
#  'HMR_9678': 0.6138072116416102,
#  'HMR_0709': 0.48642731208676515,
#  'HMR_2190': 60.606568366108625,
#  'HMR_2191': 60.606568366108625,
#  'HMR_2193': 60.606568366108625,
#  'HMR_2194': 60.606568366108625,
#  'HMR_2296': 0.3721345741434462,
#  'HMR_0504': 0.07965207645252059,
#  'HMR_2347': 0.14209636301559958,
#  'HMR_2348': 0.14209636301559958,
#  'HMR_2349': 0.14209636301559958,
#  'HMR_2350': 0.14209636301559958,
#  'HMR_0297': 0.15899002962004688,
#  'HMR_0296': 0.050393571643813986,
#  'HMR_9759': 0.025860119086769943,
#  'HMR_3562': 0.025860119086769943,
#  'HMR_2353': 0.07104818150779979,
#  'HMR_2354': 0.07104818150779979,
#  'HMR_2355': 0.07104818150779979,
#  'HMR_2356': 0.07104818150779979,
#  'HMR_0510': 0.07965207645252059,
#  'HMR_2293': 21.657495930981504,
#  'HMR_0249': -153.29169786704998,
#  'HMR_9792': 3.413535719453632,
#  'HMR_3827': -467.1822809505695,
#  'HMR_4141': -467.1822809505695,
#  'HMR_6522': -380.7398158213411,
#  'HMR_4410': 1000.0,
#  'HMR_4964': 152.07790322808938,
#  'HMR_4957': 152.07790322808938,
#  'HMR_3825': 110.934697379147,
#  'HMR_3829': -637.6433788292893,
#  'HMR_9737': 1000.0,
#  'HMR_9070': -1000.0,
#  'EX_m01370x': -1000.0,
#  'HMR_5050': 54.39921466369501,
#  'HMR_6034': 1000.0,
#  'HMR_0155': -1000.0,
#  'HMR_9086': -1000.0,
#  'EX_m01252x': -1000.0,
#  'HMR_6015': -73.24489795373096,
#  'HMR_9133': 63.061101425143534,
#  'EX_m02819x': 63.061101425143534,
#  'HMR_6016': 136.30599937887453,
#  'HMR_6041': 136.30599937887453,
#  'HMR_5015': 136.30599937887453,
#  'HMR_4461': -136.30599937887453,
#  'HMR_9134': -136.30599937887453,
#  'EX_m00157x': -136.30599937887453,
#  'HMR_4358': 339.3719247248139,
#  'HMR_4363': 1000.0,
#  'HMR_4365': -1000.0,
#  'HMR_4368': 1000.0,
#  'HMR_4373': -1000.0,
#  'HMR_4193': 660.6280752751861,
#  'HMR_4930': 108.74911518949939,
#  'HMR_3256': 35.37391499442641,
#  'HMR_3254': 35.37391499442641,
#  'HMR_3252': 35.37391499442641,
#  'HMR_3250': 35.37391499442641,
#  'HMR_2640': 35.37391499442641,
#  'HMR_2638': -35.37391499442641,
#  'HMR_2636': -35.37391499442641,
#  'HMR_0494': 0.07965207645252059,
#  'HMR_0226': -35.603953205554255,
#  'HMR_9789': 0.025860119086769943,
#  'HMR_3547': 0.025860119086769943,
#  'HMR_0225': 34.56999014765639,
#  'HMR_0490': 0.07965207645252059,
#  'HMR_0204': 0.1589900296200426,
#  'HMR_9749': 0.025860119086769943,
#  'HMR_3542': 0.025860119086769943,
#  'HMR_0203': 0.050393571643813986,
#  'HMR_2281': 0.07104818150779976,
#  'HMR_0196': -13.21944810636587,
#  'HMR_9783': 2.094669646028365,
#  'HMR_3540': 2.094669646028365,
#  'HMR_8037': 4.347846527142998,
#  'HMR_8864': 4.347846527142998,
#  'HMR_9444': -4.347846527142998,
#  'EX_m00371x': -4.347846527142998,
#  'HMR_0195': 14.261380775199356,
#  'HMR_2284': 0.07104818150779976,
#  'HMR_0209': -0.15899002962004688,
#  'HMR_9791': 0.025860119086769943,
#  'HMR_3543': 0.025860119086769943,
#  'HMR_0208': 0.050393571643813986,
#  'HMR_0491': 0.07965207645252059,
#  'HMR_0488': 0.8921032562682306,
#  'HMR_0200': 0.15899002962004688,
#  'HMR_9750': 0.025860119086769943,
#  'HMR_3541': 0.025860119086769943,
#  'HMR_0199': 0.050393571643813986,
#  'HMR_0489': 0.07965207645252059,
#  'HMR_2651': 2.466799104514584,
#  'HMR_2652': -2.466799104514584,
#  'HMR_2653': -2.466799104514584,
#  'HMR_3397': 2.466799104514584,
#  'HMR_2289': 2.5378472860223837,
#  'HMR_2259': 0.1627509728795853,
#  'HMR_2260': 0.1627509728795853,
#  'HMR_2605': 0.0710481815077999,
#  'HMR_0487': 0.07965207645252059,
#  'HMR_0192': -0.15899002962004688,
#  'HMR_0191': 0.050393571643813986,
#  'HMR_9795': 0.025860119086769943,
#  'HMR_3539': 0.025860119086769943,
#  'HMR_0492': 0.07965207645252059,
#  'HMR_0213': -1.6204036072906525,
#  'HMR_9790': 0.025860119086769943,
#  'HMR_3544': 0.025860119086769943,
#  'HMR_0212': 1.5118071493144194,
#  'HMR_0497': 0.07965207645252059,
#  'HMR_0542': 0.07965207645252059,
#  'HMR_0516': 0.07965207645252059,
#  'HMR_0495': 0.8443120103967182,
#  'HMR_0501': 4.237490467274095,
#  'HMR_0518': 0.07965207645252059,
#  'HMR_7601': 0.1273798995548451,
#  'HMR_7162': 159.22487444355636,
#  'HMR_8479': 218.7065483753244,
#  'HMR_8478': -280.29236022991967,
#  'HMR_8476': 61.58581185459528,
#  'HMR_6368': -61.58581185459528,
#  'HMR_9296': 61.58581185459528,
#  'EX_m01668x': 61.58581185459528,
#  'HMR_8639': 318.4497488871127,
#  'HMR_8641': 159.22487444355636,
#  'HMR_7765': 159.22487444355636,
#  'HMR_7767': -159.22487444355636,
#  'HMR_7676': 249.36135828971112,
#  'HMR_4969': -249.36135828971112,
#  'HMR_7142': 90.13648384616025,
#  'HMR_9141': 311.11019975157035,
#  'EX_m01288x': 311.11019975157035,
#  'HMR_7905': -401.2466835977306,
#  'HMR_7144': 401.2466835977306,
#  'HMR_9378': 159.22487444355087,
#  'EX_m02583x': 159.22487444355087,
#  'HMR_9618': 249.36135828971112,
#  'HMR_9104': -249.36135828971112,
#  'EX_m00536x': -249.36135828971112,
#  'HMR_4882': 1000.0,
#  'HMR_9437': -1000.0,
#  'EX_m03118x': -1000.0,
#  'HMR_4352': 338.6947364726203,
#  'HMR_4477': -338.6947364726203,
#  'HMR_4350': 1000.0,
#  'HMR_4841': 1000.0,
#  'HMR_5002': 1000.0,
#  'HMR_9401': -1000.0,
#  'EX_m02841x': -1000.0,
#  'HMR_4565': 62.5519471251103,
#  'HMR_4379': 125.1038942502206,
#  'HMR_4375': -125.1038942502206,
#  'HMR_4595': 213.59084222239971,
#  'HMR_8772': 213.59084222239971,
#  'HMR_8773': 213.59084222239971,
#  'HMR_8775': 213.59084222239971,
#  'HMR_7702': -213.59084222239971,
#  'HMR_7708': 213.59084222239971,
#  'HMR_4788': 213.59084222239971,
#  'HMR_5113': 937.1936583739661,
#  'HMR_5124': -213.59084222239971,
#  'HMR_8762': 27.63285529351731,
#  'HMR_8761': 27.63285529351731,
#  'HMR_8760': 27.63285529351731,
#  'HMR_9417': 27.63285529351731,
#  'EX_m01745x': 27.63285529351731,
#  'HMR_0453': 27.63285529351731,
#  ...}

# %% [markdown]
# ### Replace glycogen with glucose :

# %%
for metabolite in healthy.metabolites:
    if "glucose" in metabolite.name:
        print(metabolite.id, metabolite.name)
# Out:
# m00946c 4,6-dideoxy-4-oxo-dTDP-D-glucose
# m01286c ADP-glucose
# m01286s ADP-glucose
# m01388c beta-D-glucose
# m01389c beta-D-glucose-6-phosphate
# m01751c dTDP-glucose
# m01965c glucose
# m01965g glucose
# m01965l glucose
# m01965r glucose
# m01965s glucose
# m01967c glucose-1-phosphate
# m01968c glucose-6-phosphate
# m01968r glucose-6-phosphate
# m03108c UDP-glucose
# m03108g UDP-glucose
# m03108r UDP-glucose
# m01965x glucose
# m01286x ADP-glucose

# %%
healthy.reactions.get_by_id("biomass_components").add_metabolites({healthy.metabolites.get_by_id("m01965c") : 1.0})

# %%
print(healthy.reactions.biomass_components)
# Out:
# biomass_components: m01307c + m01365c + m01369c + m01370c + m01371c + m01450c + m01451r + m01589c + m01623c + m01628c + 2.0 m01965c + m01974c + m01975c + m01986c + m02034c + m02125c + m02184c + m02360c + m02392c + m02426c + m02471c + m02724c + m02733c + m02750c + m02770c + m02847c + m02896c + m02908c + m02993c + m03089c + m03101c + m03130c + m03135c --> m01285c + m02039x + m03161c + temp001x

# %%
healthy.objective = "biomass_components"
healthy.optimize()
# Out:
# <Solution 177.531 at 0x7fbaaebdfc10>

# %%
vu.print_exchanges(healthy, "all")
# Out:
# ##########
# INTAKES :
#
# EX_m03146x : 0           ub : 1000.0	---		metabolites : 	 id : m03146x --- metabolite name : VLDL remnant_ ; id : m03146x
# EX_m02680x : 0           ub : 1000.0	---		metabolites : 	 id : m02680x --- metabolite name : pantothenate ; id : m02680x
# EX_m00549x : 0           ub : 1000.0	---		metabolites : 	 id : m00549x --- metabolite name : 1-organyl-2-lyso-sn-glycero-3-phosphocholine ; id : m00549x
# EX_m02961x : 0           ub : 1000.0	---		metabolites : 	 id : m02961x --- metabolite name : taurine ; id : m02961x
# EX_m02389x : 3           ub : 1000.0	---		metabolites : 	 id : m02389x --- metabolite name : linolenate ; id : m02389x
# EX_m02360x : 17          ub : 1000.0	---		metabolites : 	 id : m02360x --- metabolite name : leucine ; id : m02360x
# EX_m02450x : 49          ub : 1000.0	---		metabolites : 	 id : m02450x --- metabolite name : maltose ; id : m02450x
# EX_m01745x : 50          ub : 1000.0	---		metabolites : 	 id : m01745x --- metabolite name : D-tagatose ; id : m01745x
# EX_m02819x : 70          ub : 1000.0	---		metabolites : 	 id : m02819x --- metabolite name : pyruvate ; id : m02819x
# EX_m03135x : 95          ub : 1000.0	---		metabolites : 	 id : m03135x --- metabolite name : valine ; id : m03135x
# EX_m02930x : 99          ub : 1000.0	---		metabolites : 	 id : m02930x --- metabolite name : sphingosine-1-phosphate ; id : m02930x
# EX_m02658x : 102         ub : 1000.0	---		metabolites : 	 id : m02658x --- metabolite name : ornithine ; id : m02658x
# EX_m01619x : 102         ub : 1000.0	---		metabolites : 	 id : m01619x --- metabolite name : creatine ; id : m01619x
# EX_m01840x : 111         ub : 1000.0	---		metabolites : 	 id : m01840x --- metabolite name : fructose ; id : m01840x
# EX_m02184x : 119         ub : 1000.0	---		metabolites : 	 id : m02184x --- metabolite name : isoleucine ; id : m02184x
# EX_m01369x : 128         ub : 1000.0	---		metabolites : 	 id : m01369x --- metabolite name : asparagine ; id : m01369x
# EX_m02817x : 134         ub : 1000.0	---		metabolites : 	 id : m02817x --- metabolite name : pyridoxine ; id : m02817x
# EX_m01451x : 144         ub : 1000.0	---		metabolites : 	 id : m01451x --- metabolite name : cholesterol-ester pool ; id : m01451x
# EX_m02946x : 149         ub : 1000.0	---		metabolites : 	 id : m02946x --- metabolite name : sulfate ; id : m02946x
# EX_m02471x : 151         ub : 1000.0	---		metabolites : 	 id : m02471x --- metabolite name : methionine ; id : m02471x
# EX_m02125x : 152         ub : 1000.0	---		metabolites : 	 id : m02125x --- metabolite name : histidine ; id : m02125x
# EX_m03089x : 159         ub : 1000.0	---		metabolites : 	 id : m03089x --- metabolite name : tryptophan ; id : m03089x
# EX_m02993x : 173         ub : 1000.0	---		metabolites : 	 id : m02993x --- metabolite name : threonine ; id : m02993x
# EX_m02171x : 178         ub : 1000.0	---		metabolites : 	 id : m02171x --- metabolite name : inositol ; id : m02171x
# EX_m02366x : 194         ub : 1000.0	---		metabolites : 	 id : m02366x --- metabolite name : leukotriene C4 ; id : m02366x
# EX_m02470x : 218         ub : 1000.0	---		metabolites : 	 id : m02470x --- metabolite name : methanol ; id : m02470x
# EX_m01630x : 231         ub : 1000.0	---		metabolites : 	 id : m01630x --- metabolite name : cytidine ; id : m01630x
# EX_m03155x : 234         ub : 1000.0	---		metabolites : 	 id : m03155x --- metabolite name : xylitol ; id : m03155x
# EX_m02037x : 238         ub : 1000.0	---		metabolites : 	 id : m02037x --- metabolite name : guanine ; id : m02037x
# EX_m01260x : 256         ub : 1000.0	---		metabolites : 	 id : m01260x --- metabolite name : acetylcholine ; id : m01260x
# EX_m01789x : 265         ub : 1000.0	---		metabolites : 	 id : m01789x --- metabolite name : estrone 3-sulfate ; id : m01789x
# EX_m02724x : 271         ub : 1000.0	---		metabolites : 	 id : m02724x --- metabolite name : phenylalanine ; id : m02724x
# EX_m02896x : 312         ub : 1000.0	---		metabolites : 	 id : m02896x --- metabolite name : serine ; id : m02896x
# EX_m02998x : 330         ub : 1000.0	---		metabolites : 	 id : m02998x --- metabolite name : thyroxine ; id : m02998x
# EX_m00577x : 338         ub : 1000.0	---		metabolites : 	 id : m00577x --- metabolite name : 2,6-dimethylheptanoyl-carnitine ; id : m00577x
# EX_m03130x : 522         ub : 1000.0	---		metabolites : 	 id : m03130x --- metabolite name : UTP ; id : m03130x
# EX_m02560x : 562         ub : 1000.0	---		metabolites : 	 id : m02560x --- metabolite name : NEFA blood pool in ; id : m02560x
# EX_m02949x : 586         ub : 1000.0	---		metabolites : 	 id : m02949x --- metabolite name : sulfite ; id : m02949x
# EX_m01666x : 762         ub : 1000.0	---		metabolites : 	 id : m01666x --- metabolite name : deoxyadenosine ; id : m01666x
# EX_m02552x : 901         ub : 1000.0	---		metabolites : 	 id : m02552x --- metabolite name : NAD+ ; id : m02552x
# EX_m01368x : 912         ub : 1000.0	---		metabolites : 	 id : m01368x --- metabolite name : ascorbate ; id : m01368x
# EX_m02426x : 1000        ub : 1000.0	---		metabolites : 	 id : m02426x --- metabolite name : lysine ; id : m02426x
# EX_m02630x : 1000        ub : 1000.0	---		metabolites : 	 id : m02630x --- metabolite name : O2 ; id : m02630x
# EX_m01975x : 1000        ub : 1000.0	---		metabolites : 	 id : m01975x --- metabolite name : glutamine ; id : m01975x
# EX_m01628x : 1000        ub : 1000.0	---		metabolites : 	 id : m01628x --- metabolite name : cysteine ; id : m01628x
# EX_m02040x : 1000        ub : 1000.0	---		metabolites : 	 id : m02040x --- metabolite name : H2O ; id : m02040x
# EX_m02370x : 1000        ub : 1000.0	---		metabolites : 	 id : m02370x --- metabolite name : leukotriene F4 ; id : m02370x
# EX_m01069x : 1000        ub : 1000.0	---		metabolites : 	 id : m01069x --- metabolite name : 5-alpha-dihydrotestosterone ; id : m01069x
# EX_m01344x : 1000        ub : 1000.0	---		metabolites : 	 id : m01344x --- metabolite name : antipyrine ; id : m01344x
# EX_m01615x : 1000        ub : 1000.0	---		metabolites : 	 id : m01615x --- metabolite name : cortisol ; id : m01615x
# EX_m02041x : 1000        ub : 1000.0	---		metabolites : 	 id : m02041x --- metabolite name : H2O2 ; id : m02041x
# EX_m02631x : 1000        ub : 1000.0	---		metabolites : 	 id : m02631x --- metabolite name : O2- ; id : m02631x
# EX_m02147x : 1000        ub : 1000.0	---		metabolites : 	 id : m02147x --- metabolite name : hydroxide ; id : m02147x
# EX_m03123x : 1000        ub : 1000.0	---		metabolites : 	 id : m03123x --- metabolite name : uridine ; id : m03123x
#
# ##########
# SECRETIONS :
#
# EX_temp001x : 178        ub : 1000.0	---		metabolites : 	 id : temp001x --- metabolite name : biomass ; id : temp001x
# EX_m02842x : 0           ub : 1000.0	---		metabolites : 	 id : m02842x --- metabolite name : riboflavin ; id : m02842x
# EX_m02931x : -1          ub : 1000.0	---		metabolites : 	 id : m02931x --- metabolite name : sphingosylphosphorylcholine ; id : m02931x
# EX_m00325x : -2          ub : 1000.0	---		metabolites : 	 id : m00325x --- metabolite name : 12-hydroxydodecanoic acid ; id : m00325x
# EX_m00371x : -5          ub : 1000.0	---		metabolites : 	 id : m00371x --- metabolite name : 14-hydroxytetradecanoic acid ; id : m00371x
# EX_m02661x : -22         ub : 1000.0	---		metabolites : 	 id : m02661x --- metabolite name : oxalate ; id : m02661x
# EX_m01797x : -68         ub : 1000.0	---		metabolites : 	 id : m01797x --- metabolite name : ethanolamine ; id : m01797x
# EX_m00648x : -70         ub : 1000.0	---		metabolites : 	 id : m00648x --- metabolite name : 2-hydroxybutyrate ; id : m00648x
# EX_m01672x : -75         ub : 1000.0	---		metabolites : 	 id : m01672x --- metabolite name : deoxyribose ; id : m01672x
# EX_m02813x : -134        ub : 1000.0	---		metabolites : 	 id : m02813x --- metabolite name : pyridoxal ; id : m02813x
# EX_m02182x : -147        ub : 1000.0	---		metabolites : 	 id : m02182x --- metabolite name : isocaproic-aldehyde ; id : m02182x
# EX_m00432x : -147        ub : 1000.0	---		metabolites : 	 id : m00432x --- metabolite name : 19-hydroxytestosterone ; id : m00432x
# EX_m01983x : -158        ub : 1000.0	---		metabolites : 	 id : m01983x --- metabolite name : glycerol ; id : m01983x
# EX_m02039x : -178        ub : 1000.0	---		metabolites : 	 id : m02039x --- metabolite name : H+ ; id : m02039x
# EX_m03161x : -178        ub : 1000.0	---		metabolites : 	 id : m03161x --- metabolite name : glycogen ; id : m03161x
# EX_m02418x : -194        ub : 1000.0	---		metabolites : 	 id : m02418x --- metabolite name : LTD4 ; id : m02418x
# EX_m01982x : -230        ub : 1000.0	---		metabolites : 	 id : m01982x --- metabolite name : glycerate ; id : m01982x
# EX_m01787x : -265        ub : 1000.0	---		metabolites : 	 id : m01787x --- metabolite name : estradiol-17beta ; id : m01787x
# EX_m00665x : -304        ub : 1000.0	---		metabolites : 	 id : m00665x --- metabolite name : 2-methylcitrate ; id : m00665x
# EX_m02997x : -313        ub : 1000.0	---		metabolites : 	 id : m02997x --- metabolite name : thymine ; id : m02997x
# EX_m02174x : -330        ub : 1000.0	---		metabolites : 	 id : m02174x --- metabolite name : iodide ; id : m02174x
# EX_m03052x : -330        ub : 1000.0	---		metabolites : 	 id : m03052x --- metabolite name : triiodothyronine ; id : m03052x
# EX_m02348x : -338        ub : 1000.0	---		metabolites : 	 id : m02348x --- metabolite name : L-carnitine ; id : m02348x
# EX_m00816x : -415        ub : 1000.0	---		metabolites : 	 id : m00816x --- metabolite name : 3-mercaptolactate-cysteine-disulfide ; id : m00816x
# EX_m01986x : -470        ub : 1000.0	---		metabolites : 	 id : m01986x --- metabolite name : glycine ; id : m01986x
# EX_m01288x : -631        ub : 1000.0	---		metabolites : 	 id : m01288x --- metabolite name : ADP-ribose ; id : m01288x
# EX_m01513x : -715        ub : 1000.0	---		metabolites : 	 id : m01513x --- metabolite name : choline ; id : m01513x
# EX_m02770x : -867        ub : 1000.0	---		metabolites : 	 id : m02770x --- metabolite name : proline ; id : m02770x
# EX_m00536x : -901        ub : 1000.0	---		metabolites : 	 id : m00536x --- metabolite name : 1-methylnicotinamide ; id : m00536x
# EX_m00204x : -910        ub : 1000.0	---		metabolites : 	 id : m00204x --- metabolite name : [protein]-L-lysine ; id : m00204x
# EX_m01655x : -912        ub : 1000.0	---		metabolites : 	 id : m01655x --- metabolite name : dehydroascorbic acid ; id : m01655x
# EX_m01370x : -1000       ub : 1000.0	---		metabolites : 	 id : m01370x --- metabolite name : aspartate ; id : m01370x
# EX_m02578x : -1000       ub : 1000.0	---		metabolites : 	 id : m02578x --- metabolite name : NH3 ; id : m02578x
# EX_m02046x : -1000       ub : 1000.0	---		metabolites : 	 id : m02046x --- metabolite name : HCO3- ; id : m02046x
# EX_m01252x : -1000       ub : 1000.0	---		metabolites : 	 id : m01252x --- metabolite name : acetate ; id : m01252x
# EX_m02403x : -1000       ub : 1000.0	---		metabolites : 	 id : m02403x --- metabolite name : L-lactate ; id : m02403x
# EX_m01071x : -1000       ub : 1000.0	---		metabolites : 	 id : m01071x --- metabolite name : 5alpha-dihydrotestosterone-sulfate ; id : m01071x
# EX_m01249x : -1000       ub : 1000.0	---		metabolites : 	 id : m01249x --- metabolite name : acetaldehyde ; id : m01249x
# EX_m01279x : -1000       ub : 1000.0	---		metabolites : 	 id : m01279x --- metabolite name : adenine ; id : m01279x
# EX_m01614x : -1000       ub : 1000.0	---		metabolites : 	 id : m01614x --- metabolite name : corticosterone ; id : m01614x
# EX_m01768x : -1000       ub : 1000.0	---		metabolites : 	 id : m01768x --- metabolite name : edaravone ; id : m01768x
# EX_m02369x : -1000       ub : 1000.0	---		metabolites : 	 id : m02369x --- metabolite name : leukotriene E4 ; id : m02369x
# EX_m02841x : -1000       ub : 1000.0	---		metabolites : 	 id : m02841x --- metabolite name : ribitol ; id : m02841x
# EX_m03118x : -1000       ub : 1000.0	---		metabolites : 	 id : m03118x --- metabolite name : uracil ; id : m03118x

# %%
vu.run_parcours("EX_temp001x", healthy)
# Out:
# [EX_temp001x] : Getting all related reactions and fluxes...
# 1.0 biomass -->
#
# 1.0 temp001x -->
# FLUX : 159.22487444355835 --- ID : EX_temp001x --- COMPARTMENT : {'C_x'}
#
# SUBSYSTEM :  --- GENE NAME : Null
#
# ---
#
#
# 1.0 alanine + 1.0 arginine + 1.0 asparagine + 1.0 aspartate + 1.0 cholesterol + 1.0 cholesterol-ester pool + 1.0 CL pool + 1.0 cysteine + 1.0 DNA_C10H17O8PR2(C5H8O5PR)n + 1.0 DNA-5-methylcytosine_C10H16N3O7P(C5H8O5PR)n(C5H8O5PR)n + 1.0 glutamate + 1.0 glutamine + 1.0 glycine + 1.0 histidine + 1.0 isoleucine + 1.0 leucine + 1.0 lipid droplet_ + 1.0 lysine + 1.0 methionine + 1.0 phenylalanine + 1.0 phosphatidate-LD-TAG pool + 1.0 PI pool + 1.0 proline + 1.0 RNA_C10H18O13P2R2(C5H8O6PR)n + 1.0 serine + 1.0 SM pool + 1.0 threonine + 1.0 tryptophan + 1.0 tyrosine + 1.0 valine + 1.0 ATP + 1.0 CTP + 1.0 GTP + 1.0 UTP + 1.0 glucose --> 1.0 biomass + 1.0 H+ + 1.0 ADP
#
# 1.0 m01307c + 1.0 m01365c + 1.0 m01369c + 1.0 m01370c + 1.0 m01450c + 1.0 m01451r + 1.0 m01589c + 1.0 m01628c + 1.0 m01721n + 1.0 m01722n + 1.0 m01974c + 1.0 m01975c + 1.0 m01986c + 1.0 m02125c + 1.0 m02184c + 1.0 m02360c + 1.0 m02392c + 1.0 m02426c + 1.0 m02471c + 1.0 m02724c + 1.0 m02733c + 1.0 m02750c + 1.0 m02770c + 1.0 m02847c + 1.0 m02896c + 1.0 m02908c + 1.0 m02993c + 1.0 m03089c + 1.0 m03101c + 1.0 m03135c + 1.0 m01371c + 1.0 m01623c + 1.0 m02034c + 1.0 m03130c + 1.0 m01965c --> 1.0 temp001x + 1.0 m02039x + 1.0 m01285c
# FLUX : 159.22487444355835 --- ID : biomass_components --- COMPARTMENT : {'C_x', 'C_c', 'C_r', 'C_n'}
#
# SUBSYSTEM :  --- GENE NAME : Null
#
# ---
#
#
# 1.0 alanine <-- 1.0 alanine
#
# 1.0 m01307c <-- 1.0 m01307p
# FLUX : -0.25475979910969215 --- ID : HMR_4790 --- COMPARTMENT : {'C_p', 'C_c'}
#
# SUBSYSTEM : Transport, peroxisomal --- GENE NAME :
#
# ---
#
#
# 1.0 pyruvate + 1.0 serine --> 1.0 alanine + 1.0 hydroxypyruvate
#
# 1.0 m02819p + 1.0 m02896p --> 1.0 m01307p + 1.0 m02154p
# FLUX : 0.25475979910969215 --- ID : HMR_4467 --- COMPARTMENT : {'C_p'}
#
# SUBSYSTEM : Glycine, serine and threonine metabolism --- GENE NAME : AGXT
#
# ---
#
#
# 1.0 H+ + 1.0 NADH + 1.0 pyruvate --> 1.0 L-lactate + 1.0 NAD+
#
# 1.0 m02039p + 1.0 m02553p + 1.0 m02819p --> 1.0 m02403p + 1.0 m02552p
# FLUX : 108.49435539039207 --- ID : HMR_4281 --- COMPARTMENT : {'C_p'}
#
# SUBSYSTEM : Glycolysis / Gluconeogenesis --- GENE NAME : LDHB/LDHAL6A/LDHC/UEVLD/LDHAL6B
#
# ---
#
#
# 1.0 H+ + 1.0 L-lactate <-- 1.0 H+ + 1.0 L-lactate
#
# 1.0 m02039c + 1.0 m02403c <-- 1.0 m02039p + 1.0 m02403p
# FLUX : -108.49435539039207 --- ID : HMR_3007 --- COMPARTMENT : {'C_p', 'C_c'}
#
# SUBSYSTEM : Transport, peroxisomal --- GENE NAME : SLC16A1
#
# ---
#
#
# 1.0 2-hydroxybutyrate + 1.0 L-lactate <-- 1.0 2-hydroxybutyrate + 1.0 L-lactate
#
# 1.0 m00648c + 1.0 m02403s <-- 1.0 m00648s + 1.0 m02403c
# FLUX : -1000.0 --- ID : HMR_6011 --- COMPARTMENT : {'C_s', 'C_c'}
#
# SUBSYSTEM : Transport, extracellular --- GENE NAME : SLC16A4/SLC16A6/SLC16A1/SLC16A8/SLC16A3/SLC16A5/SLC16A7
#
# ---
#
#
# 1.0 2-hydroxybutyrate + 1.0 propanoate --> 1.0 2-hydroxybutyrate + 1.0 propanoate
#
# 1.0 m00648c + 1.0 m02772s --> 1.0 m00648s + 1.0 m02772c
# FLUX : 1000.0 --- ID : HMR_6010 --- COMPARTMENT : {'C_s', 'C_c'}
#
# SUBSYSTEM : Transport, extracellular --- GENE NAME : SLC16A4/SLC16A6/SLC16A1/SLC16A8/SLC16A3/SLC16A5/SLC16A7
#
# ---
#
#
# 1.0 acetoacetate + 1.0 propanoate <-- 1.0 acetoacetate + 1.0 propanoate
#
# 1.0 m01253c + 1.0 m02772s <-- 1.0 m01253s + 1.0 m02772c
# FLUX : -1000.0 --- ID : HMR_6003 --- COMPARTMENT : {'C_s', 'C_c'}
#
# SUBSYSTEM : Transport, extracellular --- GENE NAME : SLC16A4/SLC16A6/SLC16A1/SLC16A8/SLC16A3/SLC16A5/SLC16A7
#
# ---
#
#
# 1.0 acetoacetate + 1.0 retinoate --> 1.0 acetoacetate + 1.0 retinoate
#
# 1.0 m01253c + 1.0 m02833s --> 1.0 m01253s + 1.0 m02833c
# FLUX : 1000.0 --- ID : HMR_6005 --- COMPARTMENT : {'C_s', 'C_c'}
#
# SUBSYSTEM : Transport, extracellular --- GENE NAME : SLC16A4/SLC16A6/SLC16A1/SLC16A8/SLC16A3/SLC16A5/SLC16A7
#
# ---
#
#
# 1.0 retinoate --> 1.0 retinoate
#
# 1.0 m02833c --> 1.0 m02833s
# FLUX : 1000.0 --- ID : HMR_8721 --- COMPARTMENT : {'C_s', 'C_c'}
#
# SUBSYSTEM : Transport, extracellular --- GENE NAME :
#
# ---
#
#
# 1.0 H+ + 1.0 NADPH + 1.0 retinoate <-- 1.0 H2O + 1.0 NADP+ + 1.0 retinal
#
# 1.0 m02039c + 1.0 m02555c + 1.0 m02833c <-- 1.0 m02040c + 1.0 m02554c + 1.0 m02832c
# FLUX : -543.4283340104735 --- ID : HMR_8698 --- COMPARTMENT : {'C_c'}
#
# SUBSYSTEM : Retinol metabolism --- GENE NAME :
#
# ---
#
#
# 1.0 13-cis-retinal --> 1.0 retinal
#
# 1.0 m00349c --> 1.0 m02832c
# FLUX : 543.4283340104735 --- ID : HMR_6672 --- COMPARTMENT : {'C_c'}
#
# SUBSYSTEM : Retinol metabolism --- GENE NAME :
#
# ---
#
#
# 1.0 13-cis-retinal + 1.0 H2O + 1.0 NAD+ <-- 1.0 13-cis-retinoate + 1.0 H+ + 1.0 NADH
#
# 1.0 m00349c + 1.0 m02040c + 1.0 m02552c <-- 1.0 m00350c + 1.0 m02039c + 1.0 m02553c
# FLUX : -543.4283340104735 --- ID : HMR_6675 --- COMPARTMENT : {'C_c'}
#
# SUBSYSTEM : Retinol metabolism --- GENE NAME : ALDH1A2/ALDH1A1
#
# ---
#
#
# 1.0 13-cis-retinoate <-- 1.0 retinoate
#
# 1.0 m00350c <-- 1.0 m02833c
# FLUX : -543.4283340104735 --- ID : HMR_6661 --- COMPARTMENT : {'C_c'}
#
# SUBSYSTEM : Retinol metabolism --- GENE NAME :
#
# ---
#
#
# 1.0 acetoacetate + 1.0 AKG --> 1.0 acetoacetate + 1.0 AKG
#
# 1.0 m01253s + 1.0 m01306c --> 1.0 m01253c + 1.0 m01306s
# FLUX : 45.68801376434809 --- ID : HMR_6025 --- COMPARTMENT : {'C_s', 'C_c'}
#
# SUBSYSTEM : Transport, extracellular --- GENE NAME : SLC16A4/SLC16A6/SLC16A1/SLC16A8/SLC16A3/SLC16A5/SLC16A7
#
# ---
#
#
# 1.0 AKG + 1.0 alanine <-- 1.0 glutamate + 1.0 pyruvate
#
# 1.0 m01306c + 1.0 m01307c <-- 1.0 m01974c + 1.0 m02819c
# FLUX : -1000.0 --- ID : HMR_3899 --- COMPARTMENT : {'C_c'}
#
# SUBSYSTEM : Alanine, aspartate and glutamate metabolism --- GENE NAME : GPT
#
# ---
#
#
# 1.0 glutamate --> 1.0 glutamate
#
# 1.0 m01974l --> 1.0 m01974c
# FLUX : 101.42821314714931 --- ID : HMR_5067 --- COMPARTMENT : {'C_l', 'C_c'}
#
# SUBSYSTEM : Transport, lysosomal --- GENE NAME : SLC36A1
#
# ---
#
#
# 1.0 apoE_ + 158.0 ATP + 158.0 H2O --> 158.0 ADP + 39.0 alanine + 34.0 arginine + 1.0 asparagine + 11.0 aspartate + 2.0 cysteine + 40.0 glutamate + 32.0 glutamine + 18.0 glycine + 2.0 histidine + 2.0 isoleucine + 41.0 leucine + 13.0 lysine + 8.0 methionine + 4.0 phenylalanine + 158.0 Pi + 8.0 proline + 14.0 serine + 12.0 threonine + 8.0 tryptophan + 4.0 tyrosine + 24.0 valine
#
# 1.0 m01359l + 158.0 m01371l + 158.0 m02040l --> 158.0 m01285l + 39.0 m01307l + 34.0 m01365l + 1.0 m01369l + 11.0 m01370l + 2.0 m01628l + 40.0 m01974l + 32.0 m01975l + 18.0 m01986l + 2.0 m02125l + 2.0 m02184l + 41.0 m02360l + 13.0 m02426l + 8.0 m02471l + 4.0 m02724l + 158.0 m02751l + 8.0 m02770l + 14.0 m02896l + 12.0 m02993l + 8.0 m03089l + 4.0 m03101l + 24.0 m03135l
# FLUX : 1.2283693633737807 --- ID : HMR_5282 --- COMPARTMENT : {'C_l'}
#
# SUBSYSTEM : Protein degradation --- GENE NAME : CTSK/CTSW/TPP1/CTSE/CTSH/CTSA/CTSF/CTSZ/CTSD/CTSO/CTSC/CTSV/CTSL/CTSB
#
# ---
#
#
# 1.0 VLDL remnant_ --> 165.0 2-lysolecithin pool + 1.0 apoB100_ + 7.0 apoE_ + 500.0 cholesterol + 1645.0 cholesterol-ester pool + 2165.0 PC-LD pool + 185.0 PE-LD pool + 1.0 PI pool + 755.0 SM pool
#
# 1.0 m03146l --> 165.0 m00656l + 1.0 m01351l + 7.0 m01359l + 500.0 m01450l + 1645.0 m01451l + 2165.0 m02684l + 185.0 m02685l + 1.0 m02750l + 755.0 m02908l
# FLUX : 0.1754813376248258 --- ID : HMR_5243 --- COMPARTMENT : {'C_l'}
#
# SUBSYSTEM : Pool reactions --- GENE NAME :
#
# ---
#
#
# 1.0 VLDL remnant_ --> 1.0 VLDL remnant_
#
# 1.0 m03146s --> 1.0 m03146l
# FLUX : 0.1754813376248258 --- ID : HMR_5241 --- COMPARTMENT : {'C_s', 'C_l'}
#
# SUBSYSTEM : Transport, extracellular --- GENE NAME : LDLR
#
# ---
#
#
# 1.0 VLDL remnant_ --> 1.0 VLDL remnant_
#
# 1.0 m03146x --> 1.0 m03146s
# FLUX : 0.1754813376248258 --- ID : HMR_9029 --- COMPARTMENT : {'C_s', 'C_x'}
#
# SUBSYSTEM : Exchange reactions --- GENE NAME :
#
# ---
#
#
# --> 1.0 VLDL remnant_
#
# --> 1.0 m03146x
# FLUX : 0.1754813376248258 --- ID : EX_m03146x --- COMPARTMENT : {'C_x'}
#
# SUBSYSTEM :  --- GENE NAME : EX_m03146x
#
# ---
#
#
# 1.0 2-lysolecithin pool --> 1.0 2-lysolecithin pool
#
# 1.0 m00656l --> 1.0 m00656r
# FLUX : 28.954420708096254 --- ID : HMR_5255 --- COMPARTMENT : {'C_l', 'C_r'}
#
# SUBSYSTEM : Transport, lysosome to ER --- GENE NAME :
#
# ---
#
#
# 1.0 2-lysolecithin pool <-- 1.0 2-lysolecithin pool
#
# 1.0 m00656c <-- 1.0 m00656r
# FLUX : -28.95442070809627 --- ID : HMR_0462 --- COMPARTMENT : {'C_c', 'C_r'}
#
# SUBSYSTEM : Transport, endoplasmic reticular --- GENE NAME :
#
# ---
#
#
# 0.19 1,2-diacylglycerol-LD-TAG pool + 0.0014 1-acyl-PE pool + 0.0024 1-radyl-2-acyl-sn-glycero-3-phosphocholine + 0.0006 2-lysolecithin pool + 0.005 cholesterol + 0.34 cholesterol-ester pool + 0.005 fatty acid-LD-TG1 pool + 0.0008 O-1-alk-1-enyl-2-acyl-sn-glycero-3-phosphoethanolamine + 0.0092 PC-LD pool + 0.0034 PE-LD pool + 0.0016 PI pool + 0.0002 PS-LD pool + 0.0004 SM pool + 0.44 TAG-LD pool --> 1.0 lipid droplet_
#
# 0.19 m00240c + 0.0014 m00511c + 0.0024 m00560c + 0.0006 m00656c + 0.005 m01450c + 0.34 m01451c + 0.005 m01813c + 0.0008 m02629c + 0.0092 m02684c + 0.0034 m02685c + 0.0016 m02750c + 0.0002 m02808c + 0.0004 m02908c + 0.44 m02958c --> 1.0 m02392c
# FLUX : 159.22487444355835 --- ID : HMR_0031 --- COMPARTMENT : {'C_c'}
#
# SUBSYSTEM : Pool reactions --- GENE NAME : FITM1/PLIN4/PLIN3
#
# ---
#
#
# 1.0 1,2-diacylglycerol-LD-TAG pool + 1.0 ATP --> 1.0 ADP + 1.0 phosphatidate-LD-TAG pool
#
# 1.0 m00240c + 1.0 m01371c --> 1.0 m01285c + 1.0 m02733c
# FLUX : 159.22487444355835 --- ID : HMR_0604 --- COMPARTMENT : {'C_c'}
#
# SUBSYSTEM : Acylglycerides metabolism --- GENE NAME : Null/DGKD/DGKA/DGKB/DGKH/DGKZ/DGKQ/DGKI/DGKE/DGKG
#
# ---
#
#
# 1.0 1,2-diacylglycerol-LD-TAG pool + 1.0 H2O --> 1.0 1-acylglycerol-LD-TG1 pool + 1.0 fatty acid-LD-TG2 pool
#
# 1.0 m00240c + 1.0 m02040c --> 1.0 m00509c + 1.0 m01814c
# FLUX : 0.1273798995548467 --- ID : HMR_0667 --- COMPARTMENT : {'C_c'}
#
# SUBSYSTEM : Acylglycerides metabolism --- GENE NAME : CEL/PNLIPRP1/LIPF/LIPE/PNLIPRP3/PNPLA4/PNPLA3/AADAC/LIPG/LIPC/PNLIPRP2/PNLIP
#
# ---
#
#
# 1.0 1-acylglycerol-LD-TG1 pool + 1.0 ATP --> 1.0 1-acylglycerol-3P-LD-TG1 pool + 1.0 ADP
#
# 1.0 m00509c + 1.0 m01371c --> 1.0 m00490c + 1.0 m01285c
# FLUX : 0.1273798995548467 --- ID : HMR_0673 --- COMPARTMENT : {'C_c'}
#
# SUBSYSTEM : Glycerolipid metabolism --- GENE NAME : AGK
#
# ---
#
#
# 1.0 1-acylglycerol-3P-LD-TG1 pool + 1.0 NADP+ --> 1.0 acylglycerone-phosphate + 1.0 H+ + 1.0 NADPH
#
# 1.0 m00490c + 1.0 m02554c --> 1.0 m01278c + 1.0 m02039c + 1.0 m02555c
# FLUX : 0.1273798995548467 --- ID : HMR_7591 --- COMPARTMENT : {'C_c'}
#
# SUBSYSTEM : Glycerophospholipid metabolism --- GENE NAME : AKR1A1
#
# ---
#
#
# 1.0 acylglycerone-phosphate --> 1.0 acylglycerone-phosphate
#
# 1.0 m01278c --> 1.0 m01278p
# FLUX : 0.1273798995548467 --- ID : HMR_7590 --- COMPARTMENT : {'C_p', 'C_c'}
#
# SUBSYSTEM : Transport, peroxisomal --- GENE NAME :
#
# ---
#
#
# 1.0 acylglycerone-phosphate + 1.0 hexadecanol --> 1.0 alkyl-glycerone-3-phosphate + 1.0 palmitate
#
# 1.0 m01278p + 1.0 m02114p --> 1.0 m01311p + 1.0 m02674p
# FLUX : 0.1273798995548467 --- ID : HMR_7594 --- COMPARTMENT : {'C_p'}
#
# SUBSYSTEM : Glycerophospholipid metabolism --- GENE NAME : AGPS
#
# ---
#
#
# 2.0 H+ + 2.0 NADPH + 1.0 palmitoyl-CoA --> 1.0 CoA + 1.0 hexadecanol + 2.0 NADP+
#
# 2.0 m02039p + 2.0 m02555p + 1.0 m02678p --> 1.0 m01597p + 1.0 m02114p + 2.0 m02554p
# FLUX : 0.1273798995548467 --- ID : HMR_0703 --- COMPARTMENT : {'C_p'}
#
# SUBSYSTEM : Ether lipid metabolism --- GENE NAME : FAR1/FAR2
#
# ---
#
#
# 1.0 3-oxooctadecanoyl-CoA + 1.0 CoA --> 1.0 acetyl-CoA + 1.0 palmitoyl-CoA
#
# 1.0 m00890p + 1.0 m01597p --> 1.0 m01261p + 1.0 m02678p
# FLUX : 0.6138072116416613 --- ID : HMR_3077 --- COMPARTMENT : {'C_p'}
#
# SUBSYSTEM : Beta oxidation of even-chain fatty acids (peroxisomal) --- GENE NAME : ACAA1/MYO5B
#
# ---
#
#
# 1.0 3-hydroxyoctadecanoyl-CoA + 1.0 NAD+ --> 1.0 3-oxooctadecanoyl-CoA + 1.0 H+ + 1.0 NADH
#
# 1.0 m00793p + 1.0 m02552p --> 1.0 m00890p + 1.0 m02039p + 1.0 m02553p
# FLUX : 0.6138072116416613 --- ID : HMR_3076 --- COMPARTMENT : {'C_p'}
#
# SUBSYSTEM : Beta oxidation of even-chain fatty acids (peroxisomal) --- GENE NAME : EHHADH/HSD17B4
#
# ---
#
#
# 1.0 (2E)-octadecenoyl-CoA + 1.0 H2O --> 1.0 3-hydroxyoctadecanoyl-CoA
#
# 1.0 m00057p + 1.0 m02040p --> 1.0 m00793p
# FLUX : 0.6138072116416613 --- ID : HMR_3075 --- COMPARTMENT : {'C_p'}
#
# SUBSYSTEM : Beta oxidation of even-chain fatty acids (peroxisomal) --- GENE NAME : EHHADH
#
# ---
#
#
# 1.0 O2 + 1.0 stearoyl-CoA --> 1.0 (2E)-octadecenoyl-CoA + 1.0 H2O2
#
# 1.0 m02630p + 1.0 m02941p --> 1.0 m00057p + 1.0 m02041p
# FLUX : 0.6138072116416613 --- ID : HMR_3074 --- COMPARTMENT : {'C_p'}
#
# SUBSYSTEM : Beta oxidation of even-chain fatty acids (peroxisomal) --- GENE NAME : ACOX1/ACOX3
#
# ---
#
#
# 1.0 3-oxoeicosanoyl-CoA + 1.0 CoA --> 1.0 acetyl-CoA + 1.0 stearoyl-CoA
#
# 1.0 m00872p + 1.0 m01597p --> 1.0 m01261p + 1.0 m02941p
# FLUX : 0.6138072116416613 --- ID : HMR_3073 --- COMPARTMENT : {'C_p'}
#
# SUBSYSTEM : Beta oxidation of even-chain fatty acids (peroxisomal) --- GENE NAME : ACAA1/MYO5B
#
# ---
#
#
# 1.0 3-hydroxyeicosanoyl-CoA + 1.0 NAD+ --> 1.0 3-oxoeicosanoyl-CoA + 1.0 H+ + 1.0 NADH
#
# 1.0 m00777p + 1.0 m02552p --> 1.0 m00872p + 1.0 m02039p + 1.0 m02553p
# FLUX : 0.6138072116416613 --- ID : HMR_3072 --- COMPARTMENT : {'C_p'}
#
# SUBSYSTEM : Beta oxidation of even-chain fatty acids (peroxisomal) --- GENE NAME : EHHADH/HSD17B4
#
# ---
#
#
# 1.0 (2E)-eicosenoyl-CoA + 1.0 H2O --> 1.0 3-hydroxyeicosanoyl-CoA
#
# 1.0 m00043p + 1.0 m02040p --> 1.0 m00777p
# FLUX : 0.6138072116416613 --- ID : HMR_3071 --- COMPARTMENT : {'C_p'}
#
# SUBSYSTEM : Beta oxidation of even-chain fatty acids (peroxisomal) --- GENE NAME : EHHADH
#
# ---
#
#
# 1.0 eicosanoyl-CoA + 1.0 O2 --> 1.0 (2E)-eicosenoyl-CoA + 1.0 H2O2
#
# 1.0 m01773p + 1.0 m02630p --> 1.0 m00043p + 1.0 m02041p
# FLUX : 0.6138072116416613 --- ID : HMR_3070 --- COMPARTMENT : {'C_p'}
#
# SUBSYSTEM : Beta oxidation of even-chain fatty acids (peroxisomal) --- GENE NAME : ACOX1/ACOX3
#
# ---
#
#
# 1.0 3-oxodocosanoyl-CoA + 1.0 CoA --> 1.0 acetyl-CoA + 1.0 eicosanoyl-CoA
#
# 1.0 m00866p + 1.0 m01597p --> 1.0 m01261p + 1.0 m01773p
# FLUX : 0.6138072116416613 --- ID : HMR_3069 --- COMPARTMENT : {'C_p'}
#
# SUBSYSTEM : Beta oxidation of even-chain fatty acids (peroxisomal) --- GENE NAME : ACAA1/MYO5B
#
# ---
#
#
# 1.0 3-hydroxydocosanoyl-CoA + 1.0 NAD+ --> 1.0 3-oxodocosanoyl-CoA + 1.0 H+ + 1.0 NADH
#
# 1.0 m00776p + 1.0 m02552p --> 1.0 m00866p + 1.0 m02039p + 1.0 m02553p
# FLUX : 0.6138072116416613 --- ID : HMR_3068 --- COMPARTMENT : {'C_p'}
#
# SUBSYSTEM : Beta oxidation of even-chain fatty acids (peroxisomal) --- GENE NAME : EHHADH/HSD17B4
#
# ---
#
#
# 1.0 (2E)-docosenoyl-CoA + 1.0 H2O --> 1.0 3-hydroxydocosanoyl-CoA
#
# 1.0 m00040p + 1.0 m02040p --> 1.0 m00776p
# FLUX : 0.6138072116416613 --- ID : HMR_3067 --- COMPARTMENT : {'C_p'}
#
# SUBSYSTEM : Beta oxidation of even-chain fatty acids (peroxisomal) --- GENE NAME : EHHADH
#
# ---
#
#
# 1.0 docosanoyl-CoA + 1.0 O2 --> 1.0 (2E)-docosenoyl-CoA + 1.0 H2O2
#
# 1.0 m01725p + 1.0 m02630p --> 1.0 m00040p + 1.0 m02041p
# FLUX : 0.6138072116416613 --- ID : HMR_3066 --- COMPARTMENT : {'C_p'}
#
# SUBSYSTEM : Beta oxidation of even-chain fatty acids (peroxisomal) --- GENE NAME : ACOX1/ACOX3
#
# ---
#
#
# 1.0 3-oxotetracosanoyl-CoA + 1.0 CoA --> 1.0 acetyl-CoA + 1.0 docosanoyl-CoA
#
# 1.0 m00904p + 1.0 m01597p --> 1.0 m01261p + 1.0 m01725p
# FLUX : 0.6138072116416613 --- ID : HMR_3065 --- COMPARTMENT : {'C_p'}
#
# SUBSYSTEM : Beta oxidation of even-chain fatty acids (peroxisomal) --- GENE NAME : ACAA1/MYO5B
#
# ---
#
#
# 1.0 3-hydroxytetracosanoyl-CoA + 1.0 NAD+ --> 1.0 3-oxotetracosanoyl-CoA + 1.0 H+ + 1.0 NADH
#
# 1.0 m00800p + 1.0 m02552p --> 1.0 m00904p + 1.0 m02039p + 1.0 m02553p
# FLUX : 0.6138072116416613 --- ID : HMR_3064 --- COMPARTMENT : {'C_p'}
#
# SUBSYSTEM : Beta oxidation of even-chain fatty acids (peroxisomal) --- GENE NAME : EHHADH/HSD17B4
#
# ---
#
#
# 1.0 (2E)-tetracosenoyl-CoA + 1.0 H2O --> 1.0 3-hydroxytetracosanoyl-CoA
#
# 1.0 m00064p + 1.0 m02040p --> 1.0 m00800p
# FLUX : 0.6138072116416613 --- ID : HMR_3063 --- COMPARTMENT : {'C_p'}
#
# SUBSYSTEM : Beta oxidation of even-chain fatty acids (peroxisomal) --- GENE NAME : EHHADH
#
# ---
#
#
# 1.0 O2 + 1.0 tetracosanoyl-CoA --> 1.0 (2E)-tetracosenoyl-CoA + 1.0 H2O2
#
# 1.0 m02630p + 1.0 m02971p --> 1.0 m00064p + 1.0 m02041p
# FLUX : 0.6138072116416613 --- ID : HMR_3062 --- COMPARTMENT : {'C_p'}
#
# SUBSYSTEM : Beta oxidation of even-chain fatty acids (peroxisomal) --- GENE NAME : ACOX1/ACOX3
#
# ---
#
#
# 1.0 tetracosanoyl-CoA --> 1.0 tetracosanoyl-CoA
#
# 1.0 m02971c --> 1.0 m02971p
# FLUX : 0.4832811065741809 --- ID : HMR_3019 --- COMPARTMENT : {'C_p', 'C_c'}
#
# SUBSYSTEM : Transport, peroxisomal --- GENE NAME : ABCD1
#
# ---
#
#
# 0.0001 (10Z)-heptadecenoyl-CoA + 0.0001 (11Z)-docosenoyl-CoA + 0.0001 (11Z)-eicosenoyl-CoA + 0.0001 (11Z,14Z)-eicosadienoyl-CoA + 0.0001 (11Z,14Z,17Z)-eicosatrienoyl-CoA + 0.0001 (13Z)-docosenoyl-CoA + 0.0001 (13Z)-eicosenoyl-CoA + 0.0001 (13Z)-octadecenoyl-CoA + 0.0001 (13Z,16Z)-docosadienoyl-CoA + 0.0001 (15Z)-tetracosenoyl-CoA + 0.0008 (4Z,7Z,10Z,13Z,16Z)-docosapentaenoyl-CoA + 0.0268 (4
A + 0.0194 cis-vaccenoyl-CoA + 0.0141 dihomo-gamma-linolenoyl-CoA + 0.0001 docosanoyl-CoA + 0.0001 eicosanoyl-CoA + 0.0081 gamma-linolenoyl-CoA + 0.0001 heneicosanoyl-CoA + 0.0001 heptadecanoyl-CoA + 0.0001 hexacosanoyl-CoA + 0.0001 hexacosenoyl-CoA + 0.0001 lauroyl-CoA + 0.0023 linolenoyl-CoA + 0.278 linoleoyl-CoA + 0.003 myristoyl-CoA + 0.0001 nonadecanoyl-CoA + 0.4519 oleoyl-CoA + 0.0001 palmitoleoyl-CoA + 0.0849 palmitoyl-CoA + 0.0001 pentadecanoyl-CoA + 0.0584 stearoyl-CoA + 0.0001 tetracosanoyl-CoA + 0.0001 tricosanoyl-CoA + 0.0001 tridecanoyl-CoA --> 1.0 acyl-CoA-LD-TG3 pool
#
# 0.0001 m00004c + 0.0001 m00006c + 0.0001 m00007c + 0.0001 m00009c + 0.0001 m00012c + 0.0001 m00016c + 0.0001 m00018c + 0.0001 m00020c + 0.0001 m00023c + 0.0001 m00025c + 0.0011 m00093c + 0.0221 m00095c + 0.0001 m00101c + 0.0035 m00103c + 0.0001 m00106c + 0.0026 m00108c + 0.0001 m00110c + 0.0001 m00113c + 0.0001 m00116c + 0.0001 m00118c + 0.0022 m00119c + 0.0038 m00121c + 0.0001 m00123c + 0.0001 m00125c + 0.0001 m00127c + 0.0001 m00129c + 0.0001 m00131c + 0.0001 m00134c + 0.0001 m00262c + 0.0001 m00264c + 0.0001 m00317c + 0.0001 m00343c + 0.0001 m01141c + 0.014 m01191c + 0.0001 m01236c + 0.0001 m01237c + 0.0264 m01364c + 0.0194 m01586c + 0.0141 m01697c + 0.0001 m01725c + 0.0001 m01773c + 0.0081 m01934c + 0.0001 m02052c + 0.0001 m02101c + 0.0001 m02110c + 0.0001 m02112c + 0.0001 m02345c + 0.0023 m02390c + 0.278 m02391c + 0.003 m02495c + 0.0001 m02612c + 0.4519 m02647c + 0.0001 m02677c + 0.0849 m02678c + 0.0001 m02689c + 0.0584 m02941c + 0.0001 m02971c + 0.0001 m03047c + 0.0001 m03050c --> 1.0 m01277c
# FLUX : 70.05894475516567 --- ID : HMR_0547 --- COMPARTMENT : {'C_c'}
#
# SUBSYSTEM : Pool reactions --- GENE NAME :
#
# ---
#
#
# 1.0 (11Z)-docosenoyl-CoA + 1.0 AMP + 1.0 PPi <-- 1.0 ATP + 1.0 cis-cetoleic acid + 1.0 CoA
#
# 1.0 m00006c + 1.0 m01334c + 1.0 m02759c <-- 1.0 m01371c + 1.0 m01582c + 1.0 m01597c
# FLUX : -0.15899002962007255 --- ID : HMR_0323 --- COMPARTMENT : {'C_c'}
#
# SUBSYSTEM : Fatty acid activation (cytosolic) --- GENE NAME : ACSL1/ACSL4/SLC27A2/ACSL5/ACSBG2/ACSL6/ACSL3
#
# ---
#
#
# 1.0 (11Z,14Z)-eicosadienoic acid + 1.0 ATP + 1.0 CoA --> 1.0 (11Z,14Z)-eicosadienoyl-CoA + 1.0 AMP + 1.0 PPi
#
# 1.0 m00008c + 1.0 m01371c + 1.0 m01597c --> 1.0 m00009c + 1.0 m01334c + 1.0 m02759c
# FLUX : 0.914893604277288 --- ID : HMR_0429 --- COMPARTMENT : {'C_c'}
#
# SUBSYSTEM :
c + 0.0931 m01689c + 0.0089 m01696c + 0.0329 m01741c + 0.0005 m01771c + 0.0005 m01778c + 0.0286 m01784c + 0.0011 m01932c + 0.0005 m02053c + 0.0005 m02344c + 0.0005 m02385c + 0.0177 m02387c + 0.0035 m02389c + 0.0005 m02456c + 0.0005 m02457c + 0.0055 m02494c + 0.0005 m02564c + 0.0005 m02613c + 0.0323 m02646c + 0.0174 m02648c + 0.0337 m02674c + 0.0058 m02675c + 0.0005 m02690c + 0.0005 m02745c + 0.4731 m02938c + 0.0025 m02939c + 0.0005 m03045c + 0.0005 m03051c + 0.0005 m03153c
# FLUX : 192.63953529575434 --- ID : HMR_0690 --- COMPARTMENT : {'C_c'}
#
# SUBSYSTEM : Pool reactions --- GENE NAME :
#
# ---
#
#
# 1.0 1-acylglycerol-LD-PS pool + 1.0 H2O --> 1.0 fatty acid-LD-PS pool + 1.0 glycerol
#
# 1.0 m00507c + 1.0 m02040c --> 1.0 m01811c + 1.0 m01983c
# FLUX : 96.31976764787717 --- ID : HMR_0682 --- COMPARTMENT : {'C_c'}
#
# SUBSYSTEM : Acylglycerides metabolism --- GENE NAME : MGLL/ABHD6
#
# ---
#
#
# 1.0 1,2-diacylglycerol-LD-PS pool + 1.0 H2O --> 1.0 1-acylglycerol-LD-PS pool + 1.0 fatty acid-LD-PS pool
#
# 1.0 m00238c + 1.0 m02040c --> 1.0 m00507c + 1.0 m01811c
# FLUX : 96.31976764787717 --- ID : HMR_0671 --- COMPARTMENT : {'C_c'}
#
# SUBSYSTEM : Acylglycerides metabolism --- GENE NAME : CEL/PNLIPRP1/LIPF/LIPE/PNLIPRP3/PNPLA4/PNPLA3/AADAC/LIPG/LIPC/PNLIPRP2/PNLIP
#
# ---
#
#
# 1.0 H2O + 1.0 phosphatidate-LD-PS pool --> 1.0 1,2-diacylglycerol-LD-PS pool + 1.0 Pi
#
# 1.0 m02040c + 1.0 m02731c --> 1.0 m00238c + 1.0 m02751c
# FLUX : 96.31976764787717 --- ID : HMR_0599 --- COMPARTMENT : {'C_c'}
#
# SUBSYSTEM : Glycerophospholipid metabolism --- GENE NAME : PLPP5/LPIN1/PLPPR4/PLPP3/PLPP4/LPIN2/PLPPR2/PLPP1/PLPP2
#
# ---
#
#
# 1.0 H2O + 1.0 PS-LD pool --> 1.0 phosphatidate-LD-PS pool + 1.0 serine
#
# 1.0 m02040c + 1.0 m02808c --> 1.0 m02731c + 1.0 m02896c
# FLUX : 96.31976764787717 --- ID : HMR_0660 --- COMPARTMENT : {'C_c'}
#
# SUBSYSTEM : Glycerophospholipid metabolism --- GENE NAME : PLD1/PLD3/PLD2
#
# ---
#
#
# 1.0 PC-LD pool + 1.0 serine --> 1.0 choline + 1.0 PS-LD pool
#
# 1.0 m02684c + 1.0 m02896c --> 1.0 m01513c + 1.0 m02808c
# FLUX : 64.6518445595022 --- ID : HMR_0623 --- COMPARTMENT : {'C_c'}
#
# SUBSYSTEM : Glycerophospholipid metabolism --- GENE NAME : PTDSS1
#
# ---
#
#
# 1.0 cholesterol + 1.0 PC-LD pool --> 1.0 2-lysolecithin pool + 1.0 cholesterol-ester pool
#
# 1.0 m01450c + 1.0 m02684c --> 1.0 m00656c + 1.0 m01451c
# FLUX : 54.13645731080984 --- ID : HMR_0634 --- COMPARTMENT : {'C_c'}
#
# SUBSYSTEM : Glycerophospholipid metabolism --- GENE NAME : LCAT
#
# ---
#
#
# 1.0 cholesterol <-- 1.0 cholesterol
#
# 1.0 m01450c <-- 1.0 m01450m
# FLUX : -214.157456126586 --- ID : HMR_1915 --- COMPARTMENT : {'C_c', 'C_m'}
#
# SUBSYSTEM : Transport, mitochondrial --- GENE NAME :
#
# ---
#
#
# 1.0 cholesterol + 1.0 H+ + 1.0 NADPH + 2.0 O2 --> 2.0 H2O + 1.0 isocaproic-aldehyde + 1.0 NADP+ + 1.0 pregnenolone
#
# 1.0 m01450m + 1.0 m02039m + 1.0 m02555m + 2.0 m02630m --> 2.0 m02040m + 1.0 m02182m + 1.0 m02554m + 1.0 m02763m
# FLUX : 132.18440355353061 --- ID : HMR_7935 --- COMPARTMENT : {'C_m'}
#
# SUBSYSTEM : Steroid metabolism --- GENE NAME : CYP11A1
#
# ---
#
#
# 1.0 isocaproic-aldehyde --> 1.0 isocaproic-aldehyde
#
# 1.0 m02182m --> 1.0 m02182c
# FLUX : 132.18440355353061 --- ID : HMR_1930 --- COMPARTMENT : {'C_c', 'C_m'}
#
# SUBSYSTEM : Transport, mitochondrial --- GENE NAME :
#
# ---
#
#
# 1.0 isocaproic-aldehyde --> 1.0 isocaproic-aldehyde
#
# 1.0 m02182c --> 1.0 m02182s
# FLUX : 132.18440355353061 --- ID : HMR_8100 --- COMPARTMENT : {'C_s', 'C_c'}
#
# SUBSYSTEM : Transport, extracellular --- GENE NAME :
#
# ---
#
#
# 1.0 isocaproic-aldehyde <-- 1.0 isocaproic-aldehyde
#
# 1.0 m02182x <-- 1.0 m02182s
# FLUX : -132.18440355353061 --- ID : HMR_9225 --- COMPARTMENT : {'C_s', 'C_x'}
#
# SUBSYSTEM : Exchange reactions --- GENE NAME :
#
# ---
#
#
# <-- 1.0 isocaproic-aldehyde
#
# <-- 1.0 m02182x
# FLUX : -132.18440355353061 --- ID : EX_m02182x --- COMPARTMENT : {'C_x'}
#
# SUBSYSTEM :  --- GENE NAME : EX_m02182x
#
# ---
#
#
# 1.0 pregnenolone <-- 1.0 pregnenolone
#
# 1.0 m02763c <-- 1.0 m02763m
# FLUX : -132.18440355353061 --- ID : HMR_1936 --- COMPARTMENT : {'C_c', 'C_m'}
#
# SUBSYSTEM : Transport, mitochondrial --- GENE NAME :
#
# ---
#
#
# 1.0 NAD+ + 1.0 pregnenolone --> 1.0 H+ + 1.0 NADH + 1.0 pregn-5-ene-3,20-dione
#
# 1.0 m02552c + 1.0 m02763c --> 1.0 m02039c + 1.0 m02553c + 1.0 m02760c
# FLUX : 132.18440355353061 --- ID : HMR_1979 --- COMPARTMENT : {'C_c'}
#
# SUBSYSTEM : Glucocorticoid biosynthesis --- GENE NAME : HSD3B1/HSD3B2
#
# ---
#
#
# 1.0 pregn-5-ene-3,20-dione --> 1.0 progesterone
#
# 1.0 m02760c --> 1.0 m02769c
# FLUX : 132.18440355353061 --- ID : HMR_1980 --- COMPARTMENT : {'C_c'}
#
# SUBSYSTEM : Glucocorticoid biosynthesis --- GENE NAME : HSD3B1/HSD3B2
#
# ---
#
#
# 1.0 progesterone --> 1.0 progesterone
#
# 1.0 m02769c --> 1.0 m02769s
# FLUX : 132.18440355353061 --- ID : HMR_8931 --- COMPARTMENT : {'C_s', 'C_c'}
#
# SUBSYSTEM : Transport, extracellular --- GENE NAME :
#
# ---
#
#
# 1.0 progesterone <-- 1.0 progesterone
#
# 1.0 m02769x <-- 1.0 m02769s
# FLUX : -132.18440355353061 --- ID : HMR_9393 --- COMPARTMENT : {'C_s', 'C_x'}
#
# SUBSYSTEM : Exchange reactions --- GENE NAME :
#
# ---
#
#
# <-- 1.0 progesterone
#
# <-- 1.0 m02769x
# FLUX : -132.18440355353061 --- ID : EX_m02769x --- COMPARTMENT : {'C_x'}
#
# SUBSYSTEM :  --- GENE NAME : EX_m02769x
#
# ---
#
#
# 1.0 cholesterol --> 1.0 cholesterol
#
# 1.0 m01450l --> 1.0 m01450m
# FLUX : 346.3418596801166 --- ID : HMR_5046 --- COMPARTMENT : {'C_l', 'C_m'}
#
# SUBSYSTEM : Transport, mitochondrial --- GENE NAME : STARD3
#
# ---
#
#
# 1.0 cholesterol-ester-11-eico + 1.0 H2O --> 1.0 cholesterol + 1.0 cis-gondoic acid
#
# 1.0 m01458l + 1.0 m02040l --> 1.0 m01450l + 1.0 m01584l
# FLUX : 0.025860119086770363 --- ID : HMR_3561 --- COMPARTMENT : {'C_l'}
#
# SUBSYSTEM : Formation and hydrolysis of cholesterol esters --- GENE NAME : CEL/LIPA
#
# ---
#
#
# 1.0 cholesterol-ester pool --> 0.0001 cholesterol-ester-10,13,16,19-docosa + 0.0001 cholesterol-ester-10,13,16-docosa + 0.0001 cholesterol-ester-10-hepta + 0.0001 cholesterol-ester-11,14,17-eico + 0.0001 cholesterol-ester-11,14-eicosa + 0.0001 cholesterol-ester-11-docose + 0.0001 cholesterol-ester-11-eico + 0.0001 cholesterol-ester-12,15,18,21-tetracosa + 0.0001 cholesterol-ester-13,16,19-doco + 0.0001 cholesterol-ester-13,16-docosa + 0.0001 cholesterol-ester-13-docose + 0.0001 cholesterol-ester-13-eicose + 0.0001 cholesterol-ester-13-octade + 0.0001 cholesterol-ester-15-tetra + 0.0041 cholesterol-ester-4,7,10,13,16,19-doco + 0.0001 cholesterol-ester-4,7,10,13,16-docosa + 0.0071 cholesterol-ester-5,8,11,14,17-eico + 0.0001 cholesterol-ester-5,8,11-eico + 0.0001 cholesterol-ester-5-tetra + 0.0001 cholesterol-ester-6,9,12,15,18,21-tetra + 0.0001 cholesterol-ester-6,9,12,15,18-tetraco + 0.0001 cholesterol-ester-6,9,12,15-octa + 0.0001 cholesterol-ester-6,9-octa + 0.0001 cholesterol-ester-7,10,13,16,19-docosa + 0.0001 cholesterol-ester-7,10,13,16-docosa + 0.0406 cholesterol-ester-7-hexa + 0.0001 cholesterol-ester-7-octade + 0.0001 cholesterol-ester-7-tetrade + 0.0001 cholesterol-ester-8,11,14,17-eico + 0.0001 cholesterol-ester-8,11-eico + 0.0001 cholesterol-ester-9,12,15,18,21-tetra + 0.0001 cholesterol-ester-9,12,15,18-tetraco + 0.0001 cholesterol-ester-9-eicose + 0.0001 cholesterol-ester-9-heptade + 0.0001 cholesterol-ester-9-octa + 0.0001 cholesterol-ester-9-tetrade + 0.0518 cholesterol-ester-arach + 0.0001 cholesterol-ester-cis-vac + 0.005 cholesterol-ester-dihomo-gamma + 0.0001 cholesterol-ester-docosa + 0.0001 cholesterol-ester-eico + 0.0001 cholesterol-ester-gamma-lin + 0.0001 cholesterol-ester-heneico + 0.0001 cholesterol-ester-hepta + 0.0001 cholesterol-ester-hexacosa + 0.0001 cholesterol-ester-hexecose + 0.0001 cholesterol-ester-laur + 0.5254 cholesterol-ester-lin + 0.0061 cholesterol-ester-linolen + 0.0081 cholesterol-ester-myrist + 0.0001 cholesterol-ester-nanode + 0.1958 cholesterol-ester-ol + 0.138 cholesterol-ester-palm + 0.0001 cholesterol-ester-palmn + 0.0001 cholesterol-ester-penta + 0.0132 cholesterol-ester-stea + 0.0001 cholesterol-ester-tetraco + 0.0001 cholesterol-ester-trico + 0.0001 cholesterol-ester-tridec
#
# 1.0 m01451l --> 0.0001 m01452l + 0.0001 m01453l + 0.0001 m01454l + 0.0001 m01455l + 0.0001 m01456l + 0.0001 m01457l + 0.0001 m01458l + 0.0001 m01459l + 0.0001 m01460l + 0.0001 m01461l + 0.0001 m01462l + 0.0001 m01463l + 0.0001 m01464l + 0.0001 m01465l + 0.0041 m01466l + 0.0001 m01467l + 0.0071 m01468l + 0.0001 m01469l + 0.0001 m01470l + 0.0001 m01471l + 0.0001 m01472l + 0.0001 m01473l + 0.0001 m01474l + 0.0001 m01475l + 0.0001 m01476l + 0.0406 m01477l + 0.0001 m01478l + 0.0001 m01479l + 0.0001 m01480l + 0.0001 m01481l + 0.0001 m01482l + 0.0001 m01483l + 0.0001 m01484l + 0.0001 m01485l + 0.0001 m01486l + 0.0001 m01487l + 0.0518 m01488l + 0.0001 m01489l + 0.005 m01490l + 0.0001 m01491l + 0.0001 m01492l + 0.0001 m01493l + 0.0001 m01494l + 0.0001 m01495l + 0.0001 m01496l + 0.0001 m01497l + 0.0001 m01498l + 0.5254 m01499l + 0.0061 m01500l + 0.0081 m01501l + 0.0001 m01502l + 0.1958 m01503l + 0.138 m01504l + 0.0001 m01505l + 0.0001 m01506l + 0.0132 m01507l + 0.0001 m01508l + 0.0001 m01509l + 0.0001 m01510l
# FLUX : 258.6011908677036 --- ID : HMR_3537 --- COMPARTMENT : {'C_l'}
#
# SUBSYSTEM : Formation and hydrolysis of cholesterol esters --- GENE NAME :
#
# ---
#
#
# 1.0 cholesterol-ester pool --> 1.0 cholesterol-ester pool
#
# 1.0 m01451l --> 1.0 m01451r
# FLUX : 159.22487444355835 --- ID : HMR_3597 --- COMPARTMENT : {'C_l', 'C_r'}
#
# SUBSYSTEM : Transport, lysosome to ER --- GENE NAME :
#
# ---
#
#
# 1.0 cholesterol-ester pool --> 1.0 cholesterol-ester pool
#
# 1.0 m01451x --> 1.0 m01451l
# FLUX : 129.15926491842356 --- ID : HMR_9736 --- COMPARTMENT : {'C_x', 'C_l'}
#
# SUBSYSTEM : Exchange reactions --- GENE NAME : Fake cholesterol Uptake
#
# ---
#
#
# --> 1.0 cholesterol-ester pool
#
# --> 1.0 m01451x
# FLUX : 129.15926491842356 --- ID : EX_m01451x --- COMPARTMENT : {'C_x'}
#
# SUBSYSTEM :  --- GENE NAME : EX_m01451x
#
# ---
#
#
# 1.0 cholesterol-ester-10,13,16,19-docosa + 1.0 H2O --> 1.0 10,13,16,19-docosatetraenoic acid + 1.0 cholesterol
#
# 1.0 m01452l + 1.0 m02040l --> 1.0 m00260l + 1.0 m01450l
# FLUX : 0.025860119086770363 --- ID : HMR_3584 --- COMPARTMENT : {'C_l'}
#
# SUBSYSTEM : Formation and hydrolysis of cholesterol esters --- GENE NAME : CEL/LIPA
#
# ---
#
#
# 1.0 10,13,16,19-docosatetraenoic acid --> 1.0 10,13,16,19-docosatetraenoic acid
#
# 1.0 m00260l --> 1.0 m00260c
# FLUX : 0.025860119086770363 --- ID : HMR_9753 --- COMPARTMENT : {'C_l', 'C_c'}
#
# SUBSYSTEM : Transport, lysosome to cytosol --- GENE NAME :
#
# ---
#
#
# 1.0 10,13,16,19-docosatetraenoic acid --> 1.0 10,13,16,19-docosatetraenoic acid
#
# 1.0 m00260s --> 1.0 m00260c
# FLUX : 0.05039357164381437 --- ID : HMR_0388 --- COMPARTMENT : {'C_s', 'C_c'}
#
# SUBSYSTEM : Transport, extracellular --- GENE NAME : FABP5/SLC27A1/FABP1/FABP12/SLC27A3/SLC27A4/FABP4/SLC27A6
#
# ---
#
#
# 1.0 NEFA blood pool in --> 0.0048 (10Z)-heptadecenoic acid + 0.0016 (11Z,14Z)-eicosadienoic acid + 0.0016 (11Z,14Z,17Z)-eicosatrienoic acid + 0.0001 (13Z)-eicosenoic acid + 0.0001 (13Z)-octadecenoic acid + 0.0001 (13Z,16Z)-docosadienoic acid + 0.0001 (4Z,7Z,10Z,13Z,16Z)-DPA + 0.0001 (6Z,9Z)-octadecadienoic acid + 0.0001 (6Z,9Z,12Z,15Z,18Z)-TPA + 0.0001 (6Z,9Z,12Z,15Z,18Z,21Z)-THA + 0.0001 (7Z)-octadecenoic acid + 0.0001 (7Z)-tetradecenoic acid + 0.0001 (9E)-tetradecenoic acid + 0.0001 (9Z,12Z,15Z,18Z)-TTA + 0.0001 (9Z,12Z,15Z,18Z,21Z)-TPA + 0.0001 10,13,16,19-docosatetraenoic acid + 0.0001 10,13,16-docosatriynoic acid + 0.0001 12,15,18,21-tetracosatetraenoic acid + 0.0001 13,16,19-docosatrienoic acid + 0.0001 7-palmitoleic acid + 0.0001 8,11-eicosadienoic acid + 0.0001 9-eicosenoic acid + 0.0001 9-heptadecylenic acid + 0.0017 adrenic acid + 0.0137 arachidonate + 0.0007 behenic acid + 0.0005 cerotic acid + 0.0001 cis-cetoleic acid + 0.0002 cis-erucic acid + 0.0001 cis-gondoic acid + 0.0001 cis-vaccenic acid + 0.0046 DHA + 0.0025 dihomo-gamma-linolenate + 0.0019 DPA + 0.0011 eicosanoate + 0.0001 elaidate + 0.002 EPA + 0.0048 gamma-linolenate + 0.0001 henicosanoic acid + 0.0034 lauric acid + 0.0012 lignocerate + 0.071 linoleate + 0.0005 linolenate + 0.0056 margaric acid + 0.0005 mead acid + 0.0283 myristic acid + 0.0003 nervonic acid + 0.0001 nonadecylic acid + 0.3746 oleate + 0.0001 omega-3-arachidonic acid + 0.2949 palmitate + 0.0686 palmitolate + 0.003 pentadecylic acid + 0.0001 physeteric acid + 0.1031 stearate + 0.0001 stearidonic acid + 0.0002 tricosanoic acid + 0.0001 tridecylic acid + 0.0001 ximenic acid
#
# 1.0 m02560s --> 0.0048 m00003s + 0.0016 m00008s + 0.0016 m00010s + 0.0001 m00017s + 0.0001 m00019s + 0.0001 m00021s + 0.0001 m00094s + 0.0001 m00104s + 0.0001 m00111s + 0.0001 m00114s + 0.0001 m00115s + 0.0001 m00117s + 0.0001 m00128s + 0.0001 m00132s + 0.0001 m00135s + 0.0001 m00260s + 0.0001 m00265s + 0.0001 m00315s + 0.0001 m00341s + 0.0001 m01197s + 0.0001 m01207s + 0.0001 m01235s + 0.0001 m01238s + 0.0017 m01291s + 0.0137 m01362s + 0.0007 m01373s + 0.0005 m01432s + 0.0001 m01582s + 0.0002 m01583s + 0.0001 m01584s + 0.0001 m01585s + 0.0046 m01689s + 0.0025 m01696s + 0.0019 m01741s + 0.0011 m01771s + 0.0001 m01778s + 0.002 m01784s + 0.0048 m01932s + 0.0001 m02053s + 0.0034 m02344s + 0.0012 m02385s + 0.071 m02387s + 0.0005 m02389s + 0.0056 m02456s + 0.0005 m02457s + 0.0283 m02494s + 0.0003 m02564s + 0.0001 m02613s + 0.3746 m02646s + 0.0001 m02648s + 0.2949 m02674s + 0.0686 m02675s + 0.003 m02690s + 0.0001 m02745s + 0.1031 m02938s + 0.0001 m02939s + 0.0002 m03045s + 0.0001 m03051s + 0.0001 m03153s
# FLUX : 503.93571643814363 --- ID : HMR_0015 --- COMPARTMENT : {'C_s'}
#
# SUBSYSTEM : Transport, extracellular --- GENE NAME :
#
# ---
#
#
# 1.0 NEFA blood pool in --> 1.0 NEFA blood pool in
#
# 1.0 m02560x --> 1.0 m02560s
# FLUX : 503.93571643814363 --- ID : HMR_9033 --- COMPARTMENT : {'C_s', 'C_x'}
#
# SUBSYSTEM : Exchange reactions --- GENE NAME :
#
# ---
#
#
# --> 1.0 NEFA blood pool in
#
# --> 1.0 m02560x
# FLUX : 503.93571643814363 --- ID : EX_m02560x --- COMPARTMENT : {'C_x'}
#
# SUBSYSTEM :  --- GENE NAME : EX_m02560x
#
# ---
#
#
# 1.0 (10Z)-heptadecenoic acid --> 1.0 (10Z)-heptadecenoic acid
#
# 1.0 m00003s --> 1.0 m00003c
# FLUX : 2.4188914389030893 --- ID : HMR_0240 --- COMPARTMENT : {'C_s', 'C_c'}
#
# SUBSYSTEM : Transport, extracellular --- GENE NAME : FABP5/SLC27A1/FABP1/FABP12/SLC27A3/SLC27A4/FABP4/SLC27A6
#
# ---
#
#
# 1.0 (10Z)-heptadecenoic acid + 1.0 ATP + 1.0 CoA --> 1.0 (10Z)-heptadecenoyl-CoA + 1.0 AMP + 1.0 PPi
#
# 1.0 m00003c + 1.0 m01371c + 1.0 m01597c --> 1.0 m00004c + 1.0 m01334c + 1.0 m02759c
# FLUX : 2.5274878968793475 --- ID : HMR_0241 --- COMPARTMENT : {'C_c'}
#
# SUBSYSTEM :
--- COMPARTMENT : {'C_c'}
#
# SUBSYSTEM : Pool reactions --- GENE NAME :
#
# ---
#
#
# 1.0 H2O + 1.0 PE-LD pool --> 1.0 1-acyl-PE pool + 1.0 fatty acid-LD-PE pool
#
# 1.0 m02040c + 1.0 m02685c --> 1.0 m00511c + 1.0 m01809c
# FLUX : 0.2229148242209817 --- ID : HMR_0643 --- COMPARTMENT : {'C_c'}
#
# SUBSYSTEM : Glycerophospholipid metabolism --- GENE NAME : PLA2G2A/PLB1/JMJD7-PLA2G4B/PLAAT3/PLA2G10/PLA2G4E/PLA2G4C/PLA2G2E/PLA2G2D/PLA2G5/PLA2G4D/PLA2G3/PLA2G4F/PLA2G4A/PLA2G1B/PLA2G12A/PLA2G6/PLA2G2F
#
# ---
#
#
# 1.0 PE-LD pool <-- 1.0 PE-LD pool
#
# 1.0 m02685c <-- 1.0 m02685r
# FLUX : -32.46404746059277 --- ID : HMR_0464 --- COMPARTMENT : {'C_c', 'C_r'}
#
# SUBSYSTEM : Transport, endoplasmic reticular --- GENE NAME :
#
# ---
#
#
# 1.0 PE-LD pool --> 1.0 PE-LD pool
#
# 1.0 m02685l --> 1.0 m02685r
# FLUX : 32.464047460592774 --- ID : HMR_5252 --- COMPARTMENT : {'C_l', 'C_r'}
#
# SUBSYSTEM : Transport, lysosome to ER --- GENE NAME :
#
# ---
#
#
# 1.0 PE-LD pool + 1.0 serine --> 1.0 ethanolamine + 1.0 PS-LD pool
#
# 1.0 m02685c + 1.0 m02896c --> 1.0 m01797c + 1.0 m02808c
# FLUX : 31.69976806326369 --- ID : HMR_0622 --- COMPARTMENT : {'C_c'}
#
# SUBSYSTEM : Glycerophospholipid metabolism --- GENE NAME : PTDSS2
#
# ---
#
#
# 1.0 serine --> 1.0 serine
#
# 1.0 m02896s --> 1.0 m02896c
# FLUX : 73.52562378139211 --- ID : HMR_5079 --- COMPARTMENT : {'C_s', 'C_c'}
#
# SUBSYSTEM : Transport, extracellular --- GENE NAME : SLC7A1/SLC7A5/SLC7A8/SLC43A1/SLC7A2/SLC36A1/SLC43A2/SLC3A2/SLC7A7/SLC7A10/SLC7A3
#
# ---
#
#
# 1.0 serine --> 1.0 serine
#
# 1.0 m02896x --> 1.0 m02896s
# FLUX : 73.52562378139211 --- ID : HMR_9069 --- COMPARTMENT : {'C_s', 'C_x'}
#
# SUBSYSTEM : Exchange reactions --- GENE NAME :
#
# ---
#
#
# --> 1.0 serine
#
# --> 1.0 m02896x
# FLUX : 73.52562378139211 --- ID : EX_m02896x --- COMPARTMENT : {'C_x'}
#
# SUBSYSTEM :  --- GENE NAME : EX_m02896x
#
# ---
#
#
# 1.0 serine --> 1.0 serine
#
# 1.0 m02896c --> 1.0 m02896p
# FLUX : 0.25475979910969215 --- ID : HMR_4468 --- COMPARTMENT : {'C_p', 'C_c'}
#
# SUBSYSTEM : Transport, peroxisomal --- GENE NAME :
#
# ---
#
#
# 1.0 serine --> 1.0 serine
#
# 1.0 m02896l --> 1.0 m02896c
# FLUX : 85.98585543616464 --- ID : HMR_5060 --- COMPARTMENT : {'C_l', 'C_c'}
#
# SUBSYSTEM : Transport, lysosomal --- GENE NAME : SLC36A1
#
# ---
#
#
# 1.0 apoB100_ + 2280.0 ATP + 2280.0 H2O --> 2280.0 ADP + 275.0 alanine + 150.0 arginine + 247.0 asparagine + 233.0 aspartate + 25.0 cysteine + 298.0 glutamate + 230.0 glutamine + 207.0 glycine + 115.0 histidine + 285.0 isoleucine + 533.0 leucine + 357.0 lysine + 79.0 methionine + 224.0 phenylalanine + 2280.0 Pi + 171.0 proline + 392.0 serine + 300.0 threonine + 37.0 tryptophan + 151.0 tyrosine + 252.0 valine
#
# 1.0 m01351l + 2280.0 m01371l + 2280.0 m02040l --> 2280.0 m01285l + 275.0 m01307l + 150.0 m01365l + 247.0 m01369l + 233.0 m01370l + 25.0 m01628l + 298.0 m01974l + 230.0 m01975l + 207.0 m01986l + 115.0 m02125l + 285.0 m02184l + 533.0 m02360l + 357.0 m02426l + 79.0 m02471l + 224.0 m02724l + 2280.0 m02751l + 171.0 m02770l + 392.0 m02896l + 300.0 m02993l + 37.0 m03089l + 151.0 m03101l + 252.0 m03135l
# FLUX : 0.1754813376248258 --- ID : HMR_5265 --- COMPARTMENT : {'C_l'}
#
# SUBSYSTEM : Protein degradation --- GENE NAME : CTSK/CTSW/TPP1/CTSE/CTSH/CTSA/CTSF/CTSZ/CTSD/CTSO/CTSC/CTSV/CTSL/CTSB
#
# ---
#
#
# 1.0 alanine --> 1.0 alanine
#
# 1.0 m01307l --> 1.0 m01307c
# FLUX : 96.16377301840454 --- ID : HMR_5064 --- COMPARTMENT : {'C_l', 'C_c'}
#
# SUBSYSTEM : Transport, lysosomal --- GENE NAME : SLC36A1
#
# ---
#
#
# 1.0 arginine --> 1.0 arginine
#
# 1.0 m01365l --> 1.0 m01365c
# FLUX : 68.0867589984324 --- ID : HMR_5048 --- COMPARTMENT : {'C_l', 'C_c'}
#
# SUBSYSTEM : Transport, lysosomal --- GENE NAME : SLC36A1
#
# ---
#
#
# 1.0 arginine + 1.0 glycine --> 1.0 arginine + 1.0 glycine
#
# 1.0 m01365s + 1.0 m01986c --> 1.0 m01365c + 1.0 m01986s
# FLUX : 596.8528950945858 --- ID : HMR_5923 --- COMPARTMENT : {'C_s', 'C_c'}
#
# SUBSYSTEM : Transport, extracellular --- GENE NAME : SLC7A6/SLC7A9/SLC3A1
#
# ---
#
#
# 1.0 arginine --> 1.0 arginine
#
# 1.0 m01365x --> 1.0 m01365s
# FLUX : 91.13811544512583 --- ID : HMR_9066 --- COMPARTMENT : {'C_s', 'C_x'}
#
# SUBSYSTEM : Exchange reactions --- GENE NAME :
#
# ---
#
#
# --> 1.0 arginine
#
# --> 1.0 m01365x
# FLUX : 91.13811544512583 --- ID : EX_m01365x --- COMPARTMENT : {'C_x'}
#
# SUBSYSTEM :  --- GENE NAME : EX_m01365x
#
# ---
#
#
# 1.0 arginine + 1.0 Na+ + 1.0 threonine --> 1.0 arginine + 1.0 Na+ + 1.0 threonine
#
# 1.0 m01365c + 1.0 m02519s + 1.0 m02993s --> 1.0 m01365s + 1.0 m02519c + 1.0 m02993c
# FLUX : 505.71477964946 --- ID : HMR_5893 --- COMPARTMENT : {'C_s', 'C_c'}
#
# SUBSYSTEM : Transport, extracellular --- GENE NAME : SLC7A6
#
# ---
#
#
# 1.0 leucine + 1.0 threonine <-- 1.0 leucine + 1.0 threonine
#
# 1.0 m02360c + 1.0 m02993s <-- 1.0 m02360s + 1.0 m02993c
# FLUX : -413.87473885383474 --- ID : HMR_5560 --- COMPARTMENT : {'C_s', 'C_c'}
#
# SUBSYSTEM : Transport, extracellular --- GENE NAME : SLC7A5
#
# ---
#
#
# 1.0 leucine --> 1.0 leucine
#
# 1.0 m02360l --> 1.0 m02360c
# FLUX : 143.89469685235716 --- ID : HMR_5055 --- COMPARTMENT : {'C_l', 'C_c'}
#
# SUBSYSTEM : Transport, lysosomal --- GENE NAME : SLC36A1
#
# ---
#
#
# 1.0 leucine --> 1.0 leucine
#
# 1.0 m02360c --> 1.0 m02360s
# FLUX : 398.5445612626336 --- ID : HMR_5085 --- COMPARTMENT : {'C_s', 'C_c'}
#
# SUBSYSTEM : Transport, extracellular --- GENE NAME : SLC7A1/SLC7A5/SLC7A8/SLC43A1/SLC7A2/SLC36A1/SLC43A2/SLC3A2/SLC7A7/SLC7A3
#
# ---
#
#
# 1.0 leucine --> 1.0 leucine
#
# 1.0 m02360x --> 1.0 m02360s
# FLUX : 15.330177591201164 --- ID : HMR_9040 --- COMPARTMENT : {'C_s', 'C_x'}
#
# SUBSYSTEM : Exchange reactions --- GENE NAME :
#
# ---
#
#
# --> 1.0 leucine
#
# ...
#  'HMR_0368': 0.05039357164381437,
#  'HMR_9752': 0.025860119086770363,
#  'HMR_3579': 0.025860119086770363,
#  'HMR_2493': 3.1290983101973104,
#  'HMR_2491': 3.1290983101973104,
#  'HMR_2489': 3.1290983101973104,
#  'HMR_2486': 3.1290983101973104,
#  'HMR_0525': 0.6850078574916859,
#  'HMR_2720': -9.075351558598149,
#  'HMR_2865': -9.075351558598149,
#  'HMR_2866': 9.075351558598149,
#  'HMR_2984': -9.075351558598149,
#  'HMR_2949': -61.023984501366016,
#  'HMR_2803': -61.023984501366016,
#  'HMR_2801': 61.023984501366016,
#  'HMR_2626': 61.023984501366016,
#  'HMR_0217': -199.14095257126192,
#  'HMR_0216': 148.61064277760855,
#  'HMR_9788': 35.686964339743106,
#  'HMR_3545': 35.686964339743106,
#  'HMR_9678': 0.6138072116416613,
#  'HMR_0709': 0.4864273120868146,
#  'HMR_2190': 60.60656836610772,
#  'HMR_2191': 60.60656836610772,
#  'HMR_2193': 60.60656836610772,
#  'HMR_2194': 60.60656836610772,
#  'HMR_2296': 0.3721345741434037,
#  'HMR_0504': 0.07965207645252162,
#  'HMR_2347': 0.1420963630155541,
#  'HMR_2348': 0.1420963630155541,
#  'HMR_2349': 0.1420963630155541,
#  'HMR_2350': 0.1420963630155541,
#  'HMR_0297': 0.15899002962007255,
#  'HMR_0296': 0.05039357164381437,
#  'HMR_9759': 0.025860119086770363,
#  'HMR_3562': 0.025860119086770363,
#  'HMR_2353': 0.07104818150777706,
#  'HMR_2354': 0.07104818150777706,
#  'HMR_2355': 0.07104818150777706,
#  'HMR_3146': 35.30286681291932,
#  'HMR_0175': -35.30286681291932,
#  'HMR_3032': -35.30286681291932,
#  'HMR_3033': -35.30286681291932,
#  'HMR_3034': 35.30286681291932,
#  'HMR_3030': 427.3241034831815,
#  'HMR_3029': -427.3241034831815,
#  'HMR_2591': -427.3241034831815,
#  'HMR_3097': 35.30286681291932,
#  'HMR_3096': 35.30286681291932,
#  'HMR_3095': 35.30286681291932,
#  'HMR_3094': 35.30286681291932,
#  'HMR_3984': 415.07045692808555,
#  'HMR_3849': 306.5761015376935,
#  'HMR_3850': 306.5761015376935,
#  'HMR_3867': -306.5761015376935,
#  'HMR_3848': -306.5761015376935,
#  'HMR_3102': 35.30286681291932,
#  'HMR_3101': 35.30286681291932,
#  'HMR_3100': 35.30286681291932,
#  'HMR_3099': 35.30286681291932,
#  'HMR_3098': 35.30286681291932,
#  'HMR_3103': 35.30286681291932,
#  'HMR_3104': 35.30286681291932,
#  'HMR_3105': 35.30286681291932,
#  'HMR_3947': 415.07045692808555,
#  'HMR_3980': 229.57095848469322,
#  'HMR_4201': 827.6244938675821,
#  'HMR_8043': 1000.0,
#  'HMR_8042': -1000.0,
#  'HMR_9265': 1000.0,
#  'EX_m01344x': 1000.0,
#  'HMR_8044': 1000.0,
#  'HMR_9306': -1000.0,
#  'EX_m01768x': -1000.0,
#  'HMR_5296': 172.37550613241785,
#  'HMR_9372': -172.37550613241785,
#  'EX_m02470x': -172.37550613241785,
#  'HMR_8408': -1000.0,
#  'HMR_9354': 1000.0,
#  'EX_m02041x': 1000.0,
#  'HMR_8619': 269.4255180208233,
#  'HMR_6396': 297.85856122999877,
#  'HMR_8846': 471.5669567908245,
#  'HMR_9301': -471.5669567908245,
#  'EX_m01655x': -471.5669567908245,
#  'HMR_6393': -500.0,
#  'HMR_6605': -500.0,
#  'HMR_6606': 500.0,
#  'HMR_7684': 1000.0,
#  'HMR_5007': 1000.0,
#  'HMR_4654': -262.01431041399024,
#  'HMR_5006': 262.01431041399024,
#  'HMR_4656': 262.01431041399024,
#  'HMR_4335': 262.01431041399024,
#  'HMR_3952': -262.01431041399024,
#  'HMR_9386': 1000.0,
#  'EX_m02147x': 1000.0,
#  'HMR_8618': -471.5669567908245,
#  'HMR_9158': 471.5669567908245,
#  'EX_m01368x': 471.5669567908245,
#  'HMR_8411': 461.1489639583534,
#  'HMR_8410': 230.5744819791767,
#  'HMR_3946': -162.98583172340767,
#  'HMR_3982': 33.79432512788452,
#  'HMR_3959': -1000.0,
#  'HMR_9383': 1000.0,
#  'EX_m02631x': 1000.0,
#  'HMR_3057': 0.1305261050674804,
#  'HMR_3022': 0.1305261050674804,
#  'HMR_0341': -0.36056431619533,
#  'HMR_9764': 0.025860119086770363,
#  'HMR_3572': 0.025860119086770363,
#  'HMR_0340': 0.2519678582190718,
#  'HMR_0520': 0.07965207645252162,
#  'HMR_3058': 0.1305261050674804,
#  'HMR_3059': 0.1305261050674804,
#  'HMR_3060': 0.1305261050674804,
#  'HMR_3106': -0.6138072116416993,
#  'HMR_3475': 570.5075184748512,
#  'HMR_9679': 570.5075184748512,
#  'HMR_8628': 356.24758357144106,
#  'HMR_8627': 356.24758357144106,
#  'HMR_8626': 356.24758357144106,
#  'HMR_3827': -467.18228095054394,
#  'HMR_4141': -467.18228095054394,
#  'HMR_6522': -380.73981582136025,
#  'HMR_4410': 1000.0,
#  'HMR_4964': 152.0779032280958,
#  'HMR_4957': 152.0779032280958,
#  'HMR_3825': 110.93469737910289,
#  'HMR_3829': -637.6433788293184,
#  'HMR_9737': 1000.0,
#  'HMR_9070': -1000.0,
#  'EX_m01370x': -1000.0,
#  'HMR_5050': 54.399214663696,
#  'HMR_6034': 1000.0,
#  'HMR_0155': -1000.0,
#  'HMR_9086': -1000.0,
#  'EX_m01252x': -1000.0,
#  'HMR_6015': -73.24489795370772,
#  'HMR_9133': 63.06110142515365,
#  'EX_m02819x': 63.06110142515365,
#  'HMR_6016': 136.30599937886143,
#  'HMR_6041': 136.30599937886143,
#  'HMR_5015': 136.30599937886143,
#  'HMR_4461': -136.30599937886143,
#  'HMR_9134': -136.30599937886143,
#  'EX_m00157x': -136.30599937886143,
#  'HMR_4358': 339.3719247248041,
#  'HMR_4363': 1000.0,
#  'HMR_4365': -1000.0,
#  'HMR_4368': 1000.0,
#  'HMR_4373': -1000.0,
#  'HMR_4193': 660.6280752751959,
#  'HMR_4930': 108.74911518950177,
#  'HMR_3256': 35.373914994427096,
#  'HMR_3254': 35.373914994427096,
#  'HMR_3252': 35.373914994427096,
#  'HMR_3250': 35.373914994427096,
#  'HMR_2640': 35.373914994427096,
#  'HMR_2638': -35.373914994427096,
#  'HMR_2636': -35.373914994427096,
#  'HMR_0494': 0.07965207645252162,
#  'HMR_0226': -35.603953205554944,
#  'HMR_9789': 0.025860119086770363,
#  'HMR_3547': 0.025860119086770363,
#  'HMR_0225': 34.56999014765665,
#  'HMR_0490': 0.07965207645252162,
#  'HMR_0204': 0.15899002962007255,
#  'HMR_9749': 0.025860119086770363,
#  'HMR_3542': 0.025860119086770363,
#  'HMR_0203': 0.05039357164381437,
#  'HMR_2281': 0.07104818150777706,
#  'HMR_0196': -13.219448106365988,
#  'HMR_9783': 2.0946696460283993,
#  'HMR_3540': 2.0946696460283993,
#  'HMR_8037': 4.347846527143162,
#  'HMR_8864': 4.347846527143162,
#  'HMR_9444': -4.347846527143162,
#  'EX_m00371x': -4.347846527143162,
#  'HMR_0195': 14.261380775199465,
#  'HMR_2284': 0.07104818150777706,
#  'HMR_0209': -0.15899002962007255,
#  'HMR_9791': 0.025860119086770363,
#  'HMR_3543': 0.025860119086770363,
#  'HMR_0208': 0.05039357164381437,
#  'HMR_0491': 0.07965207645252162,
#  'HMR_0488': 0.892103256268242,
#  'HMR_0200': 0.15899002962007255,
#  'HMR_9750': 0.025860119086770363,
#  'HMR_3541': 0.025860119086770363,
#  'HMR_0199': 0.05039357164381437,
#  'HMR_0489': 0.07965207645252162,
#  'HMR_2651': 2.4667991045147186,
#  'HMR_2652': -2.4667991045147186,
