# %%
import cobra
import pandas as pd
import importlib
import utils as u
import test_cutsets as tc
from itertools import combinations, combinations_with_replacement, permutations, chain, product
import pickle
from test_cutsets import itertools_product
from tqdm import tqdm
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 5
#       3 import importlib
#       4 import utils as u
# ----> 5 import test_cutsets as tc
#       6 from itertools import combinations, combinations_with_replacement, permutations, chain, product
#       7 import pickle
#
# ModuleNotFoundError: No module named 'test_cutsets'

# %%
importlib.reload(tc)
importlib.reload(u)
# Out:
# <module 'utils' from '/home/jmuller/Documents/Stage_metabo/aspmcs/code/utils.py'>

# %% [markdown]
# ## CNApy

# %%
targets = {"glucose_transporter" : ["HMR_9034", "EX_m01965x"],
"pkm2" : ["HMR_4358"],
"ldha" : ["HMR_4281"],
"dhfr" : ["HMR_4333"],
"tyms" : ["HMR_4644"],
"DNA pol" : ["HMR_7160"],
"statin" : ['HMR_1440', 'HMR_1445', 'HMR_1448_rev', 'HMR_1454', 'HMR_1465_rev', 'HMR_1467', 'HMR_1470', 'HMR_1473', 'HMR_1451', 'HMR_1457', 'HMR_1460']}

# %%
mcs_cnapy = np.load("../../cnapy/fv_mat.npy", allow_pickle=True)

# %%
reac_id = np.load("../../cnapy/2/reac_id.npy", allow_pickle=True).tolist()

# %%
mcs_list = mcs_cnapy.tolist()
mcs_reactions = []
for elem in mcs_list:
    v = elem.toarray()[0]
    v_l = v.tolist()
    if sum(v_l) < -1.0 :
        indices = [i for i, x in enumerate(v_l) if x == -1]
        reac_cs = [reac_id[i] for i in indices]
    else:
        reac_cs = [reac_id[v_l.index(-1)]]
    mcs_reactions.append(reac_cs)

# %%
for mcs in mcs_reactions:
    with HepG2 as cancer:
        for reac_id in mcs:
            # cut every reaction in the mcs
            cancer.reactions.get_by_id(reac_id).bounds = (0.0,0.0)
        HepG2.objective = "biomass_components"
        sol = HepG2.optimize()
        print(sol.objective_value)

# %% [markdown]
# ### Loading results and decompressing cutsets reactions

# %%
# pour parse output de maxime
# ce que fait parse output = lit le csv, c'est a dire les reactions avec flux(R) > 0 (support(R))
# ce qu'affiche clingo: cutset(R) = support(R) & interest(R), interest(R) étant les reactions rsub mais pas tgt ni m000x
# func ici, ça recupere réactions interest(R)
func = lambda x: x.startswith('mcs_rsub') and not x.endswith('tgt')

# %%
comp_cs_list = u.parse_output("../../aspefm_mcs_checker/output_mcs_statin.txt")

# %%
decompressed_cs_list = u.decompress_cutsets("../new_reactionSubsets.txt", comp_cs_list)

# %%
model = cobra.io.read_sbml_model('../../models_storage/HepG2_medium.xml')

# %%
healthy = cobra.io.read_sbml_model("../../models_storage/iHep_updated_v011.xml")

# %%
healthy.optimize()
# Out:
# <Solution 165.033 at 0x7fa462bf7940>

# %%
from collections import defaultdict

# %%
reactions_count = {}
for reaction in model.reactions:
    reactions_count[reaction.id] = reactions_count.get(reaction.id, 0) + 1

# %%
decompressed_cs_list[5:]
subsystems = {}
subsystems2reacs = defaultdict(list)
for cutset in decompressed_cs_list[5:]:
    for decomp_reac in cutset:
        for reac_id in decomp_reac:
            if reac_id.endswith("_rev"):
                reac_id = reac_id[:-4]
            subsystems[model.reactions.get_by_id(reac_id).subsystem] = subsystems.get(model.reactions.get_by_id(reac_id).subsystem, 1) + 1
            subsystems2reacs[model.reactions.get_by_id(reac_id).subsystem].append(reac_id)
            #print(reac_id)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 9
#       7 if reac_id.endswith("_rev"):
#       8     reac_id = reac_id[:-4]
# ----> 9 subsystems[model.reactions.get_by_id(reac_id).subsystem] = subsystems.get(model.reactions.get_by_id(reac_id).subsystem, 1) + 1
#      10 subsystems2reacs[model.reactions.get_by_id(reac_id).subsystem].append(reac_id)
#      11 #print(reac_id)
#
# NameError: name 'model' is not defined

# %% [markdown]
# ### glycogenesis
# HMR_9728

# %%
len(decompressed_cs_list[5:])
# Out:
# 3

# %%
h_c = healthy.copy()

# %%
decompressed_cs_list_path = "../results/vanilla_run/res_final/merged_decompressed_cutsets.p"
with open(decompressed_cs_list_path, "rb") as input_mcs:
    decompressed_cs_list = pickle.load(input_mcs)

# %%
flat_list = [item for sublist in decompressed_cs_list for item in sublist]

# %%
len(flat_list)
# Out:
# 14919

# %%
decompressed_cs_list
# Out:
# [[('EX_m02125x_rev',), ('HMR_9038',)],
#  [('EX_m02993x_rev',), ('HMR_9044',)],
#  [('HMR_1440', 'EX_temp006x'),
#   ('HMR_1440', 'HMR_9736_rev'),
#   ('HMR_1445', 'EX_temp006x'),
#   ('HMR_1445', 'HMR_9736_rev'),
#   ('HMR_1448_rev', 'EX_temp006x'),
#   ('HMR_1448_rev', 'HMR_9736_rev'),
#   ('HMR_1454', 'EX_temp006x'),
#   ('HMR_1454', 'HMR_9736_rev'),
#   ('HMR_1465_rev', 'EX_temp006x'),
#   ('HMR_1465_rev', 'HMR_9736_rev'),
#   ('HMR_1467', 'EX_temp006x'),
#   ('HMR_1467', 'HMR_9736_rev'),
#   ('HMR_1470', 'EX_temp006x'),
#   ('HMR_1470', 'HMR_9736_rev'),
#   ('HMR_1473', 'EX_temp006x'),
#   ('HMR_1473', 'HMR_9736_rev'),
#   ('HMR_1451', 'EX_temp006x'),
#   ('HMR_1451', 'HMR_9736_rev'),
#   ('HMR_1457', 'EX_temp006x'),
#   ('HMR_1457', 'HMR_9736_rev'),
#   ('HMR_1460', 'EX_temp006x'),
#   ('HMR_1460', 'HMR_9736_rev')],
#  [('HMR_3890', 'EX_m01975x_rev'), ('HMR_3890', 'HMR_9063')],
#  [('HMR_1495', 'HMR_1496', 'HMR_1535', 'EX_temp006x'),
#   ('HMR_1495', 'HMR_1496', 'HMR_1535', 'HMR_9736_rev'),
#   ('HMR_1495', 'HMR_1496', 'HMR_1536', 'EX_temp006x'),
#   ('HMR_1495', 'HMR_1496', 'HMR_1536', 'HMR_9736_rev'),
#   ('HMR_1495', 'HMR_1496', 'HMR_1538', 'EX_temp006x'),
#   ('HMR_1495', 'HMR_1496', 'HMR_1538', 'HMR_9736_rev'),
#   ('HMR_1495', 'HMR_1496', 'HMR_1539', 'EX_temp006x'),
#   ('HMR_1495', 'HMR_1496', 'HMR_1539', 'HMR_9736_rev'),
#   ('HMR_1495', 'HMR_1496', 'HMR_1540', 'EX_temp006x'),
#   ('HMR_1495', 'HMR_1496', 'HMR_1540', 'HMR_9736_rev'),
#   ('HMR_1495', 'HMR_1496', 'HMR_1543', 'EX_temp006x'),
#   ('HMR_1495', 'HMR_1496', 'HMR_1543', 'HMR_9736_rev'),
#   ('HMR_1495', 'HMR_1496', 'HMR_1544', 'EX_temp006x'),
#   ('HMR_1495', 'HMR_1496', 'HMR_1544', 'HMR_9736_rev'),
#   ('HMR_1495', 'HMR_1496', 'HMR_1545', 'EX_temp006x'),
#   ('HMR_1495', 'HMR_1496', 'HMR_1545', 'HMR_9736_rev'),
#   ('HMR_1495', 'HMR_1496', 'HMR_1546', 'EX_temp006x'),
#   ('HMR_1495', 'HMR_1496', 'HMR_1546', 'HMR_9736_rev'),
#   ('HMR_1495', 'HMR_1496', 'HMR_1547', 'EX_temp006x'),
#   ('HMR_1495', 'HMR_1496', 'HMR_1547', 'HMR_9736_rev'),
#   ('HMR_1495', 'HMR_1496', 'HMR_1548', 'EX_temp006x'),
#   ('HMR_1495', 'HMR_1496', 'HMR_
#   ('HMR_4885', 'HMR_4947_rev', 'HMR_4120', 'EX_m02040x_rev'),
#   ('HMR_4885', 'HMR_4947_rev', 'HMR_4120', 'HMR_9047'),
#   ('HMR_4885', 'HMR_4947_rev', 'HMR_9350_rev', 'EX_m02040x_rev'),
#   ('HMR_4885', 'HMR_4947_rev', 'HMR_9350_rev', 'HMR_9047')],
#  [('HMR_4947_rev', 'HMR_4060', 'EX_m03106x'),
#   ('HMR_4947_rev', 'HMR_4060', 'HMR_9435_rev')],
#  [('HMR_4947_rev', 'HMR_8487', 'EX_m03106x', 'EX_m03114x'),
#   ('HMR_4947_rev', 'HMR_8487', 'EX_m03106x', 'HMR_9436_rev'),
#   ('HMR_4947_rev', 'HMR_8487', 'HMR_9435_rev', 'EX_m03114x'),
#   ('HMR_4947_rev', 'HMR_8487', 'HMR_9435_rev', 'HMR_9436_rev')],
#  [('HMR_4947_rev', 'HMR_5035_rev', 'EX_m03106x', 'EX_m03114x', 'EX_m03123x'),
#   ('HMR_4947_rev', 'HMR_5035_rev', 'EX_m03106x', 'EX_m03114x', 'HMR_9439_rev'),
#   ('HMR_4947_rev', 'HMR_5035_rev', 'EX_m03106x', 'HMR_9436_rev', 'EX_m03123x'),
#   ('HMR_4947_rev',
#    'HMR_5035_rev',
#    'EX_m03106x',
#    'HMR_9436_rev',
#    'HMR_9439_rev'),
#   ('HMR_4947_rev', 'HMR_5035_rev', 'HMR_9435_rev', 'EX_m03114x', 'EX_m03123x'),
#   ('HMR_4947_rev',
#    'HMR_5035_rev',
#    'HMR_9435_rev',
#    'EX_m03114x',
#    'HMR_9439_rev'),
#   ('HMR_4947_rev',
#    'HMR_5035_rev',
#    'HMR_9435_rev',
#    'HMR_9436_rev',
#    'EX_m03123x'),
#   ('HMR_4947_rev',
#    'HMR_5035_rev',
#    'HMR_9435_rev',
#    'HMR_9436_rev',
#    'HMR_9439_rev')],
#  [('EX_m01369x_rev', 'HMR_3903'), ('HMR_9062', 'HMR_3903')],
#  [('EX_m02184x_rev',), ('HMR_9039',)],
#  [('HMR_4338', 'HMR_4437', 'EX_m01986x', 'HMR_4326', 'HMR_5143'),
#   ('HMR_4338', 'HMR_4437', 'HMR_9067_rev', 'HMR_4326', 'HMR_5143'),
#   ('HMR_4338', 'HMR_4658_rev', 'EX_m01986x', 'HMR_4326', 'HMR_5143'),
#   ('HMR_4338', 'HMR_4658_rev', 'HMR_9067_rev', 'HMR_4326', 'HMR_5143'),
#   ('HMR_4338', 'HMR_4660', 'EX_m01986x', 'HMR_4326', 'HMR_5143'),
#   ('HMR_4338', 'HMR_4660', 'HMR_9067_rev', 'HMR_4326', 'HMR_5143'),
#   ('HMR_4338', 'HMR_4712', 'EX_m01986x', 'HMR_4326', 'HMR_5143'),
#   ('HMR_4338', 'HMR_4712', 'HMR_9067_rev', 'HMR_4326', 'HMR_5143'),
#   ('HMR_4338', 'HMR_3929_rev', 'EX_m01986x', 'HMR_4326', 'HMR_5143'),
#   ('HMR_4338', 'HMR_3929_rev', 'HMR_9067_rev', 'HMR_4326', 'HMR_5143')],
#  [('HMR_4338', 'HMR_4437', 'EX_m01986x', 'HMR_4326', 'HMR_5131'),
#   ('HMR_4338', 'HMR_4437', 'HMR_9067_rev', 'HMR_4326', 'HMR_5131'),
#   ('HMR_4338', 'HMR_4658_rev', 'EX_m01986x', 'HMR_4326', 'HMR_5131'),
#   ('HMR_4338', 'HMR_4658_rev', 'HMR_9067_rev', 'HMR_4326', 'HMR_5131'),
#   ('HMR_4338', 'HMR_4660', 'EX_m01986x', 'HMR_4326', 'HMR_5131'),
#   ('HMR_4338', 'HMR_4660', 'HMR_9067_rev', 'HMR_4326', 'HMR_5131'),
#   ('HMR_4338', 'HMR_4712', 'EX_m01986x', 'HMR_4326', 'HMR_5131'),
#   ('HMR_4338', 'HMR_4712', 'HMR_9067_rev', 'HMR_4326', 'HMR_5131'),
#   ('HMR_4338', 'HMR_3929_rev', 'EX_m01986x', 'HMR_4326', 'HMR_5131'),
#   ('HMR_4338', 'HMR_3929_rev', 'HMR_9067_rev', 'HMR_4326', 'HMR_5131')],
#  [('HMR_4338', 'EX_m01308x', 'HMR_4437', 'EX_m01986x', 'HMR_4326'),
#   ('HMR_4338', 'EX_m01308x', 'HMR_4437', 'HMR_9067_rev', 'HMR_4326'),
#   ('HMR_4338', 'EX_m01308x', 'HMR_4658_rev', 'EX_m01986x', 'HMR_4326'),
#   ('HMR_4338', 'EX_m01308x', 'HMR_4658_rev', 'HMR_9067_rev', 'HMR_4326'),
#   ('HMR_4338', 'EX_m01308x', 'HMR_4660', 'EX_m01986x', 'HMR_4326'),
#   ('HMR_4338', 'EX_m01308x', 'HMR_4660', 'HMR_9067_rev', 'HMR_4326'),
#   ('HMR_4338', 'EX_m01308x', 'HMR_4712', 'EX_m01986x', 'HMR_4326'),
#   ('HMR_4338', 'EX_m01308x', 'HMR_4712', 'HMR_9067_rev', 'HMR_4326'),
#   ('HMR_4338', 'EX_m01308x', 'HMR_3929_rev', 'EX_m01986x', 'HMR_4326'),
#   ('HMR_4338', 'EX_m01308x', 'HMR_3929_rev', 'HMR_9067_rev', 'HMR_4326'),
#   ('HMR_4338', 'HMR_5198', 'HMR_4437', 'EX_m01986x', 'HMR_4326'),
#   ('HMR_4338', 'HMR_5198', 'HMR_4437', 'HMR_9067_rev', 'HMR_4326'),
#   ('HMR_4338', 'HMR_5198', 'HMR_4658_rev', 'EX_m01986x', 'HMR_4326'),
#   ('HMR_4338', 'HMR_5198', 'HMR_4658_rev', 'HMR_9067_rev', 'HMR_4326'),
#   ('HMR_4338', 'HMR_5198', 'HMR_4660', 'EX_m01986x', 'HMR_4326'),
#   ('HMR_4338', 'HMR_5198', 'HMR_4660', 'HMR_9067_rev', 'HMR_4326'),
#   ('HMR_4338', 'HMR_5198', 'HMR_4712', 'EX_m01986x', 'HMR_4326'),
#   ('HMR_4338', 'HMR_5198', 'HMR_4712', 'HMR_9067_rev', 'HMR_4326'),
#   ('HMR_4338', 'HMR_5198', 'HMR_3929_rev', 'EX_m01986x', 'HMR_4326'),
#   ('HMR_4338', 'HMR_5198', 'HMR_3929_rev', 'HMR_9067_rev', 'HMR_4326'),
#   ('HMR_4338', 'HMR_9730_rev', 'HMR_4437', 'EX_m01986x', 'HMR_4326'),
#   ('HMR_4338', 'HMR_9730_rev', 'HMR_4437', 'HMR_9067_rev', 'HMR_4326'),
#   ('HMR_4338', 'HMR_9730_rev', 'HMR_4658_rev', 'EX_m01986x', 'HMR_4326'),
#   ('HMR_4338', 'HMR_9730_rev', 'HMR_4658_rev', 'HMR_9067_rev', 'HMR_4326'),
#   ('HMR_4338', 'HMR_9730_rev', 'HMR_4660', 'EX_m01986x', 'HMR_4326'),
#   ('HMR_4338', 'HMR_9730_rev', 'HMR_4660', 'HMR_9067_rev', 'HMR_4326'),
#   ('HMR_4338', 'HMR_9730_rev', 'HMR_4712', 'EX_m01986x', 'HMR_4326'),
#   ('HMR_4338', 'HMR_9730_rev', 'HMR_4712', 'HMR_9067_rev', 'HMR_4326'),
#   ('HMR_4338', 'HMR_9730_rev', 'HMR_3929_rev', 'EX_m01986x', 'HMR_4326'),
#   ('HMR_4338', 'HMR_9730_rev', 'HMR_3929_rev', 'HMR_9067_rev', 'HMR_4326')],
#  [('HMR_4338', 'HMR_4437', 'EX_m01986x', 'HMR_4326', 'HMR_5130'),
#   ('HMR_4338', 'HMR_4437', 'HMR_9067_rev', 'HMR_4326', 'HMR_5130'),
#   ('HMR_4338', 'HMR_4658_rev', 'EX_m01986x', 'HMR_4326', 'HMR_5130'),
#   ('HMR_4338', 'HMR_4658_rev', 'HMR_9067_rev', 'HMR_4326', 'HMR_5130'),
#   ('HMR_4338', 'HMR_4660', 'EX_m01986x', 'HMR_4326', 'HMR_5130'),
#   ('HMR_4338', 'HMR_4660', 'HMR_9067_rev', 'HMR_4326', 'HMR_5130'),
#   ('HMR_4338', 'HMR_4712', 'EX_m01986x', 'HMR_4326', 'HMR_5130'),
#   ('HMR_4338', 'HMR_4712', 'HMR_9067_rev', 'HMR_4326', 'HMR_5130'),
#   ('HMR_4338', 'HMR_3929_rev', 'EX_m01986x', 'HMR_4326', 'HMR_5130'),
#   ('HMR_4338', 'HMR_3929_rev', 'HMR_9067_rev', 'HMR_4326', 'HMR_5130')],
#  [('HMR_4338', 'HMR_4437', 'EX_m01986x', 'HMR_4326', 'HMR_5134'),
#   ('HMR_4338', 'HMR_4437', 'HMR_9067_rev', 'HMR_4326', 'HMR_5134'),
#   ('HMR_4338', 'HMR_4658_rev', 'EX_m01986x', 'HMR_4326', 'HMR_5134'),
#   ('HMR_4338', 'HMR_4658_rev', 'HMR_9067_rev', 'HMR_4326', 'HMR_5134'),
#   ('HMR_4338', 'HMR_4660', 'EX_m01986x', 'HMR_4326', 'HMR_5134'),
#   ('HMR_4338', 'HMR_4660', 'HMR_9067_rev', 'HMR_4326', 'HMR_5134'),
#   ('HMR_4338', 'HMR_4712', 'EX_m01986x', 'HMR_4326', 'HMR_5134'),
#   ('HMR_4338', 'HMR_4712', 'HMR_9067_rev', 'HMR_4326', 'HMR_5134'),
#   ('HMR_4338', 'HMR_3929_rev', 'EX_m01986x', 'HMR_4326', 'HMR_5134'),
#   ('HMR_4338', 'HMR_3929_rev', 'HMR_9067_rev', 'HMR_4326', 'HMR_5134')],
#  [('HMR_4338', 'HMR_4437', 'EX_m01986x', 'HMR_4326', 'HMR_5139'),
#   ('HMR_4338', 'HMR_4437', 'HMR_9067_rev', 'HMR_4326', 'HMR_5139'),
#   ('HMR_4338', 'HMR_4658_rev', 'EX_m01986x', 'HMR_4326', 'HMR_5139'),
#   ('HMR_4338', 'HMR_4658_rev', 'HMR_9067_rev', 'HMR_4326', 'HMR_5139'),
#   ('HMR_4338', 'HMR_4660', 'EX_m01986x', 'HMR_4326', 'HMR_5139'),
#   ('HMR_4338', 'HMR_4660', 'HMR_9067_rev', 'HMR_4326', 'HMR_5139'),
#   ('HMR_4338', 'HMR_4712', 'EX_m01986x', 'HMR_4326', 'HMR_5139'),
#   ('HMR_4338', 'HMR_4712', 'HMR_9067_rev', 'HMR_4326', 'HMR_5139'),
#   ('HMR_4338', 'HMR_3929_rev', 'EX_m01986x', 'HMR_4326', 'HMR_5139'),
#   ('HMR_4338', 'HMR_3929_rev', 'HMR_9067_rev', 'HMR_4326', 'HMR_5139')],
#  [('HMR_4338', 'HMR_4437', 'EX_m01986x', 'HMR_4326', 'HMR_5151'),
#   ('HMR_4338', 'HMR_4437', 'HMR_9067_rev', 'HMR_4326', 'HMR_5151'),
#   ('HMR_4338', 'HMR_4658_rev', 'EX_m01986x', 'HMR_4326', 'HMR_5151'),
#   ('HMR_4338', 'HMR_4658_rev', 'HMR_9067_rev', 'HMR_4326', 'HMR_5151'),
#   ('HMR_4338', 'HMR_4660', 'EX_m01986x', 'HMR_4326', 'HMR_5151'),
#   ('HMR_4338', 'HMR_4660', 'HMR_9067_rev', 'HMR_4326', 'HMR_5151'),
#   ('HMR_4338', 'HMR_4712', 'EX_m01986x', 'HMR_4326', 'HMR_5151'),
#   ('HMR_4338', 'HMR_4712', 'HMR_9067_rev', 'HMR_4326', 'HMR_5151'),
#   ('HMR_4338', 'HMR_3929_rev', 'EX_m01986x', 'HMR_4326', 'HMR_5151'),
#   ('HMR_4338', 'HMR_3929_rev', 'HMR_9067_rev', 'HMR_4326', 'HMR_5151')],
#  [('HMR_4338', 'HMR_4437', 'EX_m01986x', 'HMR_4326', 'HMR_5140'),
#   ('HMR_4338', 'HMR_4437', 'HMR_9067_rev', 'HMR_4326', 'HMR_5140'),
#   ('HMR_4338', 'HMR_4658_rev', 'EX_m01986x', 'HMR_4326', 'HMR_5140'),
#   ('HMR_4338', 'HMR_4658_rev', 'HMR_9067_rev', 'HMR_4326', 'HMR_5140'),
#   ('HMR_4338', 'HMR_4660', 'EX_m01986x', 'HMR_4326', 'HMR_5140'),
#   ('HMR_4338', 'HMR_4660', 'HMR_9067_rev', 'HMR_4326', 'HMR_5140'),
#   ('HMR_4338', 'HMR_4712', 'EX_m01986x', 'HMR_4326', 'HMR_5140'),
#   ('HMR_4338', 'HMR_4712', 'HMR_9067_rev', 'HMR_4326', 'HMR_5140'),
#   ('HMR_4338', 'HMR_3929_rev', 'EX_m01986x', 'HMR_4326', 'HMR_5140'),
#   ('HMR_4338', 'HMR_3929_rev', 'HMR_9067_rev', 'HMR_4326', 'HMR_5140')],
#  [('HMR_4338', 'HMR_4437', 'EX_m01986x', 'HMR_4326', 'HMR_5138'),
#   ('HMR_4338', 'HMR_4437', 'HMR_9067_rev', 'HMR_4326', 'HMR_5138'),
#   ('HMR_4338', 'HMR_4658_rev', 'EX_m01986x', 'HMR_4326', 'HMR_5138'),
#   ('HMR_4338', 'HMR_4658_rev', 'HMR_9067_rev', 'HMR_4326', 'HMR_5138'),
#   ('HMR_4338', 'HMR_4660', 'EX_m01986x', 'HMR_4326', 'HMR_5138'),
#   ('HMR_4338', 'HMR_4660', 'HMR_9067_rev', 'HMR_4326', 'HMR_5138'),
#   ('HMR_4338', 'HMR_4712', 'EX_m01986x', 'HMR_4326', 'HMR_5138'),
#   ('HMR_4338', 'HMR_4712', 'HMR_9067_rev', 'HMR_4326', 'HMR_5138'),
#   ('HMR_4338', 'HMR_3929_rev', 'EX_m01986x', 'HMR_4326', 'HMR_5138'),
#   ('HMR_4338', 'HMR_3929_rev', 'HMR_9067_rev', 'HMR_4326', 'HMR_5138')],
#  [('HMR_4338', 'HMR_4437', 'EX_m01986x', 'HMR_4324', 'HMR_5139'),
#   ('HMR_4338', 'HMR_4437', 'HMR_9067_rev', 'HMR_4324', 'HMR_5139'),
#   ('HMR_4338', 'HMR_4658_rev', 'EX_m01986x', 'HMR_4324', 'HMR_5139'),
#   ('HMR_4338', 'HMR_4658_rev', 'HMR_9067_rev', 'HMR_4324', 'HMR_5139'),
#   ('HMR_4338', 'HMR_4660', 'EX_m01986x', 'HMR_4324', 'HMR_5139'),
#   ('HMR_4338', 'HMR_4660', 'HMR_9067_rev', 'HMR_4324', 'HMR_5139'),
#   ('HMR_4338', 'HMR_4712', 'EX_m01986x', 'HMR_4324', 'HMR_5139'),
#   ('HMR_4338', 'HMR_4712', 'HMR_9067_rev', 'HMR_4324', 'HMR_5139'),
#   ('HMR_4338', 'HMR_3929_rev', 'EX_m01986x', 'HMR_4324', 'HMR_5139'),
#   ('HMR_4338', 'HMR_3929_rev', 'HMR_9067_rev', 'HMR_4324', 'HMR_5139')],
#  [('HMR_4338', 'HMR_4437', 'EX_m01986x', 'HMR_4324', 'HMR_5131'),
#   ('HMR_4338', 'HMR_4437', 'HMR_9067_rev', 'HMR_4324', 'HMR_5131'),
#   ('HMR_4338', 'HMR_4658_rev', 'EX_m01986x', 'HMR_4324', 'HMR_5131'),
#   ('HMR_4338', 'HMR_4658_rev', 'HMR_9067_rev', 'HMR_4324', 'HMR_5131'),
#   ('HMR_4338', 'HMR_4660', 'EX_m01986x', 'HMR_4324', 'HMR_5131'),
#   ('HMR_4338', 'HMR_4660', 'HMR_9067_rev', 'HMR_4324', 'HMR_5131'),
#   ('HMR_4338', 'HMR_4712', 'EX_m01986x', 'HMR_4324', 'HMR_5131'),
#   ('HMR_4338', 'HMR_4712', 'HMR_9067_rev', 'HMR_4324', 'HMR_5131'),
#   ('HMR_4338', 'HMR_3929_rev', 'EX_m01986x', 'HMR_4324', 'HMR_5131'),
#   ('HMR_4338', 'HMR_3929_rev', 'HMR_9067_rev', 'HMR_4324', 'HMR_5131')],
#  [('HMR_4338', 'HMR_4437', 'EX_m01986x', 'HMR_4324', 'HMR_5130'),
#   ('HMR_4338', 'HMR_4437', 'HMR_9067_rev', 'HMR_4324', 'HMR_5130'),
#   ('HMR_4338', 'HMR_4658_rev', 'EX_m01986x', 'HMR_4324', 'HMR_5130'),
#   ('HMR_4338', 'HMR_4658_rev', 'HMR_9067_rev', 'HMR_4324', 'HMR_5130'),
#   ('HMR_4338', 'HMR_4660', 'EX_m01986x', 'HMR_4324', 'HMR_5130'),
#   ('HMR_4338', 'HMR_4660', 'HMR_9067_rev', 'HMR_4324', 'HMR_5130'),
#   ('HMR_4338', 'HMR_4712', 'EX_m01986x', 'HMR_4324', 'HMR_5130'),
#   ('HMR_4338', 'HMR_4712', 'HMR_9067_rev', 'HMR_4324', 'HMR_5130'),
#   ('HMR_4338', 'HMR_3929_rev', 'EX_m01986x', 'HMR_4324', 'HMR_5130'),
#   ('HMR_4338', 'HMR_3929_rev', 'HMR_9067_rev', 'HMR_4324', 'HMR_5130')],
#  [('HMR_4338', 'HMR_4437', 'EX_m01986x', 'HMR_4324', 'HMR_5138'),
#   ('HMR_4338', 'HMR_4437', 'HMR_9067_rev', 'HMR_4324', 'HMR_5138'),
#   ('HMR_4338', 'HMR_4658_rev', 'EX_m01986x', 'HMR_4324', 'HMR_5138'),
#   ('HMR_4338', 'HMR_4658_rev', 'HMR_9067_rev', 'HMR_4324', 'HMR_5138'),
#   ('HMR_4338', 'HMR_4660', 'EX_m01986x', 'HMR_4324', 'HMR_5138'),
#   ('HMR_4338', 'HMR_4660', 'HMR_9067_rev', 'HMR_4324', 'HMR_5138'),
#   ('HMR_4338', 'HMR_4712', 'EX_m01986x', 'HMR_4324', 'HMR_5138'),
#   ('HMR_4338', 'HMR_4712', 'HMR_9067_rev', 'HMR_4324', 'HMR_5138'),
#   ('HMR_4338', 'HMR_3929_rev', 'EX_m01986x', 'HMR_4324', 'HMR_5138'),
#   ('HMR_4338', 'HMR_3929_rev', 'HMR_9067_rev', 'HMR_4324', 'HMR_5138')],
#  [('HMR_4338', 'HMR_4437', 'EX_m01986x', 'HMR_4324', 'HMR_5143'),
#   ('HMR_4338', 'HMR_4437', 'HMR_9067_rev', 'HMR_4324', 'HMR_5143'),
#   ('HMR_4338', 'HMR_4658_rev', 'EX_m01986x', 'HMR_4324', 'HMR_5143'),
#   ('HMR_4338', 'HMR_4658_rev', 'HMR_9067_rev', 'HMR_4324', 'HMR_5143'),
#   ('HMR_4338', 'HMR_4660', 'EX_m01986x', 'HMR_4324', 'HMR_5143'),
#   ('HMR_4338', 'HMR_4660', 'HMR_9067_rev', 'HMR_4324', 'HMR_5143'),
#   ('HMR_4338', 'HMR_4712', 'EX_m01986x', 'HMR_4324', 'HMR_5143'),
#   ('HMR_4338', 'HMR_4712', 'HMR_9067_rev', 'HMR_4324', 'HMR_5143'),
#   ('HMR_4338', 'HMR_3929_rev', 'EX_m01986x', 'HMR_4324', 'HMR_5143'),
#   ('HMR_4338', 'HMR_3929_rev', 'HMR_9067_rev', 'HMR_4324', 'HMR_5143')],
#  [('HMR_4338', 'HMR_4437', 'EX_m01986x', 'HMR_4324', 'HMR_5151'),
#   ('HMR_4338', 'HMR_4437', 'HMR_9067_rev', 'HMR_4324', 'HMR_5151'),
#   ('HMR_4338', 'HMR_4658_rev', 'EX_m01986x', 'HMR_4324', 'HMR_5151'),
#   ('HMR_4338', 'HMR_4658_rev', 'HMR_9067_rev', 'HMR_4324', 'HMR_5151'),
#   ('HMR_4338', 'HMR_4660', 'EX_m01986x', 'HMR_4324', 'HMR_5151'),
#   ('HMR_4338', 'HMR_4660', 'HMR_9067_rev', 'HMR_4324', 'HMR_5151'),
#   ('HMR_4338', 'HMR_4712', 'EX_m01986x', 'HMR_4324', 'HMR_5151'),
#   ('HMR_4338', 'HMR_4712', 'HMR_9067_rev', 'HMR_4324', 'HMR_5151'),
#   ('HMR_4338', 'HMR_3929_rev', 'EX_m01986x', 'HMR_4324', 'HMR_5151'),
#   ('HMR_4338', 'HMR_3929_rev', 'HMR_9067_rev', 'HMR_4324', 'HMR_5151')],
#  [('HMR_4338', 'HMR_4437', 'EX_m01986x', 'HMR_4324', 'HMR_5140'),
#   ('HMR_4338', 'HMR_4437', 'HMR_9067_rev', 'HMR_4324', 'HMR_5140'),
#   ('HMR_4338', 'HMR_4658_rev', 'EX_m01986x', 'HMR_4324', 'HMR_5140'),
#   ('HMR_4338', 'HMR_4658_rev', 'HMR_9067_rev', 'HMR_4324', 'HMR_5140'),
#   ('HMR_4338', 'HMR_4660', 'EX_m01986x', 'HMR_4324', 'HMR_5140'),
#   ('HMR_4338', 'HMR_4660', 'HMR_9067_rev', 'HMR_4324', 'HMR_5140'),
#   ('HMR_4338', 'HMR_4712', 'EX_m01986x', 'HMR_4324', 'HMR_5140'),
#   ('HMR_4338', 'HMR_4712', 'HMR_9067_rev', 'HMR_4324', 'HMR_5140'),
#   ('HMR_4338', 'HMR_3929_rev', 'EX_m01986x', 'HMR_4324', 'HMR_5140'),
#   ('HMR_4338', 'HMR_3929_rev', 'HMR_9067_rev', 'HMR_4324', 'HMR_5140')],
#  [('HMR_4338', 'HMR_4437', 'EX_m01986x', 'HMR_4324', 'HMR_5134'),
#   ('HMR_4338', 'HMR_4437', 'HMR_9067_rev', 'HMR_4324', 'HMR_5134'),
#   ('HMR_4338', 'HMR_4658_rev', 'EX_m01986x', 'HMR_4324', 'HMR_5134'),
#   ('HMR_4338', 'HMR_4658_rev', 'HMR_9067_rev', 'HMR_4324', 'HMR_5134'),
#   ('HMR_4338', 'HMR_4660', 'EX_m01986x', 'HMR_4324', 'HMR_5134'),
#   ('HMR_4338', 'HMR_4660', 'HMR_9067_rev', 'HMR_4324', 'HMR_5134'),
#   ('HMR_4338', 'HMR_4712', 'EX_m01986x', 'HMR_4324', 'HMR_5134'),
#   ('HMR_4338', 'HMR_4712', 'HMR_9067_rev', 'HMR_4324', 'HMR_5134'),
#   ('HMR_4338', 'HMR_3929_rev', 'EX_m01986x', 'HMR_4324', 'HMR_5134'),
#   ('HMR_4338', 'HMR_3929_rev', 'HMR_9067_rev', 'HMR_4324', 'HMR_5134')],
#  [('HMR_4338', 'EX_m01308x', 'HMR_4437', 'EX_m01986x', 'HMR_4324'),
#   ('HMR_4338', 'EX_m01308x', 'HMR_4437', 'HMR_9067_rev', 'HMR_4324'),
#   ('HMR_4338', 'EX_m01308x', 'HMR_4658_rev', 'EX_m01986x', 'HMR_4324'),
#   ('HMR_4338', 'EX_m01308x', 'HMR_4658_rev', 'HMR_9067_rev', 'HMR_4324'),
#   ('HMR_4338', 'EX_m01308x', 'HMR_4660', 'EX_m01986x', 'HMR_4324'),
#   ('HMR_4338', 'EX_m01308x', 'HMR_4660', 'HMR_9067_rev', 'HMR_4324'),
#   ('HMR_4338', 'EX_m01308x', 'HMR_4712', 'EX_m01986x', 'HMR_4324'),
#   ('HMR_4338', 'EX_m01308x', 'HMR_4712', 'HMR_9067_rev', 'HMR_4324'),
#   ('HMR_4338', 'EX_m01308x', 'HMR_3929_rev', 'EX_m01986x', 'HMR_4324'),
#   ('HMR_4338', 'EX_m01308x', 'HMR_3929_rev', 'HMR_9067_rev', 'HMR_4324'),
#   ('HMR_4338', 'HMR_5198', 'HMR_4437', 'EX_m01986x', 'HMR_4324'),
#   ('HMR_4338', 'HMR_5198', 'HMR_4437', 'HMR_9067_rev', 'HMR_4324'),
#   ('HMR_4338', 'HMR_5198', 'HMR_4658_rev', 'EX_m01986x', 'HMR_4324'),
#   ('HMR_4338', 'HMR_5198', 'HMR_4658_rev', 'HMR_9067_rev', 'HMR_4324'),
#   ('HMR_4338', 'HMR_5198', 'HMR_4660', 'EX_m01986x', 'HMR_4324'),
#   ('HMR_4338', 'HMR_5198', 'HMR_4660', 'HMR_9067_rev', 'HMR_4324'),
#   ('HMR_4338', 'HMR_5198', 'HMR_4712', 'EX_m01986x', 'HMR_4324'),
#   ('HMR_4338', 'HMR_5198', 'HMR_4712', 'HMR_9067_rev', 'HMR_4324'),
#   ('HMR_4338', 'HMR_5198', 'HMR_3929_rev', 'EX_m01986x', 'HMR_4324'),
#   ('HMR_4338', 'HMR_5198', 'HMR_3929_rev', 'HMR_9067_rev', 'HMR_4324'),
#   ('HMR_4338', 'HMR_9730_rev', 'HMR_4437', 'EX_m01986x', 'HMR_4324'),
#   ('HMR_4338', 'HMR_9730_rev', 'HMR_4437', 'HMR_9067_rev', 'HMR_4324'),
#   ('HMR_4338', 'HMR_9730_rev', 'HMR_4658_rev', 'EX_m01986x', 'HMR_4324'),
#   ('HMR_4338', 'HMR_9730_rev', 'HMR_4658_rev', 'HMR_9067_rev', 'HMR_4324'),
#   ('HMR_4338', 'HMR_9730_rev', 'HMR_4660', 'EX_m01986x', 'HMR_4324'),
#   ('HMR_4338', 'HMR_9730_rev', 'HMR_4660', 'HMR_9067_rev', 'HMR_4324'),
#   ('HMR_4338', 'HMR_9730_rev', 'HMR_4712', 'EX_m01986x', 'HMR_4324'),
#   ('HMR_4338', 'HMR_9730_rev', 'HMR_4712', 'HMR_9067_rev', 'HMR_4324'),
#   ('HMR_4338', 'HMR_9730_rev', 'HMR_3929_rev', 'EX_m01986x', 'HMR_4324'),
#   ('HMR_4338', 'HMR_9730_rev', 'HMR_3929_rev', 'HMR_9067_rev', 'HMR_4324')],
#  [('HMR_3940', 'HMR_8539', 'EX_m03101x_rev'),
#   ('HMR_3940', 'HMR_8539', 'HMR_9064')],
#  [('HMR_8538', 'HMR_3940', 'EX_m03101x_rev'),
#   ('HMR_8538', 'HMR_3940', 'HMR_9064')],
#  [('EX_m01308x', 'EX_m01513x_rev', 'EX_m01628x', 'HMR_4324', 'EX_m02946x'),
#   ('EX_m01308x', 'EX_m01513x_rev', 'EX_m01628x', 'HMR_4324', 'HMR_3865'),
#   ('EX_m01308x', 'EX_m01513x_rev', 'EX_m01628x', 'HMR_4324', 'HMR_3866'),
#   ('EX_m01308x', 'EX_m01513x_rev', 'EX_m01628x', 'HMR_4324', 'HMR_3908'),
#   ('EX_m01308x', 'EX_m01513x_rev', 'EX_m01628x', 'HMR_4324', 'HMR_9074_rev'),
#   ('EX_m01308x', 'EX_m01513x_rev', 'HMR_9065_rev', 'HMR_4324', 'EX_m02946x'),
#   ('EX_m01308x', 'EX_m01513x_rev', 'HMR_9065_rev', 'HMR_4324', 'HMR_3865'),
#   ('EX_m01308x', 'EX_m01513x_rev', 'HMR_9065_rev', 'HMR_4324', 'HMR_3866'),
#   ('EX_m01308x', 'EX_m01513x_rev', 'HMR_9065_rev', 'HMR_4324', 'HMR_3908'),
#   ('EX_m01308x', 'EX_m01513x_rev', 'HMR_9065_rev', 'HMR_4324', 'HMR_9074_rev'),
#   ('EX_m01308x', 'HMR_4954_rev', 'EX_m01628x', 'HMR_4324', 'EX_m02946x'),
#   ('HMR_9055', 'HMR_1512', 'HMR_1549', 'HMR_1570'),
#   ('HMR_9055', 'HMR_1512', 'HMR_1550', 'HMR_1570'),
#   ('HMR_9055', 'HMR_1512', 'HMR_1551', 'HMR_1570'),
#   ('HMR_9055', 'HMR_1512', 'HMR_1552', 'HMR_1570')],
#  [('HMR_0018_rev', 'HMR_1512', 'HMR_1535', 'HMR_1570'),
#   ('HMR_0018_rev', 'HMR_1512', 'HMR_1536', 'HMR_1570'),
#   ('HMR_0018_rev', 'HMR_1512', 'HMR_1538', 'HMR_1570'),
#   ('HMR_0018_rev', 'HMR_1512', 'HMR_1539', 'HMR_1570'),
#   ('HMR_0018_rev', 'HMR_1512', 'HMR_1540', 'HMR_1570'),
#   ('HMR_0018_rev', 'HMR_1512', 'HMR_1543', 'HMR_1570'),
#   ('HMR_0018_rev', 'HMR_1512', 'HMR_1544', 'HMR_1570'),
#   ('HMR_0018_rev', 'HMR_1512', 'HMR_1545', 'HMR_1570'),
#   ('HMR_0018_rev', 'HMR_1512', 'HMR_1546', 'HMR_1570'),
#   ('HMR_0018_rev', 'HMR_1512', 'HMR_1547', 'HMR_1570'),
#   ('HMR_0018_rev', 'HMR_1512', 'HMR_1548', 'HMR_1570'),
#   ('HMR_0018_rev', 'HMR_1512', 'HMR_1549', 'HMR_1570'),
#   ('HMR_0018_rev', 'HMR_1512', 'HMR_1550', 'HMR_1570'),
#   ('HMR_0018_rev', 'HMR_1512', 'HMR_1551', 'HMR_1570'),
#   ('HMR_0018_rev', 'HMR_1512', 'HMR_1552', 'HMR_1570')]]

# %% [markdown]
# ### Cell testinf every combination of every cutset

# %%
def test_cutsets_comb(decompressed_cs_list, model, objective, bounds_modifications = None):    
    i = 0
    invalid_cutsets_comb_index = []
    invalid_cutsets_index = {}
    fluxes_per_cs = []
    not_in_healthy = []
    for cutset_reaction_combinations in decompressed_cs_list:
        j = 0
        cs_fluxes = {}
        #For each combination of the cutset:
        for cutset_combination in cutset_reaction_combinations:
            #print("reactions_id: " + str(reactions_id))
            #reactions_bounds = []
            with model as model_buffer:
                # Cut reactions from MCS
                for rid in cutset_combination:
                    #print("rid: "+str(rid))
                    if rid.endswith("rev"): 
                        rid = rid[:-4]
                    try:
                        #reactions_bounds.append(model_buffer.reactions.get_by_id(rid).bounds)
                        model_buffer.reactions.get_by_id(rid).bounds = (0.0,0.0)
                        
                    except KeyError:
                        not_in_healthy.append(rid)
                # Apply bounds modifications
                
                model_buffer.objective = objective
                sol = model_buffer.optimize()
                if sol.objective_value > 1e-6:
                    #print(f"\nCutset {reactions_id} has no impact on neoglucogenesis")
                    pass
                else:
                    print(f"\nCutset {cutset_combination} prevents neoglucogenesis")
                    invalid_cutsets_comb_index.append(cutset_reaction_combinations.index(cutset_combination))
                    
                for reaction in model_buffer.reactions:
                    cs_fluxes[reaction] = reaction.flux
                fluxes_per_cs.append(cs_fluxes)
                # for reaction in model.reactions:
                #     cs_fluxes[reaction] = reaction.fluxes

                #restoring bounds
                
        if len(invalid_cutsets_index) > 0:
            invalid_cutsets_index[decompressed_cs_list.index(cutset_reaction_combinations)] = invalid_cutsets_comb_index
        j+=1

    i+=1
    print(not_in_healthy)
    return invalid_cutsets_comb_index, fluxes_per_cs

# %% [markdown]
# ### Testing only the first combination of every cutset

# %%
def test_cutsets(decompressed_cs_list, model, objective, bounds_modifications = None):
    i = 0
    invalid_cutsets_comb_index = []
    invalid_cutsets_index = {}
    fluxes_per_cs = []
    # Before anything, we copy the model, and apply the bounds changes if needed
    model_working_copy = model.copy()
    if bounds_modifications:
        for reaction, bounds in bounds_modifications:
            model_working_copy.reactions.get_by_id(reaction).bounds = bounds

    for cutset_reaction_combinations in decompressed_cs_list:
        j = 0
        
        cs_fluxes = {}
        #Take the first cutset combination :
        cutset_combination = cutset_reaction_combinations[0]
  
        #reactions_bounds = []
        #modified_reactions_bounds = []
        with model as model_buffer:
            for rid in cutset_combination:
                
                #print("rid: "+str(rid))
                if rid.endswith("rev"): 
                    rid = rid[:-4]
                try:
                    #reactions_bounds.append(model_buffer.reactions.get_by_id(rid).bounds)
                    model_buffer.reactions.get_by_id(rid).bounds = (0.0,0.0)
                    
                except KeyError:
                    pass
            

            model_buffer.objective = objective
            sol = model_buffer.optimize()

            if sol.objective_value > 1e-6:
                #print(f"\nCutset {reactions_id} has no impact on neoglucogenesis")
                pass
            else:
                print(f"\nCutset {cutset_combination} prevents {objective}")
                invalid_cutsets_comb_index.append(cutset_reaction_combinations.index(cutset_combination))
        
            for reaction in model_buffer.reactions:
                cs_fluxes[reaction] = reaction.flux
            fluxes_per_cs.append(cs_fluxes)
        # #restoring bounds
        # for rid, rbounds in zip(cutset_combination, reactions_bounds):
        #     if rid.endswith("rev"):
        #         rid = rid[:-4]
        #     try:
        #         model.reactions.get_by_id(rid).bounds = rbounds
        #     except KeyError:
        #         pass
                
        if len(invalid_cutsets_comb_index) > 0:
            invalid_cutsets_index[decompressed_cs_list.index(cutset_reaction_combinations)] = invalid_cutsets_comb_index
        j+=1

    i+=1
    return invalid_cutsets_comb_index, fluxes_per_cs

invalid_cs_index, flux2cutset = test_cutsets(decompressed_cs_list, h_c,"HMR_9728")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[89], line 64
#      61     i+=1
#      62     return invalid_cutsets_comb_index, fluxes_per_cs
# ---> 64 invalid_cs_index, flux2cutset = test_cutsets(decompressed_cs_list, h_c,"HMR_9728")
#
# Cell In[89], line 46, in test_cutsets(decompressed_cs_list, model, objective, bounds_modifications)
#      43         invalid_cutsets_comb_index.append(cutset_reaction_combinations.index(cutset_combination))
#      45     for reaction in model_buffer.reactions:
# ---> 46         cs_fluxes[reaction] = reaction.flux
#      47     fluxes_per_cs.append(cs_fluxes)
#      48 # #restoring bounds
#      49 # for rid, rbounds in zip(cutset_combination, reactions_bounds):
#      50 #     if rid.endswith("rev"):
#    (...)
#      54 #     except KeyError:
#      55 #         pass
#
# File ~/miniconda3/envs/rba/lib/python3.10/site-packages/cobra/core/reaction.py:498, in Reaction.flux(self)
#     496 try:
#     497     check_solver_status(self._model.solver.status)
# --> 498     return self.forward_variable.primal - self.reverse_variable.primal
#     499 except AttributeError:
#     500     raise RuntimeError(f"reaction '{self.id}' is not part of a model")
#
# File ~/miniconda3/envs/rba/lib/python3.10/site-packages/optlang/interface.py:280, in Variable.primal(self)
#     278 """The primal of variable (None if no solution exists)."""
#     279 if self.problem:
# --> 280     return self._get_primal()
#     281 else:
#     282     return None
#
# File ~/miniconda3/envs/rba/lib/python3.10/site-packages/optlang/cplex_interface.py:190, in Variable._get_primal(self)
#     188 def _get_primal(self):
#     189     try:
# --> 190         return self.problem.problem.solution.get_values(self.name)
#     191     except CplexSolverError as err:
#     192         raise SolverError(str(err))
#
# File ~/miniconda3/envs/rba/lib/python3.10/site-packages/cplex/_internal/_subinterfaces.py:7247, in SolutionInterface.get_values(self, *args)
#    7245 def getx(a, b=self._cplex.variables.get_num() - 1):
#    7246     return CPX_PROC.getx(self._env._e, self._cplex._lp, a, b)
# -> 7247 return apply_freeform_two_args(
#    7248     getx, self._cplex.variables._conv, args)
#
# File ~/miniconda3/envs/rba/lib/python3.10/site-packages/cplex/_internal/_aux_functions.py:149, in apply_freeform_two_args(fn, conv, args, unpack_single)
#     147 conarg0 = conv(args[0])
#     148 if isinstance(conarg0, int):
# --> 149     result = fn(conarg0, conarg0)
#     150     if unpack_single:
#     151         return result[0]
#
# File ~/miniconda3/envs/rba/lib/python3.10/site-packages/cplex/_internal/_subinterfaces.py:7246, in SolutionInterface.get_values.<locals>.getx(a, b)
#    7245 def getx(a, b=self._cplex.variables.get_num() - 1):
# -> 7246     return CPX_PROC.getx(self._env._e, self._cplex._lp, a, b)
#
# File ~/miniconda3/envs/rba/lib/python3.10/site-packages/cplex/_internal/_procedural.py:2062, in getx(env, lp, begin, end)
#    2060 xlen = _rangelen(begin, end)
#    2061 x = _safeDoubleArray(xlen)
# -> 2062 status = CR.CPXXgetx(env, lp, x, begin, end)
#    2063 check_status(env, status)
#    2064 return LAU.array_to_list(x, xlen)
#
# File ~/miniconda3/envs/rba/lib/python3.10/site-packages/cplex/_internal/_pycplex.py:1773, in CPXXgetx(env, lp, x, begin, end)
#    1772 def CPXXgetx(env: 'CPXCENVptr', lp: 'CPXCLPptr', x: 'double *', begin: 'CPXDIM', end: 'CPXDIM') -> "int":
# -> 1773     return _pycplex_platform.CPXXgetx(env, lp, x, begin, end)
#
# KeyboardInterrupt:

# %%
objective_reaction_list = ["biomass_components", "HMR_9728", "HMR_5401"]
objective2result = {}
for objective_reaction in objective_reaction_list:
    print(f"\nTesting Objective n°{objective_reaction_list.index(objective_reaction)+1}/{len(objective_reaction_list)}")
    invalid_cs_index, flux2cutset = test_cutsets_comb(decompressed_cs_list, h_c, objective_reaction)
    objective2result[objective_reaction] = (invalid_cs_index, flux2cutset)
# Out:
# Testing Objective n°1/3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[91], line 5
#       3 for objective_reaction in objective_reaction_list:
#       4     print(f"\nTesting Objective n°{objective_reaction_list.index(objective_reaction)+1}/{len(objective_reaction_list)}")
# ----> 5     invalid_cs_index, flux2cutset = test_cutsets_comb(decompressed_cs_list, h_c, objective_reaction)
#       6     objective2result[objective_reaction] = (invalid_cs_index, flux2cutset)
#
# Cell In[90], line 36, in test_cutsets_comb(decompressed_cs_list, model, objective, bounds_modifications)
#      33     invalid_cutsets_comb_index.append(cutset_reaction_combinations.index(cutset_combination))
#      35 for reaction in model_buffer.reactions:
# ---> 36     cs_fluxes[reaction] = reaction.flux
#      37 fluxes_per_cs.append(cs_fluxes)
#      38 # for reaction in model.reactions:
#      39 #     cs_fluxes[reaction] = reaction.fluxes
#      40
#      41 #restoring bounds
#
# File ~/miniconda3/envs/rba/lib/python3.10/site-packages/cobra/core/reaction.py:498, in Reaction.flux(self)
#     496 try:
#     497     check_solver_status(self._model.solver.status)
# --> 498     return self.forward_variable.primal - self.reverse_variable.primal
#     499 except AttributeError:
#     500     raise RuntimeError(f"reaction '{self.id}' is not part of a model")
#
# File ~/miniconda3/envs/rba/lib/python3.10/site-packages/optlang/interface.py:280, in Variable.primal(self)
#     278 """The primal of variable (None if no solution exists)."""
#     279 if self.problem:
# --> 280     return self._get_primal()
#     281 else:
#     282     return None
#
# File ~/miniconda3/envs/rba/lib/python3.10/site-packages/optlang/cplex_interface.py:190, in Variable._get_primal(self)
#     188 def _get_primal(self):
#     189     try:
# --> 190         return self.problem.problem.solution.get_values(self.name)
#     191     except CplexSolverError as err:
#     192         raise SolverError(str(err))
#
# File ~/miniconda3/envs/rba/lib/python3.10/site-packages/cplex/_internal/_subinterfaces.py:7247, in SolutionInterface.get_values(self, *args)
#    7245 def getx(a, b=self._cplex.variables.get_num() - 1):
#    7246     return CPX_PROC.getx(self._env._e, self._cplex._lp, a, b)
# -> 7247 return apply_freeform_two_args(
#    7248     getx, self._cplex.variables._conv, args)
#
# File ~/miniconda3/envs/rba/lib/python3.10/site-packages/cplex/_internal/_aux_functions.py:149, in apply_freeform_two_args(fn, conv, args, unpack_single)
#     147 conarg0 = conv(args[0])
#     148 if isinstance(conarg0, int):
# --> 149     result = fn(conarg0, conarg0)
#     150     if unpack_single:
#     151         return result[0]
#
# File ~/miniconda3/envs/rba/lib/python3.10/site-packages/cplex/_internal/_subinterfaces.py:7246, in SolutionInterface.get_values.<locals>.getx(a, b)
#    7245 def getx(a, b=self._cplex.variables.get_num() - 1):
# -> 7246     return CPX_PROC.getx(self._env._e, self._cplex._lp, a, b)
#
# File ~/miniconda3/envs/rba/lib/python3.10/site-packages/cplex/_internal/_procedural.py:2062, in getx(env, lp, begin, end)
#    2060 xlen = _rangelen(begin, end)
#    2061 x = _safeDoubleArray(xlen)
# -> 2062 status = CR.CPXXgetx(env, lp, x, begin, end)
#    2063 check_status(env, status)
#    2064 return LAU.array_to_list(x, xlen)
#
# File ~/miniconda3/envs/rba/lib/python3.10/site-packages/cplex/_internal/_pycplex.py:1773, in CPXXgetx(env, lp, x, begin, end)
#    1772 def CPXXgetx(env: 'CPXCENVptr', lp: 'CPXCLPptr', x: 'double *', begin: 'CPXDIM', end: 'CPXDIM') -> "int":
# -> 1773     return _pycplex_platform.CPXXgetx(env, lp, x, begin, end)
#
# KeyboardInterrupt:

# %%
model.reactions.get_by_id("HMR_4075").subsystem
# Out:
# 'Arginine and proline metabolism'

# %% [markdown]
# ### Décompression des cutsets

# %%
model = cobra.io.read_sbml_model('../../models_storage/HepG2_medium.xml')
compressed_model = cobra.io.read_sbml_model("../new_reduced.xml")
# Out:
# Adding exchange reaction EX_ext_1 with default bounds for boundary metabolite: ext_1.
# Adding exchange reaction EX_ext_10 with default bounds for boundary metabolite: ext_10.
# Adding exchange reaction EX_ext_11 with default bounds for boundary metabolite: ext_11.
# Adding exchange reaction EX_ext_12 with default bounds for boundary metabolite: ext_12.
# Adding exchange reaction EX_ext_13 with default bounds for boundary metabolite: ext_13.
# Adding exchange reaction EX_ext_14 with default bounds for boundary metabolite: ext_14.
# Adding exchange reaction EX_ext_15 with default bounds for boundary metabolite: ext_15.
# Adding exchange reaction EX_ext_16 with default bounds for boundary metabolite: ext_16.
# Adding exchange reaction EX_ext_17 with default bounds for boundary metabolite: ext_17.
# Adding exchange reaction EX_ext_18 with default bounds for boundary metabolite: ext_18.
# Adding exchange reaction EX_ext_19 with default bounds for boundary metabolite: ext_19.
# Adding exchange reaction EX_ext_2 with default bounds for boundary metabolite: ext_2.
# Adding exchange reaction EX_ext_20 with default bounds for boundary metabolite: ext_20.
# Adding exchange reaction EX_ext_21 with default bounds for boundary metabolite: ext_21.
# Adding exchange reaction EX_ext_22 with default bounds for boundary metabolite: ext_22.
# Adding exchange reaction EX_ext_23 with default bounds for boundary metabolite: ext_23.
# Adding exchange reaction EX_ext_24 with default bounds for boundary metabolite: ext_24.
# Adding exchange reaction EX_ext_25 with default bounds for boundary metabolite: ext_25.
# Adding exchange reaction EX_ext_26 with default bounds for boundary metabolite: ext_26.
# Adding exchange reaction EX_ext_27 with default bounds for boundary metabolite: ext_27.
# Adding exchange reaction EX_ext_28 with default bounds for boundary metabolite: ext_28.
# Adding exchange reaction EX_ext_29 with default bounds for boundary metabolite: ext_29.
# Adding exchange reaction EX_ext_3 with default bounds for boundary metabolite: ext_3.
# Adding exchange reaction EX_ext_30 with default bounds for boundary metabolite: ext_30.
# Adding exchange reaction EX_ext_31 with default bounds for boundary metabolite: ext_31.
# Adding exchange reaction EX_ext_32 with default bounds for boundary metabolite: ext_32.
# Adding exchange reaction EX_ext_33 with default bounds for boundary metabolite: ext_33.
# Adding exchange reaction EX_ext_34 with default bounds for boundary metabolite: ext_34.
# Adding exchange reaction EX_ext_35 with default bounds for boundary metabolite: ext_35.
# Adding exchange reaction EX_ext_36 with default bounds for boundary metabolite: ext_36.
# Adding exchange reaction EX_ext_37 with default bounds for boundary metabolite: ext_37.
# Adding exchange reaction EX_ext_38 with default bounds for boundary metabolite: ext_38.
# Adding exchange reaction EX_ext_39 with default bounds for boundary metabolite: ext_39.
# Adding exchange reaction EX_ext_4 with default bounds for boundary metabolite: ext_4.
# Adding exchange reaction EX_ext_40 with default bounds for boundary metabolite: ext_40.
# Adding exchange reaction EX_ext_41 with default bounds for boundary metabolite: ext_41.
# Adding exchange reaction EX_ext_42 with default bounds for boundary metabolite: ext_42.
# Adding exchange reaction EX_ext_43 with default bounds for boundary metabolite: ext_43.
# Adding exchange reaction EX_ext_44 with default bounds for boundary metabolite: ext_44.
# Adding exchange reaction EX_ext_45 with default bounds for boundary metabolite: ext_45.
# Adding exchange reaction EX_ext_46 with default bounds for boundary metabolite: ext_46.
# Adding exchange reaction EX_ext_47 with default bounds for boundary metabolite: ext_47.
# Adding exchange reaction EX_ext_48 with default bounds for boundary metabolite: ext_48.
# Adding exchange reaction EX_ext_49 with default bounds for boundary metabolite: ext_49.
# Adding exchange reaction EX_ext_5 with default bounds for boundary metabolite: ext_5.
# Adding exchange reaction EX_ext_50 with default bounds for boundary metabolite: ext_50.
# Adding exchange reaction EX_ext_51 with default bounds for boundary metabolite: ext_51.
# Adding exchange reaction EX_ext_52 with default bounds for boundary metabolite: ext_52.
# Adding exchange reaction EX_ext_53 with default bounds for boundary metabolite: ext_53.
# Adding exchange reaction EX_ext_54 with default bounds for boundary metabolite: ext_54.
# Adding exchange reaction EX_ext_55 with default bounds for boundary metabolite: ext_55.
# Adding exchange reaction EX_ext_56 with default bounds for boundary metabolite: ext_56.
# Adding exchange reaction EX_ext_57 with default bounds for boundary metabolite: ext_57.
# Adding exchange reaction EX_ext_58 with default bounds for boundary metabolite: ext_58.
# Adding exchange reaction EX_ext_59 with default bounds for boundary metabolite: ext_59.
# Adding exchange reaction EX_ext_6 with default bounds for boundary metabolite: ext_6.
# Adding exchange reaction EX_ext_60 with default bounds for boundary metabolite: ext_60.
# Adding exchange reaction EX_ext_61 with default bounds for boundary metabolite: ext_61.
# Adding exchange reaction EX_ext_62 with default bounds for boundary metabolite: ext_62.
# Adding exchange reaction EX_ext_63 with default bounds for boundary metabolite: ext_63.
# Adding exchange reaction EX_ext_64 with default bounds for boundary metabolite: ext_64.
# Adding exchange reaction EX_ext_65 with default bounds for boundary metabolite: ext_65.
# Adding exchange reaction EX_ext_66 with default bounds for boundary metabolite: ext_66.
# Adding exchange reaction EX_ext_67 with default bounds for boundary metabolite: ext_67.
# Adding exchange reaction EX_ext_68 with default bounds for boundary metabolite: ext_68.
# Adding exchange reaction EX_ext_69 with default bounds for boundary metabolite: ext_69.
# Adding exchange reaction EX_ext_7 with default bounds for boundary metabolite: ext_7.
# Adding exchange reaction EX_ext_70 with default bounds for boundary metabolite: ext_70.
# Adding exchange reaction EX_ext_71 with default bounds for boundary metabolite: ext_71.
# Adding exchange reaction EX_ext_72 with default bounds for boundary metabolite: ext_72.
# Adding exchange reaction EX_ext_73 with default bounds for boundary metabolite: ext_73.
# Adding exchange reaction EX_ext_74 with default bounds for boundary metabolite: ext_74.
# Adding exchange reaction EX_ext_75 with default bounds for boundary metabolite: ext_75.
# Adding exchange reaction EX_ext_76 with default bounds for boundary metabolite: ext_76.
# Adding exchange reaction EX_ext_77 with default bounds for boundary metabolite: ext_77.
# Adding exchange reaction EX_ext_78 with default bounds for boundary metabolite: ext_78.
# Adding exchange reaction EX_ext_79 with default bounds for boundary metabolite: ext_79.
# Adding exchange reaction EX_ext_8 with default bounds for boundary metabolite: ext_8.
# Adding exchange reaction EX_ext_80 with default bounds for boundary metabolite: ext_80.
# Adding exchange reaction EX_ext_81 with default bounds for boundary metabolite: ext_81.
# Adding exchange reaction EX_ext_82 with default bounds for boundary metabolite: ext_82.
# Adding exchange reaction EX_ext_83 with default bounds for boundary metabolite: ext_83.
# Adding exchange reaction EX_ext_84 with default bounds for boundary metabolite: ext_84.
# Adding exchange reaction EX_ext_85 with default bounds for boundary metabolite: ext_85.
# Adding exchange reaction EX_ext_86 with default bounds for boundary metabolite: ext_86.
# Adding exchange reaction EX_ext_87 with default bounds for boundary metabolite: ext_87.
# Adding exchange reaction EX_ext_88 with default bounds for boundary metabolite: ext_88.
# Adding exchange reaction EX_ext_89 with default bounds for boundary metabolite: ext_89.
# Adding exchange reaction EX_ext_9 with default bounds for boundary metabolite: ext_9.
# Adding exchange reaction EX_ext_90 with default bounds for boundary metabolite: ext_90.

# %% [markdown]
# ### Testing cutsets on compressed model

# %%
print(u.sol_after_ko(["rsub_166","rsub_409", "rsub_419", "rsub_77", "rsub_844"],compressed_model, "rsub_93"))
# Out:
# 0.0

# %%
for cs in cutsets_list:
    cs_names = []
    for rname in cs:
        if "mcs" in rname:
            new_rname = rname[4:]
        if "rev" in rname: 
            new_rname = rname[:-4]
        cs_names.append(new_rname)
    sol = u.sol_after_ko(cs_names, compressed_model, "rsub_93")
    print(sol, cs_names)
# Out:
# 0.0 ['rsub_844', 'rsub_94']
# 22.35605780573477 ['mcs_rsub_1084', 'rsub_844']
# 0.0 ['rsub_59', 'rsub_844']
# 0.0 ['rsub_2114', 'rsub_844']
# 0.0 ['rsub_2108', 'rsub_844']
# 0.0 ['rsub_384', 'rsub_409', 'rsub_419', 'rsub_77', 'rsub_844']
# 0.0 ['rsub_166', 'rsub_409', 'rsub_419', 'rsub_77', 'rsub_844']
# 0.0 ['rsub_387', 'rsub_409', 'rsub_419', 'rsub_77', 'rsub_844']

# %%
with open("../new_reactionSubsets.txt", 'r') as buffer_subsets:
    reaction_subsets_dict = eval(buffer_subsets.read())
listofcutsets_original_id = []
for reac_list in cutsets_list:
    #Pour chaque cutset:

    cutset_original_IDs = []
    #print(f"\n\nFor cutset {reac_list}:\n\n")
    for comp_reac_id in reac_list:
        #Pour chaque réaction compressée du cutset
        #On veut récupérer le subset de réactions pré-compression.
        reac_subset = reaction_subsets_dict[comp_reac_id[4:]]["reacs"]
        cutset_original_IDs.append(reac_subset)
    listofcutsets_original_id.append(cutset_original_IDs)

# %%
listofcutsets_original_id
# Out:
# [[['HMR_1440',
#    'HMR_1445',
#    'HMR_1448_rev',
#    'HMR_1454',
#    'HMR_1465_rev',
#    'HMR_1467',
#    'HMR_1470',
#    'HMR_1473',
#    'HMR_1451',
#    'HMR_1457',
#    'HMR_1460'],
#   ['EX_temp006x', 'HMR_9736_rev']],
#  [['HMR_0018_rev'],
#   ['HMR_1440',
#    'HMR_1445',
#    'HMR_1448_rev',
#    'HMR_1454',
#    'HMR_1465_rev',
#    'HMR_1467',
#    'HMR_1470',
#    'HMR_1473',
#    'HMR_1451',
#    'HMR_1457',
#    'HMR_1460']],
#  [['EX_m02352x', 'EX_m02353x_rev', 'HMR_0014', 'HMR_0019'],
#   ['HMR_1440',
#    'HMR_1445',
#    'HMR_1448_rev',
#    'HMR_1454',
#    'HMR_1465_rev',
#    'HMR_1467',
#    'HMR_1470',
#    'HMR_1473',
#    'HMR_1451',
#    'HMR_1457',
#    'HMR_1460']],
#  [['HMR_9055'],
#   ['HMR_1440',
#    'HMR_1445',
#    'HMR_1448_rev',
#    'HMR_1454',
#    'HMR_1465_rev',
#    'HMR_1467',
#    'HMR_1470',
#    'HMR_1473',
#    'HMR_1451',
#    'HMR_1457',
#    'HMR_1460']],
#  [['HMR_9027'],
#   ['HMR_1440',
#    'HMR_1445',
#    'HMR_1448_rev',
#    'HMR_1454',
#    'HMR_1465_rev',
#    'HMR_1467',
#    'HMR_1470',
#    'HMR_1473',
#    'HMR_1451',
#    'HMR_1457',
#    'HMR_1460']],
#  [['HMR_4693',
#    'HMR_4073',
#    'HMR_4075',
#    'HMR_4212',
#    'HMR_5384',
#    'HMR_5385',
#    'HMR_5386',
#    'HMR_5387',
#    'HMR_5389',
#    'HMR_5391',
#    'HMR_4330_rev',
#    'HMR_4689',
#    'HMR_7991',
#    'HMR_7992',
#    'HMR_4692',
#    'HMR_4953'],
#   ['HMR_3839', 'HMR_3841', 'HMR_3843'],
#   ['HMR_4437', 'HMR_4658_rev', 'HMR_4660', 'HMR_4712', 'HMR_3929_rev'],
#   ['EX_m02896x_rev', 'HMR_9069'],
#   ['HMR_1440',
#    'HMR_1445',
#    'HMR_1448_rev',
#    'HMR_1454',
#    'HMR_1465_rev',
#    'HMR_1467',
#    'HMR_1470',
#    'HMR_1473',
#    'HMR_1451',
#    'HMR_1457',
#    'HMR_1460']],
#  [['HMR_4282'],
#   ['HMR_3839', 'HMR_3841', 'HMR_3843'],
#   ['HMR_4437', 'HMR_4658_rev', 'HMR_4660', 'HMR_4712', 'HMR_3929_rev'],
#   ['EX_m02896x_rev', 'HMR_9069'],
#   ['HMR_1440',
#    'HMR_1445',
#    'HMR_1448_rev',
#    'HMR_1454',
#    'HMR_1465_rev',
#    'HMR_1467',
#    'HMR_1470',
#    'HMR_1473',
#    'HMR_1451',
#    'HMR_1457',
#    'HMR_1460']],
#  [['HMR_3807_rev'],
#   ['HMR_3839', 'HMR_3841', 'HMR_3843'],
#   ['HMR_4437', 'HMR_4658_rev', 'HMR_4660', 'HMR_4712', 'HMR_3929_rev'],
#   ['EX_m02896x_rev', 'HMR_9069'],
#   ['HMR_1440',
#    'HMR_1445',
#    'HMR_1448_rev',
#    'HMR_1454',
#    'HMR_1465_rev',
#    'HMR_1467',
#    'HMR_1470',
#    'HMR_1473',
#    'HMR_1451',
#    'HMR_1457',
#    'HMR_1460']]]

# %%
model.objective = "biomass_components"

# %%
tc.itertools_product(listofcutsets_original_id, model)
# Out:
#   8%|▊         | 2/25 [32:31<6:14:02, 975.76s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 tc.itertools_product(listofcutsets_original_id, model)
#
# File ~/Documents/Stage_metabo/aspmcs/code/test_cutsets.py:26, in itertools_product(listofcutsets, model)
#      24     good_cutsets_subs.append(comb)
#      25 else:
# ---> 26     print(f"{comb} is not a cutset.")
#      28 if len(comb) > 1 :
#      29     for nm1 in combinations(comb, len(comb)-1):
#
# File ~/Documents/Stage_metabo/aspmcs/code/utils.py:24, in sol_after_ko(lr, model)
#      22 def sol_after_ko(lr, model):
#      23     try:
# ---> 24         model_c = knock_out(model, lr)
#      25         opt = model_c.optimize()
#      26         return opt.objective_value if opt.status != 'infeasible' else 0.0
#
# File ~/Documents/Stage_metabo/aspmcs/code/utils.py:4, in knock_out(model, lr)
#       3 def knock_out(model, lr):
# ----> 4     model = model.copy()
#       5     for r in lr:
#       6         lb = False
#
# File ~/miniconda3/envs/rba/lib/python3.10/site-packages/cobra/core/model.py:435, in Model.copy(self)
#     433         new_reaction._metabolites[new_met] = stoic
#     434         new_met._reaction.add(new_reaction)
# --> 435     new_reaction.update_genes_from_gpr()
#     437 new.groups = DictList()
#     438 do_not_copy_by_ref = {"_model", "_members"}
#
# File ~/miniconda3/envs/rba/lib/python3.10/site-packages/cobra/core/reaction.py:604, in Reaction.update_genes_from_gpr(self)
#     602 context = get_context(self)
#     603 if self._gpr.body is not None:
# --> 604     new_gene_names = self._gpr.genes
#     605 else:
#     606     new_gene_names = set()
#
# File ~/miniconda3/envs/rba/lib/python3.10/site-packages/cobra/core/gene.py:394, in GPR.genes(self)
#     382 @property
#     383 def genes(self) -> FrozenSet:
#     384     """To check the genes.
#     385
#     386     This property updates the genes before returning them, in case the GPR was
#    (...)
#     392         All the genes in a frozen set. Do not try to change them with this property.
#     393     """
# --> 394     self.update_genes()
#     395     return frozenset(self._genes)
#
# File ~/miniconda3/envs/rba/lib/python3.10/site-packages/cobra/core/gene.py:406, in GPR.update_genes(self)
#     404 walker = GPRWalker()
#     405 walker.visit(self)
# --> 406 self._genes = deepcopy(walker.gene_set)
#
# File ~/miniconda3/envs/rba/lib/python3.10/copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File ~/miniconda3/envs/rba/lib/python3.10/copy.py:265, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     263 if deep and args:
#     264     args = (deepcopy(arg, memo) for arg in args)
# --> 265 y = func(*args)
#     266 if deep:
#     267     memo[id(x)] = y
#
# File ~/miniconda3/envs/rba/lib/python3.10/copy.py:264, in <genexpr>(.0)
#     262 deep = memo is not None
#     263 if deep and args:
# --> 264     args = (deepcopy(arg, memo) for arg in args)
#     265 y = func(*args)
#     266 if deep:
#
# File ~/miniconda3/envs/rba/lib/python3.10/copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File ~/miniconda3/envs/rba/lib/python3.10/copy.py:206, in _deepcopy_list(x, memo, deepcopy)
#     204 append = y.append
#     205 for a in x:
# --> 206     append(deepcopy(a, memo))
#     207 return y
#
# File ~/miniconda3/envs/rba/lib/python3.10/copy.py:128, in deepcopy(x, memo, _nil)
#     124     d[PyStringMap] = PyStringMap.copy
#     126 del d, t
# --> 128 def deepcopy(x, memo=None, _nil=[]):
#     129     """Deep copy operation on arbitrary Python objects.
#     130
#     131     See the module's __doc__ string for more info.
#     132     """
#     134     if memo is None:
#
# KeyboardInterrupt:

# %%
with open("../new_reactionSubsets.txt", 'r') as buffer_subsets:
    reaction_subsets_dict = eval(buffer_subsets.read())
listofcutsets_original_id = []
for reac_list in cutsets_list:
    #Pour chaque cutset:

    cutset_original_IDs = []
    #print(f"\n\nFor cutset {reac_list}:\n\n")
    for comp_reac_id in reac_list:
        #Pour chaque réaction compressée du cutset
        #On veut récupérer le subset de réactions pré-compression.
        reac_subset = reaction_subsets_dict[comp_reac_id[4:]]["reacs"]
        cutset_original_IDs.append(reac_subset)
    listofcutsets_original_id.append(cutset_original_IDs)
    
        #cutset_original_IDs est une liste de même taille que reac_list,
        #mais dont les éléments sont des listes de réactions qui sont 
        #les subsets de réaction pré-compression
i = 1
for cutset_orID in listofcutsets_original_id:
    #print(f"Cutset : {cutset_orID}\n")
    combinations = list(product(*cutset_orID))
    for comb in combinations:
        with model as m:
            retval = u.sol_after_ko(comb, m)
            # for reac in cs:
            #     m.reactions.get_by_id(reac.strip("_rev"))
            #opt = m.optimize()
        #print("<",opt.objective_value,">", cs )
        if retval < 1e-6:
            print("Obj_value = ",retval,"For cutset >>>", comb )
        else:
            print(f"{cs_comb} is not a cutset.")

        if len(comb) > 1 :
            for nm1 in combinations(comb, len(cs)-1):
                #with model as m:
                #    for reac in nm1:
                #        m.reactions.get_by_id(reac.strip("_rev")).knock_out()
                #    opt = m.optimize()
                #print('N-1',"<", opt.objective_value,">", nm1, 'not MIN cutset' if opt.objective_value < 1e-6 else '')
                retval = u.sol_after_ko(nm1, m)
                print('[N-1]',"Objective value = ", retval,"For n-1 subset of cutset >>>", nm1, 'not MIN cutset' if retval < 1e-6 else '')
    i+=1
    #print(f"comb : {combinations}\n")
# Out:
# Obj_value =  0.0 For cutset >>> ('HMR_3258',)
# Obj_value =  0.0 For cutset >>> ('HMR_3260',)
# Obj_value =  0.0 For cutset >>> ('HMR_3262',)
# Obj_value =  0.0 For cutset >>> ('HMR_3264',)
# Obj_value =  0.0 For cutset >>> ('HMR_3272_rev',)
# Obj_value =  0.0 For cutset >>> ('HMR_2211', 'HMR_2626', 'HMR_2654', 'HMR_3121')
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 36
#      33     print(f"{cs_comb} is not a cutset.")
#      35 if len(comb) > 1 :
# ---> 36     for nm1 in combinations(comb, len(cs)-1):
#      37         #with model as m:
#      38         #    for reac in nm1:
#      39         #        m.reactions.get_by_id(reac.strip("_rev")).knock_out()
#      40         #    opt = m.optimize()
#      41         #print('N-1',"<", opt.objective_value,">", nm1, 'not MIN cutset' if opt.objective_value < 1e-6 else '')
#      42         retval = u.sol_after_ko(nm1, m)
#      43         print('[N-1]',"Objective value = ", retval,"For n-1 subset of cutset >>>", nm1, 'not MIN cutset' if retval < 1e-6 else '')
#
# NameError: name 'cs' is not defined

# %%
nlist = [[i,j,k] for i in liste[0] for j in liste[1] for k in liste[2]]

# %%
def decompress_cutsets(subsets_file_path, comp_cutsets_list):
    with open(subsets_file_path, 'r') as buffer_subsets:
        reaction_subsets_dict = eval(buffer_subsets.read())

    decomp_cutsets_list = []
    for reac_list in comp_cutsets_list:
        #Itère sur chaque cutset

        cs_decomp = []
        cs_decomp_comb = []
        for reac in reac_list:
            reac_id = reac[4:]
            original_reac_subset = reaction_subsets_dict[reac_id]["reacs"]
            cs_decomp.append(original_reac_subset)
        
        for cutset_subset in cs_decomp:
            
            for comb in combinations(cutset_subset, len(reac_list)):
                
                cs_decomp_comb.append(comb)
        decomp_cutsets_list.append(cs_decomp_comb)
            
    return decomp_cutsets_list

# %%
decomp_cutsets_list = decompress_cutsets("../new_reactionSubsets.txt", cutsets_list)

# %%
cutsets_list
# Out:
# [['mcs_rsub_831'],
#  ['mcs_rsub_169', 'mcs_rsub_439', 'mcs_rsub_625', 'mcs_rsub_75'],
#  ['mcs_rsub_749_rev', 'mcs_rsub_750', 'mcs_rsub_751', 'mcs_rsub_752'],
#  ['mcs_rsub_750', 'mcs_rsub_751', 'mcs_rsub_752', 'mcs_rsub_820'],
#  ['mcs_rsub_547', 'mcs_rsub_75'],
#  ['mcs_rsub_1102'],
#  ['mcs_rsub_418',
#   'mcs_rsub_443',
#   'mcs_rsub_445',
#   'mcs_rsub_488',
#   'mcs_rsub_547'],
#  ['mcs_rsub_418', 'mcs_rsub_436', 'mcs_rsub_443', 'mcs_rsub_547'],
#  ['mcs_rsub_418',
#   'mcs_rsub_436',
#   'mcs_rsub_444',
#   'mcs_rsub_483',
#   'mcs_rsub_547'],
#  ['mcs_rsub_747'],
#  ['mcs_rsub_821']]

# %%
decomp_cutsets_list
# Out:
# [[('HMR_3258',),
#   ('HMR_3260',),
#   ('HMR_3262',),
#   ('HMR_3264',),
#   ('HMR_3272_rev',)],
#  [('HMR_2254', 'HMR_2255', 'HMR_2256', 'HMR_2257'),
#   ('HMR_2254', 'HMR_2255', 'HMR_2256', 'HMR_2258'),
#   ('HMR_2254', 'HMR_2255', 'HMR_2257', 'HMR_2258'),
#   ('HMR_2254', 'HMR_2256', 'HMR_2257', 'HMR_2258'),
#   ('HMR_2255', 'HMR_2256', 'HMR_2257', 'HMR_2258')],
#  [('HMR_2611', 'HMR_2612_rev', 'HMR_2613_rev', 'HMR_3398')],
#  [('HMR_2611', 'HMR_2612_rev', 'HMR_2613_rev', 'HMR_3398'),
#   ('HMR_3128', 'HMR_3129', 'HMR_3130', 'HMR_3132')],
#  [('EX_m02772x', 'HMR_9808_rev')],
#  [('HMR_0225',)],
#  [],
#  [('HMR_3206', 'HMR_3778', 'HMR_3785', 'HMR_3823'),
#   ('HMR_3206', 'HMR_3778', 'HMR_3785', 'HMR_5107'),
#   ('HMR_3206', 'HMR_3778', 'HMR_3823', 'HMR_5107'),
#   ('HMR_3206', 'HMR_3785', 'HMR_3823', 'HMR_5107'),
#   ('HMR_3778', 'HMR_3785', 'HMR_3823', 'HMR_5107')],
#  [('HMR_3206', 'HMR_3778', 'HMR_3785', 'HMR_3823', 'HMR_5107')],
#  [('HMR_2602_rev',), ('HMR_2603_rev',), ('HMR_2604',)],
#  [('HMR_3135',)]]

# %% [markdown]
# ### Models loading

# %%
model = cobra.io.read_sbml_model('../HepG2_medium.xml')
compressed_model = cobra.io.read_sbml_model("../new_reduced.xml")
# Out:
# Adding exchange reaction EX_ext_1 with default bounds for boundary metabolite: ext_1.
# Adding exchange reaction EX_ext_10 with default bounds for boundary metabolite: ext_10.
# Adding exchange reaction EX_ext_11 with default bounds for boundary metabolite: ext_11.
# Adding exchange reaction EX_ext_12 with default bounds for boundary metabolite: ext_12.
# Adding exchange reaction EX_ext_13 with default bounds for boundary metabolite: ext_13.
# Adding exchange reaction EX_ext_14 with default bounds for boundary metabolite: ext_14.
# Adding exchange reaction EX_ext_15 with default bounds for boundary metabolite: ext_15.
# Adding exchange reaction EX_ext_16 with default bounds for boundary metabolite: ext_16.
# Adding exchange reaction EX_ext_17 with default bounds for boundary metabolite: ext_17.
# Adding exchange reaction EX_ext_18 with default bounds for boundary metabolite: ext_18.
# Adding exchange reaction EX_ext_19 with default bounds for boundary metabolite: ext_19.
# Adding exchange reaction EX_ext_2 with default bounds for boundary metabolite: ext_2.
# Adding exchange reaction EX_ext_20 with default bounds for boundary metabolite: ext_20.
# Adding exchange reaction EX_ext_21 with default bounds for boundary metabolite: ext_21.
# Adding exchange reaction EX_ext_22 with default bounds for boundary metabolite: ext_22.
# Adding exchange reaction EX_ext_23 with default bounds for boundary metabolite: ext_23.
# Adding exchange reaction EX_ext_24 with default bounds for boundary metabolite: ext_24.
# Adding exchange reaction EX_ext_25 with default bounds for boundary metabolite: ext_25.
# Adding exchange reaction EX_ext_26 with default bounds for boundary metabolite: ext_26.
# Adding exchange reaction EX_ext_27 with default bounds for boundary metabolite: ext_27.
# Adding exchange reaction EX_ext_28 with default bounds for boundary metabolite: ext_28.
# Adding exchange reaction EX_ext_29 with default bounds for boundary metabolite: ext_29.
# Adding exchange reaction EX_ext_3 with default bounds for boundary metabolite: ext_3.
# Adding exchange reaction EX_ext_30 with default bounds for boundary metabolite: ext_30.
# Adding exchange reaction EX_ext_31 with default bounds for boundary metabolite: ext_31.
# Adding exchange reaction EX_ext_32 with default bounds for boundary metabolite: ext_32.
# Adding exchange reaction EX_ext_33 with default bounds for boundary metabolite: ext_33.
# Adding exchange reaction EX_ext_34 with default bounds for boundary metabolite: ext_34.
# Adding exchange reaction EX_ext_35 with default bounds for boundary metabolite: ext_35.
# Adding exchange reaction EX_ext_36 with default bounds for boundary metabolite: ext_36.
# Adding exchange reaction EX_ext_37 with default bounds for boundary metabolite: ext_37.
# Adding exchange reaction EX_ext_38 with default bounds for boundary metabolite: ext_38.
# Adding exchange reaction EX_ext_39 with default bounds for boundary metabolite: ext_39.
# Adding exchange reaction EX_ext_4 with default bounds for boundary metabolite: ext_4.
# Adding exchange reaction EX_ext_40 with default bounds for boundary metabolite: ext_40.
# Adding exchange reaction EX_ext_41 with default bounds for boundary metabolite: ext_41.
# Adding exchange reaction EX_ext_42 with default bounds for boundary metabolite: ext_42.
# Adding exchange reaction EX_ext_43 with default bounds for boundary metabolite: ext_43.
# Adding exchange reaction EX_ext_44 with default bounds for boundary metabolite: ext_44.
# Adding exchange reaction EX_ext_45 with default bounds for boundary metabolite: ext_45.
# Adding exchange reaction EX_ext_46 with default bounds for boundary metabolite: ext_46.
# Adding exchange reaction EX_ext_47 with default bounds for boundary metabolite: ext_47.
# Adding exchange reaction EX_ext_48 with default bounds for boundary metabolite: ext_48.
# Adding exchange reaction EX_ext_49 with default bounds for boundary metabolite: ext_49.
# Adding exchange reaction EX_ext_5 with default bounds for boundary metabolite: ext_5.
# Adding exchange reaction EX_ext_50 with default bounds for boundary metabolite: ext_50.
# Adding exchange reaction EX_ext_51 with default bounds for boundary metabolite: ext_51.
# Adding exchange reaction EX_ext_52 with default bounds for boundary metabolite: ext_52.
# Adding exchange reaction EX_ext_53 with default bounds for boundary metabolite: ext_53.
# Adding exchange reaction EX_ext_54 with default bounds for boundary metabolite: ext_54.
# Adding exchange reaction EX_ext_55 with default bounds for boundary metabolite: ext_55.
# Adding exchange reaction EX_ext_56 with default bounds for boundary metabolite: ext_56.
# Adding exchange reaction EX_ext_57 with default bounds for boundary metabolite: ext_57.
# Adding exchange reaction EX_ext_58 with default bounds for boundary metabolite: ext_58.
# Adding exchange reaction EX_ext_59 with default bounds for boundary metabolite: ext_59.
# Adding exchange reaction EX_ext_6 with default bounds for boundary metabolite: ext_6.
# Adding exchange reaction EX_ext_60 with default bounds for boundary metabolite: ext_60.
# Adding exchange reaction EX_ext_61 with default bounds for boundary metabolite: ext_61.
# Adding exchange reaction EX_ext_62 with default bounds for boundary metabolite: ext_62.
# Adding exchange reaction EX_ext_63 with default bounds for boundary metabolite: ext_63.
# Adding exchange reaction EX_ext_64 with default bounds for boundary metabolite: ext_64.
# Adding exchange reaction EX_ext_65 with default bounds for boundary metabolite: ext_65.
# Adding exchange reaction EX_ext_66 with default bounds for boundary metabolite: ext_66.
# Adding exchange reaction EX_ext_67 with default bounds for boundary metabolite: ext_67.
# Adding exchange reaction EX_ext_68 with default bounds for boundary metabolite: ext_68.
# Adding exchange reaction EX_ext_69 with default bounds for boundary metabolite: ext_69.
# Adding exchange reaction EX_ext_7 with default bounds for boundary metabolite: ext_7.
# Adding exchange reaction EX_ext_70 with default bounds for boundary metabolite: ext_70.
# Adding exchange reaction EX_ext_71 with default bounds for boundary metabolite: ext_71.
# Adding exchange reaction EX_ext_72 with default bounds for boundary metabolite: ext_72.
# Adding exchange reaction EX_ext_73 with default bounds for boundary metabolite: ext_73.
# Adding exchange reaction EX_ext_74 with default bounds for boundary metabolite: ext_74.
# Adding exchange reaction EX_ext_75 with default bounds for boundary metabolite: ext_75.
# Adding exchange reaction EX_ext_76 with default bounds for boundary metabolite: ext_76.
# Adding exchange reaction EX_ext_77 with default bounds for boundary metabolite: ext_77.
# Adding exchange reaction EX_ext_78 with default bounds for boundary metabolite: ext_78.
# Adding exchange reaction EX_ext_79 with default bounds for boundary metabolite: ext_79.
# Adding exchange reaction EX_ext_8 with default bounds for boundary metabolite: ext_8.
# Adding exchange reaction EX_ext_80 with default bounds for boundary metabolite: ext_80.
# Adding exchange reaction EX_ext_81 with default bounds for boundary metabolite: ext_81.
# Adding exchange reaction EX_ext_82 with default bounds for boundary metabolite: ext_82.
# Adding exchange reaction EX_ext_83 with default bounds for boundary metabolite: ext_83.
# Adding exchange reaction EX_ext_84 with default bounds for boundary metabolite: ext_84.
# Adding exchange reaction EX_ext_85 with default bounds for boundary metabolite: ext_85.
# Adding exchange reaction EX_ext_86 with default bounds for boundary metabolite: ext_86.
# Adding exchange reaction EX_ext_87 with default bounds for boundary metabolite: ext_87.
# Adding exchange reaction EX_ext_88 with default bounds for boundary metabolite: ext_88.
# Adding exchange reaction EX_ext_89 with default bounds for boundary metabolite: ext_89.
# Adding exchange reaction EX_ext_9 with default bounds for boundary metabolite: ext_9.
# Adding exchange reaction EX_ext_90 with default bounds for boundary metabolite: ext_90.

# %%
compressed_model.objective = "rsub_2116"
model.objective = 'biomass_components'

# %% [markdown]
# ### Testing cutsets on original model with combinations of reactions from compressed cutsets
# Each compressed cutset has one reaction from its reactions subset in each cs_comb.

# %%
i = 1
for cs in decomp_cutsets_list:
    print(f"\nCUTSET N° {i} : {cutsets_list[i-1]}\n\n")
    for cs_comb in cs:
        
        with model as m:
            retval = sol_after_ko(cs_comb, m)
            # for reac in cs:
            #     m.reactions.get_by_id(reac.strip("_rev"))
            #opt = m.optimize()
        #print("<",opt.objective_value,">", cs )
        if retval < 1e-6:
            print("Obj_value = ",retval,"For cutset >>>", cs_comb )
        else:
            print(f"{cs_comb} is not a cutset.")

        if len(cs_comb) > 1 :
            for nm1 in combinations(cs_comb, len(cs)-1):
                #with model as m:
                #    for reac in nm1:
                #        m.reactions.get_by_id(reac.strip("_rev")).knock_out()
                #    opt = m.optimize()
                #print('N-1',"<", opt.objective_value,">", nm1, 'not MIN cutset' if opt.objective_value < 1e-6 else '')
                retval = sol_after_ko(nm1, m)
                print('[N-1]',"Objective value = ", retval,"For n-1 subset of cutset >>>", nm1, 'not MIN cutset' if retval < 1e-6 else '')
    i+=1
# Out:
# CUTSET N° 1 : ['mcs_rsub_831']
#
#
# Obj_value =  0.0 For cutset >>> ('HMR_3258',)
# Obj_value =  0.0 For cutset >>> ('HMR_3260',)
# Obj_value =  0.0 For cutset >>> ('HMR_3262',)
# Obj_value =  0.0 For cutset >>> ('HMR_3264',)
# Obj_value =  0.0 For cutset >>> ('HMR_3272_rev',)
#
# CUTSET N° 2 : ['mcs_rsub_169', 'mcs_rsub_439', 'mcs_rsub_625', 'mcs_rsub_75']
#
#
# ('HMR_2254', 'HMR_2255', 'HMR_2256', 'HMR_2257') is not a cutset.
# ('HMR_2254', 'HMR_2255', 'HMR_2256', 'HMR_2258') is not a cutset.
# ('HMR_2254', 'HMR_2255', 'HMR_2257', 'HMR_2258') is not a cutset.
# ('HMR_2254', 'HMR_2256', 'HMR_2257', 'HMR_2258') is not a cutset.
# ('HMR_2255', 'HMR_2256', 'HMR_2257', 'HMR_2258') is not a cutset.
# ('HMR_2254', 'HMR_2255', 'HMR_2256', 'HMR_2257') is not a cutset.
# ('HMR_2254', 'HMR_2255', 'HMR_2256', 'HMR_2258') is not a cutset.
# ('HMR_2254', 'HMR_2255', 'HMR_2257', 'HMR_2258') is not a cutset.
# ('HMR_2254', 'HMR_2256', 'HMR_2257', 'HMR_2258') is not a cutset.
# ('HMR_2255', 'HMR_2256', 'HMR_2257', 'HMR_2258') is not a cutset.
#
# CUTSET N° 3 : ['mcs_rsub_749_rev', 'mcs_rsub_750', 'mcs_rsub_751', 'mcs_rsub_752']
#
#
# ('HMR_2611', 'HMR_2612_rev', 'HMR_2613_rev', 'HMR_3398') is not a cutset.
# [N-1] Objective value =  22.356057805734743 For n-1 subset of cutset >>> ('HMR_2611', 'HMR_2612_rev')
# [N-1] Objective value =  22.356057805734775 For n-1 subset of cutset >>> ('HMR_2611', 'HMR_2613_rev')
# [N-1] Objective value =  22.35605780573474 For n-1 subset of cutset >>> ('HMR_2611', 'HMR_3398')
# [N-1] Objective value =  22.356057805734753 For n-1 subset of cutset >>> ('HMR_2612_rev', 'HMR_2613_rev')
# [N-1] Objective value =  22.3560578057347 For n-1 subset of cutset >>> ('HMR_2612_rev', 'HMR_3398')
# [N-1] Objective value =  22.35605780573475 For n-1 subset of cutset >>> ('HMR_2613_rev', 'HMR_3398')
# ('HMR_2611', 'HMR_2612_rev', 'HMR_2613_rev', 'HMR_3398') is not a cutset.
# [N-1] Objective value =  22.356057805734743 For n-1 subset of cutset >>> ('HMR_2611', 'HMR_2612_rev')
# [N-1] Objective value =  22.356057805734775 For n-1 subset of cutset >>> ('HMR_2611', 'HMR_2613_rev')
# [N-1] Objective value =  22.35605780573474 For n-1 subset of cutset >>> ('HMR_2611', 'HMR_3398')
# [N-1] Objective value =  22.356057805734753 For n-1 subset of cutset >>> ('HMR_2612_rev', 'HMR_2613_rev')
# [N-1] Objective value =  22.3560578057347 For n-1 subset of cutset >>> ('HMR_2612_rev', 'HMR_3398')
# [N-1] Objective value =  22.35605780573475 For n-1 subset of cutset >>> ('HMR_2613_rev', 'HMR_3398')
# ('HMR_2611', 'HMR_2612_rev', 'HMR_2613_rev', 'HMR_3398') is not a cutset.
# [N-1] Objective value =  22.356057805734743 For n-1 subset of cutset >>> ('HMR_2611', 'HMR_2612_rev')
# [N-1] Objective value =  22.356057805734775 For n-1 subset of cutset >>> ('HMR_2611', 'HMR_2613_rev')
# [N-1] Objective value =  22.35605780573474 For n-1 subset of cutset >>> ('HMR_2611', 'HMR_3398')
# [N-1] Objective value =  22.356057805734753 For n-1 subset of cutset >>> ('HMR_2612_rev', 'HMR_2613_rev')
# [N-1] Objective value =  22.3560578057347 For n-1 subset of cutset >>> ('HMR_2612_rev', 'HMR_3398')
# [N-1] Objective value =  22.35605780573475 For n-1 subset of cutset >>> ('HMR_2613_rev', 'HMR_3398')
#
# CUTSET N° 4 : ['mcs_rsub_750', 'mcs_rsub_751', 'mcs_rsub_752', 'mcs_rsub_820']
#
#
# ('HMR_2611', 'HMR_2612_rev', 'HMR_2613_rev', 'HMR_3398') is not a cutset.
# [N-1] Objective value =  22.356057805734785 For n-1 subset of cutset >>> ('HMR_2611', 'HMR_2612_rev', 'HMR_2613_rev', 'HMR_3398')
# ('HMR_2611', 'HMR_2612_rev', 'HMR_2613_rev', 'HMR_3398') is not a cutset.
# [N-1] Objective value =  22.356057805734785 For n-1 subset of cutset >>> ('HMR_2611', 'HMR_2612_rev', 'HMR_2613_rev', 'HMR_3398')
# ('HMR_2611', 'HMR_2612_rev', 'HMR_2613_rev', 'HMR_3398') is not a cutset.
# [N-1] Objective value =  22.356057805734785 For n-1 subset of cutset >>> ('HMR_2611', 'HMR_2612_rev', 'HMR_2613_rev', 'HMR_3398')
# ('HMR_2611', 'HMR_2612_rev', 'HMR_2613_rev', 'HMR_3398') is not a cutset.
# [N-1] Objective value =  22.356057805734785 For n-1 subset of cutset >>> ('HMR_2611', 'HMR_2612_rev', 'HMR_2613_rev', 'HMR_3398')
# ('HMR_3128', 'HMR_3129', 'HMR_3130', 'HMR_3132') is not a cutset.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 24
#      17     if len(cs_comb) > 1 :
#      18         for nm1 in combinations(cs_comb, len(cs)-1):
#      19             #with model as m:
#      20             #    for reac in nm1:
#      21             #        m.reactions.get_by_id(reac.strip("_rev")).knock_out()
#      22             #    opt = m.optimize()
#      23             #print('N-1',"<", opt.objective_value,">", nm1, 'not MIN cutset' if opt.objective_value < 1e-6 else '')
# ---> 24             retval = sol_after_ko(nm1, m)
#      25             print('[N-1]',"Objective value = ", retval,"For n-1 subset of cutset >>>", nm1, 'not MIN cutset' if retval < 1e-6 else '')
#      26 i+=1
#
# File ~/Documents/Stage_metabo/aspmcs/code/utils.py:24, in sol_after_ko(lr, model)
#      22 def sol_after_ko(lr, model):
#      23     try:
# ---> 24         model_c = knock_out(model, lr)
#      25         opt = model_c.optimize()
#      26         return opt.objective_value if opt.status != 'infeasible' else 0.0
#
# File ~/Documents/Stage_metabo/aspmcs/code/utils.py:4, in knock_out(model, lr)
#       3 def knock_out(model, lr):
# ----> 4     model = model.copy()
#       5     for r in lr:
#       6         lb = False
#
# File ~/miniconda3/envs/rba/lib/python3.10/site-packages/cobra/core/model.py:470, in Model.copy(self)
#     467     new_group.add_members(new_objects)
#     469 try:
# --> 470     new._solver = deepcopy(self.solver)
#     471     # Cplex has an issue with deep copies
#     472 except Exception:  # pragma: no cover
#
# File ~/miniconda3/envs/rba/lib/python3.10/copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File ~/miniconda3/envs/rba/lib/python3.10/copy.py:273, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     271     state = deepcopy(state, memo)
#     272 if hasattr(y, '__setstate__'):
# --> 273     y.__setstate__(state)
#     274 else:
#     275     if isinstance(state, tuple) and len(state) == 2:
#
# File ~/miniconda3/envs/rba/lib/python3.10/site-packages/optlang/cplex_interface.py:714, in Model.__setstate__(self, repr_dict)
#     712 if repr_dict['status'] == 'optimal':
#     713     problem.solve()  # since the start is an optimal solution, nothing will happen here
# --> 714 self.__init__(problem=problem)
#     715 self.configuration = Configuration.clone(repr_dict['config'], problem=self)
#
# File ~/miniconda3/envs/rba/lib/python3.10/site-packages/optlang/interface.py:1188, in Model.__init__(self, name, objective, variables, constraints, problem, *args, **kwargs)
#    1186     if not (objective is None and variables is None and constraints is None):
#    1187         raise ValueError("Models constructor must be called with the problem argument OR with variables, constraints and objective")
# -> 1188     self._initialize_model_from_problem(problem)
#    1190 else:
#    1191     self._initialize_problem()
#
# File ~/miniconda3/envs/rba/lib/python3.10/site-packages/optlang/cplex_interface.py:617, in Model._initialize_model_from_problem(self, problem)
#     611 zipped_var_args = zip(self.problem.variables.get_names(),
#     612                       self.problem.variables.get_lower_bounds(),
#     613                       self.problem.variables.get_upper_bounds(),
#     614                       # self.problem.variables.get_types(), # TODO uncomment when cplex is fixed
#     615                       )
#     616 for name, lb, ub in zipped_var_args:
# --> 617     var = Variable(name, lb=lb, ub=ub, problem=self)  # Type should also be in there
#     618     super(Model, self)._add_variables([var])  # This avoids adding the variable to the glpk problem
#     619 zipped_constr_args = zip(self.problem.linear_constraints.get_names(),
#     620                          self.problem.linear_constraints.get_rows(),
#     621                          self.problem.linear_constraints.get_senses(),
#     622                          self.problem.linear_constraints.get_rhs()
#     623
#     624                          )
#
# File ~/miniconda3/envs/rba/lib/python3.10/site-packages/optlang/symbolics.py:127, in Symbol.__new__(cls, name, **kwargs)
#     124 if not isinstance(name, six.string_types):
#     125     raise TypeError("name should be a string, not %s" % repr(type(name)))
# --> 127 obj = sympy.Symbol.__new__(cls, str(uuid.uuid1()))
#     129 obj.name = name
#     130 obj._assumptions = FactKB(_assume_rules)
#
# File ~/miniconda3/envs/rba/lib/python3.10/site-packages/sympy/core/symbol.py:296, in Symbol.__new__(cls, name, **assumptions)
#     286 """Symbols are identified by name and assumptions::
#     287
#     288 >>> from sympy import Symbol
#    (...)
#     293
#     294 """
#     295 cls._sanitize(assumptions, cls)
# --> 296 return Symbol.__xnew_cached_(cls, name, **assumptions)
#
# File ~/miniconda3/envs/rba/lib/python3.10/site-packages/sympy/core/cache.py:70, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      67 @wraps(func)
#      68 def wrapper(*args, **kwargs):
#      69     try:
# ---> 70         retval = cfunc(*args, **kwargs)
#      71     except TypeError as e:
#      72         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~/miniconda3/envs/rba/lib/python3.10/site-packages/sympy/core/symbol.py:326, in Symbol.__xnew_cached_(cls, name, **assumptions)
#     323 @staticmethod
#     324 @cacheit
#     325 def __xnew_cached_(cls, name, **assumptions):  # symbols are always cached
# --> 326     return Symbol.__xnew__(cls, name, **assumptions)
#
# File ~/miniconda3/envs/rba/lib/python3.10/site-packages/sympy/core/symbol.py:304, in Symbol.__xnew__(cls, name, **assumptions)
#     301     raise TypeError("name should be a string, not %s" % repr(type(name)))
#     303 obj = Expr.__new__(cls)
# --> 304 obj.name = name
#     306 # TODO: Issue #8873: Forcing the commutative assumption here means
#     307 # later code such as ``srepr()`` cannot tell whether the user
#     308 # specified ``commutative=True`` or omitted it.  To workaround this,
#    (...)
#     312 # given dict as ``._generator``, but future modification might, e.g.,
#     313 # compute a minimal equivalent assumption set.
#     314 tmp_asm_copy = assumptions.copy()
#
# File ~/miniconda3/envs/rba/lib/python3.10/site-packages/optlang/cplex_interface.py:208, in Variable.name(self, value)
#     205 @interface.Variable.name.setter
#     206 def name(self, value):
#     207     old_name = getattr(self, "name", None)
# --> 208     super(Variable, Variable).name.fset(self, value)
#     209     if getattr(self, "problem", None) is not None:
#     210         self.problem.problem.variables.set_names(old_name, value)
#
# File ~/miniconda3/envs/rba/lib/python3.10/site-packages/optlang/interface.py:195, in Variable.name(self, value)
#     193 @name.setter
#     194 def name(self, value):
# --> 195     self.__validate_variable_name(value)
#     196     old_name = getattr(self, 'name', None)
#     197     self._name = value
#
# File ~/miniconda3/envs/rba/lib/python3.10/site-packages/optlang/interface.py:148, in Variable.__validate_variable_name(name)
#     146     raise ValueError('Variable name must not be empty string')
#     147 for char in name:
# --> 148     if char.isspace():
#     149         raise ValueError(
#     150             'Variable names cannot contain whitespace characters. "%s" contains whitespace character "%s".' % (
#     151                 name, char)
#     152         )
#
# KeyboardInterrupt:

# %% [markdown]
# ### Testing by grouping reactions from cutsets

# %%
with open("../new_reactionSubsets.txt", 'r') as buffer_subsets:
    reaction_subsets_dict = eval(buffer_subsets.read())

# %%
grouped_cutsets_list = []
grouped_cutsets_list_decomp = []
for cutset in cutsets_list:
    cutset_decomp = []
    for rid in cutset:
        reaction_id = rid[4:]
        original_ids = reaction_subsets_dict[reaction_id]["reacs"]
        cutset_decomp += original_ids
    
    grouped_cutsets_list_decomp.append(cutset_decomp)

# %%
grouped_cutsets_list_decomp
# Out:
# [['HMR_3258', 'HMR_3260', 'HMR_3262', 'HMR_3264', 'HMR_3272_rev'],
#  ['HMR_4497',
#   'HMR_4741',
#   'HMR_4735',
#   'HMR_3213',
#   'HMR_2254',
#   'HMR_2255',
#   'HMR_2256',
#   'HMR_2257',
#   'HMR_2258',
#   'EX_m02772x',
#   'HMR_9808_rev'],
#  ['HMR_2608_rev',
#   'HMR_2609_rev',
#   'HMR_2610',
#   'HMR_2611',
#   'HMR_2612_rev',
#   'HMR_2613_rev',
#   'HMR_3398',
#   'HMR_2614',
#   'HMR_2616_rev',
#   'HMR_2618_rev',
#   'HMR_2620',
#   'HMR_2621_rev',
#   'HMR_2622_rev'],
#  ['HMR_2611',
#   'HMR_2612_rev',
#   'HMR_2613_rev',
#   'HMR_3398',
#   'HMR_2614',
#   'HMR_2616_rev',
#   'HMR_2618_rev',
#   'HMR_2620',
#   'HMR_2621_rev',
#   'HMR_2622_rev',
#   'HMR_3128',
#   'HMR_3129',
#   'HMR_3130',
#   'HMR_3132'],
#  ['HMR_3977', 'EX_m02772x', 'HMR_9808_rev'],
#  ['HMR_0225'],
#  ['HMR_8442', 'HMR_3795', 'HMR_6419', 'HMR_6420', 'HMR_3780', 'HMR_3977'],
#  ['HMR_8442',
#   'HMR_3206',
#   'HMR_3778',
#   'HMR_3785',
#   'HMR_3823',
#   'HMR_5107',
#   'HMR_3795',
#   'HMR_3977'],
#  ['HMR_8442',
#   'HMR_3206',
#   'HMR_3778',
#   'HMR_3785',
#   'HMR_3823',
#   'HMR_5107',
#   'HMR_6417',
#   'HMR_6416',
#   'HMR_3748',
#   'HMR_3977'],
#  ['HMR_2602_rev', 'HMR_2603_rev', 'HMR_2604'],
#  ['HMR_3135']]

# %%
i = 1
for cs in grouped_cutsets_list_decomp:
    print(f"\nCUTSET N° {i} : {cutsets_list[i-1]}\n\n")
    
        
    with model as m:
        retval = sol_after_ko(cs, m)
        # for reac in cs:
        #     m.reactions.get_by_id(reac.strip("_rev"))
        #opt = m.optimize()
    #print("<",opt.objective_value,">", cs )
    if retval < 1e-6:
        print("Obj_value = ",retval,"For cutset >>>", cs )
    else:
        print(f"{cs} is not a cutset.")

    if len(cs) > 1 :
        for nm1 in combinations(cs, len(cs)-1):
            #with model as m:
            #    for reac in nm1:
            #        m.reactions.get_by_id(reac.strip("_rev")).knock_out()
            #    opt = m.optimize()
            #print('N-1',"<", opt.objective_value,">", nm1, 'not MIN cutset' if opt.objective_value < 1e-6 else '')
            retval = sol_after_ko(nm1, m)
            print('[N-1]',"Objective value = ", retval,"For n-1 subset of cutset >>>", nm1, 'not MIN cutset' if retval < 1e-6 else '')
    i+=1
# Out:
# CUTSET N° 1 : ['mcs_rsub_831']
#
#
# Obj_value =  0.0 For cutset >>> ['HMR_3258', 'HMR_3260', 'HMR_3262', 'HMR_3264', 'HMR_3272_rev']
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_3258', 'HMR_3260', 'HMR_3262', 'HMR_3264') not MIN cutset
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_3258', 'HMR_3260', 'HMR_3262', 'HMR_3272_rev') not MIN cutset
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_3258', 'HMR_3260', 'HMR_3264', 'HMR_3272_rev') not MIN cutset
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_3258', 'HMR_3262', 'HMR_3264', 'HMR_3272_rev') not MIN cutset
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_3260', 'HMR_3262', 'HMR_3264', 'HMR_3272_rev') not MIN cutset
#
# CUTSET N° 2 : ['mcs_rsub_169', 'mcs_rsub_439', 'mcs_rsub_625', 'mcs_rsub_75']
#
#
# Obj_value =  0.0 For cutset >>> ['HMR_4497', 'HMR_4741', 'HMR_4735', 'HMR_3213', 'HMR_2254', 'HMR_2255', 'HMR_2256', 'HMR_2257', 'HMR_2258', 'EX_m02772x', 'HMR_9808_rev']
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_4497', 'HMR_4741', 'HMR_4735', 'HMR_3213', 'HMR_2254', 'HMR_2255', 'HMR_2256', 'HMR_2257', 'HMR_2258', 'EX_m02772x') not MIN cutset
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_4497', 'HMR_4741', 'HMR_4735', 'HMR_3213', 'HMR_2254', 'HMR_2255', 'HMR_2256', 'HMR_2257', 'HMR_2258', 'HMR_9808_rev') not MIN cutset
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_4497', 'HMR_4741', 'HMR_4735', 'HMR_3213', 'HMR_2254', 'HMR_2255', 'HMR_2256', 'HMR_2257', 'EX_m02772x', 'HMR_9808_rev') not MIN cutset
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_4497', 'HMR_4741', 'HMR_4735', 'HMR_3213', 'HMR_2254', 'HMR_2255', 'HMR_2256', 'HMR_2258', 'EX_m02772x', 'HMR_9808_rev') not MIN cutset
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_4497', 'HMR_4741', 'HMR_4735', 'HMR_3213', 'HMR_2254', 'HMR_2255', 'HMR_2257', 'HMR_2258', 'EX_m02772x', 'HMR_9808_rev') not MIN cutset
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_4497', 'HMR_4741', 'HMR_4735', 'HMR_3213', 'HMR_2254', 'HMR_2256', 'HMR_2257', 'HMR_2258', 'EX_m02772x', 'HMR_9808_rev') not MIN cutset
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_4497', 'HMR_4741', 'HMR_4735', 'HMR_3213', 'HMR_2255', 'HMR_2256', 'HMR_2257', 'HMR_2258', 'EX_m02772x', 'HMR_9808_rev') not MIN cutset
# [N-1] Objective value =  17.4651278061316 For n-1 subset of cutset >>> ('HMR_4497', 'HMR_4741', 'HMR_4735', 'HMR_2254', 'HMR_2255', 'HMR_2256', 'HMR_2257', 'HMR_2258', 'EX_m02772x', 'HMR_9808_rev')
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_4497', 'HMR_4741', 'HMR_3213', 'HMR_2254', 'HMR_2255', 'HMR_2256', 'HMR_2257', 'HMR_2258', 'EX_m02772x', 'HMR_9808_rev') not MIN cutset
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_4497', 'HMR_4735', 'HMR_3213', 'HMR_2254', 'HMR_2255', 'HMR_2256', 'HMR_2257', 'HMR_2258', 'EX_m02772x', 'HMR_9808_rev') not MIN cutset
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_4741', 'HMR_4735', 'HMR_3213', 'HMR_2254', 'HMR_2255', 'HMR_2256', 'HMR_2257', 'HMR_2258', 'EX_m02772x', 'HMR_9808_rev') not MIN cutset
#
# CUTSET N° 3 : ['mcs_rsub_749_rev', 'mcs_rsub_750', 'mcs_rsub_751', 'mcs_rsub_752']
#
#
# Obj_value =  0.0 For cutset >>> ['HMR_2608_rev', 'HMR_2609_rev', 'HMR_2610', 'HMR_2611', 'HMR_2612_rev', 'HMR_2613_rev', 'HMR_3398', 'HMR_2614', 'HMR_2616_rev', 'HMR_2618_rev', 'HMR_2620', 'HMR_2621_rev', 'HMR_2622_rev']
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_2608_rev', 'HMR_2609_rev', 'HMR_2610', 'HMR_2611', 'HMR_2612_rev', 'HMR_2613_rev', 'HMR_3398', 'HMR_2614', 'HMR_2616_rev', 'HMR_2618_rev', 'HMR_2620', 'HMR_2621_rev') not MIN cutset
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_2608_rev', 'HMR_2609_rev', 'HMR_2610', 'HMR_2611', 'HMR_2612_rev', 'HMR_2613_rev', 'HMR_3398', 'HMR_2614', 'HMR_2616_rev', 'HMR_2618_rev', 'HMR_2620', 'HMR_2622_rev') not MIN cutset
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_2608_rev', 'HMR_2609_rev', 'HMR_2610', 'HMR_2611', 'HMR_2612_rev', 'HMR_2613_rev', 'HMR_3398', 'HMR_2614', 'HMR_2616_rev', 'HMR_2618_rev', 'HMR_2621_rev', 'HMR_2622_rev') not MIN cutset
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_2608_rev', 'HMR_2609_rev', 'HMR_2610', 'HMR_2611', 'HMR_2612_rev', 'HMR_2613_rev', 'HMR_3398', 'HMR_2614', 'HMR_2616_rev', 'HMR_2620', 'HMR_2621_rev', 'HMR_2622_rev') not MIN cutset
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_2608_rev', 'HMR_2609_rev', 'HMR_2610', 'HMR_2611', 'HMR_2612_rev', 'HMR_2613_rev', 'HMR_3398', 'HMR_2614', 'HMR_2618_rev', 'HMR_2620', 'HMR_2621_rev', 'HMR_2622_rev') not MIN cutset
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_2608_rev', 'HMR_2609_rev', 'HMR_2610', 'HMR_2611', 'HMR_2612_rev', 'HMR_2613_rev', 'HMR_3398', 'HMR_2616_rev', 'HMR_2618_rev', 'HMR_2620', 'HMR_2621_rev', 'HMR_2622_rev') not MIN cutset
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_2608_rev', 'HMR_2609_rev', 'HMR_2610', 'HMR_2611', 'HMR_2612_rev', 'HMR_2613_rev', 'HMR_2614', 'HMR_2616_rev', 'HMR_2618_rev', 'HMR_2620', 'HMR_2621_rev', 'HMR_2622_rev') not MIN cutset
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_2608_rev', 'HMR_2609_rev', 'HMR_2610', 'HMR_2611', 'HMR_2612_rev', 'HMR_3398', 'HMR_2614', 'HMR_2616_rev', 'HMR_2618_rev', 'HMR_2620', 'HMR_2621_rev', 'HMR_2622_rev') not MIN cutset
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_2608_rev', 'HMR_2609_rev', 'HMR_2610', 'HMR_2611', 'HMR_2613_rev', 'HMR_3398', 'HMR_2614', 'HMR_2616_rev', 'HMR_2618_rev', 'HMR_2620', 'HMR_2621_rev', 'HMR_2622_rev') not MIN cutset
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_2608_rev', 'HMR_2609_rev', 'HMR_2610', 'HMR_2612_rev', 'HMR_2613_rev', 'HMR_3398', 'HMR_2614', 'HMR_2616_rev', 'HMR_2618_rev', 'HMR_2620', 'HMR_2621_rev', 'HMR_2622_rev') not MIN cutset
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_2608_rev', 'HMR_2609_rev', 'HMR_2611', 'HMR_2612_rev', 'HMR_2613_rev', 'HMR_3398', 'HMR_2614', 'HMR_2616_rev', 'HMR_2618_rev', 'HMR_2620', 'HMR_2621_rev', 'HMR_2622_rev') not MIN cutset
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_2608_rev', 'HMR_2610', 'HMR_2611', 'HMR_2612_rev', 'HMR_2613_rev', 'HMR_3398', 'HMR_2614', 'HMR_2616_rev', 'HMR_2618_rev', 'HMR_2620', 'HMR_2621_rev', 'HMR_2622_rev') not MIN cutset
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_2609_rev', 'HMR_2610', 'HMR_2611', 'HMR_2612_rev', 'HMR_2613_rev', 'HMR_3398', 'HMR_2614', 'HMR_2616_rev', 'HMR_2618_rev', 'HMR_2620', 'HMR_2621_rev', 'HMR_2622_rev') not MIN cutset
#
# CUTSET N° 4 : ['mcs_rsub_750', 'mcs_rsub_751', 'mcs_rsub_752', 'mcs_rsub_820']
#
#
# Obj_value =  0.0 For cutset >>> ['HMR_2611', 'HMR_2612_rev', 'HMR_2613_rev', 'HMR_3398', 'HMR_2614', 'HMR_2616_rev', 'HMR_2618_rev', 'HMR_2620', 'HMR_2621_rev', 'HMR_2622_rev', 'HMR_3128', 'HMR_3129', 'HMR_3130', 'HMR_3132']
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_2611', 'HMR_2612_rev', 'HMR_2613_rev', 'HMR_3398', 'HMR_2614', 'HMR_2616_rev', 'HMR_2618_rev', 'HMR_2620', 'HMR_2621_rev', 'HMR_2622_rev', 'HMR_3128', 'HMR_3129', 'HMR_3130') not MIN cutset
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_2611', 'HMR_2612_rev', 'HMR_2613_rev', 'HMR_3398', 'HMR_2614', 'HMR_2616_rev', 'HMR_2618_rev', 'HMR_2620', 'HMR_2621_rev', 'HMR_2622_rev', 'HMR_3128', 'HMR_3129', 'HMR_3132') not MIN cutset
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_2611', 'HMR_2612_rev', 'HMR_2613_rev', 'HMR_3398', 'HMR_2614', 'HMR_2616_rev', 'HMR_2618_rev', 'HMR_2620', 'HMR_2621_rev', 'HMR_2622_rev', 'HMR_3128', 'HMR_3130', 'HMR_3132') not MIN cutset
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_2611', 'HMR_2612_rev', 'HMR_2613_rev', 'HMR_3398', 'HMR_2614', 'HMR_2616_rev', 'HMR_2618_rev', 'HMR_2620', 'HMR_2621_rev', 'HMR_2622_rev', 'HMR_3129', 'HMR_3130', 'HMR_3132') not MIN cutset
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_2611', 'HMR_2612_rev', 'HMR_2613_rev', 'HMR_3398', 'HMR_2614', 'HMR_2616_rev', 'HMR_2618_rev', 'HMR_2620', 'HMR_2621_rev', 'HMR_3128', 'HMR_3129', 'HMR_3130', 'HMR_3132') not MIN cutset
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_2611', 'HMR_2612_rev', 'HMR_2613_rev', 'HMR_3398', 'HMR_2614', 'HMR_2616_rev', 'HMR_2618_rev', 'HMR_2620', 'HMR_2622_rev', 'HMR_3128', 'HMR_3129', 'HMR_3130', 'HMR_3132') not MIN cutset
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_2611', 'HMR_2612_rev', 'HMR_2613_rev', 'HMR_3398', 'HMR_2614', 'HMR_2616_rev', 'HMR_2618_rev', 'HMR_2621_rev', 'HMR_2622_rev', 'HMR_3128', 'HMR_3129', 'HMR_3130', 'HMR_3132') not MIN cutset
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_2611', 'HMR_2612_rev', 'HMR_2613_rev', 'HMR_3398', 'HMR_2614', 'HMR_2616_rev', 'HMR_2620', 'HMR_2621_rev', 'HMR_2622_rev', 'HMR_3128', 'HMR_3129', 'HMR_3130', 'HMR_3132') not MIN cutset
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_2611', 'HMR_2612_rev', 'HMR_2613_rev', 'HMR_3398', 'HMR_2614', 'HMR_2618_rev', 'HMR_2620', 'HMR_2621_rev', 'HMR_2622_rev', 'HMR_3128', 'HMR_3129', 'HMR_3130', 'HMR_3132') not MIN cutset
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_2611', 'HMR_2612_rev', 'HMR_2613_rev', 'HMR_3398', 'HMR_2616_rev', 'HMR_2618_rev', 'HMR_2620', 'HMR_2621_rev', 'HMR_2622_rev', 'HMR_3128', 'HMR_3129', 'HMR_3130', 'HMR_3132') not MIN cutset
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_2611', 'HMR_2612_rev', 'HMR_2613_rev', 'HMR_2614', 'HMR_2616_rev', 'HMR_2618_rev', 'HMR_2620', 'HMR_2621_rev', 'HMR_2622_rev', 'HMR_3128', 'HMR_3129', 'HMR_3130', 'HMR_3132') not MIN cutset
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_2611', 'HMR_2612_rev', 'HMR_3398', 'HMR_2614', 'HMR_2616_rev', 'HMR_2618_rev', 'HMR_2620', 'HMR_2621_rev', 'HMR_2622_rev', 'HMR_3128', 'HMR_3129', 'HMR_3130', 'HMR_3132') not MIN cutset
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_2611', 'HMR_2613_rev', 'HMR_3398', 'HMR_2614', 'HMR_2616_rev', 'HMR_2618_rev', 'HMR_2620', 'HMR_2621_rev', 'HMR_2622_rev', 'HMR_3128', 'HMR_3129', 'HMR_3130', 'HMR_3132') not MIN cutset
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_2612_rev', 'HMR_2613_rev', 'HMR_3398', 'HMR_2614', 'HMR_2616_rev', 'HMR_2618_rev', 'HMR_2620', 'HMR_2621_rev', 'HMR_2622_rev', 'HMR_3128', 'HMR_3129', 'HMR_3130', 'HMR_3132') not MIN cutset
#
# CUTSET N° 5 : ['mcs_rsub_547', 'mcs_rsub_75']
#
#
# Obj_value =  0.0 For cutset >>> ['HMR_3977', 'EX_m02772x', 'HMR_9808_rev']
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_3977', 'EX_m02772x') not MIN cutset
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_3977', 'HMR_9808_rev') not MIN cutset
# [N-1] Objective value =  17.465127806131598 For n-1 subset of cutset >>> ('EX_m02772x', 'HMR_9808_rev')
#
# CUTSET N° 6 : ['mcs_rsub_1102']
#
#
# Obj_value =  0.0 For cutset >>> ['HMR_0225']
#
# CUTSET N° 7 : ['mcs_rsub_418', 'mcs_rsub_443', 'mcs_rsub_445', 'mcs_rsub_488', 'mcs_rsub_547']
#
#
# Obj_value =  0.0 For cutset >>> ['HMR_8442', 'HMR_3795', 'HMR_6419', 'HMR_6420', 'HMR_3780', 'HMR_3977']
# [N-1] Objective value =  18.781714507064493 For n-1 subset of cutset >>> ('HMR_8442', 'HMR_3795', 'HMR_6419', 'HMR_6420', 'HMR_3780')
# [N-1] Objective value =  12.72153668368734 For n-1 subset of cutset >>> ('HMR_8442', 'HMR_3795', 'HMR_6419', 'HMR_6420', 'HMR_3977')
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_8442', 'HMR_3795', 'HMR_6419', 'HMR_3780', 'HMR_3977') not MIN cutset
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_8442', 'HMR_3795', 'HMR_6420', 'HMR_3780', 'HMR_3977') not MIN cutset
# [N-1] Objective value =  12.72153668368734 For n-1 subset of cutset >>> ('HMR_8442', 'HMR_6419', 'HMR_6420', 'HMR_3780', 'HMR_3977')
# [N-1] Objective value =  20.08563582538045 For n-1 subset of cutset >>> ('HMR_3795', 'HMR_6419', 'HMR_6420', 'HMR_3780', 'HMR_3977')
#
# CUTSET N° 8 : ['mcs_rsub_418', 'mcs_rsub_436', 'mcs_rsub_443', 'mcs_rsub_547']
#
#
# Obj_value =  0.0 For cutset >>> ['HMR_8442', 'HMR_3206', 'HMR_3778', 'HMR_3785', 'HMR_3823', 'HMR_5107', 'HMR_3795', 'HMR_3977']
# [N-1] Objective value =  18.781714507064496 For n-1 subset of cutset >>> ('HMR_8442', 'HMR_3206', 'HMR_3778', 'HMR_3785', 'HMR_3823', 'HMR_5107', 'HMR_3795')
# [N-1] Objective value =  12.721536683687276 For n-1 subset of cutset >>> ('HMR_8442', 'HMR_3206', 'HMR_3778', 'HMR_3785', 'HMR_3823', 'HMR_5107', 'HMR_3977')
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_8442', 'HMR_3206', 'HMR_3778', 'HMR_3785', 'HMR_3823', 'HMR_3795', 'HMR_3977') not MIN cutset
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_8442', 'HMR_3206', 'HMR_3778', 'HMR_3785', 'HMR_5107', 'HMR_3795', 'HMR_3977') not MIN cutset
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_8442', 'HMR_3206', 'HMR_3778', 'HMR_3823', 'HMR_5107', 'HMR_3795', 'HMR_3977') not MIN cutset
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_8442', 'HMR_3206', 'HMR_3785', 'HMR_3823', 'HMR_5107', 'HMR_3795', 'HMR_3977') not MIN cutset
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_8442', 'HMR_3778', 'HMR_3785', 'HMR_3823', 'HMR_5107', 'HMR_3795', 'HMR_3977') not MIN cutset
# [N-1] Objective value =  20.08563582538046 For n-1 subset of cutset >>> ('HMR_3206', 'HMR_3778', 'HMR_3785', 'HMR_3823', 'HMR_5107', 'HMR_3795', 'HMR_3977')
#
# CUTSET N° 9 : ['mcs_rsub_418', 'mcs_rsub_436', 'mcs_rsub_444', 'mcs_rsub_483', 'mcs_rsub_547']
#
#
# Obj_value =  0.0 For cutset >>> ['HMR_8442', 'HMR_3206', 'HMR_3778', 'HMR_3785', 'HMR_3823', 'HMR_5107', 'HMR_6417', 'HMR_6416', 'HMR_3748', 'HMR_3977']
# [N-1] Objective value =  18.781714507064542 For n-1 subset of cutset >>> ('HMR_8442', 'HMR_3206', 'HMR_3778', 'HMR_3785', 'HMR_3823', 'HMR_5107', 'HMR_6417', 'HMR_6416', 'HMR_3748')
# [N-1] Objective value =  12.72153668368734 For n-1 subset of cutset >>> ('HMR_8442', 'HMR_3206', 'HMR_3778', 'HMR_3785', 'HMR_3823', 'HMR_5107', 'HMR_6417', 'HMR_6416', 'HMR_3977')
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_8442', 'HMR_3206', 'HMR_3778', 'HMR_3785', 'HMR_3823', 'HMR_5107', 'HMR_6417', 'HMR_3748', 'HMR_3977') not MIN cutset
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_8442', 'HMR_3206', 'HMR_3778', 'HMR_3785', 'HMR_3823', 'HMR_5107', 'HMR_6416', 'HMR_3748', 'HMR_3977') not MIN cutset
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_8442', 'HMR_3206', 'HMR_3778', 'HMR_3785', 'HMR_3823', 'HMR_6417', 'HMR_6416', 'HMR_3748', 'HMR_3977') not MIN cutset
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_8442', 'HMR_3206', 'HMR_3778', 'HMR_3785', 'HMR_5107', 'HMR_6417', 'HMR_6416', 'HMR_3748', 'HMR_3977') not MIN cutset
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_8442', 'HMR_3206', 'HMR_3778', 'HMR_3823', 'HMR_5107', 'HMR_6417', 'HMR_6416', 'HMR_3748', 'HMR_3977') not MIN cutset
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_8442', 'HMR_3206', 'HMR_3785', 'HMR_3823', 'HMR_5107', 'HMR_6417', 'HMR_6416', 'HMR_3748', 'HMR_3977') not MIN cutset
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_8442', 'HMR_3778', 'HMR_3785', 'HMR_3823', 'HMR_5107', 'HMR_6417', 'HMR_6416', 'HMR_3748', 'HMR_3977') not MIN cutset
# [N-1] Objective value =  20.08563582538046 For n-1 subset of cutset >>> ('HMR_3206', 'HMR_3778', 'HMR_3785', 'HMR_3823', 'HMR_5107', 'HMR_6417', 'HMR_6416', 'HMR_3748', 'HMR_3977')
#
# CUTSET N° 10 : ['mcs_rsub_747']
#
#
# Obj_value =  0.0 For cutset >>> ['HMR_2602_rev', 'HMR_2603_rev', 'HMR_2604']
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_2602_rev', 'HMR_2603_rev') not MIN cutset
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_2602_rev', 'HMR_2604') not MIN cutset
# [N-1] Objective value =  0.0 For n-1 subset of cutset >>> ('HMR_2603_rev', 'HMR_2604') not MIN cutset
#
# CUTSET N° 11 : ['mcs_rsub_821']
#
#
# Obj_value =  0.0 For cutset >>> ['HMR_3135']

# %%
from aspmcs.code.utils import knock_out

# %%
325+23
870-348
# Out:
# 522

# %%
import matplotlib.pyplot as plt
# The slices will be ordered and plotted counter-clockwise.
labels = [r"Réactions du MCS absentes du modèle sain", r"MCS coupe une voie métabolique du modèle sain", 
r"MCS n'a pas d'impact sur les voies métaboliques testées"]
total = 14919
invalid = 770+1+1
sizes = [325, 23, 522]
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
patches, texts, percent = plt.pie(sizes, colors=colors, autopct='%1.2f%%', startangle=90)
plt.legend(patches, labels, loc="upper right")
# Set aspect ratio to be equal so that pie is drawn as a circle.
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
#Compressed CS: 

import matplotlib.pyplot as plt
labels = 'MCS Not found in healthy model', 'MCS Prevents metabolic function in healthy model', 'MCS has no detected impact on heatlhy model'
sizes = [325, 23, 522]

fig, ax = plt.subplots()
fig.suptitle("Results of MCS evaluation")
ax.pie(sizes, labels=labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fa427f9e800>,
#   <matplotlib.patches.Wedge at 0x7fa45f7c57e0>,
#   <matplotlib.patches.Wedge at 0x7fa45f7841c0>],
#  [Text(0.4255346450738345, 1.0143570701887408, 'MCS Not found in healthy model'),
#   Text(-0.8332134904850835, 0.7181610399302262, 'MCS Prevents metabolic function in healthy model'),
#   Text(-0.33991853954312445, -1.0461622180497963, 'MCS has no detected impact on heatlhy model')])

# %%
14919*(325/870)
# Out:
# 5573.189655172414

# %%
# Decompressed CS:
import matplotlib.pyplot as plt
labels = 'Réactions du MCS absentes du modèle sain', 'MCS coupe une voie métabolique du modèle sain', 'MCS n\'a pas d\'impact sur les voies métaboliques testées'
total = 14919
invalid = 770+1+1
sizes = [5573, invalid, total-invalid]

fig, ax = plt.subplots()
fig.suptitle("Effet des MCS décompressés sur le modèle sain")
ax.pie(sizes, labels=labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fa45f7e1030>,
#   <matplotlib.patches.Wedge at 0x7fa45f75bdc0>,
#   <matplotlib.patches.Wedge at 0x7fa45f7e1900>],
#  [Text(0.7223491549282226, 0.8295852568449387, 'MCS Not found in healthy model'),
#   Text(-0.2788868285939146, 1.0640592731783454, 'MCS Prevents metabolic function in healthy model'),
#   Text(-0.6193401897993889, -0.9090752055244149, 'MCS has no detected impact on heatlhy model')])

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (5,5)
# The slices will be ordered and plotted counter-clockwise.
labels = [r"MCS absent du modèle sain", r"MCS invalides", 
r"MCS valides"]
total = 14919
invalid = 770+1+1
sizes = [3734, invalid, total-invalid]
colors = ['gold', 'lightcoral', 'darkseagreen']
patches, texts, percent = plt.pie(sizes, colors=colors, autopct='%1.2f%%', startangle=90)
plt.legend(patches, labels, loc="upper right")
plt.suptitle("Répartition des MCS valides, invalides et absents du modèle sain")
# Set aspect ratio to be equal so that pie is drawn as a circle.
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
HepG2 = cobra.io.read_sbml_model("../../models_storage/HepG2_medium.xml")

# %%
subS_counter = {}
subS_counter_nf = {}
not_found = []
nb_not_found = 0
for cs in flat_list:
    for rid in cs:
        try:
            if rid.endswith("_rev"):
                rid = rid[:-4]
            robj = healthy.reactions.get_by_id(rid)
            if robj.subsystem == "":
                subS_counter["Exchange reactions"] = subS_counter.get("Exchange reactions", 0) +1
            else:
                subS_counter[robj.subsystem] = subS_counter.get(robj.subsystem, 0) +1
            #The two dictionaries have to be the same size, filling the second one with zeroes:
            if robj.subsystem in subS_counter_nf or robj.subsystem == "":
                pass
            else:
                subS_counter_nf[robj.subsystem] = subS_counter_nf.get(robj.subsystem, 0)

        except KeyError:
            if rid.endswith("_rev"):
                rid = rid[:-4]
            
            robj = HepG2.reactions.get_by_id(rid)
            if robj.subsystem == "":
                subS_counter_nf["Exchange reactions"] = subS_counter_nf.get("Exchange reactions", 0) +1
            else:
                subS_counter_nf[robj.subsystem] = subS_counter_nf.get(robj.subsystem, 0) +1
            not_found.append(rid)
            nb_not_found += 1
#print(set(not_found), nb_not_found)

# %%
len(subS_counter)
# Out:
# 62

# %%
# Reading log files and extracting invalid MCS :
with open("../results/logs_comparison/log_cs_cholesterol.txt", "r") as chol_logs:
    chol_cs_eval = chol_logs.readlines()

rid_invalid_cs_list = []
for line in chol_cs_eval:
    if "prevents" in line:
        cs = line.strip("\n").split("(")[1]
        cs_isol = cs.split(")")[0]
        for rid in cs_isol.split(","):
            if len(rid[1:-1].strip("'")) < 8:
                print(rid)
            else:
                rid_invalid_cs_list.append(rid[1:-1].strip("'"))

# %%
for rid in rid_invalid_cs_list :
    if len(rid) < 8:
        print(rid_invalid_cs_list.index(rid))

# %%
rid_invalid_cs_list
# Out:
# ['HMR_0336',
#  'HMR_8947',
#  'HMR_2254',
#  'HMR_3186',
#  'HMR_2254',
#  'HMR_3187',
#  'HMR_2254',
#  'HMR_3188',
#  'HMR_2655',
#  'HMR_3118',
#  'HMR_2210',
#  'HMR_2656_rev',
#  'HMR_3115',
#  'HMR_2210',
#  'HMR_2656_rev',
#  'HMR_3116',
#  'HMR_2210',
#  'HMR_2656_rev',
#  'HMR_3117',
#  'HMR_2210',
#  'HMR_2656_rev',
#  'HMR_3118',
#  'HMR_2324',
#  'HMR_3057',
#  'HMR_2324',
#  'HMR_3058',
#  'HMR_2324',
#  'HMR_3059',
#  'HMR_2324',
#  'HMR_3060',
#  'HMR_2324',
#  'HMR_3022',
#  'HMR_2326',
#  'HMR_3057',
#  'HMR_2326',
#  'HMR_3058',
#  'HMR_2326',
#  'HMR_3059',
#  'HMR_2326',
#  'HMR_3060',
#  'HMR_2326',
#  'HMR_3022',
#  'HMR_2328',
#  'HMR_3057',
#  'HMR_2328',
#  'HMR_3058',
#  'HMR_2328',
#  'HMR_3059',
#  'HMR_2328',
#  'HMR_3060',
#  'HMR_2328',
#  'HMR_3022',
#  'HMR_2330',
#  'HMR_3057',
#  'HMR_2330',
#  'HMR_3058',
#  'HMR_2330',
#  'HMR_3059',
#  'HMR_2330',
#  'HMR_3060',
#  'HMR_2330',
#  'HMR_3022',
#  'HMR_0424',
#  'HMR_2211',
#  'HMR_2215',
#  'HMR_2702_rev',
#  'HMR_2211',
#  'HMR_2215',
#  'HMR_2703_rev',
#  'HMR_2211',
#  'HMR_2215',
#  'HMR_2704',
#  'HMR_2211',
#  'HMR_2215',
#  'HMR_3107',
#  'HMR_2211',
#  'HMR_2215',
#  'HMR_3108',
#  'HMR_2211',
#  'HMR_2215',
#  'HMR_3109',
#  'HMR_2211',
#  'HMR_2215',
#  'HMR_3110',
#  'HMR_2211',
#  'HMR_2217',
#  'HMR_2702_rev',
#  'HMR_2211',
#  'HMR_2217',
#  'HMR_2703_rev',
#  'HMR_2211',
#  'HMR_2217',
#  'HMR_2704',
#  'HMR_2211',
#  'HMR_2217',
#  'HMR_3107',
#  'HMR_2211',
#  'HMR_2217',
#  'HMR_3108',
#  'HMR_2211',
#  'HMR_2217',
#  'HMR_3109',
#  'HMR_2211',
#  'HMR_2217',
#  'HMR_3110',
#  'HMR_2211',
#  'HMR_2218',
#  'HMR_2702_rev',
#  'HMR_2211',
#  'HMR_2218',
#  'HMR_2703_rev',
#  'HMR_2211',
#  'HMR_2218',
#  'HMR_2704',
#  'HMR_2211',
#  'HMR_2218',
#  'HMR_3107',
#  'HMR_2211',
#  'HMR_2218',
#  'HMR_3108',
#  'HMR_2211',
#  'HMR_2218',
#  'HMR_3109',
#  'HMR_2211',
#  'HMR_2218',
#  'HMR_3110',
#  'HMR_2211',
#  'HMR_2219',
#  'HMR_2702_rev',
#  'HMR_2211',
#  'HMR_2219',
#  'HMR_2703_rev',
#  'HMR_2211',
#  'HMR_2219',
#  'HMR_2704',
#  'HMR_2211',
#  'HMR_2219',
#  'HMR_3107',
#  'HMR_2211',
#  'HMR_2219',
#  'HMR_3108',
#  'HMR_2211',
#  'HMR_2219',
#  'HMR_3109',
#  'HMR_2211',
#  'HMR_2219',
#  'HMR_3110',
#  'HMR_2212',
#  'HMR_2215',
#  'HMR_2702_rev',
#  'HMR_2212',
#  'HMR_2215',
#  'HMR_2703_rev',
#  'HMR_2212',
#  'HMR_2215',
#  'HMR_2704',
#  'HMR_2212',
#  'HMR_2215',
#  'HMR_3107',
#  'HMR_2212',
#  'HMR_2215',
#  'HMR_3108',
#  'HMR_2212',
#  'HMR_2215',
#  'HMR_3109',
#  'HMR_2212',
#  'HMR_2215',
#  'HMR_3110',
#  'HMR_2212',
#  'HMR_2217',
#  'HMR_2702_rev',
#  'HMR_2212',
#  'HMR_2217',
#  'HMR_2703_rev',
#  'HMR_2212',
#  'HMR_2217',
#  'HMR_2704',
#  'HMR_2212',
#  'HMR_2217',
#  'HMR_3107',
#  'HMR_2212',
#  'HMR_2217',
#  'HMR_3108',
#  'HMR_2212',
#  'HMR_2217',
#  'HMR_3109',
#  'HMR_2212',
#  'HMR_2217',
#  'HMR_3110',
#  'HMR_2212',
#  'HMR_2218',
#  'HMR_2702_rev',
#  'HMR_2212',
#  'HMR_2218',
#  'HMR_2703_rev',
#  'HMR_2212',
#  'HMR_2218',
#  'HMR_2704',
#  'HMR_2212',
#  'HMR_2218',
#  'HMR_3107',
#  'HMR_2212',
#  'HMR_2218',
#  'HMR_3108',
#  'HMR_2212',
#  'HMR_2218',
#  'HMR_3109',
#  'HMR_2212',
#  'HMR_2218',
#  'HMR_3110',
#  'HMR_2212',
#  'HMR_2219',
#  'HMR_2702_rev',
#  'HMR_2212',
#  'HMR_2219',
#  'HMR_2703_rev',
#  'HMR_2212',
#  'HMR_2219',
#  'HMR_2704',
#  'HMR_2212',
#  'HMR_2219',
#  'HMR_3107',
#  'HMR_2212',
#  'HMR_2219',
#  'HMR_3108',
#  'HMR_2212',
#  'HMR_2219',
#  'HMR_3109',
#  'HMR_2212',
#  'HMR_2219',
#  'HMR_3110',
#  'HMR_2213',
#  'HMR_2215',
#  'HMR_2702_rev',
#  'HMR_2213',
#  'HMR_2215',
#  'HMR_2703_rev',
#  'HMR_2213',
#  'HMR_2215',
#  'HMR_2704',
#  'HMR_2213',
#  'HMR_2215',
#  'HMR_3107',
#  'HMR_2213',
#  'HMR_2215',
#  'HMR_3108',
#  'HMR_2213',
#  'HMR_2215',
#  'HMR_3109',
#  'HMR_2213',
#  'HMR_2215',
#  'HMR_3110',
#  'HMR_2213',
#  'HMR_2217',
#  'HMR_2702_rev',
#  'HMR_2213',
#  'HMR_2217',
#  'HMR_2703_rev',
#  'HMR_2213',
#  'HMR_2217',
#  'HMR_2704',
#  'HMR_2213',
#  'HMR_2217',
#  'HMR_3107',
#  'HMR_2213',
#  'HMR_2217',
#  'HMR_3108',
#  'HMR_2213',
#  'HMR_2217',
#  'HMR_3109',
#  'HMR_2213',
#  'HMR_2217',
#  'HMR_3110',
#  'HMR_2213',
#  'HMR_2218',
#  'HMR_2702_rev',
#  'HMR_2213',
#  'HMR_2218',
#  'HMR_2703_rev',
#  'HMR_2213',
#  'HMR_2218',
#  'HMR_2704',
#  'HMR_2213',
#  'HMR_2218',
#  'HMR_3107',
#  'HMR_2213',
#  'HMR_2218',
#  'HMR_3108',
#  'HMR_2213',
#  'HMR_2218',
#  'HMR_3109',
#  'HMR_2213',
#  'HMR_2218',
#  'HMR_3110',
#  'HMR_2213',
#  'HMR_2219',
#  'HMR_2702_rev',
#  'HMR_2213',
#  'HMR_2219',
#  'HMR_2703_rev',
#  'HMR_2213',
#  'HMR_2219',
#  'HMR_2704',
#  'HMR_2213',
#  'HMR_2219',
#  'HMR_3107',
#  'HMR_2213',
#  'HMR_2219',
#  'HMR_3108',
#  'HMR_2213',
#  'HMR_2219',
#  'HMR_3109',
#  'HMR_2213',
#  'HMR_2219',
#  'HMR_3110',
#  'HMR_2214',
#  'HMR_2215',
#  'HMR_2702_rev',
#  'HMR_2214',
#  'HMR_2215',
#  'HMR_2703_rev',
#  'HMR_2214',
#  'HMR_2215',
#  'HMR_2704',
#  'HMR_2214',
#  'HMR_2215',
#  'HMR_3107',
#  'HMR_2214',
#  'HMR_2215',
#  'HMR_3108',
#  'HMR_2214',
#  'HMR_2215',
#  'HMR_3109',
#  'HMR_2214',
#  'HMR_2215',
#  'HMR_3110',
#  'HMR_2214',
#  'HMR_2217',
#  'HMR_2702_rev',
#  'HMR_2214',
#  'HMR_2217',
#  'HMR_2703_rev',
#  'HMR_2214',
#  'HMR_2217',
#  'HMR_2704',
#  'HMR_2214',
#  'HMR_2217',
#  'HMR_3107',
#  'HMR_2214',
#  'HMR_2217',
#  'HMR_3108',
#  'HMR_2214',
#  'HMR_2217',
#  'HMR_3109',
#  'HMR_2214',
#  'HMR_2217',
#  'HMR_3110',
#  'HMR_2214',
#  'HMR_2218',
#  'HMR_2702_rev',
#  'HMR_2214',
#  'HMR_2218',
#  'HMR_2703_rev',
#  'HMR_2214',
#  'HMR_2218',
#  'HMR_2704',
#  'HMR_2214',
#  'HMR_2218',
#  'HMR_3107',
#  'HMR_2214',
#  'HMR_2218',
#  'HMR_3108',
#  'HMR_2214',
#  'HMR_2218',
#  'HMR_3109',
#  'HMR_2214',
#  'HMR_2218',
#  'HMR_3110',
#  'HMR_2214',
#  'HMR_2219',
#  'HMR_2702_rev',
#  'HMR_2214',
#  'HMR_2219',
#  'HMR_2703_rev',
#  'HMR_2214',
#  'HMR_2219',
#  'HMR_2704',
#  'HMR_2214',
#  'HMR_2219',
#  'HMR_3107',
#  'HMR_2214',
#  'HMR_2219',
#  'HMR_3108',
#  'HMR_2214',
#  'HMR_2219',
#  'HMR_3109',
#  'HMR_2214',
#  'HMR_2219',
#  'HMR_3110',
#  'HMR_2211',
#  'HMR_2365',
#  'HMR_2702_rev',
#  'HMR_2211',
#  'HMR_2365',
#  'HMR_2703_rev',
#  'HMR_2211',
#  'HMR_2365',
#  'HMR_2704',
#  'HMR_2211',
#  'HMR_2365',
#  'HMR_3107',
#  'HMR_2211',
#  'HMR_2365',
#  'HMR_3108',
#  'HMR_2211',
#  'HMR_2365',
#  'HMR_3109',
#  'HMR_2211',
#  'HMR_2365',
#  'HMR_3110',
#  'HMR_2212',
#  'HMR_2365',
#  'HMR_2702_rev',
#  'HMR_2212',
#  'HMR_2365',
#  'HMR_2703_rev',
#  'HMR_2212',
#  'HMR_2365',
#  'HMR_2704',
#  'HMR_2212',
#  'HMR_2365',
#  'HMR_3107',
#  'HMR_2212',
#  'HMR_2365',
#  'HMR_3108',
#  'HMR_2212',
#  'HMR_2365',
#  'HMR_3109',
#  'HMR_2212',
#  'HMR_2365',
#  'HMR_3110',
#  'HMR_2213',
#  'HMR_2365',
#  'HMR_2702_rev',
#  ...]

# %%
subS_counter_inv = {}
for rid in rid_invalid_cs_list:
    if rid.endswith("_rev"):
        rid = rid[:-4]
    robj = healthy.reactions.get_by_id(rid)

    subS_counter_inv[robj.subsystem] = subS_counter_inv.get(robj.subsystem, 0) +1

# Filling the absent subsystems in the invalid mcs subsystem counter
for subsystem in subS_counter.keys():
    if subsystem in subS_counter_inv:
        pass
    else:
        subS_counter_inv[subsystem] = subS_counter_inv.get(subsystem, 0)

# %%
len(subS_counter_inv)
# Out:
# 62

# %%
sorted_dict_total = {k: v for k, v in sorted(subS_counter.items(), key=lambda item: item[1])}
labels_total = [label for label in sorted_dict_total.keys()]
sizes_total = [value for value in sorted_dict_total.values()]
labels_nf = [label for label in subS_counter_nf.keys()]
sizes_nf = [value for value in subS_counter_nf.values()]
labels_inv = [label for label in subS_counter_inv.keys()]
sizes_inv = [value for value in subS_counter_inv.values()]
plt.rcParams["figure.figsize"] = (11,13)
plt.rc('figure', titlesize=16)
fig, ax = plt.subplots()
plt.suptitle("Répartition des réactions des MCS dans les sous-groupes de réactions du modèle sain")
ax.barh(labels_total, sizes_total, color = "darkseagreen", label = "Réactions appartenant à des MCS valides")
ax.barh(labels_nf, sizes_nf, color = 'gold', label = "Réactions appartenant à des MCS absents du modèle sain")
ax.barh(labels_inv, sizes_inv, color = "lightcoral", label = "Réactions appartenant à des MCS empêchant le bon fonctionnement du modèle sain")
plt.legend()

# %%
sum(sizes_total)
# Out:
# 52373

# %%
# Values normalized by number of reactions in the subsystem
subS_counter_whole_model = {}

for reaction in healthy.reactions:
    if reaction.subsystem == "":
        subS_counter_whole_model["Exchange reactions"] = subS_counter_whole_model.get("Exchange reactions", 0) +1
    else:
        subS_counter_whole_model[reaction.subsystem] = subS_counter_whole_model.get(reaction.subsystem, 0) +1

def normalize_dict_counter(target, by):
    normalized = {}
    for k,v in target.items():
        normalized[k] = v/by[k]
    return normalized

subS_counter_norm = normalize_dict_counter(sorted_dict_total, subS_counter_whole_model)
subS_counter_nf_norm = normalize_dict_counter(subS_counter_nf, subS_counter_whole_model)
subS_counter_inv_norm = normalize_dict_counter(subS_counter_inv, subS_counter_whole_model)

# %%
sorted_dict_total_norm = {k: v for k, v in sorted(subS_counter_norm.items(), key=lambda item: item[1])}
import numpy as np
labels_total = [label for label in sorted_dict_total_norm.keys()]
sizes_total = [value for value in sorted_dict_total_norm.values()]
labels_nf = [label for label in subS_counter_nf_norm.keys()]
sizes_nf = [value for value in subS_counter_nf_norm.values()]
labels_inv = [label for label in subS_counter_inv_norm.keys()]
sizes_inv = [value for value in subS_counter_inv_norm.values()]
plt.rcParams["figure.figsize"] = (11,12)
plt.rc('figure', titlesize=16)
fig, ax = plt.subplots()
colors = ['yellowgreen', 'gold', 'lightskyblue']

fig.suptitle("Répartition des réactions des MCS dans les sous-groupes de réactions du modèle sain, normalisé par le nombre total de réactions appartenant au sous-groupe")
ax.barh(labels_total, sizes_total, color = "darkseagreen", label = "Réactions appartenant à des MCS viables")
ax.barh(labels_nf, sizes_nf, color = 'gold', label = "Réactions appartenant à des MCS absents dans le modèle sain ")
ax.barh(labels_inv, sizes_inv, color = "lightcoral", label = "Réactions appartenant à des MCS empêchant le fonctionnement du modèle sain")
fig.legend(loc="lower left")

# %%
sorted
# Out:
# {'Fatty acid activation (cytosolic)': 2,
#  'Transport, lysosome to ER': 2,
#  'Biopterin metabolism': 4,
#  'Galactose metabolism': 4,
#  'Beta oxidation of unsaturated fatty acids (n-7) (mitochondrial)': 5,
#  'Acylglycerides metabolism': 5,
#  'Phenylalanine, tyrosine and tryptophan biosynthesis': 6,
#  'Inositol phosphate metabolism': 6,
#  'Nicotinate and nicotinamide metabolism': 6,
#  'Pyruvate metabolism': 8,
#  'Transport, peroxisomal': 15,
#  'Pentose and glucuronate interconversions': 15,
#  'Glycolysis / Gluconeogenesis': 20,
#  'ROS detoxification': 29,
#  'Beta oxidation of even-chain fatty acids (peroxisomal)': 32,
#  'Pyrimidine metabolism': 37,
#  'Glutamate and glutamine metabolism': 38,
#  'Nucleotide metabolism': 40,
#  'Pool reactions': 64,
#  'Purine metabolism': 77,
#  'Sphingolipid metabolism': 84,
#  'Lysine metabolism': 99,
#  'Butanoate metabolism': 105,
#  'Protein assembly': 128,
#  'Fatty acid desaturation (even-chain)': 152,
#  'Cholesterol metabolism': 156,
#  'Oxidative phosphorylation': 229,
#  'Cysteine and methionine metabolism': 265,
#  'Fatty acid transfer reactions': 278,
#  'Sulfur metabolism': 288,
#  'Bile acid biosynthesis': 288,
#  'Fatty acid elongation (odd-chain)': 296,
#  'Glycerolipid metabolism': 299,
#  'Omega-6 fatty acid metabolism': 362,
#  'Omega-3 fatty acid metabolism': 428,
#  'Glycerophospholipid metabolism': 447,
#  'Histidine metabolism': 456,
#  'Cholesterol biosynthesis 2': 536,
#  'Glycine, serine and threonine metabolism': 554,
#  'Carnitine shuttle (cytosolic)': 557,
#  'Fatty acid biosynthesis (unsaturated)': 628,
#  'Transport, mitochondrial': 645,
#  'Pentose phosphate pathway': 734,
#  'Beta oxidation of even-chain fatty acids (mitochondrial)': 828,
#  'Folate metabolism': 848,
#  'Tricarboxylic acid cycle and glyoxylate/dicarboxylate metabolism': 996,
#  'beta-Alanine metabolism': 1197,
#  'Alanine, aspartate and glutamate metabolism': 1212,
#  'Beta oxidation of odd-chain fatty acids (mitochondrial)': 1240,
#  'Carnitine shuttle (mitochondrial)': 1440,
#  'Fatty acid elongation (even-chain)': 1588,
#  'Fatty acid biosynthesis (odd-chain)': 1758,
#  'Arginine and proline metabolism': 1901,
#  'Fatty acid biosynthesis (even-chain)': 1904,
#  'Cholesterol biosynthesis 3  (Kandustch-Russell pathway)': 2181,
#  'Transport, extracellular': 2224,
#  'Aminoacyl-tRNA biosynthesis': 2560,
#  'Cholesterol biosynthesis 1 (Bloch pathway)': 2658,
#  'Glutathione metabolism': 2798,
#  'Propanoate metabolism': 3541,
#  'Valine, leucine, and isoleucine metabolism': 4411,
#  'Exchange reactions': 8659}

# %%
# Out:
# /tmp/ipykernel_60827/1174864926.py:12: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
subS_counter
# Out:
# {'Exchange reactions': 8659,
#  'Cholesterol biosynthesis 1 (Bloch pathway)': 2658,
#  'Cholesterol metabolism': 156,
#  'Alanine, aspartate and glutamate metabolism': 1212,
#  'Cholesterol biosynthesis 3  (Kandustch-Russell pathway)': 2181,
#  'Cholesterol biosynthesis 2': 536,
#  'Glycerophospholipid metabolism': 447,
#  'Transport, extracellular': 2224,
#  'Pentose phosphate pathway': 734,
#  'Glycerolipid metabolism': 299,
#  'Pyrimidine metabolism': 37,
#  'Transport, mitochondrial': 645,
#  'Glutathione metabolism': 2798,
#  'Nucleotide metabolism': 40,
#  'Folate metabolism': 848,
#  'Histidine metabolism': 456,
#  'Aminoacyl-tRNA biosynthesis': 2560,
#  'Protein assembly': 128,
#  'Phenylalanine, tyrosine and tryptophan biosynthesis': 6,
#  'Biopterin metabolism': 4,
#  'Sulfur metabolism': 288,
#  'Bile acid biosynthesis': 288,
#  'Purine metabolism': 77,
#  'Propanoate metabolism': 3541,
#  'Valine, leucine, and isoleucine metabolism': 4411,
#  'Fatty acid biosynthesis (unsaturated)': 628,
#  'beta-Alanine metabolism': 1197,
#  'Fatty acid biosynthesis (odd-chain)': 1758,
#  'Fatty acid transfer reactions': 278,
#  'Inositol phosphate metabolism': 6,
#  'Pool reactions': 64,
#  'Fatty acid biosynthesis (even-chain)': 1904,
#  'Fatty acid elongation (even-chain)': 1588,
#  'Omega-6 fatty acid metabolism': 362,
#  'Fatty acid elongation (odd-chain)': 296,
#  'Omega-3 fatty acid metabolism': 428,
#  'Fatty acid desaturation (even-chain)': 152,
#  'Sphingolipid metabolism': 84,
#  'Fatty acid activation (cytosolic)': 2,
#  'Glycolysis / Gluconeogenesis': 20,
#  'Pyruvate metabolism': 8,
#  'Carnitine shuttle (cytosolic)': 557,
#  'Carnitine shuttle (mitochondrial)': 1440,
#  'Beta oxidation of even-chain fatty acids (mitochondrial)': 828,
#  'Transport, peroxisomal': 15,
#  'Beta oxidation of odd-chain fatty acids (mitochondrial)': 1240,
#  'Beta oxidation of unsaturated fatty acids (n-7) (mitochondrial)': 5,
#  'Oxidative phosphorylation': 229,
#  'Transport, lysosome to ER': 2,
#  'Acylglycerides metabolism': 5,
#  'Beta oxidation of even-chain fatty acids (peroxisomal)': 32,
#  'Lysine metabolism': 99,
#  'ROS detoxification': 29,
#  'Glycine, serine and threonine metabolism': 554,
#  'Arginine and proline metabolism': 1901,
#  'Cysteine and methionine metabolism': 265,
#  'Glutamate and glutamine metabolism': 38,
#  'Butanoate metabolism': 105,
#  'Galactose metabolism': 4,
#  'Tricarboxylic acid cycle and glyoxylate/dicarboxylate metabolism': 996,
#  'Nicotinate and nicotinamide metabolism': 6,
#  'Pentose and glucuronate interconversions': 15}

# %% [markdown]
# ## Cutsets

# %%
with open("../results/good_cutsets_list.p", "rb") as in_cutsets:
    cutsets_list = pickle.load(in_cutsets)

# %%
model.objective = "HMR_7869"

# %%
model.reactions.HMR_7869
# Out:
# <Reaction HMR_7869 at 0x7f733b851120>

# %%
model.metabolites.get_by_id("m01642c")
# Out:
# <Metabolite m01642c at 0x7f733d85d1b0>

# %%
for m in model.meta

# %%
model.reactions.get_by_id("HMR_7160").bounds = (0.0,1000.0)
model.optimize()
# Out:
# <Solution 1000.000 at 0x7f734bc7eb60>

# %%
for cutset_comb in cutsets_list:
    for reaction_to_cut in cutset_comb:
        print(reaction_to_cut)
        obj_val = u.sol_after_ko(list(reaction_to_cut), model, "biomass_components", "HMR_7160")

        print(obj_val)
# Out:
# ('HMR_4038',)
# Reaction HMR_7160 : flux = 1000.0
# 0.0
# ('HMR_4406',)
# Reaction HMR_7160 : flux = 1000.0
# 0.0
# ('HMR_4799',)
# Reaction HMR_7160 : flux = 1000.0
# 0.0
# ('HMR_4802',)
# Reaction HMR_7160 : flux = 1000.0
# 0.0
# ('HMR_4804_rev',)
# Reaction HMR_7160 : flux = 1000.0
# 0.0
# ('HMR_4808',)
# Reaction HMR_7160 : flux = 1000.0
# 0.0
# ('HMR_4810',)
# Reaction HMR_7160 : flux = 1000.0
# 0.0
# ('HMR_4812_rev',)
# Reaction HMR_7160 : flux = 1000.0
# 0.0
# ('HMR_4814',)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 4
#       2 for reaction_to_cut in cutset_comb:
#       3     print(reaction_to_cut)
# ----> 4     obj_val = u.sol_after_ko(list(reaction_to_cut), model, "biomass_components", "HMR_7160")
#       6     print(obj_val)
#
# File ~/Documents/Stage_metabo/aspmcs/code/utils.py:24, in sol_after_ko(lr, model, obj, check_reaction)
#      22 def sol_after_ko(lr, model, obj, check_reaction=None):
#      23     try:
# ---> 24         model_c = knock_out(model, lr)
#      25         model_c.objective = obj
#      26         opt = model_c.optimize()
#
# File ~/Documents/Stage_metabo/aspmcs/code/utils.py:4, in knock_out(model, lr)
#       3 def knock_out(model, lr):
# ----> 4     model = model.copy()
#       5     for r in lr:
#       6         lb = False
#
# File ~/miniconda3/envs/rba/lib/python3.10/site-packages/cobra/core/model.py:470, in Model.copy(self)
#     467     new_group.add_members(new_objects)
#     469 try:
# --> 470     new._solver = deepcopy(self.solver)
#     471     # Cplex has an issue with deep copies
#     472 except Exception:  # pragma: no cover
#
# File ~/miniconda3/envs/rba/lib/python3.10/copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File ~/miniconda3/envs/rba/lib/python3.10/copy.py:273, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     271     state = deepcopy(state, memo)
#     272 if hasattr(y, '__setstate__'):
# --> 273     y.__setstate__(state)
#     274 else:
#     275     if isinstance(state, tuple) and len(state) == 2:
#
# File ~/miniconda3/envs/rba/lib/python3.10/site-packages/optlang/cplex_interface.py:714, in Model.__setstate__(self, repr_dict)
#     712 if repr_dict['status'] == 'optimal':
#     713     problem.solve()  # since the start is an optimal solution, nothing will happen here
# --> 714 self.__init__(problem=problem)
#     715 self.configuration = Configuration.clone(repr_dict['config'], problem=self)
#
# File ~/miniconda3/envs/rba/lib/python3.10/site-packages/optlang/interface.py:1188, in Model.__init__(self, name, objective, variables, constraints, problem, *args, **kwargs)
#    1186     if not (objective is None and variables is None and constraints is None):
#    1187         raise ValueError("Models constructor must be called with the problem argument OR with variables, constraints and objective")
# -> 1188     self._initialize_model_from_problem(problem)
#    1190 else:
#    1191     self._initialize_problem()
#
# File ~/miniconda3/envs/rba/lib/python3.10/site-packages/optlang/cplex_interface.py:617, in Model._initialize_model_from_problem(self, problem)
#     611 zipped_var_args = zip(self.problem.variables.get_names(),
#     612                       self.problem.variables.get_lower_bounds(),
#     613                       self.problem.variables.get_upper_bounds(),
#     614                       # self.problem.variables.get_types(), # TODO uncomment when cplex is fixed
#     615                       )
#     616 for name, lb, ub in zipped_var_args:
# --> 617     var = Variable(name, lb=lb, ub=ub, problem=self)  # Type should also be in there
#     618     super(Model, self)._add_variables([var])  # This avoids adding the variable to the glpk problem
#     619 zipped_constr_args = zip(self.problem.linear_constraints.get_names(),
#     620                          self.problem.linear_constraints.get_rows(),
#     621                          self.problem.linear_constraints.get_senses(),
#     622                          self.problem.linear_constraints.get_rhs()
#     623
#     624                          )
#
# File ~/miniconda3/envs/rba/lib/python3.10/site-packages/optlang/symbolics.py:132, in Symbol.__new__(cls, name, **kwargs)
#     130 obj._assumptions = FactKB(_assume_rules)
#     131 obj._assumptions._tell('commutative', True)
# --> 132 obj._assumptions._tell('uuid', uuid.uuid1())
#     134 return obj
#
# File ~/miniconda3/envs/rba/lib/python3.10/uuid.py:677, in uuid1(node, clock_seq)
#     675 uuid_time, safely_generated = _generate_time_safe()
#     676 try:
# --> 677     is_safe = SafeUUID(safely_generated)
#     678 except ValueError:
#     679     is_safe = SafeUUID.unknown
#
# File ~/miniconda3/envs/rba/lib/python3.10/enum.py:385, in EnumMeta.__call__(cls, value, names, module, qualname, type, start)
#     360 """
#     361 Either returns an existing member, or creates a new enum class.
#     362
#    (...)
#     382 `type`, if set, will be mixed in as the first base class.
#     383 """
#     384 if names is None:  # simple value lookup
# --> 385     return cls.__new__(cls, value)
#     386 # otherwise, functional API: we're creating a new Enum type
#     387 return cls._create_(
#     388         value,
#     389         names,
#    (...)
#     393         start=start,
#     394         )
#
# File ~/miniconda3/envs/rba/lib/python3.10/enum.py:678, in Enum.__new__(cls, value)
#     672 class Enum(metaclass=EnumMeta):
#     673     """
#     674     Generic enumeration.
#     675
#     676     Derive from this class to define new enumerations.
#     677     """
# --> 678     def __new__(cls, value):
#     679         # all enum instances are actually created during class construction
#     680         # without calling this method; this method is called by the metaclass'
#     681         # __call__ (i.e. Color(3) ), and by pickle
#     682         if type(value) is cls:
#     683             # For lookups like Color(Color.RED)
#     684             return value
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt

# %%
absent = ['HMR_9808', 'HMR_0018', 'HMR_9027', 'EX_m02772x', 'HMR_0014', 'HMR_9055', 'EX_temp006x', 'HMR_0020', 'HMR_0019']
cs_counter = 0
for cs in tqdm(flat_list):
    for rid in cs:
        if rid in absent:
            cs_counter +=1
# Out:
# 100%|██████████| 14919/14919 [00:00<00:00, 284051.41it/s]

# %%
cs_counter
# Out:
# 3734

# %%
flat_list
# Out:
# [('EX_m02125x_rev',),
#  ('HMR_9038',),
#  ('EX_m02993x_rev',),
#  ('HMR_9044',),
#  ('HMR_1440', 'EX_temp006x'),
#  ('HMR_1440', 'HMR_9736_rev'),
#  ('HMR_1445', 'EX_temp006x'),
#  ('HMR_1445', 'HMR_9736_rev'),
#  ('HMR_1448_rev', 'EX_temp006x'),
#  ('HMR_1448_rev', 'HMR_9736_rev'),
#  ('HMR_1454', 'EX_temp006x'),
#  ('HMR_1454', 'HMR_9736_rev'),
#  ('HMR_1465_rev', 'EX_temp006x'),
#  ('HMR_1465_rev', 'HMR_9736_rev'),
#  ('HMR_1467', 'EX_temp006x'),
#  ('HMR_1467', 'HMR_9736_rev'),
#  ('HMR_1470', 'EX_temp006x'),
#  ('HMR_1470', 'HMR_9736_rev'),
#  ('HMR_1473', 'EX_temp006x'),
#  ('HMR_1473', 'HMR_9736_rev'),
#  ('HMR_1451', 'EX_temp006x'),
#  ('HMR_1451', 'HMR_9736_rev'),
#  ('HMR_1457', 'EX_temp006x'),
#  ('HMR_1457', 'HMR_9736_rev'),
#  ('HMR_1460', 'EX_temp006x'),
#  ('HMR_1460', 'HMR_9736_rev'),
#  ('HMR_3890', 'EX_m01975x_rev'),
#  ('HMR_3890', 'HMR_9063'),
#  ('HMR_1495', 'HMR_1496', 'HMR_1535', 'EX_temp006x'),
#  ('HMR_1495', 'HMR_1496', 'HMR_1535', 'HMR_9736_rev'),
#  ('HMR_1495', 'HMR_1496', 'HMR_1536', 'EX_temp006x'),
#  ('HMR_1495', 'HMR_1496', 'HMR_1536', 'HMR_9736_rev'),
#  ('HMR_1495', 'HMR_1496', 'HMR_1538', 'EX_temp006x'),
#  ('HMR_1495', 'HMR_1496', 'HMR_1538', 'HMR_9736_rev'),
#  ('HMR_1495', 'HMR_1496', 'HMR_1539', 'EX_temp006x'),
#  ('HMR_1495', 'HMR_1496', 'HMR_1539', 'HMR_9736_rev'),
#  ('HMR_1495', 'HMR_1496', 'HMR_1540', 'EX_temp006x'),
#  ('HMR_1495', 'HMR_1496', 'HMR_1540', 'HMR_9736_rev'),
#  ('HMR_1495', 'HMR_1496', 'HMR_1543', 'EX_temp006x'),
#  ('HMR_1495', 'HMR_1496', 'HMR_1543', 'HMR_9736_rev'),
#  ('HMR_1495', 'HMR_1496', 'HMR_1544', 'EX_temp006x'),
#  ('HMR_1495', 'HMR_1496', 'HMR_1544', 'HMR_9736_rev'),
#  ('HMR_1495', 'HMR_1496', 'HMR_1545', 'EX_temp006x'),
#  ('HMR_1495', 'HMR_1496', 'HMR_1545', 'HMR_9736_rev'),
#  ('HMR_1495', 'HMR_1496', 'HMR_1546', 'EX_temp006x'),
#  ('HMR_1495', 'HMR_1496', 'HMR_1546', 'HMR_9736_rev'),
#  ('HMR_1495', 'HMR_1496', 'HMR_1547', 'EX_temp006x'),
#  ('HMR_1495', 'HMR_1496', 'HMR_1547', 'HMR_9736_rev'),
#  ('HMR_1495', 'HMR_1496', 'HMR_1548', 'EX_temp006x'),
#  ('HMR_1495', 'HMR_1496', 'HMR_1548', 'HMR_9736_rev'),
#  ('HMR_1495', 'HMR_1496', 'HMR_1549', 'EX_temp006x'),
#  ('HMR_1495', 'HMR_1496', 'HMR_1549', 'HMR_9736_rev'),
#  ('HMR_1495', 'HMR_1496', 'HMR_1550', 'EX_temp006x'),
#  ('HMR_1495', 'HMR_1496', 'HMR_1550', 'HMR_9736_rev'),
#  ('HMR_1495', 'HMR_1496', 'HMR_1551', 'EX_temp006x'),
#  ('HMR_1495', 'HMR_1496', 'HMR_1551', 'HMR_9736_rev'),
#  ('HMR_1495', 'HMR_1496', 'HMR_1552', 'EX_temp006x'),
#  ('HMR_1495', 'HMR_1496', 'HMR_1552', 'HMR_9736_rev'),
#  ('HMR_1516', 'HMR_1533', 'HMR_1535', 'HMR_1570', 'EX_temp006x'),
#  ('HMR_1516', 'HMR_1533', 'HMR_1535', 'HMR_1570', 'HMR_9736_rev'),
#  ('HMR_1516', 'HMR_1533', 'HMR_1536', 'HMR_1570', 'EX_temp006x'),
#  ('HMR_1516', 'HMR_1533', 'HMR_1536', 'HMR_1570', 'HMR_9736_rev'),
#  ('HMR_1516', 'HMR_1533', 'HMR_1538', 'HMR_1570', 'EX_temp006x'),
#  ('HMR_1516', 'HMR_1533', 'HMR_1538', 'HMR_1570', 'HMR_9736_rev'),
#  ('HMR_1516', 'HMR_1533', 'HMR_1539', 'HMR_1570', 'EX_temp006x'),
#  ('HMR_1516', 'HMR_1533', 'HMR_1539', 'HMR_1570', 'HMR_9736_rev'),
#  ('HMR_1516', 'HMR_1533', 'HMR_1540', 'HMR_1570', 'EX_temp006x'),
#  ('HMR_1516', 'HMR_1533', 'HMR_1540', 'HMR_1570', 'HMR_9736_rev'),
#  ('HMR_1516', 'HMR_1533', 'HMR_1543', 'HMR_1570', 'EX_temp006x'),
#  ('HMR_1516', 'HMR_1533', 'HMR_1543', 'HMR_1570', 'HMR_9736_rev'),
#  ('HMR_1516', 'HMR_1533', 'HMR_1544', 'HMR_1570', 'EX_temp006x'),
#  ('HMR_1516', 'HMR_1533', 'HMR_1544', 'HMR_1570', 'HMR_9736_rev'),
#  ('HMR_1516', 'HMR_1533', 'HMR_1545', 'HMR_1570', 'EX_temp006x'),
#  ('HMR_1516', 'HMR_1533', 'HMR_1545', 'HMR_1570', 'HMR_9736_rev'),
#  ('HMR_1516', 'HMR_1533', 'HMR_1546', 'HMR_1570', 'EX_temp006x'),
#  ('HMR_1516', 'HMR_1533', 'HMR_1546', 'HMR_1570', 'HMR_9736_rev'),
#  ('HMR_1516', 'HMR_1533', 'HMR_1547', 'HMR_1570', 'EX_temp006x'),
#  ('HMR_1516', 'HMR_1533', 'HMR_1547', 'HMR_1570', 'HMR_9736_rev'),
#  ('HMR_1516', 'HMR_1533', 'HMR_1548', 'HMR_1570', 'EX_temp006x'),
#  ('HMR_1516', 'HMR_1533', 'HMR_1548', 'HMR_1570', 'HMR_9736_rev'),
#  ('HMR_1516', 'HMR_1533', 'HMR_1549', 'HMR_1570', 'EX_temp006x'),
#  ('HMR_1516', 'HMR_1533', 'HMR_1549', 'HMR_1570', 'HMR_9736_rev'),
#  ('HMR_1516', 'HMR_1533', 'HMR_1550', 'HMR_1570', 'EX_temp006x'),
#  ('HMR_1516', 'HMR_1533', 'HMR_1550', 'HMR_1570', 'HMR_9736_rev'),
#  ('HMR_1516', 'HMR_1533', 'HMR_1551', 'HMR_1570', 'EX_temp006x'),
#  ('HMR_1516', 'HMR_1533', 'HMR_1551', 'HMR_1570', 'HMR_9736_rev'),
#  ('HMR_1516', 'HMR_1533', 'HMR_1552', 'HMR_1570', 'EX_temp006x'),
#  ('HMR_1516', 'HMR_1533', 'HMR_1552', 'HMR_1570', 'HMR_9736_rev'),
#  ('HMR_1519', 'HMR_1533', 'HMR_1535', 'HMR_1570', 'EX_temp006x'),
#  ('HMR_1519', 'HMR_1533', 'HMR_1535', 'HMR_1570', 'HMR_9736_rev'),
#  ('HMR_1519', 'HMR_1533', 'HMR_1536', 'HMR_1570', 'EX_temp006x'),
#  ('HMR_1519', 'HMR_1533', 'HMR_1536', 'HMR_1570', 'HMR_9736_rev'),
#  ('HMR_1519', 'HMR_1533', 'HMR_1538', 'HMR_1570', 'EX_temp006x'),
#  ('HMR_1519', 'HMR_1533', 'HMR_1538', 'HMR_1570', 'HMR_9736_rev'),
#  ('HMR_1519', 'HMR_1533', 'HMR_1539', 'HMR_1570', 'EX_temp006x'),
#  ('HMR_1519', 'HMR_1533', 'HMR_1539', 'HMR_1570', 'HMR_9736_rev'),
#  ('HMR_1519', 'HMR_1533', 'HMR_1540', 'HMR_1570', 'EX_temp006x'),
#  ('HMR_1519', 'HMR_1533', 'HMR_1540', 'HMR_1570', 'HMR_9736_rev'),
#  ('HMR_1519', 'HMR_1533', 'HMR_1543', 'HMR_1570', 'EX_temp006x'),
#  ('HMR_1519', 'HMR_1533', 'HMR_1543', 'HMR_1570', 'HMR_9736_rev'),
#  ('HMR_1519', 'HMR_1533', 'HMR_1544', 'HMR_1570', 'EX_temp006x'),
#  ('HMR_1519', 'HMR_1533', 'HMR_1544', 'HMR_1570', 'HMR_9736_rev'),
#  ('HMR_1519', 'HMR_1533', 'HMR_1545', 'HMR_1570', 'EX_temp006x'),
#  ('HMR_1519', 'HMR_1533', 'HMR_1545', 'HMR_1570', 'HMR_9736_rev'),
#  ('HMR_1519', 'HMR_1533', 'HMR_1546', 'HMR_1570', 'EX_temp006x'),
#  ('HMR_1519', 'HMR_1533', 'HMR_1546', 'HMR_1570', 'HMR_9736_rev'),
#  ('HMR_1519', 'HMR_1533', 'HMR_1547', 'HMR_1570', 'EX_temp006x'),
#  ('HMR_1519', 'HMR_1533', 'HMR_1547', 'HMR_1570', 'HMR_9736_rev'),
#  ('HMR_1519', 'HMR_1533', 'HMR_1548', 'HMR_1570', 'EX_temp006x'),
#  ('HMR_1519', 'HMR_1533', 'HMR_1548', 'HMR_1570', 'HMR_9736_rev'),
#  ('HMR_1519', 'HMR_1533', 'HMR_1549', 'HMR_1570', 'EX_temp006x'),
#  ('HMR_1519', 'HMR_1533', 'HMR_1549', 'HMR_1570', 'HMR_9736_rev'),
#  ('HMR_1519', 'HMR_1533', 'HMR_1550', 'HMR_1570', 'EX_temp006x'),
#  ('HMR_1519', 'HMR_1533', 'HMR_1550', 'HMR_1570', 'HMR_9736_rev'),
#  ('HMR_1519', 'HMR_1533', 'HMR_1551', 'HMR_1570', 'EX_temp006x'),
#  ('HMR_1519', 'HMR_1533', 'HMR_1551', 'HMR_1570', 'HMR_9736_rev'),
#  ('HMR_1519', 'HMR_1533', 'HMR_1552', 'HMR_1570', 'EX_temp006x'),
#  ('HMR_1519', 'HMR_1533', 'HMR_1552', 'HMR_1570', 'HMR_9736_rev'),
#  ('HMR_1526', 'HMR_1533', 'HMR_1535', 'HMR_1570', 'EX_temp006x'),
#  ('HMR_1526', 'HMR_1533', 'HMR_1535', 'HMR_1570', 'HMR_9736_rev'),
#  ('HMR_1526', 'HMR_1533', 'HMR_1536', 'HMR_1570', 'EX_temp006x'),
#  ('HMR_1526', 'HMR_1533', 'HMR_1536', 'HMR_1570', 'HMR_9736_rev'),
#  ('HMR_1526', 'HMR_1533', 'HMR_1538', 'HMR_1570', 'EX_temp006x'),
#  ('HMR_1526', 'HMR_1533', 'HMR_1538', 'HMR_1570', 'HMR_9736_rev'),
#  ('HMR_1526', 'HMR_1533', 'HMR_1539', 'HMR_1570', 'EX_temp006x'),
#  ('HMR_1526', 'HMR_1533', 'HMR_1539', 'HMR_1570', 'HMR_9736_rev'),
#  ('HMR_1526', 'HMR_1533', 'HMR_1540', 'HMR_1570', 'EX_temp006x'),
#  ('HMR_1526', 'HMR_1533', 'HMR_1540', 'HMR_1570', 'HMR_9736_rev'),
#  ('HMR_1526', 'HMR_1533', 'HMR_1543', 'HMR_1570', 'EX_temp006x'),
#  ('HMR_1526', 'HMR_1533', 'HMR_1543', 'HMR_1570', 'HMR_9736_rev'),
#  ('HMR_1526', 'HMR_1533', 'HMR_1544', 'HMR_1570', 'EX_temp006x'),
#  ('HMR_1526', 'HMR_1533', 'HMR_1544', 'HMR_1570', 'HMR_9736_rev'),
#  ('HMR_1526', 'HMR_1533', 'HMR_1545', 'HMR_1570', 'EX_temp006x'),
#  ('HMR_1526', 'HMR_1533', 'HMR_1545', 'HMR_1570', 'HMR_9736_rev'),
#  ('HMR_1526', 'HMR_1533', 'HMR_1546', 'HMR_1570', 'EX_temp006x'),
#  ('HMR_1526', 'HMR_1533', 'HMR_1546', 'HMR_1570', 'HMR_9736_rev'),
#  ('HMR_1526', 'HMR_1533', 'HMR_1547', 'HMR_1570', 'EX_temp006x'),
#  ('HMR_1526', 'HMR_1533', 'HMR_1547', 'HMR_1570', 'HMR_9736_rev'),
#  ('HMR_1526', 'HMR_1533', 'HMR_1548', 'HMR_1570', 'EX_temp006x'),
#  ('HMR_1526', 'HMR_1533', 'HMR_
#  ('HMR_9083', 'HMR_0654', 'HMR_4627'),
#  ('HMR_9083', 'HMR_0654', 'HMR_4838'),
#  ('HMR_9083', 'HMR_0654', 'HMR_4839'),
#  ('HMR_9083', 'HMR_0657', 'HMR_4627'),
#  ('HMR_9083', 'HMR_0657', 'HMR_4838'),
#  ('HMR_9083', 'HMR_0657', 'HMR_4839'),
#  ('HMR_4306_rev', 'HMR_4398_rev', 'HMR_4565_rev', 'HMR_4567', 'HMR_4568'),
#  ('HMR_4474', 'HMR_4398_rev', 'HMR_4565_rev', 'HMR_4567', 'HMR_4568'),
#  ('HMR_4625', 'HMR_4398_rev', 'HMR_4565_rev', 'HMR_4567', 'HMR_4568'),
#  ('HMR_4306_rev', 'HMR_4565_rev', 'HMR_4567', 'HMR_4568', 'HMR_4296'),
#  ('HMR_4474', 'HMR_4565_rev', 'HMR_4567', 'HMR_4568', 'HMR_4296'),
#  ('HMR_4625', 'HMR_4565_rev', 'HMR_4567', 'HMR_4568', 'HMR_4296'),
#  ('HMR_4910', 'HMR_4911', 'HMR_4912', 'HMR_4947_rev', 'HMR_5413'),
#  ('HMR_4947_rev', 'HMR_5035_rev', 'HMR_4034'),
#  ('HMR_4947_rev', 'HMR_5035_rev', 'HMR_4036'),
#  ('HMR_4947_rev', 'HMR_5035_rev', 'HMR_4050_rev'),
#  ('HMR_4947_rev', 'HMR_5035_rev', 'HMR_4577_rev'),
#  ('HMR_4947_rev', 'HMR_5035_rev', 'HMR_4608_rev'),
#  ('HMR_4947_rev', 'HMR_5035_rev', 'HMR_4575'),
#  ('EX_m03089x_rev',),
#  ('HMR_9045',),
#  ('EX_m03135x_rev',),
#  ('HMR_9046',),
#  ('EX_m03130x_rev',),
#  ('HMR_9440',),
#  ('HMR_4885', 'HMR_4947_rev', 'EX_m02027x', 'EX_m02040x_rev'),
#  ('HMR_4885', 'HMR_4947_rev', 'EX_m02027x', 'HMR_9047'),
#  ('HMR_4885', 'HMR_4947_rev', 'HMR_4120', 'EX_m02040x_rev'),
#  ('HMR_4885', 'HMR_4947_rev', 'HMR_4120', 'HMR_9047'),
#  ('HMR_4885', 'HMR_4947_rev', 'HMR_9350_rev', 'EX_m02040x_rev'),
#  ('HMR_4885', 'HMR_4947_rev', 'HMR_9350_rev', 'HMR_9047'),
#  ('HMR_4947_rev', 'HMR_4060', 'EX_m03106x'),
#  ('HMR_4947_rev', 'HMR_4060', 'HMR_9435_rev'),
#  ('HMR_4947_rev', 'HMR_8487', 'EX_m03106x', 'EX_m03114x'),
#  ('HMR_4947_rev', 'HMR_8487', 'EX_m03106x', 'HMR_9436_rev'),
#  ('HMR_4947_rev', 'HMR_8487', 'HMR_9435_rev', 'EX_m03114x'),
#  ('HMR_4947_rev', 'HMR_8487', 'HMR_9435_rev', 'HMR_9436_rev'),
#  ('HMR_4947_rev', 'HMR_5035_rev', 'EX_m03106x', 'EX_m03114x', 'EX_m03123x'),
#  ('HMR_4947_rev', 'HMR_5035_rev', 'EX_m03106x', 'EX_m03114x', 'HMR_9439_rev'),
#  ('HMR_4947_rev', 'HMR_5035_rev', 'EX_m03106x', 'HMR_9436_rev', 'EX_m03123x'),
#  ('HMR_4947_rev',
#   'HMR_5035_rev',
#   'EX_m03106x',
#   'HMR_9436_rev',
#   'HMR_9439_rev'),
#  ('HMR_4947_rev', 'HMR_5035_rev', 'HMR_9435_rev', 'EX_m03114x', 'EX_m03123x'),
#  ('HMR_4947_rev',
#   'HMR_5035_rev',
#   'HMR_9435_rev',
#   'EX_m03114x',
#   'HMR_9439_rev'),
#  ('HMR_4947_rev',
#   'HMR_5035_rev',
#   'HMR_9435_rev',
#   'HMR_9436_rev',
#   'EX_m03123x'),
#  ('HMR_4947_rev',
#   'HMR_5035_rev',
#   'HMR_9435_rev',
#   'HMR_9436_rev',
#   'HMR_9439_rev'),
#  ('EX_m01369x_rev', 'HMR_3903'),
#  ('HMR_9062', 'HMR_3903'),
#  ('EX_m02184x_rev',),
#  ('HMR_9039',),
#  ('HMR_4338', 'HMR_4437', 'EX_m01986x', 'HMR_4326', 'HMR_5143'),
#  ('HMR_4338', 'HMR_4437', 'HMR_9067_rev', 'HMR_4326', 'HMR_5143'),
#  ('HMR_4338', 'HMR_4658_rev', 'EX_m01986x', 'HMR_4326', 'HMR_5143'),
#  ('HMR_4338', 'HMR_4658_rev', 'HMR_9067_rev', 'HMR_4326', 'HMR_5143'),
#  ('HMR_4338', 'HMR_4660', 'EX_m01986x', 'HMR_4326', 'HMR_5143'),
#  ('HMR_4338', 'HMR_4660', 'HMR_9067_rev', 'HMR_4326', 'HMR_5143'),
#  ('HMR_4338', 'HMR_4712', 'EX_m01986x', 'HMR_4326', 'HMR_5143'),
#  ('HMR_4338', 'HMR_4712', 'HMR_9067_rev', 'HMR_4326', 'HMR_5143'),
#  ('HMR_4338', 'HMR_3929_rev', 'EX_m01986x', 'HMR_4326', 'HMR_5143'),
#  ('HMR_4338', 'HMR_3929_rev', 'HMR_9067_rev', 'HMR_4326', 'HMR_5143'),
#  ('HMR_4338', 'HMR_4437', 'EX_m01986x', 'HMR_4326', 'HMR_5131'),
#  ('HMR_4338', 'HMR_4437', 'HMR_9067_rev', 'HMR_4326', 'HMR_5131'),
#  ('HMR_4338', 'HMR_4658_rev', 'EX_m01986x', 'HMR_4326', 'HMR_5131'),
#  ('HMR_4338', 'HMR_4658_rev', 'HMR_9067_rev', 'HMR_4326', 'HMR_5131'),
#  ('HMR_4338', 'HMR_4660', 'EX_m01986x', 'HMR_4326', 'HMR_5131'),
#  ('HMR_4338', 'HMR_4660', 'HMR_9067_rev', 'HMR_4326', 'HMR_5131'),
#  ('HMR_4338', 'HMR_4712', 'EX_m01986x', 'HMR_4326', 'HMR_5131'),
#  ('HMR_4338', 'HMR_4712', 'HMR_9067_rev', 'HMR_4326', 'HMR_5131'),
#  ('HMR_4338', 'HMR_3929_rev', 'EX_m01986x', 'HMR_4326', 'HMR_5131'),
#  ('HMR_4338', 'HMR_3929_rev', 'HMR_9067_rev', 'HMR_4326', 'HMR_5131'),
#  ('HMR_4338', 'EX_m01308x', 'HMR_4437', 'EX_m01986x', 'HMR_4326'),
#  ('HMR_4338', 'EX_m01308x', 'HMR_4437', 'HMR_9067_rev', 'HMR_4326'),
#  ('HMR_4338', 'EX_m01308x', 'HMR_4658_rev', 'EX_m01986x', 'HMR_4326'),
#  ('HMR_4338', 'EX_m01308x', 'HMR_4658_rev', 'HMR_9067_rev', 'HMR_4326'),
#  ('HMR_4338', 'EX_m01308x', 'HMR_4660', 'EX_m01986x', 'HMR_4326'),
#  ('HMR_4338', 'EX_m01308x', 'HMR_4660', 'HMR_9067_rev', 'HMR_4326'),
#  ('HMR_4338', 'EX_m01308x', 'HMR_4712', 'EX_m01986x', 'HMR_4326'),
#  ('HMR_4338', 'EX_m01308x', 'HMR_4712', 'HMR_9067_rev', 'HMR_4326'),
#  ('HMR_4338', 'EX_m01308x', 'HMR_3929_rev', 'EX_m01986x', 'HMR_4326'),
#  ('HMR_4338', 'EX_m01308x', 'HMR_3929_rev', 'HMR_9067_rev', 'HMR_4326'),
#  ('HMR_4338', 'HMR_5198', 'HMR_4437', 'EX_m01986x', 'HMR_4326'),
#  ('HMR_4338', 'HMR_5198', 'HMR_4437', 'HMR_9067_rev', 'HMR_4326'),
#  ('HMR_4338', 'HMR_5198', 'HMR_4658_rev', 'EX_m01986x', 'HMR_4326'),
#  ('HMR_4338', 'HMR_5198', 'HMR_4658_rev', 'HMR_9067_rev', 'HMR_4326'),
#  ('HMR_4338', 'HMR_5198', 'HMR_4660', 'EX_m01986x', 'HMR_4326'),
#  ('HMR_4338', 'HMR_5198', 'HMR_4660', 'HMR_9067_rev', 'HMR_4326'),
#  ('HMR_4338', 'HMR_5198', 'HMR_4712', 'EX_m01986x', 'HMR_4326'),
#  ('HMR_4338', 'HMR_5198', 'HMR_4712', 'HMR_9067_rev', 'HMR_4326'),
#  ('HMR_4338', 'HMR_5198', 'HMR_3929_rev', 'EX_m01986x', 'HMR_4326'),
#  ('HMR_4338', 'HMR_5198', 'HMR_3929_rev', 'HMR_9067_rev', 'HMR_4326'),
#  ('HMR_4338', 'HMR_9730_rev', 'HMR_4437', 'EX_m01986x', 'HMR_4326'),
#  ('HMR_4338', 'HMR_9730_rev', 'HMR_4437', 'HMR_9067_rev', 'HMR_4326'),
#  ('HMR_4338', 'HMR_9730_rev', 'HMR_4658_rev', 'EX_m01986x', 'HMR_4326'),
#  ('HMR_4338', 'HMR_9730_rev', 'HMR_4658_rev', 'HMR_9067_rev', 'HMR_4326'),
#  ('HMR_4338', 'HMR_9730_rev', 'HMR_4660', 'EX_m01986x', 'HMR_4326'),
#  ('HMR_4338', 'HMR_9730_rev', 'HMR_4660', 'HMR_9067_rev', 'HMR_4326'),
#  ('HMR_4338', 'HMR_9730_rev', 'HMR_4712', 'EX_m01986x', 'HMR_4326'),
#  ('HMR_4338', 'HMR_9730_rev', 'HMR_4712', 'HMR_9067_rev', 'HMR_4326'),
#  ('HMR_4338', 'HMR_9730_rev', 'HMR_3929_rev', 'EX_m01986x', 'HMR_4326'),
#  ('HMR_4338', 'HMR_9730_rev', 'HMR_3929_rev', 'HMR_9067_rev', 'HMR_4326'),
#  ('HMR_4338', 'HMR_4437', 'EX_m01986x', 'HMR_4326', 'HMR_5130'),
#  ('HMR_4338', 'HMR_4437', 'HMR_9067_rev', 'HMR_4326', 'HMR_5130'),
#  ('HMR_4338', 'HMR_4658_rev', 'EX_m01986x', 'HMR_4326', 'HMR_5130'),
#  ('HMR_4338', 'HMR_4658_rev', 'HMR_9067_rev', 'HMR_4326', 'HMR_5130'),
#  ('HMR_4338', 'HMR_4660', 'EX_m01986x', 'HMR_4326', 'HMR_5130'),
#  ('HMR_4338', 'HMR_4660', 'HMR_9067_rev', 'HMR_4326', 'HMR_5130'),
#  ('HMR_4338', 'HMR_4712', 'EX_m01986x', 'HMR_4326', 'HMR_5130'),
#  ('HMR_4338', 'HMR_4712', 'HMR_9067_rev', 'HMR_4326', 'HMR_5130'),
#  ('HMR_4338', 'HMR_3929_rev', 'EX_m01986x', 'HMR_4326', 'HMR_5130'),
#  ('HMR_4338', 'HMR_3929_rev', 'HMR_9067_rev', 'HMR_4326', 'HMR_5130'),
#  ('HMR_4338', 'HMR_4437', 'EX_m01986x', 'HMR_4326', 'HMR_5134'),
#  ('HMR_4338', 'HMR_4437', 'HMR_9067_rev', 'HMR_4326', 'HMR_5134'),
#  ('HMR_4338', 'HMR_4658_rev', 'EX_m01986x', 'HMR_4326', 'HMR_5134'),
#  ('HMR_4338', 'HMR_4658_rev', 'HMR_9067_rev', 'HMR_4326', 'HMR_5134'),
#  ('HMR_4338', 'HMR_4660', 'EX_m01986x', 'HMR_4326', 'HMR_5134'),
#  ('HMR_4338', 'HMR_4660', 'HMR_9067_rev', 'HMR_4326', 'HMR_5134'),
#  ('HMR_4338', 'HMR_4712', 'EX_m01986x', 'HMR_4326', 'HMR_5134'),
#  ('HMR_4338', 'HMR_4712', 'HMR_9067_rev', 'HMR_4326', 'HMR_5134'),
#  ('HMR_4338', 'HMR_3929_rev', 'EX_m01986x', 'HMR_4326', 'HMR_5134'),
#  ('HMR_4338', 'HMR_3929_rev', 'HMR_9067_rev', 'HMR_4326', 'HMR_5134'),
#  ('HMR_4338', 'HMR_4437', 'EX_m01986x', 'HMR_4326', 'HMR_5139'),
#  ('HMR_4338', 'HMR_4437', 'HMR_9067_rev', 'HMR_4
('HMR_4338', 'HMR_4712', 'HMR_9067_rev', 'HMR_4324', 'HMR_5140'),
#  ('HMR_4338', 'HMR_3929_rev', 'EX_m01986x', 'HMR_4324', 'HMR_5140'),
#  ('HMR_4338', 'HMR_3929_rev', 'HMR_9067_rev', 'HMR_4324', 'HMR_5140'),
#  ('HMR_4338', 'HMR_4437', 'EX_m01986x', 'HMR_4324', 'HMR_5134'),
#  ('HMR_4338', 'HMR_4437', 'HMR_9067_rev', 'HMR_4324', 'HMR_5134'),
#  ('HMR_4338', 'HMR_4658_rev', 'EX_m01986x', 'HMR_4324', 'HMR_5134'),
#  ('HMR_4338', 'HMR_4658_rev', 'HMR_9067_rev', 'HMR_4324', 'HMR_5134'),
#  ('HMR_4338', 'HMR_4660', 'EX_m01986x', 'HMR_4324', 'HMR_5134'),
#  ('HMR_4338', 'HMR_4660', 'HMR_9067_rev', 'HMR_4324', 'HMR_5134'),
#  ('HMR_4338', 'HMR_4712', 'EX_m01986x', 'HMR_4324', 'HMR_5134'),
#  ('HMR_4338', 'HMR_4712', 'HMR_9067_rev', 'HMR_4324', 'HMR_5134'),
#  ('HMR_4338', 'HMR_3929_rev', 'EX_m01986x', 'HMR_4324', 'HMR_5134'),
#  ('HMR_4338', 'HMR_3929_rev', 'HMR_9067_rev', 'HMR_4324', 'HMR_5134'),
#  ('HMR_4338', 'EX_m01308x', 'HMR_4437', 'EX_m01986x', 'HMR_4324'),
#  ('HMR_4338', 'EX_m01308x', 'HMR_4437', 'HMR_9067_rev', 'HMR_4324'),
#  ('HMR_4338', 'EX_m01308x', 'HMR_4658_rev', 'EX_m01986x', 'HMR_4324'),
#  ('HMR_4338', 'EX_m01308x', 'HMR_4658_rev', 'HMR_9067_rev', 'HMR_4324'),
#  ('HMR_4338', 'EX_m01308x', 'HMR_4660', 'EX_m01986x', 'HMR_4324'),
#  ('HMR_4338', 'EX_m01308x', 'HMR_4660', 'HMR_9067_rev', 'HMR_4324'),
#  ('HMR_4338', 'EX_m01308x', 'HMR_4712', 'EX_m01986x', 'HMR_4324'),
#  ('HMR_4338', 'EX_m01308x', 'HMR_4712', 'HMR_9067_rev', 'HMR_4324'),
#  ('HMR_4338', 'EX_m01308x', 'HMR_3929_rev', 'EX_m01986x', 'HMR_4324'),
#  ('HMR_4338', 'EX_m01308x', 'HMR_3929_rev', 'HMR_9067_rev', 'HMR_4324'),
#  ('HMR_4338', 'HMR_5198', 'HMR_4437', 'EX_m01986x', 'HMR_4324'),
#  ('HMR_4338', 'HMR_5198', 'HMR_4437', 'HMR_9067_rev', 'HMR_4324'),
#  ('HMR_4338', 'HMR_5198', 'HMR_4658_rev', 'EX_m01986x', 'HMR_4324'),
#  ('HMR_4338', 'HMR_5198', 'HMR_4658_rev', 'HMR_9067_rev', 'HMR_4324'),
#  ('HMR_4338', 'HMR_5198', 'HMR_4660', 'EX_m01986x', 'HMR_4324'),
#  ('HMR_4338', 'HMR_5198', 'HMR_4660', 'HMR_9067_rev', 'HMR_4324'),
#  ('HMR_4338', 'HMR_5198', 'HMR_4712', 'EX_m01986x', 'HMR_4324'),
#  ('HMR_4338', 'HMR_5198', 'HMR_4712', 'HMR_9067_rev', 'HMR_4324'),
#  ('HMR_4338', 'HMR_5198', 'HMR_3929_rev', 'EX_m01986x', 'HMR_4324'),
#  ('HMR_4338', 'HMR_5198', 'HMR_3929_rev', 'HMR_9067_rev', 'HMR_4324'),
#  ('HMR_4338', 'HMR_9730_rev', 'HMR_4437', 'EX_m01986x', 'HMR_4324'),
#  ('HMR_4338', 'HMR_9730_rev', 'HMR_4437', 'HMR_9067_rev', 'HMR_4324'),
#  ('HMR_4338', 'HMR_9730_rev', 'HMR_4658_rev', 'EX_m01986x', 'HMR_4324'),
#  ('HMR_4338', 'HMR_9730_rev', 'HMR_4658_rev', 'HMR_9067_rev', 'HMR_4324'),
#  ('HMR_4338', 'HMR_9730_rev', 'HMR_4660', 'EX_m01986x', 'HMR_4324'),
#  ('HMR_4338', 'HMR_9730_rev', 'HMR_4660', 'HMR_9067_rev', 'HMR_4324'),
#  ('HMR_4338', 'HMR_9730_rev', 'HMR_4712', 'EX_m01986x', 'HMR_4324'),
#  ('HMR_4338', 'HMR_9730_rev', 'HMR_4712', 'HMR_9067_rev', 'HMR_4324'),
#  ('HMR_4338', 'HMR_9730_rev', 'HMR_3929_rev', 'EX_m01986x', 'HMR_4324'),
#  ('HMR_4338', 'HMR_9730_rev', 'HMR_3929_rev', 'HMR_9067_rev', 'HMR_4324'),
#  ('HMR_3940', 'HMR_8539', 'EX_m03101x_rev'),
#  ('HMR_3940', 'HMR_8539', 'HMR_9064'),
#  ('HMR_8538', 'HMR_3940', 'EX_m03101x_rev'),
#  ('HMR_8538', 'HMR_3940', 'HMR_9064'),
#  ('EX_m01308x', 'EX_m01513x_rev', 'EX_m01628x', 'HMR_4324', 'EX_m02946x'),
#  ('EX_m01308x', 'EX_m01513x_rev', 'EX_m01628x', 'HMR_4324', 'HMR_3865'),
#  ('EX_m01308x', 'EX_m01513x_rev', 'EX_m01628x', 'HMR_4324', 'HMR_3866'),
#  ('EX_m01308x', 'EX_m01513x_rev', 'EX_m01628x', 'HMR_4324', 'HMR_3908'),
#  ('EX_m01308x', 'EX_m01513x_rev', 'EX_m01628x', 'HMR_4324', 'HMR_9074_rev'),
#  ('EX_m01308x', 'EX_m01513x_rev', 'HMR_9065_rev', 'HMR_4324', 'EX_m02946x'),
#  ('EX_m01308x', 'EX_m01513x_rev', 'HMR_9065_rev', 'HMR_4324', 'HMR_3865'),
#  ('EX_m01308x', 'EX_m01513x_rev', 'HMR_9065_rev', 'HMR_4324', 'HMR_3866'),
#  ('EX_m01308x', 'EX_m01513x_rev', 'HMR_9065_rev', 'HMR_4324', 'HMR_3908'),
#  ('EX_m01308x', 'EX_m01513x_rev', 'HMR_9065_rev', 'HMR_4324', 'HMR_9074_rev'),
#  ('EX_m01308x', 'HMR_4954_rev', 'EX_m01628x', 'HMR_4324', 'EX_m02946x'),
#  ('EX_m01308x', 'HMR_4954_rev', 'EX_m01628x', 'HMR_4324', 'HMR_3865'),
#  ('EX_m01308x', 'HMR_4954_rev', 'EX_m01628x', 'HMR_4324', 'HMR_3866'),
#  ('EX_m01308x', 'HMR_4954_rev', 'EX_m01628x', 'HMR_4324', 'HMR_3908'),
#  ('EX_m01308x', 'HMR_4954_rev', 'EX_m01628x', 'HMR_4324', 'HMR_9074_rev'),
#  ('EX_m01308x', 'HMR_4954_rev', 'HMR_9065_rev', 'HMR_4324', 'EX_m02946x'),
#  ('EX_m01308x', 'HMR_4954_rev', 'HMR_9065_rev', 'HMR_4324', 'HMR_3865'),
#  ('EX_m01308x', 'HMR_4954_rev', 'HMR_9065_rev', 'HMR_4324', 'HMR_3866'),
#  ('EX_m01308x', 'HMR_4954_rev', 'HMR_9065_rev', 'HMR_4324', 'HMR_3908'),
#  ('EX_m01308x', 'HMR_4954_rev', 'HMR_9065_rev', 'HMR_4324', 'HMR_9074_rev'),
#  ('EX_m01308x', 'HMR_9083', 'EX_m01628x', 'HMR_4324', 'EX_m02946x'),
#  ('EX_m01308x', 'HMR_9083', 'EX_m01628x', 'HMR_4324', 'HMR_3865'),
#  ('EX_m01308x', 'HMR_9083', 'EX_m01628x', 'HMR_4324', 'HMR_3866'),
#  ('EX_m01308x', 'HMR_9083', 'EX_m01628x', 'HMR_4324', 'HMR_3908'),
#  ('EX_m01308x', 'HMR_9083', 'EX_m01628x', 'HMR_4324', 'HMR_9074_rev'),
#  ('EX_m01308x', 'HMR_9083', 'HMR_9065_rev', 'HMR_4324', 'EX_m02946x'),
),
#  ('HMR_9083', 'HMR_9065_rev', 'HMR_4324', 'HMR_5133', 'EX_m02946x'),
#  ('HMR_9083', 'HMR_9065_rev', 'HMR_4324', 'HMR_5133', 'HMR_3865'),
#  ('HMR_9083', 'HMR_9065_rev', 'HMR_4324', 'HMR_5133', 'HMR_3866'),
#  ('HMR_9083', 'HMR_9065_rev', 'HMR_4324', 'HMR_5133', 'HMR_3908'),
#  ('HMR_9083', 'HMR_9065_rev', 'HMR_4324', 'HMR_5133', 'HMR_9074_rev'),
#  ('EX_m01513x_rev', 'EX_m01628x', 'HMR_4324', 'HMR_5137', 'EX_m02946x'),
#  ('EX_m01513x_rev', 'EX_m01628x', 'HMR_4324', 'HMR_5137', 'HMR_3865'),
#  ('EX_m01513x_rev', 'EX_m01628x', 'HMR_4324', 'HMR_5137', 'HMR_3866'),
#  ('EX_m01513x_rev', 'EX_m01628x', 'HMR_4324', 'HMR_5137', 'HMR_3908'),
#  ...]

# %%
compressed_cutsets_run1 = u.parse_output("../results/vanilla_run/output_mcs_vanilla_1.txt")
compressed_cutsets_run2 = u.parse_output("../results/vanilla_run/output_mcs_vanilla_2.txt")
compressed_cutsets_run3 = u.parse_output("../results/vanilla_run/output_mcs_vanilla_3.txt")

# %%
len_cutsets_counter_dict = {}
compressed_cutsets_no_dup = []
for cutset in compressed_cutsets_run1:
    if cutset in compressed_cutsets_no_dup:
        continue
    else:
        compressed_cutsets_no_dup.append(cutset)
for cutset in compressed_cutsets_run2:
    if cutset in compressed_cutsets_no_dup:
        continue
    else:
        compressed_cutsets_no_dup.append(cutset)
for cutset in compressed_cutsets_run3:
    if cutset in compressed_cutsets_no_dup:
        continue
    else:
        compressed_cutsets_no_dup.append(cutset)

for cutset in compressed_cutsets_no_dup:
    len_cutsets_counter_dict[len(cutset)] = len_cutsets_counter_dict.get(len(cutset), 0) + 1

# %%
len(compressed_cutsets_no_dup)
# Out:
# 374

# %%
# Compressé
x = len_cutsets_counter_dict.keys()
y = len_cutsets_counter_dict.values()

fig, ax = plt.subplots()
ax.bar(x, y)
plt.suptitle("Nombre de MCS compressés de chaque taille trouvés dans le modèle cancéreux.")
plt.xlabel("Taille des MCS")
plt.ylabel("Nombre de MCS")
plt.show()

# %%
len(flat_list)
# Out:
# 14919

# %%
len_cutsets_counter_dict_decomp = {}
for cutset in flat_list:
    len_cutsets_counter_dict_decomp[len(cutset)] = len_cutsets_counter_dict_decomp.get(len(cutset), 0) + 1

# %%
# Décompressé
x = len_cutsets_counter_dict_decomp.keys()
y = len_cutsets_counter_dict_decomp.values()

fig, ax = plt.subplots()
ax.bar(x, y)
plt.suptitle("Nombre de MCS décompressés de chaque taille trouvés dans le modèle cancéreux.")
plt.xlabel("Taille des MCS")
plt.ylabel("Nombre de MCS")
plt.show()

# %%
with open("../statin_cutsets.p", "rb") as statin_cs:
    statin_cs_list = pickle.load(statin_cs)

statin_cs_flat = [item for sublist in statin_cs_list for item in sublist]
print(len(statin_cs_flat))
# Out:
# 6039

# %%
len_cs_counter_statin = {}
for cutset in statin_cs_flat:
    len_cs_counter_statin[len(cutset)] = len_cs_counter_statin.get(len(cutset), 0) + 1

# %%
len_cs_counter_statin
# Out:
# {2: 99, 5: 5940}

# %%
# Statin décompressé
x = len_cs_counter_statin.keys()
y = len_cs_counter_statin.values()
fig, ax = plt.subplots()
ax.bar(x, y)
plt.suptitle("Nombre de MCS décompressés de chaque taille trouvés dans le modèle cancéreux.")
plt.xlabel("Taille des MCS")
plt.ylabel("Nombre de MCS")
plt.show()
