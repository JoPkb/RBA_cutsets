# %%
import cobra
import importlib
import sys
import pandas as pd
import utils.model_maj as mj
import utils.viz_utils as vu
import utils.Model_correction as mc
from cobra.core.model import Model
from cobra.io import validate_sbml_model

sys.path.append("../../aspmcs/code/compression/")
import efmtool_link_compression
# Out:
# pyparsing import
#
# INFO: No xlwt module available, Excel spreadsheet creation disabled
# CBGLPK based on swiglpk: not all methods implimented yet! 5.0
#
# *****
# Using CPLEX
# *****
#
# doFBAMinSum not available with GLPK
#
# INFO: No xlrd module available, Excel spreadsheet reading disabled
#
#
# ***********************************************************************
# * Welcome to CBMPy (0.8.4) - PySCeS Constraint Based Modelling        *
# *                http://cbmpy.sourceforge.net                         *
# * Copyright(C) Brett G. Olivier 2014 - 2020                           *
# * Systems Biology Lab, Vrije Universiteit Amsterdam                   *
# * Amsterdam, The Netherlands                                          *
# * CBMPy is developed as part of the BeBasic MetaToolKit Project       *
# * Distributed under the GNU GPL v 3.0 licence, see                    *
# * LICENCE (supplied with this release) for details                    *
# ***********************************************************************
# openjdk version "17.0.10" 2024-01-16
# OpenJDK Runtime Environment (build 17.0.10+7-Debian-1deb12u1)
# OpenJDK 64-Bit Server VM (build 17.0.10+7-Debian-1deb12u1, mixed mode, sharing)

# %%
importlib.reload(efmtool_link_compression)
# Out:
# <module 'efmtool_link_compression' from '/home/muller-prokob/Documents/github/RBA_cutsets/models_analysis/code/../../aspmcs/code/compression/efmtool_link_compression.py'>

# %% [markdown]
# ### Model loading

# %% [markdown]
# #### HCC

# %%
HCC, errors = validate_sbml_model("../../models_storage/HCC_corrected.xml")
# Out:
# SBML errors in validation, check error log for details.
# COBRA warnings in validation, check error log for details.

# %% [markdown]
# Before model reduction :
#
# * Reactions : 5076
# * genes : 2037
# * groups : 133
# * metabolites : 4339
#
# compressed : 2662
#
# After model reduction :
# * Reactions : 4642
# * genes : 2037
# * groups : 133
# * metabolites : 4339
#
# compressed : 2191 reactions

# %%
HCC
# Out:
# <Reaction HMR_4381 at 0x7f9e70e2abc0>

# %% [markdown]
# ### Matching gene IDs from differencial gene expression dataset to model reactions
#
# Each reaction from the SBML model is associated to one or more genes. Some genes are described as being over or underexpressed in HCC cells.
# The first step is then to find the reactions in the model that are only regulated by over/underexpressed genes from the dataset.
#
# Under-expressed gene-associated reactions will then be removed from the model.
# Over-expressed gene-associated reactions will be stored as positive constraints for the ASPEFM MCS computation.

# %%
# Dataset loading

downregulated_entrez_ids = pd.read_csv("../../models_storage/model_related_data/FC_HCC_DOWN.csv", sep=",")[12:].iloc[:,2].tolist()
upregulated_entrez_ids = pd.read_csv("../../models_storage/model_related_data/FC_HCC_UP.csv", sep=",")[12:].iloc[:,2].tolist()

# %%
# Functions definition : getting gene-associated reactions

def get_gene_associated_reaction(genes_IDs:list[str], model:Model) :
    """
    Function used to get all reactions associated to the given list of gene IDs and only to gene IDs contained in the given list
    gene_IDs:list[str]
    model:cobra.core.model.Model
    """
    # Definition of local variables to return
    gene_associated_reactions = {}
    n_errors = 0
    
    # Iterating over all model reactions. For each reaction, the function checks if their associated gene(s) are included in the list of genes.
    for reaction in model.reactions:
        associated = True
        try:
            model_reaction_genes = [g.annotation['ncbigene'] for g in reaction.genes]
        except KeyError:
            n_errors += 1
        
        if len(model_reaction_genes) > 0:
            for gene in model_reaction_genes:
                if gene not in genes_IDs:
                    associated = False
        else:
            associated = False

        # the boolean associated will only stay True if all the genes associated to a reaction are found in the given gene list.        
        if associated == True:
            gene_associated_reactions[reaction.id] = model_reaction_genes
    
    return gene_associated_reactions, n_errors

# Safely removing down-regulated genes-associated reactions :

def remove_and_check(model:Model, reactions:list[str], threshold = float(0.2), objective = "biomass_components"):

    reactions_removed = 0
    total_reactions = len(reactions)
    model.objective = objective

    for reaction in reactions:
        reaction_obj = model.reactions.get_by_id(reaction)
        model.remove_reactions([reaction_obj])
        new_val = model.optimize().objective_value
        print(f"obj_val : {new_val}; {type(new_val)}")
        if new_val <= threshold:
            model.add_reactions([reaction_obj])
        else:
            reactions_removed += 1
    print(f"{reactions_removed}/{total_reactions} reactions removed.")

def apply_medium(model:Model, medium_file_path:str):
    new_medium = {}
    with open(medium_file_path, "r") as medium_buffer:
        medium_data = medium_buffer.read()
    
    for line in medium_data.split("\n"):
        print(line)
        reaction_id = line.split(";")[0]
        reaction_activity = line.split(";")[2]
        if reaction_activity == "1":
            new_medium[reaction_id] = abs(float(line.split(";")[3]))
        else:
            new_medium[reaction_id] = float(0.0)
    
    model.medium = new_medium

def write_constraint_file(reactions_list, reaction_subset_path, outfile_path):
    # Takes as input a list of reactions that are associated to overexpressed genes
    # The function then selects compressed reactions which only contain these reactions.

    with open(reaction_subset_path, "r") as reaction_subset:
        data = reaction_subset.read()
        r_subsets = eval(data)

    # downregulated_reactions_list = [reaction_id for reaction_id in reactions_list]
    compressed_gene_associated_reactions = []
    for compressed_reaction_name, compressed_reaction_data in r_subsets.items():
        associated = False
        #print(f"{compressed_reaction_name} :\n")
        for reaction in compressed_reaction_data["reacs"]:
            if "rev" in reaction :
                reaction = reaction[:-4]
            if reaction in reactions_list :
                #print(f"{reaction} not in list")
                associated = True # If one of the compressed reaction subsets is not linked to an overexpressed reaction, the compressed reaction is not selected.

        if associated == True :
            print(f"{compressed_reaction_name} is gene-associated.")
            compressed_gene_associated_reactions.append(compressed_reaction_name)

    
    prefix = ":- not support"
    suffix = ".\n"

    for compressed_reaction_id in compressed_gene_associated_reactions:
        reaction_number = str(compressed_gene_associated_reactions.index(compressed_reaction_id))
        constr_out_str = ""
        constr_out_str += f'{prefix}("mcs_{compressed_reaction_id}"){suffix}'
        constr_out_str += f'target("mcs_{compressed_reaction_id}").'
        with open(outfile_path+reaction_number+"_posconstr.lp4", "w") as constr_out:
            constr_out.write(constr_out_str)

# %%
apply_medium(HCC, "../../models_storage/medium_HCC.csv")
# Out:
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# EX_m4082;(+)-alpha-pinene;;
# EX_m4083;(R)-3-hydroxybutanoate;;
# EX_m4084;1,1-dichloroethylene;;
# EX_m4085;1,2-dibromoethane;;
# EX_m4086;10-formyl-THF-glu(7);;
# EX_m4087;1-nitronaphthalene;;
# EX_m4088;25-hydroxyvitamin D2;;
# EX_m4089;2-acetyl-1-alkyl-sn-glycero-3-phosphocholine;;
# EX_m4090;2-hydroxybutyrate;;
# EX_m4091;4-(n-nitrosomethylamino)-1-(3-pyridyl)-1-butanone;;
# EX_m4092;4-nitrophenyl-phosphate;;
# EX_m4093;5-alpha-dihydrotestosterone;;
# EX_m4094;5-formyl-THF;;
# EX_m4095;7,12-dimethylbenz[a]anthracene;;
# EX_m4096;acetone;;
# EX_m4097;acetylcholine;;
# EX_m4098;ADP-glucose;;
# EX_m4099;ADP-mannose;;
# EX_m4100;aflatoxin B1;;
# EX_m4101;albumin;;
# EX_m4102;alpha-tocopherol;;
# EX_m4103;alpha-tocotrienol;;
# EX_m4104;aquacob(III)alamin;;
# EX_m4105;arginine;1;-1.5
# EX_m4106;aspartate;1;-1.5
# EX_m4107;benzo[a]pyrene;;
# EX_m4108;beta-carotene;;
# EX_m4109;betaine;;
# EX_m4110;bilirubin;;
# EX_m4111;biotin;;
# EX_m4112;bromobenzene;;
# EX_m4113;chitin-component;;
# EX_m4114;cholate;;
# EX_m4115;chondroitin sulfate B - dermatan sulfate (IdoA2S-GalNAc4S) proteoglycan;;
# EX_m4116;chondroitin sulfate C (GalNAc6S-GlcA) proteoglycan;;
# EX_m4117;chondroitin sulfate D (GlcNAc6S-GlcA2S) proteoglycan;;
# EX_m4118;chondroitin sulfate E (GalNAc4,6diS-GlcA) proteoglycan;;
# EX_m4119;chylomicron;;
# EX_m4120;citrate;;
# EX_m4121;cortisol;;
# EX_m4122;coumarin;;
# EX_m4123;creatinine;;
# EX_m4124;D-arginine;;
# EX_m4125;D-aspartate;;
# EX_m4126;debrisoquin;;
# EX_m4127;dehydroepiandrosterone sulfate;;
# EX_m4128;dITP;;
# EX_m4129;D-lactate;;
# EX_m4130;dopamine;;
# EX_m4131;D-ornithine;;
# EX_m4132;D-proline;;
# EX_m4133;D-ribulose;;
# EX_m4134;D-tagatose;;
# EX_m4135;estriol;;
# EX_m4136;estrone 3-sulfate;;
# EX_m4137;ethanol;;
# EX_m4138;Fe2+;;
# EX_m4139;galactosylglycerol;;
# EX_m4140;gamma-tocopherol;;
# EX_m4141;gamma-tocotrienol;;
# EX_m4142;glucosamine;;
# EX_m4143;glycophosphatidylinositol-(GPI)-anchored-protein-precursor;;
# EX_m4144;GSH;;
# EX_m4145;GT1a;;
# EX_m4146;GTP;;
# EX_m4147;guanosine;;
# EX_m4148;H2O;1;-25
# EX_m4149;HDL remnant;;
# EX_m4150;heparan sulfate proteoglycan;;
# EX_m4151;heptaglutamyl-folate(DHF);;
# EX_m4152;heptaglutamyl-folate(THF);;
# EX_m4153;homoserine;;
# EX_m4154;hyaluronate;;
# EX_m4155;hydrogen-cyanide;;
# EX_m4156;ITP;;
# EX_m4157;keratan sulfate I;;
# EX_m4158;keratan sulfate II (core 2-linked);;
# EX_m4159;keratan sulfate II (core 4-linked);;
# EX_m4160;lactose;;
# EX_m4161;L-arabinose;;
# EX_m4162;leukotriene C4;;
# EX_m4163;limonene;;
# EX_m4164;lysine;1;-1.5
# EX_m4165;mannose;;
# EX_m4166;methanol;;
# EX_m4167;n2m2nmasn;;
# EX_m4168;naphthalene;;
# EX_m4169;NEFA blood pool in;;
# EX_m4170;nifedipine;;
# EX_m4171;O2;1;28
# EX_m4172;O2-;;
# EX_m4173;omeprazole;;
# EX_m4174;ornithine;;
# EX_m4175;PA6;;
# EX_m4176;paclitaxel;;
# EX_m4177;pantothenate;1;-0.1
# EX_m4178;phytanic acid;;
# EX_m4179;progesterone;;
# EX_m4180;prostaglandin F2alpha;;
# EX_m4181;pyridoxamine;1;-0.1
# EX_m4182;riboflavin;1;-0.1
# EX_m4183;selenate;;
# EX_m4184;serine;1;-1.5
# EX_m4185;serotonin;;
# EX_m4186;starch structure 2;;
# EX_m4187;succinate;;
# EX_m4188;sucrose;;
# EX_m4189;thiamin;1;-0.1
# EX_m4190;tolbutamide;;
# EX_m4191;trehalose;;
# EX_m4192;trichloroethene;;
# EX_m4193;triiodothyronine;;
# EX_m4194;UTP;;
# EX_m4195;valine;1;-1.5
# EX_m4196;VLDL;;
# EX_m4197;xanthurenate;;
# EX_m4198;XTP;;
# EX_m4199;biomass;;
# EX_m4205;(5-L-glutamyl)-L-amino acid;;
# EX_m4206;10-formyl-THF;;
# EX_m4207;10-formyl-THF-glu(5);;
# EX_m4208;10-formyl-THF-glu(6);;
# EX_m4209;1-alkyl-2-lysoglycerol-3-phosphocholine;;
# EX_m4210;1-methylnicotinamide;;
# EX_m4211;1-organyl-2-lyso-sn-glycero-3-phosphocholine;;
# EX_m4212;4-aminobutyrate;;
# EX_m4213;5-hydroxy-L-tryptophan;;
# EX_m4214;5-L-gamma-glutamyl;;
# EX_m4215;6-deoxy-L-galactose;;
# EX_m4216;acetate;;
# EX_m4217;acetoacetate;;
# EX_m4218;adenine;;
# EX_m4219;adenosine;;
# EX_m4220;ADP;;
# EX_m4221;adrenaline;;
# EX_m4222;AKG;;
# EX_m4223;alanine;1;-1.5
# EX_m4224;AMP;;
# EX_m4225;asparagine;1;-1.5
# EX_m4226;beta-alanine;;
# EX_m4227;bilirubin-bisglucuronoside;;
# EX_m4228;bilirubin-monoglucuronoside;;
# EX_m4229;butyrate;;
# EX_m4230;cAMP;;
# EX_m4231;cGMP;;
# EX_m4232;chloride;;
# EX_m4233;cholesterol;;
# EX_m4234;choline;1;-0.1
# EX_m4235;chondroitin sulfate A (GalNAc4S-GlcA) proteoglycan;;
# EX_m4236;chylomicron remnant;;
# EX_m4237;citrulline;;
# EX_m4238;CMP;;
# EX_m4239;CO2;1;-21
# EX_m4240;cys-gly;;
# EX_m4241;cysteine;1;-1.5
# EX_m4242;cytidine;;
# EX_m4243;cytosine;;
# EX_m4244;D-alanine;;
# EX_m4245;decanoic acid;;
# EX_m4246;de-Fuc form of PA6;;
# EX_m4247;deoxyadenosine;;
# EX_m4248;deoxycytidine;;
# EX_m4249;deoxyguanosine;;
# EX_m4250;deoxyinosine;;
# EX_m4251;deoxyuridine;;
# EX_m4252;D-glucitol;;
# EX_m4253;dihydrofolate;;
# EX_m4254;D-serine;;
# EX_m4255;estradiol-17beta 3-glucuronide;;
# EX_m4256;estrone-glucuronide;;
# EX_m4257;ethanolamine;;
# EX_m4258;Fe3+;;
# EX_m4259;formate;;
# EX_m4260;fructose;;
# EX_m4261;galactose;;
# EX_m4262;GDP;;
# EX_m4263;glucose;1;-2
# EX_m4264;glutamate;1;-1
# EX_m4265;glutamine;1;0
# EX_m4266;glycerol;;
# EX_m4267;glycine;1;-1.5
# EX_m4268;glycochenodeoxycholate;;
# EX_m4269;glycocholate;;
# EX_m4270;GMP;;
# EX_m4271;GSSG;;
# EX_m4272;guanine;;
# EX_m4273;H+;1;-10
# EX_m4274;H2O2;;
# EX_m4275;HCO3-;1;-0.1
# EX_m4276;heptylic acid;;
# EX_m4277;hexaglutamyl-folate(DHF);;
# EX_m4278;hexaglutamyl-folate(THF);;
# EX_m4279;hexanoic acid;;
# EX_m4280;histidine;1;-1.5
# EX_m4281;hydroxide;;
# EX_m4282;hypoxanthine;;
# EX_m4283;IDP;;
# EX_m4284;IMP;;
# EX_m4285;inosine;;
# EX_m4286;inositol;1;-0.1
# EX_m4287;iodide;;
# EX_m4288;isoleucine;1;-1.5
# EX_m4289;K+;1;-0.1
# EX_m4290;keratan sulfate I, degradation product 1;;
# EX_m4291;L-carnitine;;
# EX_m4292;leucine;1;-1.5
# EX_m4293;leukotriene E4;;
# EX_m4294;linoleate;;
# EX_m4295;linolenate;;
# EX_m4296;L-lactate;;
# EX_m4297;LTD4;;
# EX_m4298;maltose;;
# EX_m4299;methionine;1;-1.5
# EX_m4300;Na+;1;-0.1
# EX_m4301;NH3;;
# EX_m4302;nonanoic acid;;
# EX_m4303;noradrenaline;;
# EX_m4304;octanoic acid;;
# EX_m4305;oxalate;;
# EX_m4306;pentaglutamyl-folate(DHF);;
# EX_m4307;pentaglutamyl-folate(THF);;
# EX_m4308;phenylalanine;1;-1.5
# EX_m4309;Pi;1;-10
# EX_m4310;PNP;;
# EX_m4311;proline;1;-1.5
# EX_m4312;propanoate;;
# EX_m4313;prostaglandin E1;;
# EX_m4314;prostaglandin E2;;
# EX_m4315;pyruvate;1;-1
# EX_m4316;retinoate;;
# EX_m4317;spermine dialdehyde;;
# EX_m4318;spermine;;
# EX_m4319;sulfate;;
# EX_m4320;taurochenodeoxycholate;;
# EX_m4321;taurocholate;;
# EX_m4322;THF;;
# EX_m4323;threonine;1;-1.5
# EX_m4324;thymidine;;
# EX_m4325;thymine;;
# EX_m4326;thyroxine;;
# EX_m4327;tryptophan;1;-1.5
# EX_m4328;tyrosine;1;-1.5
# EX_m4329;UDP;;
# EX_m4330;UMP;;
# EX_m4331;undecylic acid;;
# EX_m4332;uracil;;
# EX_m4333;urate;;
# EX_m4334;urea;;
# EX_m4335;uridine;;
# EX_m4336;valeric acid;;
# EX_m4337;VLDL remnant;;
# EX_m4338;zinc;;
# EX_m4339;cholesterol-ester pool;;

# %%
nerrors
# Out:
# 95

# %%
upregulated_reactions
# Out:
# {'HMR_4381': ['2821'],
#  'HMR_6412': ['1737'],
#  'HMR_7748': ['2821'],
#  'HMR_7749': ['2821'],
#  'HMR_4122': ['7358'],
#  'HMR_4399': ['2762'],
#  'HMR_4400': ['7264'],
#  'HMR_8768': ['7264'],
#  'HMR_4306': ['2539'],
#  'HMR_4473': ['5226'],
#  'HMR_4474': ['5226'],
#  'HMR_4565': ['6888'],
#  'HMR_4020': ['2987'],
#  'HMR_4038': ['471'],
#  'HMR_4168': ['3704'],
#  'HMR_4406': ['5471'],
#  'HMR_4799': ['2618'],
#  'HMR_4802': ['2618'],
#  'HMR_4804': ['10606'],
#  'HMR_4808': ['5198'],
#  'HMR_4810': ['10606'],
#  'HMR_4814': ['471'],
#  'HMR_5353': ['2987'],
#  'HMR_4034': ['790'],
#  'HMR_4050': ['790'],
#  'HMR_4608': ['790'],
#  'HMR_4643': ['1854', '3704'],
#  'HMR_4644': ['7298'],
#  'HMR_3965': ['1854'],
#  'HMR_3966': ['3704'],
#  'HMR_4806': ['2618'],
#  'HMR_7879': ['3704'],
#  'HMR_8483': ['1854'],
#  'HMR_8488': ['3704'],
#  'HMR_8489': ['3704'],
#  'HMR_3892': ['2744'],
#  'HMR_4075': ['6723'],
#  'HMR_4077': ['6723', '6611'],
#  'HMR_4190': ['6723', '6611'],
#  'HMR_4212': ['4953'],
#  'HMR_4422': ['4953'],
#  'HMR_3744': ['587'],
#  'HMR_3778': ['587'],
#  'HMR_3765': ['587'],
#  'HMR_5387': ['58478'],
#  'HMR_8069': ['4191'],
#  'HMR_1532': ['9453', '2224'],
#  'HMR_7263': ['22845'],
#  'HMR_7274': ['10195'],
#  'HMR_7279': ['29929'],
#  'HMR_7280': ['79053'],
#  'HMR_7574': ['175'],
#  'HMR_7585': ['175'],
#  'HMR_4141': ['4191'],
#  'HMR_4145': ['1431'],
#  'HMR_4149': ['47'],
#  'HMR_2153': ['2194'],
#  'HMR_2154': ['2194'],
#  'HMR_2157': ['2194'],
#  'HMR_2158': ['2194'],
#  'HMR_2159': ['2194'],
#  'HMR_2161': ['2194'],
#  'HMR_2162': ['2194'],
#  'HMR_2163': ['2194'],
#  'HMR_2165': ['2194'],
#  'HMR_2166': ['2194'],
#  'HMR_2167': ['2194'],
#  'HMR_2169': ['2194'],
#  'HMR_2170': ['2194'],
#  'HMR_2171': ['2194'],
#  'HMR_2174': ['2194'],
#  'HMR_2175': ['2194'],
#  'HMR_2176': ['2194'],
#  'HMR_2179': ['2194'],
#  'HMR_2180': ['2194'],
#  'HMR_2181': ['2194'],
#  'HMR_4156': ['2194'],
#  'HMR_2227': ['2194'],
#  'HMR_2228': ['2194'],
#  'HMR_2229': ['2194'],
#  'HMR_2230': ['2194'],
#  'HMR_2231': ['2194'],
#  'HMR_2232': ['2194'],
#  'HMR_2233': ['2194'],
#  'HMR_2234': ['2194'],
#  'HMR_2235': ['2194'],
#  'HMR_2236': ['2194'],
#  'HMR_2237': ['2194'],
#  'HMR_2238': ['2194'],
#  'HMR_2239': ['2194'],
#  'HMR_2240': ['2194'],
#  'HMR_2241': ['2194'],
#  'HMR_2242': ['2194'],
#  'HMR_2243': ['2194'],
#  'HMR_2244': ['2194'],
#  'HMR_2245': ['2194'],
#  'HMR_2246': ['2194'],
#  'HMR_2247': ['2194'],
#  'HMR_2249': ['2194'],
#  'HMR_2250': ['2194'],
#  'HMR_2251': ['2194'],
#  'HMR_2252': ['2194'],
#  'HMR_2254': ['2194'],
#  'HMR_2255': ['2194'],
#  'HMR_2256': ['2194'],
#  'HMR_2257': ['2194'],
#  'HMR_2150': ['2194'],
#  'HMR_2551': ['4048'],
#  'HMR_1080': ['4048'],
#  'HMR_1084': ['4048'],
#  'HMR_2829': ['6584'],
#  'HMR_2831': ['6584'],
#  'HMR_2833': ['6584'],
#  'HMR_2865': ['6584'],
#  'HMR_2875': ['6584'],
#  'HMR_2878': ['6584'],
#  'HMR_2904': ['6584'],
#  'HMR_1470': ['6713'],
#  'HMR_1457': ['9453', '2224'],
#  'HMR_1460': ['9453', '2224'],
#  'HMR_8149': ['8706'],
#  'HMR_8206': ['9514'],
#  'HMR_8212': ['9514'],
#  'HMR_0673': ['55750'],
#  'HMR_0674': ['55750'],
#  'HMR_0675': ['55750'],
#  'HMR_0676': ['55750'],
#  'HMR_0677': ['55750'],
#  'HMR_0678': ['55750'],
#  'HMR_0581': ['1040', '8760'],
#  'HMR_0582': ['9489'],
#  'HMR_0607': ['1040', '8760'],
#  'HMR_0622': ['81490'],
#  'HMR_7594': ['8540'],
#  'HMR_0792': ['9514'],
#  'HMR_1325': ['8644'],
#  'HMR_1326': ['8644'],
#  'HMR_1329': ['8644'],
#  'HMR_1382': ['8644'],
#  'HMR_1387': ['8644'],
#  'HMR_7202': ['11285'],
#  'HMR_7226': ['2799'],
#  'HMR_7230': ['3425'],
#  'HMR_7231': ['2799'],
#  'HMR_7237': ['2799'],
#  'HMR_7242': ['3425'],
#  'HMR_7376': ['175'],
#  'HMR_7381': ['2799'],
#  'HMR_7385': ['2799'],
#  'HMR_7389': ['2799'],
#  'HMR_7393': ['2799'],
#  'HMR_7397': ['2799'],
#  'HMR_7401': ['2799'],
#  'HMR_7405': ['2799'],
#  'HMR_7409': ['2799'],
#  'HMR_7413': ['2799'],
#  'HMR_7417': ['2799'],
#  'HMR_7421': ['2799'],
#  'HMR_7458': ['2799'],
#  'HMR_7463': ['2799'],
#  'HMR_7487': ['2799'],
#  'HMR_4746': ['3145'],
#  'HMR_4755': ['5498'],
#  'HMR_4757': ['5498'],
#  'HMR_4068': ['8566'],
#  'HMR_0770': ['51228'],
#  'HMR_4844': ['2194'],
#  'HMR_5003': ['3177', '2030'],
#  'HMR_5008': ['3177', '2030'],
#  'HMR_5034': ['3177', '2030'],
#  'HMR_5035': ['3177', '2030'],
#  'HMR_5037': ['3177', '2030'],
#  'HMR_5042': ['3177', '2030'],
#  'HMR_5446': ['10257'],
#  'HMR_6366': ['3177', '2030'],
#  'HMR_6367': ['3177', '2030'],
#  'HMR_6368': ['3177', '2030'],
#  'HMR_6369': ['3177', '2030'],
#  'HMR_6530': ['65010'],
#  'HMR_6531': ['65010'],
#  'HMR_6533': ['65010'],
#  'HMR_7645': ['206358'],
#  'HMR_7650': ['10257'],
#  'HMR_7691': ['10257'],
#  'HMR_7692': ['10257'],
#  'HMR_8354': ['206358'],
#  'HMR_8670': ['65010'],
#  'HMR_8736': ['65010'],
#  'HMR_8929': ['206358'],
#  'HMR_8934': ['10257'],
#  'HMR_8935': ['10257'],
#  'HMR_4997': ['3177', '2030'],
#  'HMR_5031': ['2030'],
#  'HMR_5033': ['2030'],
#  'HMR_7719': ['2030'],
#  'HMR_7646': ['206358'],
#  'HMR_8476': ['3177', '2030'],
#  'HMR_5048': ['206358'],
#  'HMR_5049': ['206358'],
#  'HMR_5050': ['206358'],
#  'HMR_5051': ['206358'],
#  'HMR_5052': ['206358'],
#  'HMR_5053': ['206358'],
#  'HMR_5054': ['206358'],
#  'HMR_5055': ['206358'],
#  'HMR_5056': ['206358'],
#  'HMR_5057': ['206358'],
#  'HMR_5058': ['206358'],
#  'HMR_5059': ['206358'],
#  'HMR_5060': ['206358'],
#  'HMR_5061': ['206358'],
#  'HMR_5062': ['206358'],
#  'HMR_5063': ['206358'],
#  'HMR_5064': ['206358'],
#  'HMR_5065': ['206358'],
#  'HMR_5066': ['206358'],
#  'HMR_5067': ['206358'],
#  'HMR_4046': ['8833']}

# %%
genes_visited = []
for genes in upregulated_reactions.values() :
    for g in genes :
        if g not in genes_visited :
            genes_visited.append(g)
print(len(genes_visited))
# Out:
# 60

# %%
# Getting up and downregulated model reactions dictionaries :

upregulated_reactions, up_errors = get_gene_associated_reaction(upregulated_entrez_ids, HCC)
downregulated_reactions, down_errors = get_gene_associated_reaction(downregulated_entrez_ids, HCC)

# Checking numbers :
print(f"Number of reactions being downregulated in the model : {len(downregulated_reactions.keys())}\nNumber of reactions being upregulated in the model : {len(upregulated_reactions.keys())}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 # Getting up and downregulated model reactions dictionaries :
# ----> 3 upregulated_reactions, up_errors = get_gene_associated_reaction(upregulated_entrez_ids, HCC)
#       4 downregulated_reactions, down_errors = get_gene_associated_reaction(downregulated_entrez_ids, HCC)
#       6 # Checking numbers :
#
# NameError: name 'HCC' is not defined

# %%
# Removing down-regulated genes-associated reactions from the model.
# The function checks if the removal of the reaction breaks the model. If it does, the reaction is restored.

remove_and_check(HCC, downregulated_reactions.keys())
# Out:
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.35729882091389137; <class 'float'>
# obj_val : 0.35729882091389087; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.3572988209138906; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.35729882091389137; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.35729882091389115; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.09875567845151115; <class 'float'>
# obj_val : 0.3572988209138911; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.09875567845151097; <class 'float'>
# obj_val : 0.09875567845151109; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.3572988209138907; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.3572988209138934; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.3572988209138912; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.3572988209138819; <class 'float'>
# obj_val : 0.3572988209138912; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.3572988209138907; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.3572988209138912; <class 'float'>
# obj_val : 0.3572988209138912; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.3572988209138907; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.3572988209138911; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.3572988209138906; <class 'float'>
# obj_val : 0.35729882091389126; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.07429788498687404; <class 'float'>
# obj_val : 0.07429788498687404; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.3572988209138912; <class 'float'>
# obj_val : 0.3572988209138908; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.3572988209138911; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.3572988209138911; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.35729882091389076; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.3572988209138907; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.35729882091389115; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.35729882091389087; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.35729882091389087; <class 'float'>
# obj_val : 0.3572988209138912; <class 'float'>
# obj_val : 0.3572988209138907; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.35729882091389115; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.35729882091389087; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.35729882091389115; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.35729882091389087; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.35729882091389087; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.35729882091389087; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.14591852344711095; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.35729882091389087; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.35729882091389115; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.35729882091389065; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.3572988209138863; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.3572988209138912; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.3572988209138908; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.3572988209138907; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.1558781047427025; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.0; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.35729882091389087; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.17228148438192736; <class 'float'>
# obj_val : 0.17228148438193222; <class 'float'>
# obj_val : 0.17228148438193197; <class 'float'>
# obj_val : 0.17228148438193147; <class 'float'>
# obj_val : 0.17228148438193217; <class 'float'>
# obj_val : 0.1722814843819321; <class 'float'>
# obj_val : 0.17228148438193358; <class 'float'>
# obj_val : 0.35729882091389087; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.35729882091389087; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.17228148438193275; <class 'float'>
# obj_val : 0.17228148438193203; <class 'float'>
# obj_val : 0.1722814843819317; <class 'float'>
# obj_val : 0.17228148438193233; <class 'float'>
# obj_val : 0.1722814843819318; <class 'float'>
# obj_val : 0.17228148438193147; <class 'float'>
# obj_val : 0.17228148438193247; <class 'float'>
# obj_val : 0.1722814843819317; <class 'float'>
# obj_val : 0.13030012984343156; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.3572988209138911; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.35729882091389115; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.0; <class 'float'>
# obj_val : 0.0; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913881; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.35729882091389087; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.3572988209138911; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.35729882091389115; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.35729882091389087; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.35729882091389115; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.3572988209138911; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.3572988209138907; <class 'float'>
# obj_val : 0.35729882091389087; <class 'float'>
# obj_val : 0.17228200526527468; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.35729882091389104; <class 'float'>
# obj_val : 0.3572988209138912; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.3572988209138909; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.357298820913891; <class 'float'>
# obj_val : 0.0; <class 'float'>
# 431/459 reactions removed.

# %%
HCC.objective = "biomass_components"
HCC.optimize()
# Out:
# <Solution 0.357 at 0x7f9fcc6c20b0>

# %%
vu.print_exchanges(HCC, "all")
# Out:
# ##########
# INTAKES :
#
# EX_m4239 : -21         ub : 1000.0	---		metabolites : 	 id : m4239 --- metabolite name : CO2 ; id : m4239
# EX_m4106 : -2          ub : 1000.0	---		metabolites : 	 id : m4106 --- metabolite name : aspartate ; id : m4106
# EX_m4184 : -2          ub : 1000.0	---		metabolites : 	 id : m4184 --- metabolite name : serine ; id : m4184
# EX_m4263 : -2          ub : 1000.0	---		metabolites : 	 id : m4263 --- metabolite name : glucose ; id : m4263
# EX_m4299 : -2          ub : 1000.0	---		metabolites : 	 id : m4299 --- metabolite name : methionine ; id : m4299
# EX_m4309 : -2          ub : 1000.0	---		metabolites : 	 id : m4309 --- metabolite name : Pi ; id : m4309
# EX_m4323 : -2          ub : 1000.0	---		metabolites : 	 id : m4323 --- metabolite name : threonine ; id : m4323
# EX_m4264 : -1          ub : 1000.0	---		metabolites : 	 id : m4264 --- metabolite name : glutamate ; id : m4264
# EX_m4267 : -1          ub : 1000.0	---		metabolites : 	 id : m4267 --- metabolite name : glycine ; id : m4267
# EX_m4315 : -1          ub : 1000.0	---		metabolites : 	 id : m4315 --- metabolite name : pyruvate ; id : m4315
# EX_m4105 : 0           ub : 1000.0	---		metabolites : 	 id : m4105 --- metabolite name : arginine ; id : m4105
# EX_m4164 : 0           ub : 1000.0	---		metabolites : 	 id : m4164 --- metabolite name : lysine ; id : m4164
# EX_m4195 : 0           ub : 1000.0	---		metabolites : 	 id : m4195 --- metabolite name : valine ; id : m4195
# EX_m4223 : 0           ub : 1000.0	---		metabolites : 	 id : m4223 --- metabolite name : alanine ; id : m4223
# EX_m4225 : 0           ub : 1000.0	---		metabolites : 	 id : m4225 --- metabolite name : asparagine ; id : m4225
# EX_m4234 : 0           ub : 1000.0	---		metabolites : 	 id : m4234 --- metabolite name : choline ; id : m4234
# EX_m4275 : 0           ub : 1000.0	---		metabolites : 	 id : m4275 --- metabolite name : HCO3- ; id : m4275
# EX_m4280 : 0           ub : 1000.0	---		metabolites : 	 id : m4280 --- metabolite name : histidine ; id : m4280
# EX_m4286 : 0           ub : 1000.0	---		metabolites : 	 id : m4286 --- metabolite name : inositol ; id : m4286
# EX_m4288 : 0           ub : 1000.0	---		metabolites : 	 id : m4288 --- metabolite name : isoleucine ; id : m4288
# EX_m4292 : 0           ub : 1000.0	---		metabolites : 	 id : m4292 --- metabolite name : leucine ; id : m4292
# EX_m4308 : 0           ub : 1000.0	---		metabolites : 	 id : m4308 --- metabolite name : phenylalanine ; id : m4308
# EX_m4311 : 0           ub : 1000.0	---		metabolites : 	 id : m4311 --- metabolite name : proline ; id : m4311
# EX_m4327 : 0           ub : 1000.0	---		metabolites : 	 id : m4327 --- metabolite name : tryptophan ; id : m4327
# EX_m4328 : 0           ub : 1000.0	---		metabolites : 	 id : m4328 --- metabolite name : tyrosine ; id : m4328
#
# ##########
# SECRETIONS :
#
# EX_m4171 : 17          ub : 1000.0	---		metabolites : 	 id : m4171 --- metabolite name : O2 ; id : m4171
# EX_m4148 : 11          ub : 1000.0	---		metabolites : 	 id : m4148 --- metabolite name : H2O ; id : m4148
# EX_m4295 : 4           ub : 1000.0	---		metabolites : 	 id : m4295 --- metabolite name : linolenate ; id : m4295
# EX_m4312 : 2           ub : 1000.0	---		metabolites : 	 id : m4312 --- metabolite name : propanoate ; id : m4312
# EX_m4241 : 1           ub : 1000.0	---		metabolites : 	 id : m4241 --- metabolite name : cysteine ; id : m4241
# EX_m4301 : 1           ub : 1000.0	---		metabolites : 	 id : m4301 --- metabolite name : NH3 ; id : m4301
# EX_m4199 : 0           ub : 1000.0	---		metabolites : 	 id : m4199 --- metabolite name : biomass ; id : m4199

# %% [markdown]
# ### Writing modified model to file and compressing it

# %%
import os
os.getcwd()
# Out:
# '/home/muller-prokob/Documents/github/RBA_cutsets/models_analysis/code'

# %%
cobra.io.write_sbml_model(HCC, "../../models_storage/HCC_reduced.xml")

# %%
efmtool_link_compression.compress_model("../../models_storage/HCC_reduced.xml", "../../aspmcs/code/compression/", "../../HCC_compressed_2/", "new")
# Out:
# /home/muller-prokob/miniconda3/envs/cobra/lib/python3.10/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# Flipped EX_m4105
# Flipped EX_m4164
# Flipped EX_m4195
# Flipped EX_m4223
# Flipped EX_m4225
# Flipped EX_m4280
# Flipped EX_m4288
# Flipped EX_m4292
# Flipped EX_m4308
# Flipped EX_m4309
# Flipped EX_m4311
# Flipped EX_m4327
# Flipped EX_m4328
# Flipped HMR_4837
# Flipped HMR_8584
# Flipped HMR_4128
# Flipped HMR_4303
# Flipped HMR_4415
# Flipped HMR_4316
# Flipped HMR_8498
# Flipped HMR_5351
# Flipped HMR_4404
# Flipped HMR_4474
# Flipped HMR_4501
# Flipped HMR_4625
# Flipped HMR_4134
# Flipped HMR_4450
# Flipped HMR_4804
# Flipped HMR_4812
# Flipped HMR_4030
# Removing 175 reactions:
# [HMR_6603, HMR_6602, HMR_8589, HMR_3212, HMR_6601, EX_m4258, EX_m4138, EX_m4135, EX_m4256, EX_m4136, EX_m4139, HMR_6609, EX_m4140, EX_m4141, EX_m4145, EX_m4266, EX_m4142, EX_m4143, HMR_8341, HMR_6610, HMR_4399, HMR_4036, HMR_5401, HMR_6611, HMR_8755, EX_m4269, EX_m4302, EX_m4149, EX_m4303, EX_m4300, EX_m4268, EX_m4306, EX_m4307, EX_m4305, EX_m4151, EX_m4152, HMR_8074, EX_m4150, EX_m4155, EX_m4276, EX_m4277, EX_m4310, EX_m4154, HMR_4034, HMR_8727, EX_m4319, HMR_4521, EX_m4159, EX_m4313, EX_m4157, EX_m4278, EX_m4158, EX_m4279, EX_m4316, EX_m4162, EX_m4163, EX_m4161, EX_m4287, EX_m4320, EX_m4167, EX_m4321, HMR_4416, HMR_4497, EX_m4168, EX_m4289, EX_m4322, EX_m4169, EX_m4207, EX_m4208, EX_m4326, EX_m4206, EX_m4173, EX_m4293, EX_m4177, EX_m4210, EX_m4331, EX_m4178, EX_m4175, EX_m4176, EX_m4297, EX_m4290, EX_m4170, EX_m4291, HMR_4623, EX_m4214, EX_m4215, EX_m4336, EX_m4179, EX_m4213, EX_m4337, EX_m4338, EX_m4185, EX_m4182, EX_m4183, EX_m4100, EX_m4221, EX_m4189, HMR_5396, HMR_5395, HMR_5398, HMR_5397, EX_m4181, HMR_6537, HMR_9804, HMR_9803, EX_m4104, EX_m4102, EX_m4103, EX_m4108, EX_m4109, EX_m4227, EX_m4107, EX_m4228, EX_m4196, EX_m4193, EX_m4111, EX_m4232, EX_m4112, EX_m4197, EX_m4110, HMR_4592, HMR_4350, HMR_4473, HMR_4595, EX_m4192, EX_m4190, HMR_4591, HMR_4841, EX_m4115, EX_m4236, EX_m4116, EX_m4237, EX_m4113, EX_m4114, EX_m4235, EX_m4119, HMR_4604, EX_m4117, EX_m4118, EX_m4085, EX_m4086, EX_m4083, EX_m4084, EX_m4122, EX_m4243, EX_m4123, EX_m4087, EX_m4088, EX_m4121, HMR_7674, HMR_8764, HMR_8762, EX_m4082, HMR_4059, EX_m4126, EX_m4127, EX_m4124, EX_m4245, EX_m4125, EX_m4246, EX_m4130, EX_m4094, EX_m4095, EX_m4133, EX_m4254, EX_m4134, EX_m4255, EX_m4131, EX_m4132, EX_m4253, HMR_8653, EX_m4092, EX_m4093, HMR_4050, EX_m4091]
# EX_m4089 : 1.0 m836 =>
# EX_m4090 : 1.0 m856 + 1.0 m882 + 1.0 m2666 + 1.0 m3270 => 1.0 m855 + 1.0 m3265
# EX_m4096 : 1.0 m2674 + 1.0 m2829 + 1.0 m3274 => 1.0 m2673 + 1.0 m3279 + 1.0 m3342
# EX_m4097 : 1.0 m1573 =>
# EX_m4098 : 1.0 m1668 + 1.0 m2553 => 1.0 m2674
# EX_m4099 : 1.0 m1668 + 1.0 m3178 => 1.0 m2674
# EX_m4101 : 304.0 m1605 + 63.0 m1638 + 27.0 m1704 + 17.0 m1710 + 36.0 m1713 + 35.0 m2123 + 62.0 m2566 + 20.0 m2571 + 13.0 m2586 + 16.0 m2803 + 9.0 m2868 + 64.0 m3051 + 60.0 m3149 + 7.0 m3200 + 35.0 m3497 + 304.0 m3534 + 24.0 m3558 + 28.0 m3687 + 29.0 m3851 + 2.0 m3979 + 19.0 m3984 + 43.0 m4051 => 304.0 m1717 + 304.0 m2676
# EX_m4105 : => 1.0 m1706
# EX_m4106 : 1.0 m1715 =
# EX_m4120 : 1.0 m2065 =>
# EX_m4128 : 1.0 m2196 + 1.0 m3532 + 1.0 m3543 => 2.0 m2674
# EX_m4129 : 1.0 m2258 + 1.0 m2666 => 1.0 m2673
# EX_m4137 : 1.0 m2404 =>
# EX_m4144 : 1.0 m2644 =>
# EX_m4146 : 1.0 m2529 + 1.0 m3539 => 1.0 m2681
# EX_m4147 : 1.0 m2665 =>
# EX_m4148 : 1.0 m2681 =
# EX_m4153 : 1.0 m1604 + 1.0 m2815 + 1.0 m3532 + 1.0 m3850 => 1.0 m1716 + 1.0 m2674 + 1.0 m2814
# EX_m4156 : 1.0 m2877 =>
# EX_m4160 : 1.0 m2487 + 1.0 m2552 => 1.0 m2681
# EX_m4164 : => 1.0 m3152
# EX_m4165 : 1.0 m3172 =>
# EX_m4166 : 1.0 m3196 =>
# EX_m4171 : 1.0 m3351 =
# EX_m4172 : 1.0 m3352 =>
# EX_m4174 : 1.0 m3405 =>
# EX_m4180 : 1.0 m3581 =>
# EX_m4184 : = 1.0 m3689
# EX_m4186 : 1.0 m2552 + 1.0 m3171 => 1.0 m2681
# EX_m4187 : 1.0 m3766 =>
# EX_m4188 : 1.0 m2461 + 1.0 m2552 => 1.0 m2681
# EX_m4191 : 2.0 m2552 => 1.0 m2681
# EX_m4194 : 1.0 m4046 =>
# EX_m4195 : => 1.0 m4053
# EX_m4198 : 1.0 m3543 + 1.0 m4066 => 1.0 m2674
# EX_m4199 : 0.555 m7 + 0.555 m11 + 0.555 m14 + 0.555 m21 + 0.555 m30 + 0.555 m36 + 0.555 m43 + 0.555 m50 + 0.555 m59 + 0.555 m64 + 4.605 m161 + 146.155 m168 + 0.555 m181 + 35.925 m187 + 0.555 m196 + 13.43 m202 + 0.555 m207 + 0.555 m215 + 0.555 m223 + 0.555 m229 + 5.21 m233 + 28.59 m239 + 0.555 m245 + 0.555 m251 + 0.555 m257 + 0.555 m263 + 0.555 m268 + 0.555 m276 + 550.0 m389 + 0.555 m425 + 0.555 m431 + 0.555 m483 + 0.555 m522 + 1.0 m712 + 0.555 m1431 + 151.7 m1492 + 0.555 m1536 + 0.555 m1539 + 1250.0 m1637 + 286.52 m1699 + 1250.0 m1703 + 1250.0 m1709 + 1250.0 m1712 + 1.0 m1716 + 5000.0 m1718 + 1250.0 m1833 + 1250.0 m1841 + 131.17 m2059 + 1.0 m2116 + 1250.0 m2122 + 53.255 m2235 + 2500.0 m2262 + 0.555 m2271 + 0.555 m2345 + 1.0 m2407 + 28.455 m2504 + 1250.0 m2565 + 1250.0 m2570 + 1250.0 m2585 + 1250.0 m2677 + 0.555 m2701 + 0.555 m2750 + 0.555 m2773 + 0.555 m2778 + 1250.0 m2802 + 1250.0 m2867 + 0.555 m3032 + 1250.0 m3050 + 16.765 m3097 + 952.9 m3100 + 1250.0 m3104 + 1250.0 m3148 + 1250.0 m3199 + 88.65 m3219 + 1251.5 m3279 + 0.555 m3324 + 1.0 m3342 + 1564.545 m3388 + 0.555 m3435 + 2647.195 m3439 + 0.555 m3466 + 1250.0 m3496 + 1250.0 m3508 + 1250.0 m3529 + 1250.0 m3557 + 1250.0 m3638 + 1250.0 m3662 + 2500.5 m3686 + 1250.0 m3701 + 3750.0 m3708 + 622.12 m3758 + 0.555 m3813 + 1250.0 m3850 + 0.555 m3935 + 0.555 m3942 + 1250.0 m3978 + 1250.0 m3983 + 1250.0 m3999 + 1250.0 m4050 => 1251.0 m1604 + 5000.0 m1606 + 1.0 m2071 + 1250.5 m2081 + 1800.5 m2086 + 5000.0 m2087 + 1248.5 m2666 + 2.0 m2674 + 1251.5 m3274 + 1.0 m3341 + 1250.0 m3535 + 1.0 m3543 + 2500.0 m3544 + 1250.0 m3658 + 1250.5 m3731 + 550.0 m3789 + 1250.0 m3989
# EX_m4205 : 1.0 m172 =>
# EX_m4209 : 1.0 m836 + 1.0 m2681 => 1.0 m1560
# EX_m4211 : 1.0 m836 + 1.0 m2681 => 1.0 m1560
# EX_m4212 : 1.0 m1243 + 1.0 m2565 => 1.0 m1241 + 1.0 m2081
# EX_m4216 : 1.0 m1560 =>
# EX_m4217 : 1.0 m1563 + 1.0 m2669 + 1.0 m2809 => 1.0 m1561 + 1.0 m1575 + 1.0 m2666
# EX_m4218 : 1.0 m1594 =>
# EX_m4219 : 1.0 m1599 =>
# EX_m4220 : 1.0 m1675 + 1.0 m3539 => 1.0 m2681
# EX_m4222 : 1.0 m1636 =>
# EX_m4223 : => 1.0 m1641
# EX_m4224 : 1.0 m1675 =>
# EX_m4225 : => 1.0 m1711
# EX_m4226 : 1.0 m1736 =>
# EX_m4229 : 1.0 m1668 + 1.0 m1768 + 1.0 m1771 + 1.0 m3543 => 1.0 m1716 + 1.0 m1767 + 1.0 m2086
# EX_m4230 : 1.0 m1716 + 1.0 m1780 + 1.0 m2674 => 1.0 m1604 + 1.0 m3532
# EX_m4231 : 1.0 m1716 + 1.0 m1806 + 1.0 m2674 => 1.0 m1604 + 1.0 m3532
# EX_m4233 : 1.0 m1838 =>
# EX_m4234 : = 1.0 m1968
# EX_m4238 : 1.0 m2075 =>
# EX_m4239 : 1.0 m2081 =
# EX_m4240 : 1.0 m2121 =>
# EX_m4241 : = 1.0 m2124
# EX_m4242 : 1.0 m2128 =>
# EX_m4244 : 1.0 m1637 + 1.0 m2142 => 1.0 m2140
# EX_m4247 : 1.0 m2185 =>
# EX_m4248 : 1.0 m2156 + 1.0 m2674 => 1.0 m3532
# EX_m4249 : 1.0 m2193 =>
# EX_m4250 : 1.0 m2196 =>
# EX_m4251 : 1.0 m2199 =>
# EX_m4252 : 1.0 m2548 + 1.0 m2666 + 1.0 m3279 => 1.0 m3274
# EX_m4257 : 1.0 m2407 =>
# EX_m4259 : 1.0 m2456 =>
# EX_m4260 : 1.0 m2461 =>
# EX_m4261 : 1.0 m2487 =>
# EX_m4262 : 1.0 m2529 =>
# EX_m4263 : 1.0 m2552 =
# EX_m4264 : = 1.0 m2569
# EX_m4265 : 1.0 m2573 =>
# EX_m4267 : = 1.0 m2589
# EX_m4270 : 1.0 m2635 =>
# EX_m4271 : 2.0 m2644 + 1.0 m2688 => 2.0 m2681
# EX_m4272 : 1.0 m2661 =>
# EX_m4273 : = 1.0 m2673
# EX_m4274 : 1.0 m2688 =>
# EX_m4275 : = 1.0 m2693
# EX_m4280 : => 1.0 m2805
# EX_m4281 : 2.0 m1822 + 2.0 m2666 + 1.0 m3279 + 1.0 m3342 => 2.0 m1821 + 1.0 m2674 + 1.0 m3274
# EX_m4282 : 1.0 m2838 =>
# EX_m4283 : 1.0 m2843 =>
# EX_m4284 : 1.0 m2681 + 1.0 m2843 => 1.0 m3539
# EX_m4285 : 1.0 m2855 =>
# EX_m4286 : = 1.0 m2857
# EX_m4288 : => 1.0 m2870
# EX_m4292 : => 1.0 m3053
# EX_m4294 : 1.0 m3086 =>
# EX_m4295 : 1.0 m3093 =>
# EX_m4296 : 1.0 m3122 =>
# EX_m4298 : 1.0 m3171 =>
# EX_m4299 : 1.0 m3201 =
# EX_m4301 : 1.0 m3299 =>
# EX_m4304 : 1.0 m1668 + 1.0 m3383 + 1.0 m3543 => 1.0 m1716 + 1.0 m2089
# EX_m4308 : => 1.0 m3498
# EX_m4309 : => 1.0 m3539
# EX_m4311 : => 1.0 m3560
# EX_m4312 : 1.0 m882 + 1.0 m2086 + 1.0 m3265 + 1.0 m3564 => 1.0 m2081 + 1.0 m2666 + 1.0 m3270 + 1.0 m3566
# EX_m4314 : 1.0 m3579 =>
# EX_m4315 : = 1.0 m3615
# EX_m4317 : 2.0 m2681 + 2.0 m3351 + 1.0 m3730 => 2.0 m2688 + 2.0 m3299
# EX_m4318 : 1.0 m3730 =>
# EX_m4323 : = 1.0 m3852
# EX_m4324 : 1.0 m3853 =>
# EX_m4325 : 1.0 m3532 + 1.0 m3853 => 1.0 m845
# EX_m4327 : => 1.0 m3980
# EX_m4328 : => 1.0 m3986
# EX_m4329 : 1.0 m3995 =>
# EX_m4330 : 1.0 m4019 =>
# EX_m4332 : 1.0 m4025 =>
# EX_m4333 : 1.0 m4029 =>
# EX_m4334 : 1.0 m1703 + 1.0 m2674 + 1.0 m4032 => 1.0 m3405 + 1.0 m4030
# EX_m4335 : 1.0 m4037 =>
# EX_m4339 : 1.0 m1841 =>
# HMR_3905 : 1.0 m2404 + 1.0 m3265 = 1.0 m1550 + 1.0 m2666 + 1.0 m3270
# HMR_3907 : 1.0 m2404 + 1.0 m3274 = 1.0 m1550 + 1.0 m2666 + 1.0 m3279
# HMR_4099 : 1.0 m1557 + 1.0 m1718 + 1.0 m2087 = 1.0 m1575 + 1.0 m1671 + 1.0 m3544
# HMR_4137 : 1.0 m2087 + 1.0 m3266 + 1.0 m3613 = 1.0 m1575 + 1.0 m2082 + 1.0 m2669 + 1.0 m3271
# HMR_4281 : 1.0 m2671 + 1.0 m3272 + 1.0 m3612 = 1.0 m3119 + 1.0 m3268
# HMR_4388 : 1.0 m2666 + 1.0 m3270 + 1.0 m3612 = 1.0 m3119 + 1.0 m3265
# HMR_4283 : 1.0 m1550 + 1.0 m2674 + 1.0 m3274 = 1.0 m1555 + 1.0 m2666 + 1.0 m3279
# HMR_8357 : 1.0 m1550 + 1.0 m2677 + 1.0 m3266 = 1.0 m1557 + 1.0 m2669 + 1.0 m3271
# HMR_4379 : 1.0 m1716 + 1.0 m2464 = 1.0 m1604 + 1.0 m2462
# HMR_4301 : 1.0 m2464 + 1.0 m4043 = 1.0 m2462 + 1.0 m3989
# HMR_4355 : 1.0 m2223 + 1.0 m2375 = 1.0 m3674
# HMR_4358 : 1.0 m1604 + 1.0 m3481 = 1.0 m1716 + 1.0 m3612
# HMR_4360 : 1.0 m2674 + 1.0 m3203 + 1.0 m3274 = 1.0 m2666 + 1.0 m3279 + 1.0 m3612
# HMR_4363 : 1.0 m1183 = 1.0 m2674 + 1.0 m3481
# HMR_4368 : 1.0 m396 + 1.0 m1604 = 1.0 m1183 + 1.0 m1716
# HMR_4370 : 1.0 m396 + 1.0 m2674 = 1.0 m1183 + 1.0 m3532
# HMR_4373 : 1.0 m396 + 1.0 m2666 + 1.0 m3270 = 1.0 m2514 + 1.0 m3265 + 1.0 m3532
# HMR_4375 : 1.0 m2223 + 1.0 m2514 = 1.0 m2462
# HMR_4377 : 1.0 m2462 + 1.0 m2674 = 1.0 m2464 + 1.0 m3532
# HMR_4381 : 1.0 m2464 = 1.0 m2554
# HMR_4391 : 1.0 m2223 = 1.0 m2514
# HMR_4394 : 1.0 m1716 + 1.0 m2548 = 1.0 m1604 + 1.0 m2554
# HMR_4396 : 1.0 m2553 = 1.0 m2554
# HMR_6410 : 1.0 m2087 + 1.0 m3105 + 1.0 m3613 = 1.0 m1575 + 1.0 m2082 + 1.0 m2244
# HMR_7745 : 1.0 m1739 = 1.0 m2548
# HMR_7746 : 1.0 m1716 + 1.0 m1739 = 1.0 m1604 + 1.0 m1740
# HMR_7747 : 1.0 m1604 + 1.0 m1739 = 1.0 m1668 + 1.0 m1740
# HMR_7748 : 1.0 m1740 = 1.0 m2554
# HMR_7749 : 1.0 m1740 = 1.0 m2464
# HMR_8757 : 1.0 m2404 + 1.0 m2666 + 1.0 m3279 + 1.0 m3342 = 1.0 m1550 + 2.0 m2674 + 1.0 m3274
# HMR_3989 : 1.0 m2681 + 1.0 m3171 = 2.0 m2552
# HMR_4122 : 1.0 m2563 + 2.0 m2674 + 2.0 m3265 + 1.0 m3999 = 2.0 m2666 + 1.0 m2856 + 2.0 m3270 + 1.0 m3342 + 1.0 m4001
# HMR_8587 : 1.0 m2674 + 1.0 m3171 = 2.0 m2548
# HMR_3944 : 1.0 m2553 + 1.0 m4043 = 1.0 m3543 + 1.0 m3999
# HMR_4128 : 1.0 m3999 => 1.0 m3996
# HMR_4130 : 1.0 m1716 + 1.0 m2485 = 1.0 m1604 + 1.0 m1656
# HMR_4131 : 1.0 m2553 + 1.0 m3996 = 1.0 m1656 + 1.0 m3999
# HMR_4132 : 1.0 m1716 + 1.0 m2485 + 1.0 m3999 = 1.0 m1604 + 1.0 m2553 + 1.0 m3996
# HMR_4774 : 1.0 m1790 + 1.0 m2875 = 1.0 m2116 + 1.0 m2841
# HMR_8767 : 1.0 m1656 + 1.0 m4043 = 1.0 m3543 + 1.0 m3996
# HMR_4297 : 1.0 m1716 + 1.0 m2674 = 1.0 m1604 + 1.0 m3532
# HMR_4319 : 1.0 m1716 + 1.0 m2460 = 1.0 m1604 + 1.0 m2464
# HMR_4383 : 1.0 m2464 => 1.0 m3178
# HMR_4386 : 1.0 m2525 + 1.0 m3543 = 1.0 m2654 + 1.0 m3532
# HMR_4400 : 1.0 m3270 + 1.0 m3274 = 1.0 m3265 + 1.0 m3279
# HMR_4490 : 1.0 m1716 + 1.0 m3172 = 1.0 m1604 + 1.0 m3178
# HMR_1568 : 1.0 m1550 + 1.0 m2674 + 1.0 m3265 = 1.0 m1555 + 1.0 m2666 + 1.0 m3270
# HMR_3853 : 1.0 m2640 + 1.0 m3203 = 1.0 m316
# HMR_3854 : 1.0 m2666 + 1.0 m3203 + 1.0 m3270 = 1.0 m3013 + 1.0 m3265
# HMR_3855 : 1.0 m2666 + 1.0 m3013 + 1.0 m3279 = 1.0 m3274 + 1.0 m3561
# HMR_3857 : 1.0 m316 + 1.0 m2674 = 1.0 m2258 + 1.0 m2640
# HMR_4087 : 1.0 m3159 + 1.0 m3266 = 1.0 m2082 + 1.0 m2669 + 1.0 m3271 + 1.0 m3613
# HMR_4089 : 1.0 m3158 + 1.0 m3274 = 1.0 m2081 + 1.0 m2666 + 1.0 m3279 + 1.0 m3612
# HMR_4091 : 1.0 m3159 + 1.0 m3275 = 1.0 m2082 + 1.0 m2669 + 1.0 m3280 + 1.0 m3613
# HMR_4093 : 1.0 m1574 + 1.0 m2674 = 1.0 m1555 + 1.0 m2086
# HMR_4095 : 1.0 m1575 + 1.0 m2677 = 1.0 m1557 + 1.0 m2087
# HMR_4101 : 1.0 m2654 + 1.0 m3355 = 1.0 m2081 + 1.0 m2525 + 1.0 m3481
# HMR_4193 : 1.0 m1790 + 1.0 m3481 = 1.0 m2116 + 1.0 m3612
# HMR_8497 : 1.0 m2666 + 1.0 m3203 + 1.0 m3279 = 1.0 m2829 + 1.0 m3274
# HMR_8499 : 1.0 m2666 + 1.0 m2829 + 1.0 m3279 + 1.0 m3342 = 2.0 m2674 + 1.0 m3203 + 1.0 m3274
# HMR_8500 : 1.0 m2666 + 1.0 m2829 + 1.0 m3279 = 1.0 m3274 + 1.0 m3561
# HMR_8502 : 1.0 m316 + 1.0 m2666 + 1.0 m3270 = 1.0 m2257 + 1.0 m2640 + 1.0 m3265
# HMR_8503 : 1.0 m2674 + 1.0 m3013 + 1.0 m3265 = 1.0 m2666 + 1.0 m3119 + 1.0 m3270
# HMR_8504 : 1.0 m2257 + 1.0 m2674 + 1.0 m3265 = 1.0 m2258 + 1.0 m2666 + 1.0 m3270
# HMR_8506 : 1.0 m2677 + 1.0 m3013 + 1.0 m3266 = 1.0 m2669 + 1.0 m3120 + 1.0 m3271
# HMR_8507 : 1.0 m3265 + 1.0 m3561 = 1.0 m2257 + 1.0 m2666 + 1.0 m3270
# HMR_8508 : 1.0 m3265 + 1.0 m3561 = 1.0 m2666 + 1.0 m3013 + 1.0 m3270
# HMR_8509 : 1.0 m2257 + 1.0 m2666 + 1.0 m3279 = 1.0 m3274 + 1.0 m3561
# HMR_8511 : 1.0 m316 + 1.0 m2669 + 1.0 m2677 = 1.0 m2258 + 1.0 m2641 + 1.0 m2666
# HMR_8516 : 1.0 m2223 = 1.0 m3203 + 1.0 m3532
# HMR_4280 : 1.0 m2669 + 1.0 m3271 + 1.0 m3613 = 1.0 m3120 + 1.0 m3266
# HMR_0153 : 1.0 m1668 + 1.0 m3543 + 1.0 m3566 = 1.0 m1716 + 1.0 m2086 + 1.0 m3562
# HMR_3797 : 1.0 m1671 + 1.0 m3544 + 1.0 m3567 = 1.0 m1718 + 1.0 m2087 + 1.0 m3563
# HMR_4331 : 1.0 m1668 + 1.0 m3543 + 1.0 m3566 = 1.0 m1716 + 1.0 m2086 + 1.0 m3562
# HMR_4460 : 1.0 m1718 + 1.0 m2087 + 1.0 m3563 = 1.0 m1671 + 1.0 m3544 + 1.0 m3567
# HMR_1434 : 2.0 m2086 + 1.0 m2808 = 3.0 m1574 + 1.0 m2674
# HMR_3163 : 1.0 m1575 + 1.0 m1771 + 1.0 m2413 + 2.0 m2677 + 1.0 m3266 = 1.0 m2087 + 1.0 m2417 + 1.0 m2669 + 1.0 m2809 + 1.0 m3271
# HMR_4306 : 1.0 m2081 + 0.5 m2464 + 1.0 m2514 + 2.0 m2666 + 2.0 m3279 + 0.5 m3675 => 0.5 m2375 + 1.0 m2554 + 1.0 m2674 + 2.0 m3274 + 0.5 m3635
# HMR_4354 : 1.0 m3634 = 1.0 m3635
# HMR_4565 : 1.0 m2514 + 1.0 m3675 = 1.0 m2375 + 1.0 m2464
# HMR_4567 : 1.0 m1604 + 1.0 m3674 = 1.0 m1716 + 1.0 m3675
# HMR_4568 : 1.0 m3674 + 1.0 m3989 = 1.0 m3675 + 1.0 m4043
# HMR_3998 : 1.0 m1604 + 1.0 m2674 = 1.0 m1668 + 1.0 m3532
# HMR_4000 : 1.0 m1716 = 1.0 m1780 + 1.0 m3543
# HMR_4002 : 2.0 m1604 = 1.0 m1668 + 1.0 m1716
# HMR_4004 : 2.0 m1606 = 1.0 m1671 + 1.0 m1718
# HMR_4010 : 1.0 m1668 + 1.0 m2674 = 1.0 m1596 + 1.0 m3532
# HMR_4081 : 1.0 m1675 + 1.0 m2681 = 1.0 m1599 + 1.0 m3539
# HMR_4082 : 1.0 m1671 + 1.0 m2677 = 1.0 m1598 + 1.0 m3535
# HMR_4012 : 1.0 m1596 + 1.0 m1716 = 1.0 m1604 + 1.0 m1668
# HMR_4014 : 1.0 m1780 + 1.0 m2674 = 1.0 m1668
# HMR_4020 : 1.0 m1604 + 1.0 m2525 = 1.0 m1716 + 1.0 m2631
# HMR_4022 : 1.0 m2654 = 1.0 m1806 + 1.0 m3543
# HMR_4038 : 2.0 m436 + 1.0 m1712 + 4.0 m1716 + 1.0 m2081 + 2.0 m2570 + 1.0 m2585 + 1.0 m2674 + 1.0 m3597 => 4.0 m1604 + 1.0 m2465 + 2.0 m2565 + 1.0 m2848 + 4.0 m3532 + 1.0 m3543 + 2.0 m3833
# HMR_4040 : 1.0 m2674 + 1.0 m2848 + 1.0 m3265 = 1.0 m2666 + 1.0 m3270 + 1.0 m4066
# HMR_4042 : 1.0 m1712 + 1.0 m2654 + 1.0 m2848 = 1.0 m1668 + 1.0 m2465 + 1.0 m2525 + 1.0 m3532
# HMR_4048 : 1.0 m1806 + 1.0 m2674 = 1.0 m2631
# HMR_4080 : 1.0 m1668 + 1.0 m2674 = 1.0 m2848 + 1.0 m3295
# HMR_4085 : 1.0 m1668 + 1.0 m3543 = 1.0 m1594 + 1.0 m3597
# HMR_4134 : 1.0 m2635 + 1.0 m3539 => 1.0 m2529 + 1.0 m2681
# HMR_4168 : 1.0 m2654 + 1.0 m2674 = 1.0 m2631 + 1.0 m3543
# HMR_4171 : 1.0 m2525 + 1.0 m3481 = 1.0 m2654 + 1.0 m3612
# HMR_4290 : 1.0 m2681 + 1.0 m2877 => 1.0 m2843 + 1.0 m3539
# HMR_4417 : 1.0 m2674 + 1.0 m2848 = 1.0 m2854 + 1.0 m3532
# HMR_4418 : 1.0 m2848 + 1.0 m3543 = 1.0 m2838 + 1.0 m3597
# HMR_4419 : 1.0 m2631 + 1.0 m2666 + 1.0 m3279 = 1.0 m2848 + 1.0 m3274 + 1.0 m3295
# HMR_4421 : 1.0 m2137 + 1.0 m3481 = 1.0 m2150 + 1.0 m3612
# HMR_4449 : 1.0 m2631 + 1.0 m2674 = 1.0 m2663 + 1.0 m3532
# HMR_4450 : 1.0 m2665 + 1.0 m3539 => 1.0 m2635 + 1.0 m2681
# HMR_4452 : 1.0 m2631 + 1.0 m3543 = 1.0 m2661 + 1.0 m3597
# HMR_4480 : 1.0 m1604 + 1.0 m2137 = 1.0 m1716 + 1.0 m2143
# HMR_4481 : 1.0 m1596 + 1.0 m2674 = 1.0 m2854 + 1.0 m3295
# HMR_4482 : 1.0 m1599 + 1.0 m2681 = 1.0 m2855 + 1.0 m3299
# HMR_4486 : 1.0 m2548 + 1.0 m2875 = 1.0 m2554 + 1.0 m2841
# HMR_4487 : 1.0 m2150 + 1.0 m2548 = 1.0 m2137 + 1.0 m2554
# HMR_4488 : 1.0 m2460 + 1.0 m2875 = 1.0 m2464 + 1.0 m2841
# HMR_4489 : 1.0 m2150 + 1.0 m2460 = 1.0 m2137 + 1.0 m2464
# HMR_4492 : 1.0 m2875 + 1.0 m3172 = 1.0 m2841 + 1.0 m3178
# HMR_4493 : 1.0 m2150 + 1.0 m3172 = 1.0 m2137 + 1.0 m3178
# HMR_4495 : 1.0 m2544 + 1.0 m2875 = 1.0 m2546 + 1.0 m2841
# HMR_4496 : 1.0 m2150 + 1.0 m2544 = 1.0 m2137 + 1.0 m2546
# HMR_4518 : 1.0 m2661 + 1.0 m2674 = 1.0 m3295 + 1.0 m4063
# HMR_4519 : 1.0 m2674 + 1.0 m2838 + 1.0 m3265 = 1.0 m2666 + 1.0 m3270 + 1.0 m4063
# HMR_4520 : 1.0 m2674 + 1.0 m2838 + 1.0 m3342 = 1.0 m2682 + 1.0 m4063
# HMR_4573 : 1.0 m2208 + 1.0 m3481 = 1.0 m2216 + 1.0 m3612
# HMR_4574 : 1.0 m2854 + 1.0 m3532 = 1.0 m2838 + 1.0 m3634
# HMR_4600 : 1.0 m1716 + 1.0 m2193 = 1.0 m1604 + 1.0 m2214
# HMR_4602 : 1.0 m2214 + 1.0 m2674 = 1.0 m2193 + 1.0 m3532
# HMR_4603 : 1.0 m845 + 1.0 m2661 = 1.0 m2193 + 1.0 m3532
# HMR_4611 : 1.0 m1716 + 1.0 m3845 = 1.0 m2150 + 1.0 m2674 + 1.0 m3416
# HMR_4612 : 1.0 m1604 + 1.0 m3845 = 1.0 m2137 + 1.0 m2674 + 1.0 m3416
# HMR_4614 : 1.0 m2654 + 1.0 m3845 = 1.0 m2216 + 1.0 m2674 + 1.0 m3416
# HMR_4615 : 1.0 m2525 + 1.0 m3845 = 1.0 m2208 + 1.0 m2674 + 1.0 m3416
# HMR_4617 : 1.0 m2116 + 1.0 m3845 = 1.0 m2157 + 1.0 m2674 + 1.0 m3416
# HMR_4618 : 1.0 m3845 + 1.0 m4043 = 1.0 m2328 + 1.0 m2674 + 1.0 m3416
# HMR_4619 : 1.0 m1790 + 1.0 m3845 = 1.0 m2153 + 1.0 m2674 + 1.0 m3416
# HMR_4621 : 1.0 m3845 + 1.0 m3989 = 1.0 m2322 + 1.0 m2674 + 1.0 m3416
# HMR_4632 : 1.0 m2143 + 1.0 m2674 = 1.0 m2185 + 1.0 m3532
# HMR_4646 : 1.0 m2674 + 1.0 m3265 + 1.0 m4063 = 1.0 m2666 + 1.0 m3270 + 1.0 m4027
# HMR_4648 : 1.0 m2686 + 1.0 m3268 = 1.0 m2671 + 1.0 m3272 + 1.0 m3348
# HMR_4649 : 1.0 m2674 + 1.0 m3342 + 1.0 m4063 = 1.0 m2682 + 1.0 m4027
# HMR_4651 : 1.0 m2663 + 1.0 m3532 = 1.0 m2661 + 1.0 m3634
# HMR_4663 : 1.0 m2674 + 1.0 m4066 = 1.0 m3634 + 1.0 m4063
# HMR_4694 : 1.0 m2185 + 1.0 m2674 = 1.0 m2196 + 1.0 m3295
# HMR_4695 : 1.0 m845 + 1.0 m1594 = 1.0 m2185 + 1.0 m3532
# HMR_4709 : 1.0 m845 + 1.0 m2838 = 1.0 m2196 + 1.0 m3532
# HMR_5301 : 1.0 m2654 + 1.0 m4034 = 1.0 m2525 + 1.0 m4014
# HMR_5353 : 1.0 m1604 + 1.0 m2208 = 1.0 m1716 + 1.0 m2214
# HMR_7144 : 1.0 m1614 + 1.0 m2666 + 1.0 m3302 = 1.0 m3265 + 1.0 m3635
# HMR_4016 : 1.0 m1604 + 1.0 m2654 = 1.0 m1716 + 1.0 m2525
# HMR_4018 : 1.0 m1606 + 1.0 m2655 = 1.0 m1718 + 1.0 m2527
# HMR_4044 : 1.0 m1604 + 1.0 m2150 = 1.0 m1716 + 1.0 m2137
# HMR_4291 : 1.0 m1604 + 1.0 m2875 = 1.0 m1716 + 1.0 m2841
# HMR_4420 : 1.0 m1606 + 1.0 m2151 = 1.0 m1718 + 1.0 m2138
# HMR_4570 : 1.0 m1604 + 1.0 m2216 = 1.0 m1716 + 1.0 m2208
# HMR_4572 : 1.0 m1606 + 1.0 m2216 = 1.0 m1718 + 1.0 m2208
# HMR_4006 : 1.0 m1604 + 1.0 m4043 = 1.0 m1716 + 1.0 m3989
# HMR_4028 : 1.0 m1604 + 1.0 m2116 = 1.0 m1716 + 1.0 m1790
# HMR_4670 : 1.0 m1604 + 1.0 m2157 = 1.0 m1716 + 1.0 m2153
# HMR_4673 : 1.0 m1604 + 1.0 m2328 = 1.0 m1716 + 1.0 m2322
# HMR_4675 : 1.0 m1718 + 1.0 m2323 = 1.0 m1606 + 1.0 m2329
# HMR_6614 : 1.0 m2137 + 1.0 m2319 = 1.0 m2150 + 1.0 m2313
# HMR_6615 : 1.0 m1718 + 1.0 m2138 = 1.0 m1606 + 1.0 m2151
# HMR_6616 : =
# HMR_4635 : 1.0 m1604 + 1.0 m2319 = 1.0 m1716 + 1.0 m2313
# HMR_3931 : 1.0 m2666 + 1.0 m3279 + 1.0 m3416 = 1.0 m3274 + 1.0 m3845
# HMR_3969 : 1.0 m2875 + 1.0 m4034 = 1.0 m2841 + 1.0 m4014
# HMR_4032 : 1.0 m1716 + 1.0 m3295 + 1.0 m4043 = 1.0 m1604 + 1.0 m2116 + 1.0 m3532
# HMR_4056 : 1.0 m2316 + 1.0 m2674 = 1.0 m3532 + 1.0 m3853
# HMR_4060 : 1.0 m2681 + 1.0 m3995 = 1.0 m3539 + 1.0 m4019
# HMR_4127 : 1.0 m2674 + 1.0 m3999 = 1.0 m2553 + 1.0 m4014
# HMR_4177 : 1.0 m2071 + 1.0 m2674 = 1.0 m2126 + 1.0 m3532
# HMR_4179 : 1.0 m2075 + 1.0 m2681 = 1.0 m2128 + 1.0 m3539
# HMR_4182 : 1.0 m2126 + 1.0 m2654 = 1.0 m2071 + 1.0 m2525
# HMR_4183 : 1.0 m2116 + 2.0 m2681 = 1.0 m2075 + 2.0 m3539
# HMR_4194 : 1.0 m1716 + 1.0 m2570 + 1.0 m2674 + 1.0 m4043 = 1.0 m1604 + 1.0 m2116 + 1.0 m2565 + 1.0 m3532
# HMR_4210 : 1.0 m3481 + 1.0 m3989 = 1.0 m3612 + 1.0 m4043
# HMR_4345 : 1.0 m1734 + 1.0 m2081 + 1.0 m3274 + 1.0 m3295 => 1.0 m2666 + 2.0 m2674 + 1.0 m3279 + 1.0 m4025
# HMR_4470 : 1.0 m3270 + 1.0 m3274 = 1.0 m3265 + 1.0 m3279
# HMR_4484 : 1.0 m1606 + 1.0 m2138 + 1.0 m2313 + 1.0 m2677 = 1.0 m1604 + 1.0 m2151 + 1.0 m3535 + 1.0 m3853
# HMR_4579 : 1.0 m3532 + 1.0 m4034 = 1.0 m3634 + 1.0 m4025
# HMR_4580 : 1.0 m2126 + 1.0 m2674 = 1.0 m3295 + 1.0 m4034
# HMR_4637 : 1.0 m1604 + 1.0 m2313 = 1.0 m1716 + 1.0 m2316
# HMR_4642 : 1.0 m2325 + 1.0 m2674 = 1.0 m2199 + 1.0 m3532
# HMR_4643 : 1.0 m1718 + 1.0 m2329 + 1.0 m2677 = 1.0 m1606 + 1.0 m2323 + 1.0 m3544
# HMR_4644 : 1.0 m1718 + 1.0 m2325 + 1.0 m2444 + 1.0 m2452 + 3.0 m2669 + 1.0 m3271 + 2.0 m3280 => 1.0 m1606 + 1.0 m2240 + 1.0 m2316 + 1.0 m2677 + 1.0 m3266 + 2.0 m3275 + 1.0 m3535
# HMR_4676 : 1.0 m2126 + 1.0 m2328 = 1.0 m2071 + 1.0 m2322
# HMR_5299 : 1.0 m1716 + 1.0 m4034 = 1.0 m1604 + 1.0 m4014
# HMR_5352 : 1.0 m2328 + 1.0 m4034 = 1.0 m2322 + 1.0 m4014
# HMR_6621 : 3.0 m1606 + 1.0 m2322 + 1.0 m2329 + 2.0 m2677 + 1.0 m3417 = 1.0 m1604 + 2.0 m1718 + 1.0 m2323 + 1.0 m3535 + 1.0 m3846 + 1.0 m4034
# HMR_6627 : 1.0 m2313 + 1.0 m3481 = 1.0 m2319 + 1.0 m3612
# HMR_3965 : 1.0 m2322 + 1.0 m2674 = 1.0 m2325 + 1.0 m3532
# HMR_3966 : 1.0 m1718 + 1.0 m2677 = 1.0 m1671 + 1.0 m3544
# HMR_3968 : 1.0 m1604 + 1.0 m2322 = 1.0 m1716 + 1.0 m2325
# HMR_4061 : 1.0 m2681 + 1.0 m4046 = 1.0 m3539 + 1.0 m3995
# HMR_4083 : 1.0 m1598 + 1.0 m1718 = 1.0 m1606 + 1.0 m1671
# HMR_4180 : 1.0 m1716 + 1.0 m2126 = 1.0 m1604 + 1.0 m2071
# HMR_4185 : 1.0 m1716 + 1.0 m2674 + 1.0 m3447 + 1.0 m3769 = 1.0 m1602 + 1.0 m1668 + 1.0 m3532 + 1.0 m3543
# HMR_4186 : 1.0 m1602 + 1.0 m1716 = 1.0 m1604 + 1.0 m3450
# HMR_4507 : 1.0 m2156 + 1.0 m2674 = 1.0 m2325 + 1.0 m3295
# HMR_4516 : 1.0 m2153 + 1.0 m2674 = 1.0 m2156 + 1.0 m3532
# HMR_4680 : 1.0 m845 + 1.0 m4025 = 1.0 m2199 + 1.0 m3532
# HMR_7160 : 0.3 m2150 + 0.2 m2157 + 0.2 m2216 + 0.3 m2319 = 1.0 m2262 + 1.0 m3543
# HMR_7161 : 0.18 m1716 + 0.3 m2116 + 0.34 m2654 + 0.18 m4043 = 1.0 m3543 + 1.0 m3638
# HMR_7162 : 0.18 m1604 + 0.3 m1790 + 0.34 m2525 + 0.18 m3989 = 1.0 m3532 + 1.0 m3638
# HMR_7163 : 1.0 m2262 + 1.0 m2674 = 0.3 m2143 + 0.2 m2156 + 0.2 m2214 + 0.3 m2316
# HMR_7164 : 1.0 m2674 + 1.0 m3638 = 0.18 m1668 + 0.3 m2071 + 0.34 m2631 + 0.18 m4014
# HMR_7713 : 1.0 m1596 + 1.0 m3534 = 1.0 m1668 + 1.0 m2676
# HMR_7716 : 1.0 m3534 + 1.0 m4034 = 1.0 m2676 + 1.0 m4014
# HMR_7721 : 1.0 m2126 + 1.0 m3534 = 1.0 m2071 + 1.0 m2676
# HMR_7725 : 1.0 m3534 + 1.0 m3853 = 1.0 m2316 + 1.0 m2676
# HMR_7728 : 1.0 m2663 + 1.0 m3534 = 1.0 m2631 + 1.0 m2676
# HMR_7800 : 1.0 m1604 + 1.0 m2525 = 1.0 m1668 + 1.0 m2654
# HMR_7802 : 2.0 m2137 = 1.0 m2143 + 1.0 m2150
# HMR_8461 : 1.0 m2153 + 1.0 m2525 = 1.0 m2156 + 1.0 m2654
# HMR_8474 : 1.0 m1716 + 2.0 m2681 = 1.0 m1675 + 2.0 m3539
# HMR_8482 : 1.0 m2669 + 1.0 m3280 + 1.0 m3417 = 1.0 m3275 + 1.0 m3846
# HMR_8486 : 1.0 m1596 + 1.0 m3532 = 1.0 m1594 + 1.0 m3634
# HMR_8487 : 1.0 m2681 + 1.0 m4019 = 1.0 m3539 + 1.0 m4037
# HMR_8489 : 1.0 m2848 + 1.0 m3543 => 1.0 m2674 + 1.0 m2877
# HMR_3802 : 1.0 m1634 + 1.0 m2669 + 1.0 m3271 + 1.0 m3296 = 1.0 m2567 + 1.0 m2677 + 1.0 m3266
# HMR_3804 : 1.0 m1634 + 1.0 m2669 + 1.0 m3280 + 1.0 m3296 = 1.0 m2567 + 1.0 m2677 + 1.0 m3275
# HMR_3829 : 1.0 m1633 + 1.0 m1712 = 1.0 m2565 + 1.0 m3355
# HMR_3831 : 1.0 m1712 = 1.0 m2465 + 1.0 m3295
# HMR_3870 : 1.0 m2646 + 1.0 m2669 + 1.0 m3280 = 2.0 m2641 + 1.0 m3275
# HMR_3890 : 1.0 m1716 + 1.0 m2565 + 1.0 m3295 = 1.0 m1604 + 1.0 m2570 + 1.0 m3532
# HMR_3892 : 1.0 m2570 + 1.0 m2666 + 1.0 m2677 = 1.0 m2567 + 1.0 m2669 + 1.0 m3296
# HMR_4118 : 1.0 m2645 + 1.0 m2666 + 1.0 m3279 = 2.0 m2640 + 1.0 m3274
# HMR_4287 : 1.0 m3271 + 1.0 m3275 = 1.0 m3266 + 1.0 m3280
# HMR_8626 : 1.0 m1575 + 1.0 m1714 + 1.0 m2674 = 1.0 m1555 + 1.0 m1712 + 1.0 m2087
# HMR_3833 : 1.0 m3265 + 1.0 m3279 = 1.0 m3270 + 1.0 m3274
# HMR_3837 : 1.0 m750 + 1.0 m2669 + 1.0 m3271 = 1.0 m3266 + 1.0 m3559
# HMR_3838 : 1.0 m750 + 1.0 m3987 = 1.0 m3559 + 1.0 m3988
# HMR_4075 : 1.0 m3602 + 1.0 m3728 = 2.0 m3719
# HMR_4212 : 2.0 m996 + 2.0 m2682 + 1.0 m3405 + 1.0 m3602 + 1.0 m3728 => 1.0 m2081 + 2.0 m2674 + 2.0 m3342 + 2.0 m3719 + 1.0 m3730
# HMR_4606 : 1.0 m1716 + 1.0 m2674 = 1.0 m1668 + 1.0 m3543
# HMR_4778 : 1.0 m3265 + 1.0 m3279 = 1.0 m3270 + 1.0 m3274
# HMR_4779 : 1.0 m3266 + 1.0 m3922 = 1.0 m2669 + 1.0 m3000 + 1.0 m3271
# HMR_4781 : 1.0 m3275 + 1.0 m3922 = 1.0 m2669 + 1.0 m3000 + 1.0 m3280
# HMR_6929 : 1.0 m2086 + 1.0 m2674 + 1.0 m3228 + 1.0 m3230 + 1.0 m3342 = 1.0 m1553 + 1.0 m1574 + 1.0 m2682 + 1.0 m3602 + 1.0 m3728
# HMR_6938 : 1.0 m2086 + 1.0 m3228 = 1.0 m1574 + 1.0 m3719
# HMR_6939 : =
# HMR_6941 : =
# HMR_6942 : =
# HMR_6943 : =
# HMR_6956 : 1.0 m1553 + 1.0 m2086 + 1.0 m2682 + 1.0 m3228 = 1.0 m1574 + 1.0 m2674 + 1.0 m3230 + 1.0 m3342
# HMR_6958 : 1.0 m2674 + 1.0 m3230 + 1.0 m3342 = 1.0 m1553 + 1.0 m2682 + 1.0 m3719
# HMR_8609 : 1.0 m750 + 1.0 m2669 + 1.0 m3280 = 1.0 m3275 + 1.0 m3559
# HMR_8611 : 1.0 m2413 + 1.0 m3559 = 1.0 m750 + 1.0 m2417
# HMR_0457 : 1.0 m1716 + 1.0 m2581 + 1.0 m2674 + 1.0 m3265 + 1.0 m3274 = 1.0 m1183 + 1.0 m1604 + 2.0 m2666 + 1.0 m3270 + 1.0 m3279
# HMR_3883 : 1.0 m3686 = 1.0 m3295 + 1.0 m3612
# HMR_3939 : =
# HMR_3974 : 1.0 m3686 = 1.0 m3295 + 1.0 m3612
# HMR_4348 : 1.0 m3850 = 1.0 m882 + 1.0 m3295
# HMR_4696 : 1.0 m1964 + 1.0 m2674 + 1.0 m2812 + 1.0 m3265 + 1.0 m3274 + 1.0 m3658 + 1.0 m3667 = 1.0 m2250 + 1.0 m2585 + 3.0 m2666 + 1.0 m3199 + 1.0 m3270 + 1.0 m3279 + 1.0 m3662
# HMR_4700 : 1.0 m2446 + 1.0 m2666 + 1.0 m3279 + 1.0 m3667 = 1.0 m2250 + 1.0 m2674 + 1.0 m3274
# HMR_5392 : 5.0 m1716 + 5.0 m2674 = 5.0 m1604 + 5.0 m3532
# HMR_6409 : 1.0 m2669 + 1.0 m3105 + 1.0 m3271 = 1.0 m2244 + 1.0 m3266
# HMR_8433 : 1.0 m2587 + 1.0 m3105 + 1.0 m3835 = 1.0 m1332 + 1.0 m2082 + 1.0 m2244 + 1.0 m3296
# HMR_8435 : 1.0 m2587 + 1.0 m3266 + 1.0 m3835 = 1.0 m1332 + 1.0 m2082 + 1.0 m2669 + 1.0 m3271 + 1.0 m3296
# HMR_5338 : 1.0 m1574 + 1.0 m2674 = 1.0 m1555 + 1.0 m2086
# HMR_4239 : 1.0 m2244 + 1.0 m3266 = 1.0 m2669 + 1.0 m3105 + 1.0 m3271
# HMR_4596 : 1.0 m1634 + 1.0 m2565 = 1.0 m1633 + 1.0 m2567
# HMR_4681 : 1.0 m2674 + 1.0 m3492 = 1.0 m2682 + 1.0 m3490
# HMR_4683 : 1.0 m2674 + 1.0 m3265 + 1.0 m3490 = 1.0 m2666 + 1.0 m3270 + 1.0 m3492
# HMR_4685 : 1.0 m3266 + 1.0 m3280 = 1.0 m3271 + 1.0 m3275
# HMR_4686 : 1.0 m2666 + 1.0 m3279 + 1.0 m3492 = 1.0 m2674 + 1.0 m3274 + 1.0 m3490
# HMR_8529 : 1.0 m2674 + 1.0 m3202 + 1.0 m3335 + 1.0 m3342 + 1.0 m3662 = 1.0 m1615 + 1.0 m2446 + 1.0 m2682 + 1.0 m3295 + 1.0 m3658
# HMR_6745 : 1.0 m1615 + 1.0 m3295 = 1.0 m3202 + 1.0 m3335
# HMR_6746 : 1.0 m1615 + 1.0 m3295 = 1.0 m3202 + 1.0 m3335
# HMR_6748 : 1.0 m3265 + 1.0 m3279 = 1.0 m3270 + 1.0 m3274
# HMR_6753 : 1.0 m3265 + 1.0 m3279 = 1.0 m3270 + 1.0 m3274
# HMR_6760 : 1.0 m3265 + 1.0 m3279 = 1.0 m3270 + 1.0 m3274
# HMR_6766 : 1.0 m3265 + 1.0 m3279 = 1.0 m3270 + 1.0 m3274
# HMR_6790 : 1.0 m3265 + 1.0 m3279 = 1.0 m3270 + 1.0 m3274
# HMR_6829 : 1.0 m2674 + 1.0 m3450 = 1.0 m3447 + 1.0 m3769
# HMR_6838 : 1.0 m2674 + 1.0 m3450 = 1.0 m3447 + 1.0 m3769
# HMR_6844 : 1.0 m2674 + 1.0 m3450 = 1.0 m3447 + 1.0 m3769
# HMR_6850 : 1.0 m2674 + 1.0 m3450 = 1.0 m3447 + 1.0 m3769
# HMR_3875 : 1.0 m1716 + 2.0 m2674 + 1.0 m3199 + 1.0 m3658 = 1.0 m1596 + 1.0 m2812 + 1.0 m3532 + 1.0 m3543 + 1.0 m3662
# HMR_3868 : 1.0 m2645 + 1.0 m2666 + 1.0 m3270 = 2.0 m2640 + 1.0 m3265
# HMR_3869 : 1.0 m2646 + 1.0 m2669 + 1.0 m3271 = 2.0 m2641 + 1.0 m3266
# HMR_4116 : 2.0 m2640 + 1.0 m2682 = 1.0 m2645 + 2.0 m2674
# HMR_4121 : 2.0 m2641 + 1.0 m2684 = 1.0 m2646 + 2.0 m2677
# HMR_4175 : 1.0 m2640 + 1.0 m2674 = 1.0 m2120 + 1.0 m2565
# HMR_4176 : 1.0 m2644 + 1.0 m2681 = 1.0 m2121 + 1.0 m2569
# HMR_4324 : 1.0 m1637 + 1.0 m1716 + 1.0 m2565 = 1.0 m172 + 1.0 m1604 + 1.0 m3532
# HMR_4328 : 1.0 m2120 + 1.0 m2674 = 1.0 m2122 + 1.0 m2585
# HMR_4329 : 1.0 m2121 + 1.0 m2681 = 1.0 m2124 + 1.0 m2589
# HMR_8769 : 1.0 m1637 + 1.0 m2640 = 1.0 m172 + 1.0 m2121
# HMR_4079 : 1.0 m996 + 1.0 m2674 + 1.0 m3274 = 1.0 m1734 + 1.0 m2666 + 1.0 m3279
# HMR_4174 : 1.0 m1712 => 1.0 m1734 + 1.0 m2081
# HMR_4425 : 1.0 m1716 + 1.0 m2674 = 1.0 m1668 + 1.0 m3543
# HMR_7993 : 1.0 m996 + 1.0 m2674 + 1.0 m3265 = 1.0 m1734 + 1.0 m2666 + 1.0 m3270
# HMR_4494 : 1.0 m1716 + 1.0 m2544 = 1.0 m1604 + 1.0 m2546
# HMR_8367 : 1.0 m2875 + 1.0 m3248 + 1.0 m4043 = 1.0 m2841 + 1.0 m3543 + 1.0 m4004
# HMR_8377 : 1.0 m2116 + 1.0 m3259 = 1.0 m2076 + 1.0 m3543
# HMR_5130 : 1.0 m1716 + 1.0 m3975 + 1.0 m3983 = 1.0 m1668 + 1.0 m3145 + 1.0 m3543
# HMR_5131 : 1.0 m1637 + 1.0 m1716 + 1.0 m3957 = 1.0 m1668 + 1.0 m3020 + 1.0 m3543
# HMR_5132 : 1.0 m1703 + 1.0 m1716 + 1.0 m3958 = 1.0 m1668 + 1.0 m3025 + 1.0 m3543
# HMR_5133 : 1.0 m1709 + 1.0 m1716 + 1.0 m3959 = 1.0 m1668 + 1.0 m3026 + 1.0 m3543
# HMR_5134 : 1.0 m1712 + 1.0 m1716 + 1.0 m3960 = 1.0 m1668 + 1.0 m3027 + 1.0 m3543
# HMR_5135 : 1.0 m1716 + 1.0 m2122 + 1.0 m3961 = 1.0 m1668 + 1.0 m3048 + 1.0 m3543
# HMR_5136 : 1.0 m1716 + 1.0 m2570 + 1.0 m3962 = 1.0 m1668 + 1.0 m3076 + 1.0 m3543
# HMR_5137 : 1.0 m1716 + 1.0 m2565 + 1.0 m3963 = 1.0 m1668 + 1.0 m3077 + 1.0 m3543
# HMR_5138 : 1.0 m1716 + 1.0 m2585 + 1.0 m3964 = 1.0 m1668 + 1.0 m2613 + 1.0 m3543
# HMR_5139 : 1.0 m1716 + 1.0 m2802 + 1.0 m3965 = 1.0 m1668 + 1.0 m3079 + 1.0 m3543
# HMR_5140 : 1.0 m1716 + 1.0 m2867 + 1.0 m3966 = 1.0 m1668 + 1.0 m3116 + 1.0 m3543
# HMR_5141 : 1.0 m1716 + 1.0 m3050 + 1.0 m3967 = 1.0 m1668 + 1.0 m3123 + 1.0 m3543
# HMR_5142 : 1.0 m1716 + 1.0 m3148 + 1.0 m3968 = 1.0 m1668 + 1.0 m3124 + 1.0 m3543
# HMR_5143 : 1.0 m1716 + 1.0 m3199 + 1.0 m3969 = 1.0 m1668 + 1.0 m3126 + 1.0 m3543
# HMR_5145 : 1.0 m1716 + 1.0 m3496 + 1.0 m3970 = 1.0 m1668 + 1.0 m3136 + 1.0 m3543
# HMR_5146 : 1.0 m1716 + 1.0 m3557 + 1.0 m3971 = 1.0 m1668 + 1.0 m3138 + 1.0 m3543
# HMR_5147 : 1.0 m1716 + 1.0 m3686 + 1.0 m3972 = 1.0 m1668 + 1.0 m3139 + 1.0 m3543
# HMR_5148 : 1.0 m1716 + 1.0 m3850 + 1.0 m3973 = 1.0 m1668 + 1.0 m3143 + 1.0 m3543
# HMR_5149 : 1.0 m1716 + 1.0 m3974 + 1.0 m3978 = 1.0 m1668 + 1.0 m3144 + 1.0 m3543
# HMR_5150 : 1.0 m1716 + 1.0 m3976 + 1.0 m4050 = 1.0 m1668 + 1.0 m3146 + 1.0 m3543
# HMR_7261 : 1.0 m1790 + 1.0 m3538 = 1.0 m2116 + 1.0 m2680
# HMR_7308 : 1.0 m294 + 1.0 m3173 = 1.0 m295 + 1.0 m2675
# HMR_7310 : 1.0 m295 + 1.0 m2675 = 1.0 m294 + 1.0 m3173
# HMR_7311 : 1.0 m293 + 1.0 m2675 = 1.0 m288 + 1.0 m3173
# HMR_7313 : 1.0 m295 + 1.0 m2675 = 1.0 m294 + 1.0 m3173
# HMR_7317 : 1.0 m293 + 1.0 m2675 = 1.0 m288 + 1.0 m3173
# HMR_7318 : 1.0 m293 + 1.0 m2675 = 1.0 m288 + 1.0 m3173
# HMR_5169 : 855.0 m1716 + 142.0 m1717 + 21.0 m2613 + 1140.0 m2674 + 142.0 m2676 + 21.0 m3020 + 20.0 m3025 + 11.0 m3026 + 10.0 m3027 + 5.0 m3048 + 17.0 m3076 + 22.0 m3077 + 6.0 m3079 + 10.0 m3116 + 31.0 m3123 + 19.0 m3124 + 12.0 m3126 + 6.0 m3136 + 12.0 m3138 + 20.0 m3139 + 12.0 m3143 + 5.0 m3144 + 4.0 m3145 + 21.0 m3146 = 855.0 m1604 + 142.0 m1605 + 21.0 m1638 + 20.0 m1704 + 11.0 m1710 + 10.0 m1713 + 5.0 m2123 + 22.0 m2566 + 17.0 m2571 + 21.0 m2586 + 6.0 m2803 + 10.0 m2868 + 31.0 m3051 + 19.0 m3149 + 12.0 m3200 + 6.0 m3497 + 855.0 m3532 + 142.0 m3534 + 12.0 m3558 + 20.0 m3687 + 12.0 m3851 + 21.0 m3957 + 20.0 m3958 + 11.0 m3959 + 10.0 m3960 + 5.0 m3961 + 17.0 m3962 + 22.0 m3963 + 21.0 m3964 + 6.0 m3965 + 10.0 m3966 + 31.0 m3967 + 19.0 m3968 + 12.0 m3969 + 6.0 m3970 + 12.0 m3971 + 20.0 m3972 + 12.0 m3973 + 5.0 m3974 + 4.0 m3975 + 21.0 m3976 + 5.0 m3979 + 4.0 m3984 + 21.0 m4051
# HMR_5170 : 579.0 m1716 + 96.0 m1717 + 13.0 m2613 + 772.0 m2674 + 96.0 m2676 + 10.0 m3020 + 4.0 m3025 + 3.0 m3026 + 9.0 m3027 + 8.0 m3048 + 4.0 m3076 + 11.0 m3077 + 3.0 m3079 + 12.0 m3116 + 28.0 m3123 + 11.0 m3124 + 4.0 m3126 + 5.0 m3136 + 19.0 m3138 + 20.0 m3139 + 10.0 m3143 + 3.0 m3144 + 4.0 m3145 + 12.0 m3146 = 579.0 m1604 + 96.0 m1605 + 10.0 m1638 + 4.0 m1704 + 3.0 m1710 + 9.0 m1713 + 8.0 m2123 + 11.0 m2566 + 4.0 m2571 + 13.0 m2586 + 3.0 m2803 + 12.0 m2868 + 28.0 m3051 + 11.0 m3149 + 4.0 m3200 + 5.0 m3497 + 579.0 m3532 + 96.0 m3534 + 19.0 m3558 + 20.0 m3687 + 10.0 m3851 + 10.0 m3957 + 4.0 m3958 + 3.0 m3959 + 9.0 m3960 + 8.0 m3961 + 4.0 m3962 + 11.0 m3963 + 13.0 m3964 + 3.0 m3965 + 12.0 m3966 + 28.0 m3967 + 11.0 m3968 + 4.0 m3969 + 5.0 m3970 + 19.0 m3971 + 20.0 m3972 + 10.0 m3973 + 3.0 m3974 + 4.0 m3975 + 12.0 m3976 + 3.0 m3979 + 4.0 m3984 + 12.0 m4051
# HMR_5172 : 1225.0 m1716 + 18.0 m2613 + 1575.0 m2674 + 22.0 m3020 + 12.0 m3025 + 12.0 m3026 + 26.0 m3027 + 6.0 m3048 + 14.0 m3076 + 15.0 m3077 + 9.0 m3079 + 12.0 m3116 + 39.0 m3123 + 18.0 m3124 + 8.0 m3126 + 20.0 m3136 + 15.0 m3138 + 31.0 m3139 + 25.0 m3143 + 7.0 m3144 + 13.0 m3145 + 28.0 m3146 = 1225.0 m1604 + 22.0 m1637 + 12.0 m1703 + 12.0 m1709 + 26.0 m1712 + 6.0 m2122 + 15.0 m2565 + 14.0 m2570 + 18.0 m2585 + 9.0 m2802 + 12.0 m2867 + 39.0 m3050 + 18.0 m3148 + 8.0 m3199 + 20.0 m3496 + 1225.0 m3532 + 15.0 m3557 + 31.0 m3686 + 25.0 m3850 + 22.0 m3957 + 12.0 m3958 + 12.0 m3959 + 26.0 m3960 + 6.0 m3961 + 14.0 m3962 + 15.0 m3963 + 18.0 m3964 + 9.0 m3965 + 12.0 m3966 + 39.0 m3967 + 18.0 m3968 + 8.0 m3969 + 20.0 m3970 + 15.0 m3971 + 31.0 m3972 + 25.0 m3973 + 7.0 m3974 + 13.0 m3975 + 28.0 m3976 + 7.0 m3978 + 13.0 m3983 + 28.0 m4050
# HMR_7617 : 1.0 m1716 + 1.0 m2674 = 1.0 m1604 + 1.0 m3532
# HMR_7621 : 1.0 m3265 = 1.0 m1614 + 1.0 m3304
# HMR_7624 : 1.0 m2674 + 1.0 m3265 = 1.0 m1614 + 1.0 m2666 + 1.0 m3304
# HMR_4187 : 1.0 m2674 + 1.0 m3450 = 1.0 m1602 + 1.0 m3532
# HMR_4701 : 1.0 m2250 + 1.0 m3658 = 1.0 m3662 + 1.0 m3667
# HMR_8662 : 1.0 m1606 + 1.0 m2655 = 1.0 m1718 + 1.0 m2527
# HMR_8667 : 1.0 m1606 + 1.0 m2655 = 1.0 m1718 + 1.0 m2527
# HMR_0710 : 1.0 m2864 + 1.0 m3274 = 1.0 m1633 + 1.0 m2081 + 1.0 m2666 + 1.0 m3279
# HMR_3957 : 1.0 m2865 + 1.0 m3266 = 1.0 m1634 + 1.0 m2082 + 1.0 m2669 + 1.0 m3271
# HMR_3958 : 1.0 m2865 + 1.0 m3275 = 1.0 m1634 + 1.0 m2082 + 1.0 m2669 + 1.0 m3280
# HMR_4111 : 1.0 m2864 + 1.0 m3274 = 1.0 m1633 + 1.0 m2081 + 1.0 m2666 + 1.0 m3279
# HMR_4112 : 1.0 m3414 = 1.0 m1634 + 1.0 m2082
# HMR_4113 : =
# HMR_4139 : 1.0 m2666 + 1.0 m3270 + 1.0 m3355 = 1.0 m3158 + 1.0 m3265
# HMR_4141 : 1.0 m2669 + 1.0 m3271 + 1.0 m3356 = 1.0 m3159 + 1.0 m3266
# HMR_4145 : 1.0 m2064 + 1.0 m2087 = 1.0 m1575 + 1.0 m2677 + 1.0 m3356
# HMR_4147 : 1.0 m2087 + 1.0 m2655 + 1.0 m3764 = 1.0 m2527 + 1.0 m3535 + 1.0 m3767
# HMR_4149 : 1.0 m1716 + 1.0 m2063 + 1.0 m2086 = 1.0 m1574 + 1.0 m1604 + 1.0 m3355 + 1.0 m3532
# HMR_4152 : 1.0 m1606 + 1.0 m3535 + 1.0 m3767 = 1.0 m1718 + 1.0 m2087 + 1.0 m3764
# HMR_4209 : 1.0 m1634 + 1.0 m3105 = 1.0 m2082 + 1.0 m3743
# HMR_4408 : 1.0 m2465 + 1.0 m2674 = 1.0 m3158
# HMR_4410 : 1.0 m2466 + 1.0 m2677 = 1.0 m3159
# HMR_4454 : 1.0 m2063 = 1.0 m2864
# HMR_4456 : 1.0 m2064 = 1.0 m2865
# HMR_4458 : 1.0 m2865 = 1.0 m2064
# HMR_4586 : 1.0 m2669 + 1.0 m3280 + 1.0 m3414 = 1.0 m2865 + 1.0 m3275
# HMR_4588 : 1.0 m2669 + 1.0 m3271 + 1.0 m3414 = 1.0 m2865 + 1.0 m3266
# HMR_4652 : 1.0 m2466 + 1.0 m3987 = 1.0 m3764 + 1.0 m3988
# HMR_5294 : 1.0 m2064 = 1.0 m1557 + 1.0 m3356
# HMR_5297 : 1.0 m1634 + 1.0 m2087 + 1.0 m3266 = 1.0 m2082 + 1.0 m2669 + 1.0 m3271 + 1.0 m3767
# HMR_6411 : 1.0 m1634 + 1.0 m3105 = 1.0 m2082 + 1.0 m3743
# HMR_6414 : 1.0 m2087 + 1.0 m3743 = 1.0 m2244 + 1.0 m3767
# HMR_8743 : 1.0 m2417 + 1.0 m2466 = 1.0 m2413 + 1.0 m3764
# HMR_3975 : 1.0 m2680 + 1.0 m3543 = 1.0 m3532 + 1.0 m3538
# HMR_3977 : 1.0 m2674 + 1.0 m3543 = 2.0 m3532
# HMR_6911 : 1.0 m2417 + 1.0 m3988 = 1.0 m2413 + 1.0 m3987
# HMR_6912 : 1.0 m2677 + 1.0 m3544 = 2.0 m3535
# HMR_6914 : 12.0 m2669 + 1.0 m3344 + 2.0 m3987 = 12.0 m2666 + 2.0 m2677 + 2.0 m3988
# HMR_6916 : 1.0 m1606 + 4.0 m2666 + 1.0 m3535 = 1.0 m1718 + 4.0 m2669 + 1.0 m2677
# HMR_6921 : 5.0 m2669 + 1.0 m3271 + 1.0 m3988 = 4.0 m2666 + 1.0 m3266 + 1.0 m3987
# HMR_3960 : 2.0 m2666 + 2.0 m3343 = 1.0 m2682 + 1.0 m3342
# HMR_8409 : 2.0 m2673 + 2.0 m3352 = 1.0 m2688 + 1.0 m3351
# HMR_8410 : 1.0 m2669 + 1.0 m3343 = 0.5 m2684 + 0.5 m3344
# HMR_0188 : 1.0 m1668 + 1.0 m3032 + 1.0 m3543 = 1.0 m1716 + 1.0 m2086 + 1.0 m3029
# HMR_0192 : 1.0 m1668 + 1.0 m3543 + 1.0 m3942 = 1.0 m1716 + 1.0 m2086 + 1.0 m3945
# HMR_0196 : 1.0 m1668 + 1.0 m3219 + 1.0 m3543 = 1.0 m1716 + 1.0 m2086 + 1.0 m3215
# HMR_0200 : 1.0 m260 + 1.0 m1716 + 1.0 m2086 = 1.0 m263 + 1.0 m1668 + 1.0 m3543
# HMR_0204 : 1.0 m226 + 1.0 m1716 + 1.0 m2086 = 1.0 m229 + 1.0 m1668 + 1.0 m3543
# HMR_0209 : 1.0 m1431 + 1.0 m1668 + 1.0 m3543 = 1.0 m1716 + 1.0 m2086 + 1.0 m3519
# HMR_0213 : 1.0 m1668 + 1.0 m3466 + 1.0 m3543 = 1.0 m1716 + 1.0 m2086 + 1.0 m3469
# HMR_0217 : 1.0 m1668 + 1.0 m3439 + 1.0 m3543 = 1.0 m1716 + 1.0 m2086 + 1.0 m3424
# HMR_0226 : 1.0 m1668 + 1.0 m3435 + 1.0 m3543 = 1.0 m1716 + 1.0 m2086 + 1.0 m3429
# HMR_0233 : 1.0 m1492 + 1.0 m1668 + 1.0 m3543 = 1.0 m1498 + 1.0 m1716 + 1.0 m2086
# HMR_0237 : 1.0 m1668 + 1.0 m2750 + 1.0 m3543 = 1.0 m1716 + 1.0 m2086 + 1.0 m3179
# HMR_0241 : 1.0 m4 + 1.0 m1716 + 1.0 m2086 = 1.0 m7 + 1.0 m1668 + 1.0 m3543
# HMR_0245 : 1.0 m1539 + 1.0 m1668 + 1.0 m3543 = 1.0 m1542 + 1.0 m1716 + 1.0 m2086
# HMR_0249 : 1.0 m1668 + 1.0 m3543 + 1.0 m3758 = 1.0 m1716 + 1.0 m2086 + 1.0 m3748
# HMR_0255 : 1.0 m47 + 1.0 m1716 + 1.0 m2086 = 1.0 m50 + 1.0 m1668 + 1.0 m3543
# HMR_0259 : 1.0 m1668 + 1.0 m2059 + 1.0 m3543 = 1.0 m1716 + 1.0 m2056 + 1.0 m2086
# HMR_0263 : 1.0 m1716 + 1.0 m2086 + 1.0 m3384 = 1.0 m1668 + 1.0 m3388 + 1.0 m3543
# HMR_0267 : 1.0 m257 + 1.0 m1668 + 1.0 m3543 = 1.0 m1716 + 1.0 m2086 + 1.0 m2361
# HMR_0271 : 1.0 m223 + 1.0 m1668 + 1.0 m3543 = 1.0 m221 + 1.0 m1716 + 1.0 m2086
# HMR_0275 : 1.0 m190 + 1.0 m1716 + 1.0 m2086 = 1.0 m196 + 1.0 m1668 + 1.0 m3543
# HMR_0279 : 1.0 m1668 + 1.0 m3324 + 1.0 m3543 = 1.0 m1716 + 1.0 m2086 + 1.0 m3327
# HMR_0283 : 1.0 m1668 + 1.0 m2345 + 1.0 m3543 = 1.0 m1716 + 1.0 m2086 + 1.0 m2339
# HMR_0289 : 1.0 m40 + 1.0 m1716 + 1.0 m2086 = 1.0 m43 + 1.0 m1668 + 1.0 m3543
# HMR_0293 : 1.0 m14 + 1.0 m1668 + 1.0 m3543 = 1.0 m1716 + 1.0 m2053 + 1.0 m2086
# HMR_0297 : 1.0 m1533 + 1.0 m1716 + 1.0 m2086 = 1.0 m1536 + 1.0 m1668 + 1.0 m3543
# HMR_0301 : 1.0 m245 + 1.0 m1668 + 1.0 m3543 = 1.0 m1510 + 1.0 m1716 + 1.0 m2086
# HMR_0305 : 1.0 m181 + 1.0 m1668 + 1.0 m3543 = 1.0 m1716 + 1.0 m2086 + 1.0 m3182
# HMR_0309 : 1.0 m1668 + 1.0 m2701 + 1.0 m3543 = 1.0 m1716 + 1.0 m2086 + 1.0 m2704
# HMR_0313 : 1.0 m1668 + 1.0 m2271 + 1.0 m3543 = 1.0 m1716 + 1.0 m1723 + 1.0 m2086
# HMR_0319 : 1.0 m36 + 1.0 m1668 + 1.0 m3543 = 1.0 m1716 + 1.0 m2050 + 1.0 m2086
# HMR_0323 : 1.0 m11 + 1.0 m1668 + 1.0 m3543 = 1.0 m1716 + 1.0 m2047 + 1.0 m2086
# HMR_0327 : 1.0 m1668 + 1.0 m3543 + 1.0 m3935 = 1.0 m1716 + 1.0 m2086 + 1.0 m3930
# HMR_0331 : 1.0 m1668 + 1.0 m3543 + 1.0 m3813 = 1.0 m1716 + 1.0 m2086 + 1.0 m3081
# HMR_0337 : 1.0 m64 + 1.0 m1668 + 1.0 m3543 = 1.0 m1716 + 1.0 m2086 + 1.0 m3289
# HMR_0341 : 1.0 m1668 + 1.0 m2773 + 1.0 m3543 = 1.0 m1716 + 1.0 m1803 + 1.0 m2086
# HMR_0345 : 1.0 m1668 + 1.0 m2778 + 1.0 m3543 = 1.0 m1716 + 1.0 m2086 + 1.0 m4069
# HMR_0349 : 1.0 m1668 + 1.0 m3097 + 1.0 m3543 = 1.0 m1716 + 1.0 m2086 + 1.0 m3093
# HMR_0353 : 1.0 m202 + 1.0 m1668 + 1.0 m3543 = 1.0 m1716 + 1.0 m2086 + 1.0 m3752
# HMR_0357 : 1.0 m251 + 1.0 m1668 + 1.0 m3543 = 1.0 m1716 + 1.0 m2086 + 1.0 m3392
# HMR_0361 : 1.0 m187 + 1.0 m1668 + 1.0 m3543 = 1.0 m1716 + 1.0 m2086 + 1.0 m2369
# HMR_0365 : 1.0 m239 + 1.0 m1668 + 1.0 m3543 = 1.0 m1716 + 1.0 m2086 + 1.0 m2301
# HMR_0369 : 1.0 m279 + 1.0 m1716 + 1.0 m2086 = 1.0 m276 + 1.0 m1668 + 1.0 m3543
# HMR_0373 : 1.0 m218 + 1.0 m1716 + 1.0 m2086 = 1.0 m215 + 1.0 m1668 + 1.0 m3543
# HMR_0377 : 1.0 m168 + 1.0 m1668 + 1.0 m3543 = 1.0 m1716 + 1.0 m2086 + 1.0 m2219
# HMR_0381 : 1.0 m24 + 1.0 m1716 + 1.0 m2086 = 1.0 m30 + 1.0 m1668 + 1.0 m3543
# HMR_0385 : 1.0 m516 + 1.0 m1716 + 1.0 m2086 = 1.0 m522 + 1.0 m1668 + 1.0 m3543
# HMR_0389 : 1.0 m420 + 1.0 m1716 + 1.0 m2086 = 1.0 m425 + 1.0 m1668 + 1.0 m3543
# HMR_0393 : 1.0 m479 + 1.0 m1716 + 1.0 m2086 = 1.0 m483 + 1.0 m1668 + 1.0 m3543
# HMR_0397 : 1.0 m1668 + 1.0 m3100 + 1.0 m3543 = 1.0 m1716 + 1.0 m2086 + 1.0 m3086
# HMR_0401 : 1.0 m1668 + 1.0 m2504 + 1.0 m3543 = 1.0 m1716 + 1.0 m2086 + 1.0 m2498
# HMR_0405 : 1.0 m1668 + 1.0 m2235 + 1.0 m3543 = 1.0 m1716 + 1.0 m2086 + 1.0 m2231
# HMR_0409 : 1.0 m1668 + 1.0 m1699 + 1.0 m3543 = 1.0 m1690 + 1.0 m1716 + 1.0 m2086
# HMR_0413 : 1.0 m233 + 1.0 m1668 + 1.0 m3543 = 1.0 m1617 + 1.0 m1716 + 1.0 m2086
# HMR_0417 : 1.0 m271 + 1.0 m1716 + 1.0 m2086 = 1.0 m268 + 1.0 m1668 + 1.0 m3543
# HMR_0421 : 1.0 m210 + 1.0 m1716 + 1.0 m2086 = 1.0 m207 + 1.0 m1668 + 1.0 m3543
# HMR_0425 : 1.0 m165 + 1.0 m1716 + 1.0 m2086 = 1.0 m161 + 1.0 m1668 + 1.0 m3543
# HMR_0429 : 1.0 m18 + 1.0 m1716 + 1.0 m2086 = 1.0 m21 + 1.0 m1668 + 1.0 m3543
# HMR_0433 : 1.0 m53 + 1.0 m1716 + 1.0 m2086 = 1.0 m59 + 1.0 m1668 + 1.0 m3543
# HMR_0437 : 1.0 m431 + 1.0 m1668 + 1.0 m3543 = 1.0 m434 + 1.0 m1716 + 1.0 m2086
# HMR_2942 : 1.0 m1674 + 1.0 m3547 = 1.0 m1721 + 1.0 m2680
# HMR_2943 : 1.0 m1674 + 1.0 m3547 = 1.0 m1721 + 1.0 m2680
# HMR_2944 : 1.0 m1674 + 1.0 m3547 = 1.0 m1721 + 1.0 m2680
# HMR_2945 : 1.0 m1674 + 1.0 m3547 = 1.0 m1721 + 1.0 m2680
# HMR_2946 : 1.0 m1721 + 1.0 m2680 = 1.0 m1674 + 1.0 m3547
# HMR_2947 : 1.0 m1721 + 1.0 m2680 = 1.0 m1674 + 1.0 m3547
# HMR_2948 : 1.0 m1674 + 1.0 m3547 = 1.0 m1721 + 1.0 m2680
# HMR_2949 : 1.0 m1674 + 1.0 m3547 = 1.0 m1721 + 1.0 m2680
# HMR_2951 : 1.0 m1674 + 1.0 m3547 = 1.0 m1721 + 1.0 m2680
# HMR_2952 : 1.0 m1674 + 1.0 m3547 = 1.0 m1721 + 1.0 m2680
# HMR_2954 : 1.0 m1674 + 1.0 m3547 = 1.0 m1721 + 1.0 m2680
# HMR_2955 : 1.0 m1721 + 1.0 m2680 = 1.0 m1674 + 1.0 m3547
# HMR_2956 : 1.0 m1674 + 1.0 m3547 = 1.0 m1721 + 1.0 m2680
# HMR_2957 : 1.0 m1674 + 1.0 m3547 = 1.0 m1721 + 1.0 m2680
# HMR_2959 : 1.0 m1721 + 1.0 m2680 = 1.0 m1674 + 1.0 m3547
# HMR_2961 : 1.0 m1674 + 1.0 m3547 = 1.0 m1721 + 1.0 m2680
# HMR_2962 : 1.0 m1721 + 1.0 m2680 = 1.0 m1674 + 1.0 m3547
# HMR_2963 : 1.0 m1674 + 1.0 m3547 = 1.0 m1721 + 1.0 m2680
# HMR_2964 : 1.0 m1721 + 1.0 m2680 = 1.0 m1674 + 1.0 m3547
# HMR_2965 : 1.0 m1674 + 1.0 m3547 = 1.0 m1721 + 1.0 m2680
# HMR_2966 : 1.0 m1674 + 1.0 m3547 = 1.0 m1721 + 1.0 m2680
# HMR_2967 : 1.0 m1674 + 1.0 m3547 = 1.0 m1721 + 1.0 m2680
# HMR_2968 : 1.0 m1721 + 1.0 m2680 = 1.0 m1674 + 1.0 m3547
# HMR_2969 : 1.0 m1721 + 1.0 m2680 = 1.0 m1674 + 1.0 m3547
# HMR_2970 : 1.0 m1674 + 1.0 m3547 = 1.0 m1721 + 1.0 m2680
# HMR_2971 : 1.0 m1674 + 1.0 m3547 = 1.0 m1721 + 1.0 m2680
# HMR_2972 : 1.0 m1674 + 1.0 m3547 = 1.0 m1721 + 1.0 m2680
# HMR_2973 : 1.0 m1674 + 1.0 m3547 = 1.0 m1721 + 1.0 m2680
# HMR_2974 : 1.0 m1674 + 1.0 m3547 = 1.0 m1721 + 1.0 m2680
# HMR_2975 : 1.0 m1674 + 1.0 m3547 = 1.0 m1721 + 1.0 m2680
# HMR_2976 : 1.0 m1674 + 1.0 m3547 = 1.0 m1721 + 1.0 m2680
# HMR_2977 : 1.0 m1674 + 1.0 m3547 = 1.0 m1721 + 1.0 m2680
# HMR_2978 : 1.0 m1674 + 1.0 m3547 = 1.0 m1721 + 1.0 m2680
# HMR_2979 : 1.0 m1674 + 1.0 m3547 = 1.0 m1721 + 1.0 m2680
# HMR_2980 : 1.0 m1674 + 1.0 m3547 = 1.0 m1721 + 1.0 m2680
# HMR_2981 : 1.0 m1674 + 1.0 m3547 = 1.0 m1721 + 1.0 m2680
# HMR_2982 : 1.0 m1674 + 1.0 m3547 = 1.0 m1721 + 1.0 m2680
# HMR_2983 : 1.0 m1674 + 1.0 m3547 = 1.0 m1721 + 1.0 m2680
# HMR_2984 : 1.0 m1674 + 1.0 m3547 = 1.0 m1721 + 1.0 m2680
# HMR_2985 : 1.0 m1674 + 1.0 m3547 = 1.0 m1721 + 1.0 m2680
# HMR_2986 : 1.0 m1721 + 1.0 m2680 = 1.0 m1674 + 1.0 m3547
# HMR_2987 : 1.0 m1721 + 1.0 m2680 = 1.0 m1674 + 1.0 m3547
# HMR_2988 : 1.0 m1674 + 1.0 m3547 = 1.0 m1721 + 1.0 m2680
# HMR_2989 : 1.0 m1721 + 1.0 m2680 = 1.0 m1674 + 1.0 m3547
# HMR_2990 : 1.0 m1721 + 1.0 m2680 = 1.0 m1674 + 1.0 m3547
# HMR_2991 : 1.0 m1674 + 1.0 m3547 = 1.0 m1721 + 1.0 m2680
# HMR_2992 : 1.0 m1674 + 1.0 m3547 = 1.0 m1721 + 1.0 m2680
# HMR_2994 : 1.0 m1674 + 1.0 m3547 = 1.0 m1721 + 1.0 m2680
# HMR_2996 : 1.0 m1674 + 1.0 m3547 = 1.0 m1721 + 1.0 m2680
# HMR_2998 : 1.0 m1674 + 1.0 m3547 = 1.0 m1721 + 1.0 m2680
# HMR_2999 : 1.0 m1721 + 1.0 m2680 = 1.0 m1674 + 1.0 m3547
# HMR_3000 : 1.0 m1721 + 1.0 m2680 = 1.0 m1674 + 1.0 m3547
# HMR_3001 : 1.0 m1721 + 1.0 m2680 = 1.0 m1674 + 1.0 m3547
# HMR_3002 : 1.0 m1721 + 1.0 m2680 = 1.0 m1674 + 1.0 m3547
# HMR_3003 : 1.0 m1721 + 1.0 m2680 = 1.0 m1674 + 1.0 m3547
# HMR_2152 : 1.0 m1574 + 12.0 m2666 + 6.0 m3162 + 12.0 m3279 => 5.0 m344 + 6.0 m2081 + 1.0 m2086 + 6.0 m2674 + 12.0 m3274 + 1.0 m3816
# HMR_2178 : 2.0 m2666 + 1.0 m3162 + 2.0 m3279 + 1.0 m3816 => 2.0 m344 + 1.0 m2081 + 2.0 m3274 + 1.0 m3424
# HMR_4156 : 1.0 m1574 + 1.0 m1716 + 1.0 m2666 + 1.0 m2691 = 1.0 m1604 + 1.0 m3166 + 1.0 m3532
# HMR_2286 : 1.0 m2666 + 1.0 m3279 + 1.0 m3342 + 1.0 m3439 = 2.0 m2674 + 1.0 m3274 + 1.0 m3435
# HMR_2287 : 1.0 m2666 + 1.0 m3279 + 1.0 m3342 + 1.0 m3439 = 1.0 m1492 + 2.0 m2674 + 1.0 m3274
# HMR_2293 : 1.0 m2666 + 1.0 m3279 + 1.0 m3342 + 1.0 m3758 = 1.0 m2059 + 2.0 m2674 + 1.0 m3274
# HMR_2294 : 1.0 m2666 + 1.0 m3279 + 1.0 m3342 + 1.0 m3758 => 2.0 m2674 + 1.0 m3274 + 1.0 m3388
# HMR_0709 : 1.0 m2679 + 1.0 m3441 = 1.0 m2089 + 1.0 m3426
# HMR_2151 : 1.0 m344 + 1.0 m3166 => 1.0 m2086 + 1.0 m3162
# HMR_2177 : 1.0 m2674 + 1.0 m3816 = 1.0 m344 + 1.0 m3215
# HMR_2472 : 1.0 m2666 + 1.0 m3097 + 1.0 m3279 + 1.0 m3342 = 1.0 m202 + 2.0 m2674 + 1.0 m3274
# HMR_2475 : 1.0 m202 + 2.0 m2666 + 1.0 m3166 + 2.0 m3279 = 1.0 m251 + 1.0 m2081 + 1.0 m2086 + 1.0 m2674 + 2.0 m3274
# HMR_2484 : 1.0 m251 + 1.0 m2666 + 1.0 m3279 + 1.0 m3342 => 1.0 m187 + 2.0 m2674 + 1.0 m3274
# HMR_2515 : 1.0 m233 + 1.0 m2081 + 1.0 m2086 + 1.0 m2674 + 2.0 m3274 => 1.0 m251 + 2.0 m2666 + 1.0 m3166 + 2.0 m3279
# HMR_2368 : 1.0 m2666 + 1.0 m3100 + 1.0 m3279 + 1.0 m3342 = 1.0 m2504 + 2.0 m2674 + 1.0 m3274
# HMR_2380 : 1.0 m2235 + 1.0 m2666 + 1.0 m3279 + 1.0 m3342 => 1.0 m1699 + 2.0 m2674 + 1.0 m3274
# HMR_3444 : 1.0 m1699 + 9.0 m2087 + 7.0 m2413 + 8.0 m2677 + 9.0 m3266 + 2.0 m3280 + 1.0 m3344 = 8.0 m1575 + 1.0 m1771 + 1.0 m2086 + 7.0 m2417 + 7.0 m2669 + 1.0 m2684 + 9.0 m3271 + 2.0 m3275
# HMR_0942 : 1.0 m2412 + 1.0 m2666 + 1.0 m3279 = 1.0 m2416 + 1.0 m3274
# HMR_0946 : 1.0 m2412 + 1.0 m2666 + 1.0 m3279 = 1.0 m2416 + 1.0 m3274
# HMR_0950 : 1.0 m2412 + 1.0 m2666 + 1.0 m3279 = 1.0 m2416 + 1.0 m3274
# HMR_0954 : 1.0 m2412 + 1.0 m2666 + 1.0 m3279 = 1.0 m2416 + 1.0 m3274
# HMR_0958 : 1.0 m1690 + 1.0 m3342 = 1.0 m1327
# HMR_0959 : 1.0 m1327 = 1.0 m2674 + 1.0 m3054
# HMR_0960 : 1.0 m1327 + 2.0 m2640 + 2.0 m2666 + 1.0 m3342 = 1.0 m2645 + 2.0 m2674 + 1.0 m3057
# HMR_0963 : 1.0 m770 + 1.0 m2646 + 2.0 m2677 + 2.0 m3271 + 2.0 m3275 = 1.0 m1327 + 2.0 m2641 + 2.0 m2669 + 2.0 m3266 + 2.0 m3280 + 2.0 m3344
# HMR_0983 : 1.0 m1342 + 1.0 m1690 + 1.0 m2674 + 1.0 m3274 = 1.0 m571 + 1.0 m2666 + 1.0 m3054 + 1.0 m3279
# HMR_1010 : 1.0 m1342 + 2.0 m2674 = 1.0 m571 + 2.0 m2666 + 1.0 m3342
# HMR_1015 : 1.0 m571 + 1.0 m3342 = 1.0 m1342 + 1.0 m2682
# HMR_1029 : 1.0 m1690 + 2.0 m2640 + 2.0 m2666 + 2.0 m3342 = 1.0 m2645 + 2.0 m2674 + 1.0 m3057
# HMR_1080 : 1.0 m2674 + 1.0 m3054 = 1.0 m3057
# HMR_1100 : 4.0 m2666 + 1.0 m3057 + 4.0 m3279 + 3.0 m3342 = 1.0 m770 + 4.0 m2674 + 4.0 m3274
# HMR_1101 : 1.0 m3266 + 1.0 m3280 = 1.0 m3271 + 1.0 m3275
# HMR_1105 : 1.0 m3272 + 1.0 m3277 = 1.0 m3268 + 1.0 m3282
# HMR_1126 : 1.0 m3057 + 2.0 m3265 + 2.0 m3279 + 1.0 m3342 = 1.0 m770 + 2.0 m3270 + 2.0 m3274
# HMR_8557 : 1.0 m1690 + 1.0 m2666 + 1.0 m3279 + 2.0 m3342 => 1.0 m2674 + 1.0 m3274 + 1.0 m3588
# HMR_0154 : 1.0 m2674 + 1.0 m3566 = 1.0 m2086 + 1.0 m3562
# HMR_0189 : 1.0 m2674 + 1.0 m3032 = 1.0 m2086 + 1.0 m3029
# HMR_0193 : 1.0 m2674 + 1.0 m3942 = 1.0 m2086 + 1.0 m3945
# HMR_0197 : 1.0 m2674 + 1.0 m3219 = 1.0 m2086 + 1.0 m3215
# HMR_0201 : 1.0 m263 + 1.0 m2674 = 1.0 m260 + 1.0 m2086
# HMR_0206 : 1.0 m229 + 1.0 m2674 = 1.0 m226 + 1.0 m2086
# HMR_0210 : 1.0 m1431 + 1.0 m2674 = 1.0 m2086 + 1.0 m3519
# HMR_0214 : 1.0 m2674 + 1.0 m3466 = 1.0 m2086 + 1.0 m3469
# HMR_0223 : 1.0 m2674 + 1.0 m3439 = 1.0 m2086 + 1.0 m3424
# HMR_0230 : 1.0 m2674 + 1.0 m3435 = 1.0 m2086 + 1.0 m3429
# HMR_0234 : 1.0 m1492 + 1.0 m2674 = 1.0 m1498 + 1.0 m2086
# HMR_0238 : 1.0 m2674 + 1.0 m2750 = 1.0 m2086 + 1.0 m3179
# HMR_0242 : 1.0 m7 + 1.0 m2674 = 1.0 m4 + 1.0 m2086
# HMR_0246 : 1.0 m1539 + 1.0 m2674 = 1.0 m1542 + 1.0 m2086
# HMR_0250 : 1.0 m2674 + 1.0 m3758 = 1.0 m2086 + 1.0 m3748
# HMR_0256 : 1.0 m50 + 1.0 m2674 = 1.0 m47 + 1.0 m2086
# HMR_0260 : 1.0 m2059 + 1.0 m2674 = 1.0 m2056 + 1.0 m2086
# HMR_0264 : 1.0 m2674 + 1.0 m3388 = 1.0 m2086 + 1.0 m3384
# HMR_0268 : 1.0 m257 + 1.0 m2674 = 1.0 m2086 + 1.0 m2361
# HMR_0272 : 1.0 m223 + 1.0 m2674 = 1.0 m221 + 1.0 m2086
# HMR_0276 : 1.0 m196 + 1.0 m2674 = 1.0 m190 + 1.0 m2086
# HMR_0280 : 1.0 m2674 + 1.0 m3324 = 1.0 m2086 + 1.0 m3327
# HMR_0284 : 1.0 m2345 + 1.0 m2674 = 1.0 m2086 + 1.0 m2339
# HMR_0290 : 1.0 m43 + 1.0 m2674 = 1.0 m40 + 1.0 m2086
# HMR_0294 : 1.0 m14 + 1.0 m2674 = 1.0 m2053 + 1.0 m2086
# HMR_0298 : 1.0 m1536 + 1.0 m2674 = 1.0 m1533 + 1.0 m2086
# HMR_0302 : 1.0 m245 + 1.0 m2674 = 1.0 m1510 + 1.0 m2086
# HMR_0306 : 1.0 m181 + 1.0 m2674 = 1.0 m2086 + 1.0 m3182
# HMR_0310 : 1.0 m2674 + 1.0 m2701 = 1.0 m2086 + 1.0 m2704
# ...
# rsub_1206 : 1.0 m2691 + 1.0 m3950 = 1.0 m2693 + 1.0 m3948
# rsub_1207 : 1.0 m2640 + 1.0 m2691 + 1.0 m3950 = 1.0 m2644 + 1.0 m2693 + 1.0 m3948
# rsub_1208 : 1.0 m2640 + 1.0 m2691 + 1.0 m3629 = 1.0 m2644 + 1.0 m2693 + 1.0 m3627
# rsub_1209 : 1.0 m2691 + 1.0 m3579 = 1.0 m2693 + 1.0 m3577
# rsub_1210 : 1.0 m2640 + 1.0 m2691 + 1.0 m3579 = 1.0 m2644 + 1.0 m2693 + 1.0 m3577
# rsub_1211 : 1.0 m1751 + 1.0 m2575 + 1.0 m2691 = 1.0 m1749 + 1.0 m2576 + 1.0 m2693
# rsub_1212 : 1.0 m1751 + 1.0 m2691 + 1.0 m3694 = 1.0 m1749 + 1.0 m2693 + 1.0 m3695
# rsub_1213 : 1.0 m1751 + 1.0 m2691 + 1.0 m3696 = 1.0 m1749 + 1.0 m2693 + 1.0 m3697
# rsub_1214 : 1.0 m2575 + 1.0 m2691 + 1.0 m3862 = 1.0 m2576 + 1.0 m2693 + 1.0 m3860
# rsub_1215 : 1.0 m2691 + 1.0 m3694 + 1.0 m3862 = 1.0 m2693 + 1.0 m3695 + 1.0 m3860
# rsub_1216 : 1.0 m2691 + 1.0 m3696 + 1.0 m3862 = 1.0 m2693 + 1.0 m3697 + 1.0 m3860
# rsub_1217 : 1.0 m2575 + 1.0 m2691 + 1.0 m3950 = 1.0 m2576 + 1.0 m2693 + 1.0 m3948
# rsub_1218 : 1.0 m2691 + 1.0 m3694 + 1.0 m3950 = 1.0 m2693 + 1.0 m3695 + 1.0 m3948
# rsub_1219 : 1.0 m2691 + 1.0 m3696 + 1.0 m3950 = 1.0 m2693 + 1.0 m3697 + 1.0 m3948
# rsub_1220 : 1.0 m2575 + 1.0 m2691 + 1.0 m3629 = 1.0 m2576 + 1.0 m2693 + 1.0 m3627
# rsub_1221 : 1.0 m2691 + 1.0 m3629 + 1.0 m3694 = 1.0 m2693 + 1.0 m3627 + 1.0 m3695
# rsub_1222 : 1.0 m2691 + 1.0 m3629 + 1.0 m3696 = 1.0 m2693 + 1.0 m3627 + 1.0 m3697
# rsub_1223 : 1.0 m2575 + 1.0 m2691 + 1.0 m3579 = 1.0 m2576 + 1.0 m2693 + 1.0 m3577
# rsub_1224 : 1.0 m2691 + 1.0 m3579 + 1.0 m3694 = 1.0 m2693 + 1.0 m3577 + 1.0 m3695
# rsub_1225 : 1.0 m2691 + 1.0 m3579 + 1.0 m3696 = 1.0 m2693 + 1.0 m3577 + 1.0 m3697
# rsub_1226 : 1.0 m2640 + 1.0 m2691 + 1.0 m3336 = 1.0 m2644 + 1.0 m2693 + 1.0 m3335
# rsub_1227 : 1.0 m2640 + 1.0 m2691 + 1.0 m3691 = 1.0 m2644 + 1.0 m2693 + 1.0 m3690
# rsub_1228 : 1.0 m1573 + 1.0 m2640 + 1.0 m2691 = 1.0 m1572 + 1.0 m2644 + 1.0 m2693
# rsub_1229 : 1.0 m2294 + 1.0 m2640 + 1.0 m2691 = 1.0 m2293 + 1.0 m2644 + 1.0 m2693
# rsub_1230 : 1.0 m3335 = 1.0 m3336
# rsub_1231 : 2.0 m3242 + 1.0 m3336 = 2.0 m3241 + 1.0 m3335
# rsub_1232 : 1.0 m3690 = 1.0 m3691
# rsub_1233 : 1.0 m1572 = 1.0 m1573
# rsub_1234 : 1.0 m3579 = 1.0 m3577
# rsub_1235 : 1.0 m2691 = 1.0 m2693
# rsub_1236 : 1.0 m3627 = 1.0 m3629
# rsub_1237 : 1.0 m2589 + 1.0 m2673 = 1.0 m2585 + 1.0 m2666
# rsub_1238 : 1.0 m1641 + 1.0 m2673 = 1.0 m1637 + 1.0 m2666
# rsub_1239 : 1.0 m2673 + 1.0 m3560 = 1.0 m2666 + 1.0 m3557
# rsub_1240 : 1.0 m2673 + 1.0 m3689 = 1.0 m2666 + 1.0 m3686
# rsub_1241 : 1.0 m3242 + 1.0 m3689 = 1.0 m3241 + 1.0 m3686
# rsub_1242 : 1.0 m2124 + 1.0 m3242 = 1.0 m2122 + 1.0 m3241
# rsub_1243 : 1.0 m2815 + 1.0 m3242 = 1.0 m2814 + 1.0 m3241
# rsub_1244 : 1.0 m2573 + 1.0 m2666 + 1.0 m3242 = 1.0 m2570 + 1.0 m2673 + 1.0 m3241
# rsub_1245 : 1.0 m2666 + 1.0 m3242 + 1.0 m3689 = 1.0 m2673 + 1.0 m3241 + 1.0 m3686
# rsub_1246 : 1.0 m1711 + 1.0 m2666 + 1.0 m3242 = 1.0 m1709 + 1.0 m2673 + 1.0 m3241
# rsub_1247 : 1.0 m2666 + 1.0 m2815 + 1.0 m3242 = 1.0 m2673 + 1.0 m2814 + 1.0 m3241
# rsub_1248 : 1.0 m2666 + 1.0 m2805 + 1.0 m3242 = 1.0 m2673 + 1.0 m2802 + 1.0 m3241
# rsub_1249 : 1.0 m1822 + 1.0 m2691 = 1.0 m1821 + 1.0 m2693
# rsub_1250 : 2.0 m1822 + 1.0 m3242 + 1.0 m3301 = 2.0 m1821 + 1.0 m3241 + 1.0 m3300
# rsub_1251 : 1.0 m1822 + 1.0 m3301 = 1.0 m1821 + 1.0 m3300
# rsub_1252 : 1.0 m1822 + 2.0 m3769 = 1.0 m1821 + 2.0 m3773
# rsub_1253 : 2.0 m1822 + 1.0 m3410 = 2.0 m1821 + 1.0 m3412
# rsub_1254 : 2.0 m1822 + 1.0 m2691 = 2.0 m1821 + 1.0 m2693
# rsub_1255 : 1.0 m1822 + 2.0 m2691 = 1.0 m1821 + 2.0 m2693
# rsub_1256 : 1.0 m2293 = 1.0 m2294
# rsub_1257 : 1.0 m2294 + 2.0 m3242 = 1.0 m2293 + 2.0 m3241
# rsub_1258 : 1.0 m2861 + 1.0 m3242 = 1.0 m2859 + 1.0 m3241
# rsub_1259 : 0.6666666666666666 m1604 + 0.6666666666666666 m3532 = 0.6666666666666666 m1716 + 0.6666666666666666 m2674
# rsub_1260 : 2.0 m1716 + 3.0 m2293 + 2.0 m2674 = 2.0 m1604 + 3.0 m2294 + 2.0 m3532
# rsub_1261 : 2.0 m1716 + 2.0 m2674 + 3.0 m3335 = 2.0 m1604 + 3.0 m3336 + 2.0 m3532
# rsub_1262 : 1.0 m2140 + 1.0 m2573 = 1.0 m2142 + 1.0 m2570
# rsub_1263 : 1.0 m2140 + 1.0 m2589 = 1.0 m2142 + 1.0 m2585
# rsub_1264 : 1.0 m2142 + 1.0 m2673 = 1.0 m2140 + 1.0 m2666
# rsub_1265 : 1.0 m1716 + 1.0 m2674 + 1.0 m2691 = 1.0 m1604 + 1.0 m2693 + 1.0 m3532
# rsub_1266 : 1.0 m2121 + 2.0 m2673 = 1.0 m2120 + 2.0 m2666
# rsub_1267 : 1.0 m1716 + 3.0 m1734 + 1.0 m2674 = 1.0 m1604 + 3.0 m1736 + 1.0 m3532
# rsub_1268 : 1.0 m1716 + 3.0 m2585 + 1.0 m2674 = 1.0 m1604 + 3.0 m2589 + 1.0 m3532
# rsub_1269 : 3.0 m1241 + 1.0 m1716 + 1.0 m2674 = 3.0 m1243 + 1.0 m1604 + 1.0 m3532
# rsub_1270 : 1.0 m2859 = 1.0 m2861
# rsub_1271 : 2.0 m2691 + 1.0 m3412 = 2.0 m2693 + 1.0 m3410
# rsub_1272 : 1.0 m856 + 1.0 m2673 = 1.0 m855 + 1.0 m2666
# rsub_1273 : 2.0 m2691 + 1.0 m3241 = 2.0 m2693 + 1.0 m3242
# rsub_1274 : 3.0 m2691 + 1.0 m3241 = 3.0 m2693 + 1.0 m3242
# rsub_1275 : 1.0 m1243 + 1.0 m2673 = 1.0 m1241 + 1.0 m2666
# rsub_1276 : 1.0 m1716 + 1.0 m1823 + 1.0 m2674 = 1.0 m1604 + 1.0 m1827 + 1.0 m3532
# rsub_1277 : 1.0 m1827 + 1.0 m2691 = 1.0 m1823 + 1.0 m2693
# rsub_1278 : 2.0 m1822 + 1.0 m2452 = 2.0 m1821 + 1.0 m2456
# rsub_1279 : 1.0 m3242 = 1.0 m3241
# rsub_1280 : 1.0 m2308 + 1.0 m2573 = 1.0 m2309 + 1.0 m2570
# rsub_1281 : 1.0 m2308 + 1.0 m2589 = 1.0 m2309 + 1.0 m2585
# rsub_1282 : 1.0 m3410 + 2.0 m3773 = 1.0 m3412 + 2.0 m3769
# rsub_1283 : 1.0 m2674 + 1.0 m4030 = 1.0 m2681 + 1.0 m4032
# rsub_1284 : 1.0 m2593 + 1.0 m2691 = 1.0 m2592 + 1.0 m2693
# rsub_1285 : 1.0 m1716 + 1.0 m2674 + 1.0 m2880 = 1.0 m1604 + 1.0 m2879 + 1.0 m3532
# rsub_1286 : 1.0 m2857 + 2.0 m3242 = 1.0 m2856 + 2.0 m3241
# rsub_1287 : 1.0 m2861 + 2.0 m3242 = 1.0 m2859 + 2.0 m3241
# rsub_1288 : 1.0 m3242 + 1.0 m3295 = 1.0 m3241 + 1.0 m3299
# rsub_1289 : 1.0 m1716 + 1.0 m2674 + 1.0 m3577 = 1.0 m1604 + 1.0 m3532 + 1.0 m3579
# rsub_1290 : 2.0 m3242 + 1.0 m3560 = 2.0 m3241 + 1.0 m3557
# rsub_1291 : 1.0 m2341 + 1.0 m3242 = 1.0 m2339 + 1.0 m3241
# rsub_1292 : 1.0 m1619 + 1.0 m3242 = 1.0 m1617 + 1.0 m3241
# rsub_1293 : 1.0 m3083 + 1.0 m3242 = 1.0 m3081 + 1.0 m3241
# rsub_1294 : 1.0 m3242 + 1.0 m3291 = 1.0 m3241 + 1.0 m3289
# rsub_1295 : 1.0 m2142 = 1.0 m2140
# rsub_1296 : 1.0 m2309 = 1.0 m2308
# rsub_1297 : 1.0 m4029 = 1.0 m4027
# rsub_1298 : 2.0 m2673 + 1.0 m3773 = 2.0 m2666 + 1.0 m3769
# rsub_1299 : 1.0 m1641 + 1.0 m1822 + 2.0 m3242 = 1.0 m1637 + 1.0 m1821 + 2.0 m3241
# rsub_1300 : 1.0 m1706 + 1.0 m1822 + 2.0 m3242 = 1.0 m1703 + 1.0 m1821 + 2.0 m3241
# rsub_1301 : 1.0 m1822 + 1.0 m2805 + 2.0 m3242 = 1.0 m1821 + 1.0 m2802 + 2.0 m3241
# rsub_1302 : 1.0 m1822 + 1.0 m2870 + 2.0 m3242 = 1.0 m1821 + 1.0 m2867 + 2.0 m3241
# rsub_1303 : 1.0 m1822 + 1.0 m3053 + 2.0 m3242 = 1.0 m1821 + 1.0 m3050 + 2.0 m3241
# rsub_1304 : 1.0 m1822 + 1.0 m3152 + 2.0 m3242 = 1.0 m1821 + 1.0 m3148 + 2.0 m3241
# rsub_1305 : 1.0 m1822 + 1.0 m3201 + 2.0 m3242 = 1.0 m1821 + 1.0 m3199 + 2.0 m3241
# rsub_1306 : 1.0 m1822 + 2.0 m3242 + 1.0 m4053 = 1.0 m1821 + 2.0 m3241 + 1.0 m4050
# rsub_1307 : 1.0 m1822 + 1.0 m2124 + 2.0 m3242 = 1.0 m1821 + 1.0 m2122 + 2.0 m3241
# rsub_1308 : 1.0 m1822 + 2.0 m3242 + 1.0 m3689 = 1.0 m1821 + 2.0 m3241 + 1.0 m3686
# rsub_1309 : 1.0 m1736 + 1.0 m1822 + 2.0 m3242 = 1.0 m1734 + 1.0 m1821 + 2.0 m3241
# rsub_1310 : 1.0 m3242 + 1.0 m3766 = 1.0 m3241 + 1.0 m3763
# rsub_1311 : 1.0 m1243 + 1.0 m1822 + 2.0 m3242 = 1.0 m1241 + 1.0 m1821 + 2.0 m3241
# rsub_1312 : 1.0 m2294 + 1.0 m3242 = 1.0 m2293 + 1.0 m3241
# rsub_1313 : 1.0 m3242 + 1.0 m3336 = 1.0 m3241 + 1.0 m3335
# rsub_1314 : 1.0 m1822 + 1.0 m2589 + 1.0 m3242 = 1.0 m1821 + 1.0 m2585 + 1.0 m3241
# rsub_1315 : 1.0 m1822 + 1.0 m3242 + 1.0 m3560 = 1.0 m1821 + 1.0 m3241 + 1.0 m3557
# rsub_1316 : 1.0 m2808 = 1.0 m2809
# rsub_1317 : 1.0 m1714 + 1.0 m2565 + 1.0 m2666 = 1.0 m1712 + 1.0 m2567 + 1.0 m2669
# rsub_1318 : 1.0 m1714 + 1.0 m2565 + 1.0 m2666 = 1.0 m1712 + 1.0 m2567 + 1.0 m2669
# rsub_1319 : 1.0 m2466 + 1.0 m3532 = 1.0 m2465 + 1.0 m3535
# rsub_1320 : 1.0 m2525 + 1.0 m2655 = 1.0 m2527 + 1.0 m2654
# rsub_1321 : 1.0 m1633 + 1.0 m3764 = 1.0 m1634 + 1.0 m3763
# rsub_1322 : 1.0 m1633 + 1.0 m3159 = 1.0 m1634 + 1.0 m3158
# rsub_1323 : 1.0 m2465 + 1.0 m3764 = 1.0 m2466 + 1.0 m3763
# rsub_1324 : 1.0 m2465 + 1.0 m3159 = 1.0 m2466 + 1.0 m3158
# rsub_1325 : 1.0 m3532 + 1.0 m3764 = 1.0 m3535 + 1.0 m3763
# rsub_1326 : 1.0 m3763 + 1.0 m3779 = 1.0 m3764 + 1.0 m3778
# rsub_1327 : 1.0 m3159 + 1.0 m3532 = 1.0 m3158 + 1.0 m3535
# rsub_1328 : 1.0 m3158 + 1.0 m3771 = 1.0 m3159 + 1.0 m3769
# rsub_1329 : 1.0 m3158 + 1.0 m3779 = 1.0 m3159 + 1.0 m3778
# rsub_1330 : 1.0 m3161 + 1.0 m3532 = 1.0 m3160 + 1.0 m3535
# rsub_1331 : 1.0 m3160 + 1.0 m3771 = 1.0 m3161 + 1.0 m3769
# rsub_1332 : 1.0 m3160 + 1.0 m3779 = 1.0 m3161 + 1.0 m3778
# rsub_1333 : 1.0 m3342 = 1.0 m3344
# rsub_1334 : 1.0 m2081 = 1.0 m2082
# rsub_1335 : 1.0 m2666 + 1.0 m3612 = 1.0 m2669 + 1.0 m3613
# rsub_1336 : 1.0 m2640 + 1.0 m3535 = 1.0 m2641 + 1.0 m3532
# rsub_1337 : 1.0 m1596 = 1.0 m1598
# rsub_1338 : 1.0 m1833 = 1.0 m1836
# rsub_1339 : 1.0 m2666 + 1.0 m3406 = 1.0 m2669 + 1.0 m3405
# rsub_1340 : 1.0 m2565 + 1.0 m2666 = 1.0 m2567 + 1.0 m2669
# rsub_1341 : 2.0 m2666 = 2.0 m2669
# rsub_1342 : 1.0 m2666 + 1.0 m3119 = 1.0 m2669 + 1.0 m3120
# rsub_1343 : 1.0 m1703 + 1.0 m2666 + 1.0 m3150 = 1.0 m1705 + 1.0 m2669 + 1.0 m3148
# rsub_1344 : 1.0 m1705 + 1.0 m2666 + 1.0 m3148 = 1.0 m1703 + 1.0 m2669 + 1.0 m3150
# rsub_1345 : 1.0 m2666 + 1.0 m3150 + 1.0 m3405 = 1.0 m2669 + 1.0 m3148 + 1.0 m3406
# rsub_1346 : 1.0 m2666 + 1.0 m3148 + 1.0 m3406 = 1.0 m2669 + 1.0 m3150 + 1.0 m3405
# rsub_1347 : 1.0 m2666 + 1.0 m2802 + 1.0 m3150 = 1.0 m2669 + 1.0 m2804 + 1.0 m3148
# rsub_1348 : 1.0 m2666 + 1.0 m2804 + 1.0 m3148 = 1.0 m2669 + 1.0 m2802 + 1.0 m3150
# rsub_1349 : 1.0 m2066 + 1.0 m2666 + 1.0 m3150 = 1.0 m2067 + 1.0 m2669 + 1.0 m3148
# rsub_1350 : 1.0 m2067 + 1.0 m2666 + 1.0 m3148 = 1.0 m2066 + 1.0 m2669 + 1.0 m3150
# rsub_1351 : 1.0 m1705 + 1.0 m2666 + 1.0 m3405 = 1.0 m1703 + 1.0 m2669 + 1.0 m3406
# rsub_1352 : 1.0 m1703 + 1.0 m2666 + 1.0 m3406 = 1.0 m1705 + 1.0 m2669 + 1.0 m3405
# rsub_1353 : 1.0 m1705 + 1.0 m2666 + 1.0 m2802 = 1.0 m1703 + 1.0 m2669 + 1.0 m2804
# rsub_1354 : 1.0 m1703 + 1.0 m2666 + 1.0 m2804 = 1.0 m1705 + 1.0 m2669 + 1.0 m2802
# rsub_1355 : 1.0 m1705 + 1.0 m2066 + 1.0 m2666 = 1.0 m1703 + 1.0 m2067 + 1.0 m2669
# rsub_1356 : 1.0 m1703 + 1.0 m2067 + 1.0 m2666 = 1.0 m1705 + 1.0 m2066 + 1.0 m2669
# rsub_1357 : 1.0 m2666 + 1.0 m2802 + 1.0 m3406 = 1.0 m2669 + 1.0 m2804 + 1.0 m3405
# rsub_1358 : 1.0 m2666 + 1.0 m2804 + 1.0 m3405 = 1.0 m2669 + 1.0 m2802 + 1.0 m3406
# rsub_1359 : 1.0 m2067 + 1.0 m2666 + 1.0 m2802 = 1.0 m2066 + 1.0 m2669 + 1.0 m2804
# rsub_1360 : 1.0 m2067 + 1.0 m2666 + 1.0 m3405 = 1.0 m2066 + 1.0 m2669 + 1.0 m3406
# rsub_1361 : 1.0 m2066 + 1.0 m2666 + 1.0 m3406 = 1.0 m2067 + 1.0 m2669 + 1.0 m3405
# rsub_1362 : 1.0 m2666 + 1.0 m3150 = 1.0 m2669 + 1.0 m3148
# rsub_1363 : 1.0 m1703 + 1.0 m2666 = 1.0 m1705 + 1.0 m2669
# rsub_1364 : 1.0 m1705 + 1.0 m2666 = 1.0 m1703 + 1.0 m2669
# rsub_1365 : 1.0 m2666 + 1.0 m2804 = 1.0 m2669 + 1.0 m2802
# rsub_1366 : 1.0 m2067 + 1.0 m2666 = 1.0 m2066 + 1.0 m2669
# rsub_1367 : 1.0 m1633 + 1.0 m3535 = 1.0 m1634 + 1.0 m3532
# rsub_1368 : 1.0 m3535 + 1.0 m3707 = 1.0 m3532 + 1.0 m3708
# rsub_1369 : 1.0 m1633 + 1.0 m2641 = 1.0 m1634 + 1.0 m2640
# rsub_1370 : 1.0 m2466 + 1.0 m3158 = 1.0 m2465 + 1.0 m3159
# rsub_1371 : 1.0 m3416 + 1.0 m3846 = 1.0 m3417 + 1.0 m3845
# rsub_1372 : 1.0 m2666 = 1.0 m2669
# rsub_1373 : 1.0 m2465 + 1.0 m3779 = 1.0 m2466 + 1.0 m3778
# rsub_1374 : 1.0 m2465 + 1.0 m3771 = 1.0 m2466 + 1.0 m3769
# rsub_1375 : 1.0 m1716 + 1.0 m2674 + 1.0 m3426 + 1.0 m3439 = 1.0 m1604 + 1.0 m3424 + 1.0 m3441 + 1.0 m3532
# rsub_1376 : 1.0 m1605 + 1.0 m1716 = 1.0 m1604 + 1.0 m1717
# rsub_1377 : 1.0 m1704 = 1.0 m1703
# rsub_1378 : 1.0 m1710 = 1.0 m1709
# rsub_1379 : 1.0 m1713 = 1.0 m1712
# rsub_1380 : 1.0 m2123 = 1.0 m2122
# rsub_1381 : 1.0 m2571 = 1.0 m2570
# rsub_1382 : 1.0 m2586 = 1.0 m2585
# rsub_1383 : 1.0 m2803 = 1.0 m2802
# rsub_1384 : 1.0 m3051 = 1.0 m3050
# rsub_1385 : 1.0 m3149 = 1.0 m3148
# rsub_1386 : 1.0 m3200 = 1.0 m3199
# rsub_1387 : 1.0 m3497 = 1.0 m3496
# rsub_1388 : 1.0 m3558 = 1.0 m3557
# rsub_1389 : 1.0 m3687 = 1.0 m3686
# rsub_1390 : 1.0 m3979 = 1.0 m3978
# rsub_1391 : 1.0 m3984 = 1.0 m3983
# rsub_1392 : 1.0 m4051 = 1.0 m4050
# rsub_1393 : 1.0 m1638 = 1.0 m1637
# rsub_1394 : 1.0 m2868 = 1.0 m2867
# rsub_1395 : 1.0 m3851 = 1.0 m3850
# rsub_1396 : 1.0 m2566 = 1.0 m2565
# rsub_1397 : 1.0 m1839 => 1.0 m1841
# rsub_1398 : 2.0 m3989 = 1.0 m4014 + 1.0 m4043
# rsub_1399 : 1.0 m1716 + 1.0 m2570 + 1.0 m2674 + 1.0 m4066 = 1.0 m1668 + 1.0 m2565 + 1.0 m2631 + 1.0 m3543
# rsub_1400 : 1.0 m1637 + 1.0 m3201 = 1.0 m1641 + 1.0 m3199
# rsub_1401 : 1.0 m1574 = 1.0 m1577
# rsub_1402 : 1.0 m2682 + 1.0 m2686 = 2.0 m2679 + 1.0 m3348
# rsub_1403 : 1.0 m233 + 1.0 m2666 + 1.0 m3279 + 1.0 m3342 = 1.0 m161 + 2.0 m2674 + 1.0 m3274
# rsub_1404 : 1.0 m2430 = 0.0001 m4 + 0.0001 m18 + 0.0001 m24 + 0.0001 m40 + 0.0001 m47 + 0.0001 m53 + 0.0001 m165 + 0.0001 m190 + 0.0001 m210 + 0.0001 m218 + 0.0001 m221 + 0.0001 m226 + 0.0001 m260 + 0.0001 m271 + 0.0001 m279 + 0.0001 m420 + 0.0001 m434 + 0.0001 m479 + 0.0001 m516 + 0.0001 m1498 + 0.0001 m1510 + 0.0001 m1533 + 0.0001 m1542 + 0.0001 m1617 + 0.0024 m1690 + 0.0001 m1723 + 0.0001 m1803 + 0.0001 m2047 + 0.0001 m2050 + 0.0001 m2053 + 0.0208 m2056 + 0.0005 m2219 + 0.0013 m2231 + 0.0017 m2301 + 0.0001 m2339 + 0.0001 m2361 + 0.0013 m2369 + 0.0048 m2498 + 0.0001 m2704 + 0.0001 m3029 + 0.0001 m3081 + 0.0741 m3086 + 0.0037 m3093 + 0.0001 m3179 + 0.0001 m3182 + 0.0096 m3215 + 0.0001 m3289 + 0.0001 m3327 + 0.122 m3384 + 0.0001 m3392 + 0.64 m3424 + 0.0286 m3429 + 0.0001 m3469 + 0.0001 m3519 + 0.082 m3748 + 0.0028 m3752 + 0.0001 m3930 + 0.0001 m3945 + 0.0001 m4069
# rsub_1405 : 1.0 m2432 = 0.0001 m4 + 0.0001 m18 + 0.0001 m24 + 0.0001 m40 + 0.0001 m47 + 0.0001 m53 + 0.0016 m165 + 0.0001 m190 + 0.0001 m210 + 0.0001 m218 + 0.0001 m221 + 0.0001 m226 + 0.0001 m260 + 0.0001 m271 + 0.0001 m279 + 0.0001 m420 + 0.0001 m434 + 0.0001 m479 + 0.0001 m516 + 0.0001 m1498 + 0.0001 m1510 + 0.0001 m1533 + 0.0001 m1542 + 0.0032 m1617 + 0.0521 m1690 + 0.0001 m1723 + 0.0001 m1803 + 0.0001 m2047 + 0.0001 m2050 + 0.0001 m2053 + 0.0217 m2056 + 0.0081 m2219 + 0.0023 m2231 + 0.0018 m2301 + 0.0001 m2339 + 0.0001 m2361 + 0.0003 m2369 + 0.003 m2498 + 0.0001 m2704 + 0.0001 m3029 + 0.0001 m3081 + 0.281 m3086 + 0.0119 m3093 + 0.0001 m3179 + 0.0001 m3182 + 0.0024 m3215 + 0.0001 m3289 + 0.0001 m3327 + 0.4226 m3384 + 0.0001 m3392 + 0.12 m3424 + 0.0229 m3429 + 0.0001 m3469 + 0.0001 m3519 + 0.0384 m3748 + 0.0025 m3752 + 0.0001 m3930 + 0.0001 m3945 + 0.0001 m4069
# rsub_1406 : 2.0 m2669 + 1.0 m3344 + 1.0 m3922 = 2.0 m2677 + 1.0 m3000
# rsub_1407 : 1.0 m2239 + 1.0 m2666 + 1.0 m3279 + 1.0 m3342 = 1.0 m1798 + 2.0 m2674 + 1.0 m3274
# rsub_1408 : ext_157 = ext_158
# rsub_1409 : ext_159 = ext_160
# rsub_1410 : ext_161 = ext_162
# rsub_1411 : ext_163 = ext_164
# rsub_1412 : 1.0 m2812 + 1.0 m3686 = 1.0 m882 + 1.0 m2122 + 1.0 m3295
# rsub_1413 : 1.0 m708 + 1.0 m2674 = 1.0 m2430 + 1.0 m2581
# rsub_1414 : 1.0 m1833 + 1.0 m3454 => 1.0 m871 + 1.0 m1839
#
# rsub_36
# /home/muller-prokob/Documents/github/RBA_cutsets/models_analysis/code/../../aspmcs/code/compression/mparser/meta_network.py:45: UserWarning: Found reactions with missing internal metabolite production or consumption
#   warnings.warn('Found reactions with missing internal metabolite production or consumption')
# 784 internal metabolites
# 164 external metabolites
# 1414 total reactions
# 124 exchange reactions
# 1282 reversible reactions
# 784 internal metabolites
# 164 external metabolites
# 1414 total reactions
# 124 exchange reactions
# 1282 reversible reactions
# 784 internal metabolites
# 164 external metabolites
# 1414 total reactions
# 124 exchange reactions
# 1282 reversible reactions
# /home/muller-prokob/Documents/github/RBA_cutsets/models_analysis/code/../../aspmcs/code/compression/mparser/meta_network.py:202: UserWarning: No external metabolite definition
#   self.structures_check()
# /home/muller-prokob/Documents/github/RBA_cutsets/models_analysis/code/../../aspmcs/code/compression/mparser/meta_network.py:43: UserWarning: Found reactions with missing overall metabolite production or consumption
#   warnings.warn('Found reactions with missing overall metabolite production or consumption')
# -- Dual network --
# 1414 internal metabolites
# 0 external metabolites
# 2199 total reactions
# 124 exchange reactions
# 2066 reversible reactions

# %%
# Reduced model loading
HCC = cobra.io.read_sbml_model("../../models_storage/HCC_reduced.xml")

# %%
upregulated_reactions, nerrors = get_gene_associated_reaction(upregulated_entrez_ids, HCC)

# %%
#Writing the positive constraint file :
upregulated_reactions_list = [reaction_id for reaction_id in upregulated_reactions.keys()]
write_constraint_file(upregulated_reactions_list, "../../HCC_compressed_2/new_reactionSubsets.txt", "../../HCC_compressed_2/new_posconstr/")
# Out:
# rsub_11 is gene-associated.
# rsub_35 is gene-associated.
# rsub_36 is gene-associated.
# rsub_52 is gene-associated.
# rsub_53 is gene-associated.
# rsub_62 is gene-associated.
# rsub_63 is gene-associated.
# rsub_64 is gene-associated.
# rsub_65 is gene-associated.
# rsub_66 is gene-associated.
# rsub_84 is gene-associated.
# rsub_108 is gene-associated.
# rsub_138 is gene-associated.
# rsub_138_rev is gene-associated.
# rsub_142 is gene-associated.
# rsub_142_rev is gene-associated.
# rsub_146 is gene-associated.
# rsub_146_rev is gene-associated.
# rsub_147 is gene-associated.
# rsub_147_rev is gene-associated.
# rsub_150 is gene-associated.
# rsub_150_rev is gene-associated.
# rsub_163 is gene-associated.
# rsub_163_rev is gene-associated.
# rsub_196 is gene-associated.
# rsub_198 is gene-associated.
# rsub_198_rev is gene-associated.
# rsub_210 is gene-associated.
# rsub_210_rev is gene-associated.
# rsub_212 is gene-associated.
# rsub_219 is gene-associated.
# rsub_219_rev is gene-associated.
# rsub_266 is gene-associated.
# rsub_266_rev is gene-associated.
# rsub_298 is gene-associated.
# rsub_298_rev is gene-associated.
# rsub_303 is gene-associated.
# rsub_303_rev is gene-associated.
# rsub_304 is gene-associated.
# rsub_308 is gene-associated.
# rsub_308_rev is gene-associated.
# rsub_310 is gene-associated.
# rsub_310_rev is gene-associated.
# rsub_311 is gene-associated.
# rsub_311_rev is gene-associated.
# rsub_338 is gene-associated.
# rsub_345 is gene-associated.
# rsub_345_rev is gene-associated.
# rsub_352 is gene-associated.
# rsub_352_rev is gene-associated.
# rsub_353 is gene-associated.
# rsub_436 is gene-associated.
# rsub_436_rev is gene-associated.
# rsub_460 is gene-associated.
# rsub_460_rev is gene-associated.
# rsub_461 is gene-associated.
# rsub_461_rev is gene-associated.
# rsub_463 is gene-associated.
# rsub_463_rev is gene-associated.
# rsub_603 is gene-associated.
# rsub_604 is gene-associated.
# rsub_605 is gene-associated.
# rsub_605_rev is gene-associated.
# rsub_632 is gene-associated.
# rsub_632_rev is gene-associated.
# rsub_700 is gene-associated.
# rsub_700_rev is gene-associated.
# rsub_701 is gene-associated.
# rsub_701_rev is gene-associated.
# rsub_702 is gene-associated.
# rsub_703 is gene-associated.
# rsub_703_rev is gene-associated.
# rsub_718 is gene-associated.
# rsub_739 is gene-associated.
# rsub_739_rev is gene-associated.
# rsub_764 is gene-associated.
# rsub_764_rev is gene-associated.
# rsub_774 is gene-associated.
# rsub_774_rev is gene-associated.
# rsub_775 is gene-associated.
# rsub_775_rev is gene-associated.
# rsub_789 is gene-associated.
# rsub_811 is gene-associated.
# rsub_811_rev is gene-associated.
# rsub_812 is gene-associated.
# rsub_812_rev is gene-associated.
# rsub_814 is gene-associated.
# rsub_814_rev is gene-associated.
# rsub_828 is gene-associated.
# rsub_828_rev is gene-associated.
# rsub_829 is gene-associated.
# rsub_829_rev is gene-associated.
# rsub_830 is gene-associated.
# rsub_830_rev is gene-associated.
# rsub_831 is gene-associated.
# rsub_831_rev is gene-associated.
# rsub_832 is gene-associated.
# rsub_832_rev is gene-associated.
# rsub_833 is gene-associated.
# rsub_833_rev is gene-associated.
# rsub_834 is gene-associated.
# rsub_834_rev is gene-associated.
# rsub_835 is gene-associated.
# rsub_835_rev is gene-associated.
# rsub_836 is gene-associated.
# rsub_836_rev is gene-associated.
# rsub_837 is gene-associated.
# rsub_837_rev is gene-associated.
# rsub_838 is gene-associated.
# rsub_838_rev is gene-associated.
# rsub_839 is gene-associated.
# rsub_839_rev is gene-associated.
# rsub_840 is gene-associated.
# rsub_840_rev is gene-associated.
# rsub_841 is gene-associated.
# rsub_841_rev is gene-associated.
# rsub_946 is gene-associated.
# rsub_946_rev is gene-associated.
# rsub_1005 is gene-associated.
# rsub_1005_rev is gene-associated.
# rsub_1026 is gene-associated.
# rsub_1026_rev is gene-associated.
# rsub_1031 is gene-associated.
# rsub_1031_rev is gene-associated.
# rsub_1032 is gene-associated.
# rsub_1033 is gene-associated.
# rsub_1033_rev is gene-associated.
# rsub_1073 is gene-associated.
# rsub_1073_rev is gene-associated.
# rsub_1252 is gene-associated.
# rsub_1252_rev is gene-associated.
# rsub_1253 is gene-associated.
# rsub_1253_rev is gene-associated.
# rsub_1264 is gene-associated.
# rsub_1264_rev is gene-associated.
# rsub_1265 is gene-associated.
# rsub_1265_rev is gene-associated.
# rsub_1275 is gene-associated.
# rsub_1275_rev is gene-associated.
# rsub_1278 is gene-associated.
# rsub_1278_rev is gene-associated.
# rsub_1282 is gene-associated.
# rsub_1282_rev is gene-associated.
# rsub_1289 is gene-associated.
# rsub_1289_rev is gene-associated.
# rsub_1337 is gene-associated.
# rsub_1337_rev is gene-associated.
# rsub_1377 is gene-associated.
# rsub_1377_rev is gene-associated.
# rsub_1378 is gene-associated.
# rsub_1378_rev is gene-associated.
# rsub_1379 is gene-associated.
# rsub_1379_rev is gene-associated.
# rsub_1380 is gene-associated.
# rsub_1380_rev is gene-associated.
# rsub_1381 is gene-associated.
# rsub_1381_rev is gene-associated.
# rsub_1382 is gene-associated.
# rsub_1382_rev is gene-associated.
# rsub_1383 is gene-associated.
# rsub_1383_rev is gene-associated.
# rsub_1384 is gene-associated.
# rsub_1384_rev is gene-associated.
# rsub_1385 is gene-associated.
# rsub_1385_rev is gene-associated.
# rsub_1386 is gene-associated.
# rsub_1386_rev is gene-associated.
# rsub_1387 is gene-associated.
# rsub_1387_rev is gene-associated.
# rsub_1388 is gene-associated.
# rsub_1388_rev is gene-associated.
# rsub_1389 is gene-associated.
# rsub_1389_rev is gene-associated.
# rsub_1390 is gene-associated.
# rsub_1390_rev is gene-associated.
# rsub_1391 is gene-associated.
# rsub_1391_rev is gene-associated.
# rsub_1392 is gene-associated.
# rsub_1392_rev is gene-associated.
# rsub_1393 is gene-associated.
# rsub_1393_rev is gene-associated.
# rsub_1394 is gene-associated.
# rsub_1394_rev is gene-associated.
# rsub_1395 is gene-associated.
# rsub_1395_rev is gene-associated.
# rsub_1396 is gene-associated.
# rsub_1396_rev is gene-associated.
# rsub_1399 is gene-associated.
# rsub_1399_rev is gene-associated.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 3
#       1 #Writing the positive constraint file :
#       2 upregulated_reactions_list = [reaction_id for reaction_id in upregulated_reactions.keys()]
# ----> 3 write_constraint_file(upregulated_reactions_list, "../../HCC_compressed_2/new_reactionSubsets.txt", "../../HCC_compressed_2/new/")
#
# Cell In[2], line 102, in write_constraint_file(reactions_list, reaction_subset_path, outfile_path)
#     100 constr_out_str += f'{prefix}("mcs_{compressed_reaction_id}"){suffix}'
#     101 constr_out_str += f'target("mcs_{compressed_reaction_id}").'
# --> 102 with open(outfile_path+reaction_number+"_posconstr.lp4", "w") as constr_out:
#     103     constr_out.write(constr_out_str)
#
# File ~/miniconda3/envs/cobra/lib/python3.10/site-packages/IPython/core/interactiveshell.py:286, in _modified_open(file, *args, **kwargs)
#     279 if file in {0, 1, 2}:
#     280     raise ValueError(
#     281         f"IPython won't let you open fd={file} by default "
#     282         "as it is likely to crash IPython. If you know what you are doing, "
#     283         "you can use builtins' open."
#     284     )
# --> 286 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../HCC_compressed_2/new/0_posconstr.lp4'

# %%
# Getting only additional posconstr that have not been used before :
import os
DIR = "../../HCC_compressed_2/new_posconstr/"
DIR2 = "../../HCC_compressed_2/posconstr/"
OUTDIR = "../../HCC_compressed_2/additional_posconstr/"
#additional constraints
addposconstr =  []
for filename in os.listdir(DIR) :
    with open(DIR+filename, "r") as file_contents :
        posconstr = file_contents.read()
        addposconstr.append(posconstr)

orposconstr = []
for filename in os.listdir(DIR2) :
    with open(DIR2+filename, "r") as file_contents:
        posconstr = file_contents.read()
        orposconstr.append(posconstr)

new_posconstr = []
i=0
for posconstr in addposconstr :
    if posconstr not in orposconstr :
        with open(f"{OUTDIR}{i}_posconstr.lp4", "w") as posconstr_out: 
            posconstr_out.write(posconstr)
            print(posconstr)
            i+=1
# Out:
# :- not support("mcs_rsub_836_rev").
# target("mcs_rsub_836_rev").
# :- not support("mcs_rsub_702").
# target("mcs_rsub_702").
# :- not support("mcs_rsub_298").
# target("mcs_rsub_298").
# :- not support("mcs_rsub_832_rev").
# target("mcs_rsub_832_rev").
# :- not support("mcs_rsub_65").
# target("mcs_rsub_65").
# :- not support("mcs_rsub_700_rev").
# target("mcs_rsub_700_rev").
# :- not support("mcs_rsub_303").
# target("mcs_rsub_303").
# :- not support("mcs_rsub_829").
# target("mcs_rsub_829").
# :- not support("mcs_rsub_814_rev").
# target("mcs_rsub_814_rev").
# :- not support("mcs_rsub_701").
# target("mcs_rsub_701").
# :- not support("mcs_rsub_62").
# target("mcs_rsub_62").
# :- not support("mcs_rsub_718").
# target("mcs_rsub_718").
# :- not support("mcs_rsub_142").
# target("mcs_rsub_142").
# :- not support("mcs_rsub_739_rev").
# target("mcs_rsub_739_rev").
# :- not support("mcs_rsub_814").
# target("mcs_rsub_814").
# :- not support("mcs_rsub_436").
# target("mcs_rsub_436").
# :- not support("mcs_rsub_53").
# target("mcs_rsub_53").
# :- not support("mcs_rsub_1265_rev").
# target("mcs_rsub_1265_rev").
# :- not support("mcs_rsub_838").
# target("mcs_rsub_838").
# :- not support("mcs_rsub_835").
# target("mcs_rsub_835").
# :- not support("mcs_rsub_345_rev").
# target("mcs_rsub_345_rev").
# :- not support("mcs_rsub_840_rev").
# target("mcs_rsub_840_rev").
# :- not support("mcs_rsub_834_rev").
# target("mcs_rsub_834_rev").
# :- not support("mcs_rsub_66").
# target("mcs_rsub_66").
# :- not support("mcs_rsub_308").
# target("mcs_rsub_308").
# :- not support("mcs_rsub_837_rev").
# target("mcs_rsub_837_rev").
# :- not support("mcs_rsub_700").
# target("mcs_rsub_700").
# :- not support("mcs_rsub_436_rev").
# target("mcs_rsub_436_rev").
# :- not support("mcs_rsub_11").
# target("mcs_rsub_11").
# :- not support("mcs_rsub_36").
# target("mcs_rsub_36").
# :- not support("mcs_rsub_604").
# target("mcs_rsub_604").
# :- not support("mcs_rsub_839_rev").
# target("mcs_rsub_839_rev").
# :- not support("mcs_rsub_150").
# target("mcs_rsub_150").
# :- not support("mcs_rsub_701_rev").
# target("mcs_rsub_701_rev").
# :- not support("mcs_rsub_831_rev").
# target("mcs_rsub_831_rev").
# :- not support("mcs_rsub_832").
# target("mcs_rsub_832").
# :- not support("mcs_rsub_789").
# target("mcs_rsub_789").
# :- not support("mcs_rsub_703").
# target("mcs_rsub_703").
# :- not support("mcs_rsub_831").
# target("mcs_rsub_831").
# :- not support("mcs_rsub_841_rev").
# target("mcs_rsub_841_rev").
# :- not support("mcs_rsub_1265").
# target("mcs_rsub_1265").
# :- not support("mcs_rsub_63").
# target("mcs_rsub_63").
# :- not support("mcs_rsub_304").
# target("mcs_rsub_304").
# :- not support("mcs_rsub_64").
# target("mcs_rsub_64").
# :- not support("mcs_rsub_833_rev").
# target("mcs_rsub_833_rev").
# :- not support("mcs_rsub_603").
# target("mcs_rsub_603").
# :- not support("mcs_rsub_308_rev").
# target("mcs_rsub_308_rev").
# :- not support("mcs_rsub_345").
# target("mcs_rsub_345").
# :- not support("mcs_rsub_829_rev").
# target("mcs_rsub_829_rev").
# :- not support("mcs_rsub_142_rev").
# target("mcs_rsub_142_rev").
# :- not support("mcs_rsub_774_rev").
# target("mcs_rsub_774_rev").
# :- not support("mcs_rsub_841").
# target("mcs_rsub_841").
# :- not support("mcs_rsub_703_rev").
# target("mcs_rsub_703_rev").
# :- not support("mcs_rsub_298_rev").
# target("mcs_rsub_298_rev").
# :- not support("mcs_rsub_739").
# target("mcs_rsub_739").
# :- not support("mcs_rsub_303_rev").
# target("mcs_rsub_303_rev").
# :- not support("mcs_rsub_840").
# target("mcs_rsub_840").
# :- not support("mcs_rsub_35").
# target("mcs_rsub_35").
# :- not support("mcs_rsub_353").
# target("mcs_rsub_353").
# :- not support("mcs_rsub_196").
# target("mcs_rsub_196").
# :- not support("mcs_rsub_108").
# target("mcs_rsub_108").
# :- not support("mcs_rsub_338").
# target("mcs_rsub_338").
# :- not support("mcs_rsub_774").
# target("mcs_rsub_774").
# :- not support("mcs_rsub_52").
# target("mcs_rsub_52").
# :- not support("mcs_rsub_837").
# target("mcs_rsub_837").
# :- not support("mcs_rsub_84").
# target("mcs_rsub_84").
# :- not support("mcs_rsub_834").
# target("mcs_rsub_834").
# :- not support("mcs_rsub_839").
# target("mcs_rsub_839").
# :- not support("mcs_rsub_828_rev").
# target("mcs_rsub_828_rev").
# :- not support("mcs_rsub_150_rev").
# target("mcs_rsub_150_rev").
# :- not support("mcs_rsub_838_rev").
# target("mcs_rsub_838_rev").
# :- not support("mcs_rsub_212").
# target("mcs_rsub_212").
# :- not support("mcs_rsub_830").
# target("mcs_rsub_830").
# :- not support("mcs_rsub_833").
# target("mcs_rsub_833").
# :- not support("mcs_rsub_836").
# target("mcs_rsub_836").
# :- not support("mcs_rsub_835_rev").
# target("mcs_rsub_835_rev").
# :- not support("mcs_rsub_830_rev").
# target("mcs_rsub_830_rev").
# :- not support("mcs_rsub_828").
# target("mcs_rsub_828").

# %%
#2661 compressed reactions
